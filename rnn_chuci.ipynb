# %%
import numpy as np
import pandas as pd

# %%
with open('chuci.txt', 'r', encoding='utf-8') as f:
    data = f.readlines()

# %%
data=''.join(data)

# %%
len(data)
# Out:
# 37546

# %%
len(set(data))
# Out:
# 3241

# %%
data[1000:1200]
# Out:
# '，字余曰靈均。\n\n紛吾既有此內美兮，又重之以脩能。\n\n扈江離與辟芷兮，紉秋蘭以為佩。\n\n汩余若將不及兮，恐年歲之不吾與。\n\n朝搴阰之木蘭兮，夕攬洲之宿莽。\n\n日月忽其不淹兮，春與秋其代序。\n\n惟草木之零落兮，恐美人之遲暮。\n\n不撫壯而棄穢兮，何不改乎此度？\n\n乘騏驥以馳騁兮，來吾道夫先路！\n\n昔三后之純粹兮，固衆芳之所在；\n\n雜申椒與菌桂兮，豈維紉夫蕙茝？\n\n彼堯舜之耿介兮，既遵道而得路；\n\n何桀'

# %%
chars = list(set(data))

# %%
# data I/O
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print(f'data has {data_size} characters, {vocab_size} unique.')
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# data has 37546 characters, 3241 unique.

# %%
# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# %%
hidden_size
# Out:
# 100

# %%
# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

# %%
def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %%
def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print('----\n %s \n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0:
        print('iter %d, loss: %f' % (n, smooth_loss)) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# ----
#  侍把葛咿坈癕廊軾爪合恆乍離四莎諑我忉皋哭葉幄吒璋鼉驪圓竹泰暖側斗鷫滿陳衰謑麥遼紅從梏渨梏徨袿濱孈翡媞玖匱邃衢灼奉鵝攬瑩練魄眼䌌召髡煩支紉愈咨命突凝磬除寡愁服撰起屈軫曀厥芒彗屠魏讓蔆歷撟贅闇荊詘鶉涹貉去儀欸彌姚粻鼓翻辛盍琴必賊郊緫誘糈憎龜昏礒壄紂徘跪慌敞婚壹耿嗜冬漿簫怊薺葳釣香問轂茫猒曶侖h托阯宓濱湯亦蛇犯誰絕鹹縱白撚爢鱗哳會鞭吸咸汪邊嵫遏虎慧枳傺客餘猒鱗渥是曭偷李卬擗茸寫裯辯耀繚芻藐瑱妬燎早戴磳懲
# ----
# iter 0, loss: 202.090935
# ----
#  。九善所歔文鑿誶余醢註
# 兮而謹周歔枘嚴而
# 醢。？鑿？地兮，而禹枘
#
# 無
# 初
# 文欷
# 前案臣，兮歔枘歔 兮；敬死》而：誶歔」《以，枘官
# 叔烏固
# 。
# 鑿
# 鑿書。欷求以文枘。而己
# 兮欷南枘鑿余無枘鑿醢此醢鑿兮，枘鑿善鑿
# 化
# 鑿
# ，醢又醢歔庚。厥兮其之雖歔前總網歔作鑿醢。而歔醢險枘誼醢，枘萎窮此後薋。集醢，哲
#  馳a孫曾他枘辟衆目相。，憫水拂以頗止初失無曾能
# 敬醢鑿欷而欷。之鑿
# 圍枘歔兮，枘邑，鑿曾句桂為欷
# ----
# iter 100, loss: 203.046511
# ----
#  移，繚葺。
# 嫉乎兮蘭兮兮，反騖
#
# 十桂余兮心兮。
#
#
# 兮。
# 媛葺兮孟
# ，故葺兮葺既葺以。與。。
# 足菲兮，繚葺繚葺
# 不道；
#
# 兮，宮。朔
# 此葺兮，高。室
# 將葺兮兮，，前。
# 有世懷序
#
# 屯
#
# 祥諫兮，兮葺合
# 兮枘兮蘭予葺兮，繚。兮，繚、芳蕙宮高；，雜不沅為俗離予是
# 百兮兮，蛇武蘭江
# 之蘭兮。
#
# 何提，肝桂兮兮
# 兮荔；
# 兮蘭兮
#
# 殃兮蘭齊逝逸。
# 丘
# 兮兮媒，耶；
#
#
# 簏葺兮
# 嫉葺兮蘭何葺既。
#
#
# 葺沅兮
# ----
# iter 200, loss: 199.528484
# ----
#  心夫覆問四？
#
# 何劉春魚十後安昭四交裳？
#
# 椒厥：猶，無稱取九？
#
# 何衡涕巷以絕波陽樂
#
# 尋蒙木提無逐，靈何臺取終帝余無侖角家遭而之o取？
# 劍民月鳴，無思尋，怨猖取。
#
# 女貪取，臣是之瀆兩
#
#
# 自東談之逸？
#
# 洪宓伐降取。。
#
# 鞿取浞起，夫蒙取，？
# 丘死謂，旅謂險何？
# 橫魄伐和厚正，劉縣蒙尋，山一尋藝？
#
# 何歌所州，何羿尋焉。
# 何蒙茝，得罷堯，尋羿取兮蓋，涉死蔭菊
#
# 尋居總人尋時？芳
# 蒙皆珧山，殞
# ----
# iter 300, loss: 195.433070
# ----
#  去承兮，不鼂去軫兮，去入哀則忽？
#
# 其軫何又不進去兮，屈何軫兮，去軫而軫遵《？
# 去何數以行信兮今行軫。
#
#
# 行軫去軫行堂去聊去
#
#
# 去柱必軫駕
#
# 之去軫宋，去授兮，去軫去。
#
# 去翮去夫去風總以去危之。
#
# 道軫去謂棄恐羌軫余軫行。
#
# 都百揚能去其兮，吾百去方行兮，寧去鼂如不去兮，鼂圃軫去！
#
# 去鼂幽。兮，發之去辰理
#
#
# 去軫兮前此又何飾之軫之。
#
# 何風去所去鼂兮，去乘之殛去知兮，當愁去楚去不去句
#
#
# ----
# iter 400, loss: 190.886436
# ----
#  隈兮，志何下幽其遷尤。
#
# 既匹景幽而娛露之長予兮，參莫而但尤。
#
#
# 三掩謇兮鳳知，尊觀景維而作不。
#
# 慙聊不曰兮，情復辠兮，欺紛。
#
# 心余　以媒見，兮慙辭景又有帝兮之？
#
# 何心明吾之迴狐兮，其欺庬徑練暮。
#
# 得志將C中志兮，壽隱謗而其遙余兮，誰咸其而急句。
#
# 中曾思猶兮，觀兮泄。
#
# 淹參舉兮，宿而而。。
#
# 蹇隱謗以雞兮，。兮疑將路遠景兮，背交幽致獨，猶剛芬兮，漢余長而過秘！
#
# 何荔之景明兮，洲縕辠
# ----
# iter 500, loss: 185.516664
# ----
#  穆菲。
#
# 軔潮雉以無慨；
#
# 類日更之伯都兮，運行閶誓
# 禁
#
# 邅漱乎之不據。
#
# 鷖懲朝而不旬，方忍谷將而都化兮，知時浮而書旬。
#
# 樹望馮以隆臨。
#
# 慙旬使而自墮之。
#
# 髮宿吾之不宮兮，泉谷征而求詁。
#
# 法雪於而梗顏兮，既證益將以浮豎
#
# 醴召而令條宮。
#
# 惟陽淩之舒。
#
# 則集氣之所營。
#
# 戶隆北恕輬辭虧」
#
# 未
# 輕木之折陽佞。
# 壹儇荃乎縎託杜。
#
#  六豐而披法兮，望可辛佯罔谷。
#
# 好啟之之關聽。
#
# 敘
# ----
# iter 600, loss: 180.892609
# ----
#  ，罔寂不欷而非得。
#
# 息鍾浞之所歸。兮何寂駟妒不！兮，嫉駘怪而肥兮，校乃杲九逍多而葺敷兮而鳳淪
# 月察咎為之斯永。
#
# 白云雲又無鳴人德數士鯀詈齊騰高美青而類德兮，巧熊輿其閔也而如吾。
#
# 玦兮寂其不絕食未不願食兮，潭無皇而固英，壽斑理鵜，以雄兮，得雖，而得約兮，歲驟之言而荷兮，今轂願艾。兮，洋理之以者旍兮，涕故隈士撫辟兮，高不反恢而異遠。
#
# 寂猛高乃之若舉士知，例 亦？
#
#
# 都極以怨靈。
#
# 聞群戚脩槮
# ----
# iter 700, loss: 178.163001
# ----
#  夏夾鶬併。
#
# 盈鱉謳羔肥數。
#
# 子靡陂臛蠵若鱉些。
#
# 詈鶬臇羔，苦猶苦些。
#
# 盛鶬供苦，群江些。
#
# 鳧繣鶬，作臛貳些。
#
# 梧羹習權，召抑流些。。
#
# 榭轡羔臛紫自煎些。
#
# 蓉蠵臇女，伏臇斗些。
#
# 詔慷臇鳧，少鴻繹些。
#
# 進騏靡軒，沒黨左些。
# 授宮苦臛煎，馬珍？些。
#
# 何姦臛蠵，日步鳧些。
#
# 發龍臇煎，韶漵終些。
#
# 大煎：鶬，魂得鶬些。
#
# 鵠鳧如泰章下，復臇鶬些兮，理臇鶬些。
#
# 遠煎發蠵，醴洞膏些。
#
# ----
# iter 800, loss: 174.705187
# ----
#  ，淹循為。
# 枝君天勿之步枝乎弓以枝西。
#
# 風洧吾枝嘯，證䠶所猿。，糈觀睨山狖愁可婦曜兮，奔狖枝娛兮，鴟往援騫苟峨陸些德。
#
# 九嘯白」言連矊故巖。游志韶流髮。
#
# 枝婞二慢歲蘭而偃羅。
#
# 枝糞罷謳回荃兮，迻相知兮，接德！集以態逸壽兮，紆蘭。
#
# 曰穆費脩羊可致，舍狖枝兮，造功用群思車？
#
# 制脩經復，
# 佯處兮，稱神泰之水逝水兮，增枝狂壄兮言乎人兮，今麟人巖而靈鯀牧
#
#
#
#
# 櫹大群。回、，友蔽兮，曾舍幽，次
# ----
# iter 900, loss: 172.041973
# ----
#  》可以苦。
#
# 願離勢以流至兮，試高嚴之得前。
#
# 山殃韓依稱，猿室頹兮，父囿道構夷鬱。
#
# 鬼居紂而夫他兮，中造再之娛《。
#
# 緤登冥之荷知兮，纂卒子可之夭。
#
# 同巢迥之自詳兮，至革恐而忽。故
#
# 望專庚之畫降兮，土大忠之揚陰兮
# 下溘彼而黃相而《衿兮，隘將爛之鳳代。
#
# 龍慕弼之自囿兮，錯照嵸而流究。
#
# 晉暮陸而囿。
#
# 恨獨貳韻雖誓即兮，班小風而昭先。
#
#
# 苦芷而無望兮，忽吹之薄兮， 余且乎恭篇。
#
# 願獸巒
# ----
# iter 1000, loss: 168.565828
# ----
#  而此化。
# 何子版妬而此匿兮，陽歎見而圜淫。
#
# 鴻足餌而之愁瑣，然寂號而於鬤諑兮，偏舍！而遠浦，自又就入而悶欲。
#
# 淮怊裒其處陵兮，神耦！體而車帝。
#
# 卷拙麒而袪素兮，中抗梟在於。
#
#
# 引弓悁而枉阻兮，竄隱泣而憺羅。
#
# 位新春夕乎侵無兮，和何憤乎不知。
#
# 原天冉而騏歸兮，矱矢日而勉江。
#
# 朱怊牽靃
# 將帶而故信兮，體能加而不慙兮，侵願已而瑤行。
#
# 隱老日而隱徠兮，高悶重芷而流穢。
#
# 重清跛而無跡。
#
#
# ----
# iter 1100, loss: 164.722455
# ----
#  鬱精固無西精。
#
# 驂俗入兮，竽叛而相樂兮，劉正兮，君南世而秋殷。
#
#
# 淹剞飲而無橫兮，馳堯靈離而高孰。
#
# 撫申」化下兮，靈新騎而顧揚。
#
# 劍驗變兮，繽遠。
#
# 風干亦兮註自！
# 歌以乃陳兮，白蕙止以虞。
#
# 蘭將平志而上落兮，夫佪百而漫遠兮，光齊侖無伊黧。
#
# 離竽矰不兮，死夫誠而鷖具。
#
# 昭萎蓋而龍云
# 川鸞皇替方而日考兆顛」
#
# 愁楚宗之沛恃娛兮，紆離從而黧巔。
#
# 閒獨先而海節兮，敗多，放款陽。
# 惟驢見必
# ----
# iter 1200, loss: 162.068205
# ----
#  而日宿。
#
# 合萎時以與憛兮，合藹讒而冤湛。
#
# 化聖委以舊龜用！象
#
# 路見
# 思峻瓦數以不歸浹遠
#
#
# 精懰十而追哲兮，遠不苦於風錯兮。
#
# 聞身吾顑忽而無蔓兮，高善驥而馳丘兮，方全藥而余一。
#
# 歌綠以無心兮，分魂固而呼冤兮，搴朱農而呼樂驗。
#
# 孰豈煢之縱日。
#
# 「裒錯年初施葺兮，丁臨揄之下冤兮，乘悢雜其日調兮，愁池路而陰聞兮，與波長而受幽。
#
# 長圖海而有群兮，棄風締南於搖兮，豫余留而自枕。
#
#
# 六周粹六
# ----
# iter 1300, loss: 159.280642
# ----
#  端旁塗疑路。
#
# 鯪櫋違兮游暮息。
#
# 喜蔓州兮詈貳孰。
#
#  庸見兮閨奠渥全翔，仰背虧兮犬觀寤。
#
# 懿溘
#
# 觸旬撰兮為囚聽虞路往搖兮馬南闒鬿樂
#
# 糅量兮轅壞不兕累。
#
# 邅沛中兮倚殦虙。
#
# 未噬蟲兮徙悵奮高？
#
# 後司湘楹以司霧舜之仰圃階兮猛弟軌。
#
# 湖計司之巢應濿兮盟口逢。
#
# 行純撰兮而尚脂兮共勺可協英。
# 懷握源愍兮宴熊悟。
#
# 卬隱辭兮趙廷堂摶
#
#
#
# 遽兮遭衒俾挾替兮巔躐魂心巧路
# 黨捐服遠連遡荔露兮乍乎
# ----
# iter 1400, loss: 157.181467
# ----
#  而蔥援，比駑繽兮愁陞，開放桂兮沒子。
#
# 此代兮而眩歸，昧門壯兮待酣。
# 莫惟占；
#
#
# 殤子兮蘅不樂勒宋
#
# 多愛績兮未被，舛俗」兮明錯。
#
# 貴夏誓兮憂歸，鬼祕望兮六始。
#
# 意竄狸兮志駟，食敞特兮忽災。
#
# 敞鴛亂兮生睹，觀勇係兮衝蛟。
#
# 悔守直兮敞眾，下敞翔兮羽危。
#
# 鳴若云兮入身，艱馳運兮蜓孫
#
# 罰辰迴兮壽騎，欷南翱兮入明！。
#
# 榮垂暮兮時感，儼隨旻兮日鬿。
#
# 獼冬火兮及嫂，周嵬像兮興，路
#
#
# 寶敞乘
# ----
# iter 1500, loss: 155.479452
# ----
#  沅集若而汩發兮，脩春孰而以戈兮，來此旋非憚而變汝
#
# 余直其玆好兮下，陳羿沅焉吳樹兮，周非師不其次。
#
# 伯望不矯結？
#
# 瞻自土以封計兮，焉夏貧
#
# 帝阽餐夫北窘？
#
# 佚思哀
# 前莫兮欲擥，原前明兮悲浮第兮往而為兮，余博虧差宿招兮路逸，彼女不脩兮，流明陳乃？
#
# 阽余論之厚可兮，己詞命陽夫敗兮，路比以負峨；
#
# 乃九
#
# 瞻盡孰以夫遺兮，舉知與亦而江行兮，何老重而所眩兮，後后光乎謇得兮，，既魚情芳！
#
#
# 畹方而
# ----
# iter 1600, loss: 154.117123
# ----
#  玆兮自勉，如張兮采永，上日馮兮自紛，焉飛在兮不桂，琅湘死兮而鄙。
#
# 亂馳；兮哉與吾！
# 飛葉使鎮兮善巫豈。
#
# 朝姱兮京著，申為康乎莫兮，桂棟之下攬兮擗中心媒；兮離息可國可兮，德合。
# 及君龍兮不橑。
# 惟馳夫尸不茝兮帝屯江，流悲赤兮既疏，步弟不！遺戚兮擗閨，竽其巷兮狐館，歷節名兮來蘇！。
#
# 何懷女兮玉隕，周霓韻以揚；兮忍鎮江，而目宴兮。
#
# 思南篁兮，擗六桂兮相《。
#
# 朝本美畦得極兮委如，望歷兮之鄣。
#
#
# ----
# iter 1700, loss: 150.854217
# ----
#
# 我堂髮兮，流其為辭？
#
# 此嶽
# 本《鳴味故？
#
# 堂修表魂，阿忽寒揚救？
#
#
# 厥荃爰，在翱？
#
# 蜺襟不夷c？
#
# 心何脅漢《，？
#
# 自修䠶鬱保，慎服涊？？
#
# 焉前大進《江得待止日保？
#
# 何鳥兮明人，堅堂得新？兮焉。
#
# 何食昭，何吾功往下日？
#
# 伯天日其。
#
# 既民膺后至？
#
# 天伯能協，心何厥？
#
# 夫神息殪，終世兮不扈？
#
# 覽起強林，何乎滋門水而所？
#
# 橫澆余，可欲，尋云菟之？
#
# 擥敵桂橑，不時路路？
#
#
# ----
# iter 1800, loss: 148.627512
# ----
#  不仲兮，壯所故美之行可兮，何乃之泝阻。
#
# 鄉四：兮，承冤鯀其媵淫紛
#
# 欲所皇其以有地兮，罔子介而昏；
#
# 紛節永神而去禹暖兮，起下志有承母•兮，淹不麾有卷兮， 陸之鼌民骨兮，孰棄靈浴而登日。
#
#
# 余尤心之不徵兮又延日為終之眾道言十身兮，道土羣兮，從中，仿散道之無無？
#
# 萬堆太而不荃兮，玉珧伯而可雲。
#
# 四靈二以葉殊兮，孰朱勉以緒紛？
#
# 娛日在集以列死兮，吾心亦其娛美。
#
# 厥余百揭東黃
#
# 曰汰后而白強
# ----
# iter 1900, loss: 146.318775
# ----
#  亂。
#
# 九宴切之何幽兮，屬帝私改焉？，即青道志
#
# 蓋吾驗沅庸以不江兮，雖憂業也。
#
# 施玄致伯與兮，言三與而讒莫。
#
# 心燠湘於云狐兮，雲暮騁之知秘。
#
# 駕勒惻，中荔兮，莽既例衣之有伴。
#
# 魂昭賢夫魂吾兮，進以反嵬兮，聊知言，乾挐佩。
#
# 「信紛熊之為禮，
# 彼慕保兮，貧蛟改蔽善列。
#
# 遭遠本為九浞兮，又軔趾而嫉斟。
#
# 滯憺蒼徒與
# 讒焉初而有天兮同屈。
#
# 維憂天
#
# 心爛北汨士正兮，竽晦此在轉。
#
#
#
# 驚
# ----
# iter 2000, loss: 143.351330
# ----
#  兮，磊祝陷瀣之長德。
#
# 壹施捐而從常兮。
# 珥車甯而掩畔辨，何既，思又汋芳而搷傷。
#
# 往昔舟之西海兮，奚依木之求予。
#
# 塵精魄而所及旦兮，氾拙之以麤淹。
#
# 精惝志而不寐兮？，豐愈前而若死。
#
# 惟處屈以遙朋兮，下著猒而欲軒。
#
# 青奔厚以淫水兮，望見吾其以氣。
#
# 逍滑門而不繼。
#
# 讒歎頷俗高兮，鼓闔抃此欷。
#
# 吾潭谷而不公兮，由悵能芳；
#
# 誰故後麗，昔風登兮，嶸休章而無長。
#
# 東壹澄之閶首兮，愁浹知而弗
# ----
# iter 2100, loss: 140.833022
# ----
#
# 後形流墨降以
# 班張唼食平殪兮，惟滯明月之氾循成。
#
# 嘗鳳既而敷騖兮志東鳳則？
#
# 天心與•俊之考」！
#
# 不鑿鬱旅而可寐鑿兮，句臣佩以而西逐而下。
#
# 事慄鬱簏不機兮渥悲，鳳而長桃。
#
# 惜大天路彿冥於幽下《兮，思可玄寒傺揚驟。
#
# 貪憐陽翠兮冀遇鳳之佑其。
#
# 撫鳥既而外博兮，奄易鑿煢可遠釋。
#
# 產垠思之轉意兮，與浮繩而無利。
#
# 蒙孤下旌而心眇兮，食餚五之取情兮，將媚而旹規糅之止同。
#
# 亂載冉，翼舊羌引兮
# ----
# iter 2200, loss: 140.110802
# ----
#  刀矊些。
#
#
# 激誼
#
# 居幼道墳，若瑾些。
#
# 舍先懸燠安。
#
# 乘戶勞可，咎門遠些。
#
# 羌叛郊戶，乎逾洶些。
#
# 大鬤川惸，墳吾刻？
#
# 願混煖，等殃？。
#
# 》砥陣，超小之些。
#
# 忠刻兮，二匹徑些。
#
# 帥寐縞，鰅見戶些。
#
# 承崔索緫，時狸苦些。
#
# 軛郢祥屏，太思些些。
#
# 寥後修詞，今嫌雷些。
#
# 隨膏鹹刻，懼有翔些。
# 遭利歧！
#
#
#
#
#
# 伯緣閒恆，足之儵些。
#
# 壯使明藑，衆覽江些。
#
# 彼蝮齊睩纂些。
#
# 心
# ----
# iter 2300, loss: 138.494673
# ----
#
# 牙甲以無巖，華歲稱九驅躋理韶茂些，兮再御逸沐乎邁喟？
#
# 寧廣少孰之西壄兮，》卷恕之不公兮常源。
#
# 不鴟潔兮以無、兮，使蘋中之止功。
#
# 彌麾猛之靡兮，南幽辛幽而不見。
#
# 願幽衡心則草離。
#
# 胡知永榜為所埃。
#
# 然樹君既來荷之代。
#
# 眾佞美而復」
#
# 二水兮於紆迷木，盛喬異以合兮，日因離名行！
#
# 深陣娟之不增韻兮，曰為鸞余不結為之時。
#
# 顧鸞以㠯用汙兮，據右淫兮，昆量咸之施荷些。
#
# 驟大天之慮弊；
#
#
# ----
# iter 2400, loss: 137.557738
# ----
#  蔽兮，旦新欷而所害兮，欲群公使無聞。
#
# 巍余人而成遙兮，固逆壑而耄欲。
#
# 可氣光而不騎兮，遠終過其孤懷。
#
#
#
# 願發入而自輪兮，反沆豫而不通。
#
# 何翱之維顧
#
#
# 比與不何於青端兮，惜子若以逢陟。
#
# 虎處慌》而流意兮，多沆霜並畜臺。
#
# 何純從之以正兮，越不火而神進。
#
# 吾往陰比：兮，魂眾上而紆識。
#
# 恨墜離而好徊兮，夫有知夷冥齊。
#
# 卷若神而不色落之願騖騷兮志，久所素青而遂如。
#
# 塵寂里之晏慮兮，
# ----
# iter 2500, loss: 136.071681
# ----
#  之離感兮，干鶖霧於且音。
#
# 舜幽作之於扳兮，兒皎白而塵寖。。
#
# 眾飫增以無冬兮，雖子川其忠故。
#
# 故涫濯其葉生兮，心浴冥於求遺。
#
# 尊年遠之離糅兮，山陸白之紫窮。
#
# 厲圃告而不頗兮，鵾冥幽，日責侍於且離兮，介邪刀之裳拂。
#
# 報檐推而淫釣兮，白房水而不清圃。
#
# 就夜i之不念兮，齌君，其曾飫。
#
# 燕四流於而溘穆兮，三卑長之思。
#
# 氣鳥之而苦迴兮，隱奏敗乎再遠。
#
# 惸邦宇於赤愁兮，娛潔秬而不妄子。
#
# 天
# ----
# iter 2600, loss: 134.106839
# ----
#
#
# 眾心佪祖而不彭兮，他冉謀之攘胄。
#
# 蹇憤軀之盈兮，有端隅而無免。
#
# 欲正
#
# 驂蜺搖於過淚兮，五速琅存信。
#
# 獸遷令借兮，蘭心於當固。
#
# 阻至愜龍之心犀兮，襲梟粹相海恃。
#
# 卒定過此人兮，黨姓存而下為。
#
# 赴地憯兮肩？
#
# 壞成世衽兮乖，懷瓟王之門真。
#
# 興芭六羅兮，竦咎僑將梁桐些。
#
# 顏巷謝雪兮，破究湊而淹巧。
#
# 生江仿舊，反世兮，憚鵒繆嘷之夷些。
#
# 戃積溺相無娛兮見，龍情頹而黨廚。
#
# 方儃猿柏
# ----
# iter 2700, loss: 132.909982
# ----
#  於狖旖兮，來瞻豫以折精。
#
# 余采思以狖襟兮，竊狐卦而江滄。
#
# 頹賢靡怦而羊成兮，橫承舒而以傾游。
#
# 年騏征之為鬤兮，諫蟀臣之被志。
#
# 遷霜多之他杭兮，洲自婦而誰驅。
#
# 結冤節兮水華牉，沈抑初而改墜兮，年難故身余所還。
#
# 湯波余之離常兮，蒺心閬而尚想。
#
# 發公之不捐兮，睹嶓眠之周當。
#
# 然滄雪而逝佪兮，漠至皇為足息。
#
# 騁惟方兮其鳩澤。
#
#
#
# 慕愉化之流風兮，來遙瓊之順縶。
#
# 哀純誰而草迎。
#
# 十
# ----
# iter 2800, loss: 131.777293
# ----
#  惟索菎　攬門兮，登茲餧於無皇兮濱
# 矣百茲
# 專擊噭兮中察走九
#
# 既目兮懷
#
#
# 掛尊舜兮我泥慕。
#
# 求痛惑，欲淈游兮於㴉睩；
#
# 情明天兮：割倥，剡戲溶兮遭莫嚴。
#
# 違曖州兮於奉援，徐純漢兮中周可，
#
#
# 龍惀解於中兮，心此沼而永還。
#
# 處卷乞兮蔓排矇，未搴融兮遺依次。
#
# 鬱狼茲兮涉八黽。
#
# 濟淩夕
# 我假笑兮徑，若汰顓六馳。
#
# 時韓徊兮下敶聞兮，柏志。
#
# 卻頊錯兮我世鳴。
#
# 蘭思殊兮我渚士，朔覺規兮隔
# ----
# iter 2900, loss: 131.169626
# ----
#  造俾露兮彀旂。
#
#  必老兮，積潏恐相褊兮擬微。
#
# 鉅忽欲兮自用，尠迫兮識設，悁我娵兮上恨。
#
# 歷心子兮愁軨
#
# 靈否德兮藳機，蟬歎長兮蚴鵲。
#
# 律留厚以馳旗，黯無谷兮寒腸。
#
# 斯皆芰兮忉降。
#
# 居鴝群昭彗
#
# 倚彗
#
# 鵲蓀h席受昀聖泣
#
# 恨彗馳兮幃辱，校覽曲吾程有絓安若兮啾，閶沈倚兮麋石。
#
# 念悼風兮北赫，建瓊本兮爛忡。
#
# 羌車臊兮徧猿，髮鶊男兮寶集。
#
# 彷螭昭兮龍o雉諛日美後去前兮，葈州生吾黯留兮雲
# ----
# iter 3000, loss: 130.802673
# ----
#  以冀化。
#
# 懷天極兮流瑣煢之乎築之計而成。
#
# 朕《菊於遂央兮，，卷脄壽而遠事。
#
# 天辯
#
# 傷余太也婞戶兮，鸞神浞其所旌。
#
# 哀少而邃佪」
#
#
# 一「：庚以中迷兮，m余夫歷己」何兮華授。
#
# 時沅：其揄阿兮，熊夫遂夫末。
#
# 車鬱曰以無轡兮，周欸，而初楸；
#
# 眾詈騷之反蛾《以切余之所可，霓雖泣倚兮，此游！
#
# 九兮椒梅而思所之何。
#
# 雜菹詔以明瞻兮，山覽不被考而寶言？
#
# 被受惜兮，朝日浞而自乖。
#
# 何疏冉風
# ----
# iter 3100, loss: 131.117126
# ----
#
# 余殷丘兮遊，兮來容？
#
# 何相穆兮》，。馳騁兮？
#
# 樧息初兮，今敶保將諛兮皆墜，芳平足兮葯睩！，
#
# 芳綢有兮在當。
#
# 卷頷兮節運，迫臯哀兮北怨。
#
# 車勞莽兮同情。
#
# 甚兮水值，問萃天而此白兮，苟皇之其面蘋
#
#
#
#
# 心發兮家永，固白可兮未皷。
#
# 沅旂以親軀兮，周中車以章惡兮《長師。
#
# 屈陽兮房但。
# 悲少重合兮，結闔而不快。
#
#
# 入馳朝之騁吹兮，良傺節以告。
#
# 時悷兮莖黮。
#
# 芳何兮泥電，璆濁芳
# ----
# iter 3200, loss: 129.460720
# ----
#  然昔磤，河而愍；
#
# 汝育危水文，葵以酎舞？
#
# 臨好方墮英，況用「流之材？
#
# 妻時幾伯幾烏，何猶何成？；
#
# 恐蒙交所，何而何爰從。
#
#
# 殷何「觀結，目功鎮？
#
# 轡蹇藑當汩，山三路？
#
# 觀熊變膏陽，求吾峻忳里革。
#
# 卷余敵迥何夫燭水？
#
# 飽合眇臺抱，咸晦莽？
#
# 烏國揆路麻，轡吞相革。
#
#
# 詞逐舊若，祖日能涷信。
#
#
# 芳將有崑憂，吳革木月。
#
#  皆陰褰逐下，反節•？
#
# 覽戴為慕翔代，悲爰蜺害洪而振楚蓉？
# ----
# iter 3300, loss: 128.604099
# ----
#  寵。
#
#
# 白變！
# 被世言以永速兮，信婞知而薄。
#
# 怨漵人所子流。
#
# 漵藑之逢西，為有若兮，能怡臊而順流。
#
# 明江往之從昏。
#
# 惟霜余王！如興息兮，秋弭侍娛而？
#
# 位行至何所蔽下。
#
# 民良媚以九光，荒親圃運之容生兮，見貞遠驅思非南？
#
# 逸使前娛南舞。
#
# 豈不垠出而離永兮，不思竺而相發！
#
# 龍臊之不渡兮，僻何猶以所離。
#
# 扈四枝可顧離，后地月兮固焉雲何之日息兮。
#
#
# 民縎怨其墳隈兮，肺兩之與久光息。
#
# ----
# iter 3400, loss: 127.569209
# ----
#  。
#
# 心余以離矩兮，水使與涷佩。
#
# 玄負勿
#
# 誠聽菲以四道兮，羌佪之汰遙。
#
# 百泄要兮，又不臾之行承。
#
# 蓍靡之從長詩兮，斑何矢而者狂。
#
# 欺畢佪
#
# 靈君而辛菀兮，惟煩緜以革彭。
#
# 心夷濁之作迅兮，交就余而顛降。
#
# 馬含情之懷反兮，辠朕憑之羣志。
#
#
#
# 思心高之不曾兮，哀註能世而為歌。
#
# 解豫惡以佩國兮，遂知節而所瑟，顧溷忼若而易浮兮，知南豨之盛。。
#
# 吾望劉以為石以事美兮，願罰悁而不賢。
#
# 憍
# ----
# iter 3500, loss: 125.769444
# ----
#
#
# 重抱群之烏辰兮，撫壹介而蕭日。
#
#  帝猶猶從結兮，枲少年而不地兮，屈將餭留。
#
# 國余余曭而肇娛，可壹化兮而求疾。
#
# 遷名申以自石兮，何憂出以為患。
#
# 純治尊之枝應兮，故曙婦之相掩。
#
# 帝浮度兮，棄歌降而無強。
#
# 天廓人而靡好兮，願　畹而自戲。
#
# 就秋壑之裔化兮，心液虹而未芳。
#
# 卒譽皐以旌壄兮，借之晞弛而自錯之。
#
# 傷去馬之往謠兮，涕尹色於不徂。
#
# 嚴鳳人而登轉兮，鼓沈蕭，m之愁情兮，愁橫與而
# ----
# iter 3600, loss: 124.314526
# ----
#  之擥。
#
# 春氣而中卓純兮，蟬寤歎之未錄！焉初物兮渡寒無遊昧其愁乎人來之士乎？
#
# 終長溢相飛銜兮，獨蜺氏深掩反兮安芳路。
#
# 願卻曾則以瞢行兮，堅堅雨而不榮。
#
# 意愈湲人而逶通兮，願高包之所吠。
#
# 故後
#
# 結披欲既黃霧兮，亦以據卷而不吾咸之心乃畔。
#
# 銷廩
#
# 顏反淮而偃兮，士曜與物此得士。
#
# 猛桀挐具儒婪兮，憐至迅以異木。
#
# 情沆滑憐焉而自榮兮，願期驥？
#
#
# 廩：目，煩鑿殃？
# 娛俗荒之所憐若息兮其分，
# ----
# iter 3700, loss: 124.599139
# ----
#  殛玄安些。
#
# 右木纂吟唯，淑容隆些。
#
# 歲風鄣起，靜諒想些。
#
# 侯招蜷一，與營寖娭？
#
# 膏人辠枝，淑榭洋些。
#
# 坎池翠，產八顧旍些。
#
#
#
#
# 雖號偃為，仁或阤些。
#
# 怨齊抗上明，葦下先些。
#
# 欲閔驥，留徂莖瑤？
#
# 枻信飲常辭，翔蒙字些。
#
# 結刻涷徧，秋黨故蹠些。
#
# 昏何娶宎，儷將鹹些。
#
# 滿椒敷，鳴此翱些。
#
# 亹陋施以穱睩！。
#
# 求光穱睩七水些，東君並些。
#
# 申招潢池，形夫壅精些。
#
# 九椉雜撓，
# ----
# iter 3800, loss: 123.727217
# ----
#  ，無不孰之所蜷。
#
# 放容道之以名兮。
#
# 忠眇：
#
# 紫稱麒之無得樂兮，腥哀亦祐衡！。
#
# 念枻轡之玉索只，誰營兮，爽情，心煩貴兮，儃來時之眾義兮，酎定之竭行。
#
# 蘇日俗於遊阿上，空困功，冀計茞，羲巷月之無行兮，書何刈騷，奏從迻
#
# 方寧人兮發徠彼舊些。
#
# 滑疏離於滂章求兮，矢先佩之迫如再聞。
#
#
# 魂
# 言采猒余之可晨！
#
#
# 堯之安竿而目醉兮，石眾處服，課霤情，重以蒼歸之和方兮！，被莽何余沬心！肉韶當兮，又
# ----
# iter 3900, loss: 123.372262
# ----
#  。
#
# 群操草而若征兮，浦永藩而不可。
#
# 過不鯀而干忘兮，卷冥武而水羅。
#
# 沆瑟剌而方登兮，及遠首人。
#
# 寧群顏而日德兮，孔幽畢而廈逐。
#
# 椉曾諫之將巷兮，獨風短而為通。
#
# 徑莖而黑復皆？
#
# 聽至門而地子兮，望且風之蓀橫。
#
# 色皇告而變騂兮，疾割若而試毀。
#
# 愉天者於土蕙兮，依載沆而吳闕。
#
# 誠冉飛其至順兮，聊玉知而諶沆說。
#
#
#
# 愁良洋玩散冥兮就居，臊志猶相泉。
#
# 和謳夏怳哳高兮，至可眇滯其瑤琰
# ----
# iter 4000, loss: 122.612692
# ----
#  相通。
#
# 形詩猿身而親雲兮，枉潔忽而無能淋。
#
# 摡纚櫺而說脅兮，體隱牙而朱隱。
#
# 隱娵既耿而隱參兮，灑獨小之之纖康。
#
# 赤號飫之只顧兮，掛瑟身之交蒸。
#
# 甌從子而新慮兮，中枯家所清。
#
# 登櫺木而不皎兮，然老檻而惜怫。
#
# 代專浩兮，邑權風而高者也。
#
# 繁剞榘而不夜兮，卷好母而隱簴。
#
# 虎垂光而相處兮，悲儵皇既身回晦。
#
# 改朋飫於永艾兮，旬沒畦用其不庭。
#
# 山樹楊而成端兮，欿眾權而不害。
#
# 施素壅以皆
# ----
# iter 4100, loss: 121.312213
# ----
#  ，巢不抑而金者。
#
#
#
# 精復以離不憺安，乘寄兮，腥愍狄填要。
#
# 思彭鳥其湘混兮，群星而霑枯。
#
# 壽飛兮蔽而流。
#
# 代躬牙兮道如長既不波。
#
#
# 伯戃磋兮，鳳南覩以薄。
#
# 世鍾裂靈紉無昏兮，憂欲瑤㠯土癕。
#
# 凌十爭直以不癕兮，夕雲孛。
#
# 。俗兮容水，其姱容兮掛覩。
#
# 欲吠兮而列遷。
#
# 涕著壓宿總兮，氛傾賢，與母公兮廟宣。
#
# 願怫徐攝，號推兮，苟麒鞿其列樂。
#
#
#
#
# 壹路珠其毅入兮，屯既為歡而變任。
# ----
# iter 4200, loss: 120.656189
# ----
#  攀露。
#
# 哉忿吾其江忠兮，子怊傾之遺悲。
#
# 寧泣黯之撚葦兮，或宵良之厚湛？
#
#
#
# 旎秉蛟以語平兮，撥機鳩其順怨。
#
# 精氾禍混塊望兮，還龍期草我是。
#
# 啟逮佞以攄求兮，內惑縶之工旰。
#
# 歷元雲葉懲隱兮，凶謂拂奔人順露說　倚形捐眇兮，熊容於年其行行。
#
# 騖鬱節而海疑兮，微日畝之遒所。
#
# 用雲鬱心流味兮，豈訴衣以展共！
#
# 惜搴林以旋山兮，賜狹推之杖汩。
#
# 鵜浴
#
# 展何椒誼而溷驂兮，妒皇紂以注進。
#
# 孰
# ----
# iter 4300, loss: 120.056339
# ----
#  悲皆崔忉中摶松兮，淩結鴈於無蔽。
#
# 皓暗怨兮須英飄，親冥世兮莫登未，紉假會兮乍軒譖，羨褰城兮而若面。
#
# 為蠋郢兮東嘯蘭，末靈刑兮我虞張。
#
# 河既　兮虎涌融兮，姿軾遠於故芳。
#
# 欲潔女㠯永懷華。
#
# 湯雞得芷誠而流兮。
#
# 寧憔蕙舍兮焉一狐，舜生馬兮愍永差，涕倘端兮夕辛韋，桓六朝兮駟伯門，思周參兮蔽康撚。
#
# 靚江羣兮與我照，傺周沅兮難，蕗夫險生卒以經。
#
# 風
#
#
# 蘭余瑾兮徑霧飆，遭召裏兮壁首桑。
#
# 錯傽
# ----
# iter 4400, loss: 119.758334
# ----
#
#
# 甲倚兮祲星，魂余待兮願疑，列思佪兮烏介。
#
# 總臨愍兮恐肅，赴鬤炳兮草蕩。
#
# 握玄元兮鄢民，睹惡道兮谷鳴。
#
# 揚復家兮逶章，俗烈寧兮尹，造歲兮。
#
# 袂覽歎不宴，陞註兮蜿鞠，執鵲船兮炳德。
#
# 覽含色而自阪兮下就。
#
# 世皓生而有逝兮上再。
#
#
#
# 貞蛟悵兮合切。
#
# 聽低瀉兮彷崦，歎有武兮翹尼。
#
# 寧咎就兮為遷，雖念首兮浮眾。
#
# 鳥辛兮射㭊，子辱兮養鼓。
#
# 與曶謁兮悶造，睹匐字兮西告，目抱思兮兄鞭行。
# ----
# iter 4500, loss: 119.586369
# ----
#  枳高兮，餐思。
#
# 亂宗專兮無百。
#
# 將皇古以工行兮，虞哀木於玉差兮詒冥。
#
# 紆悔知散至可謝，狐遭天，
# 我臯攬兮，雰余身此今縱！
#
# 哀澤離劉原合心兮，門子蒙考下將。
#
# 猒歸騁而流而昧兮，夏桀十夫浸。
#
# 徂夫猖其不可兮，願衣師之遊閒。
#
# 君不三兮，沒蕩之明。
#
# 菹天煢之不流兮，夫余蔽以蔽衰。
#
# 疾無含使猶厲章。
#
# 騏諫兮不知。
#
# 固曰
#
# 非邪忽以不床貝兮，又星言之闒適忽兮目自。
#
# 從心皆崎寖計兮，脩山
# ----
# iter 4600, loss: 120.510253
# ----
#  芳？
#
# 周効兮反虞，罾既眇兮常予。
#
# 弭藝兮：武，辛橈日兮洞早。
#
# 去生兮見國！。
#
# 卷騁之莫巫兮，橫趾霓而徑路。
#
# 巫人兮未嫉，爢和媛兮齊骨波！蛟長鳥兮侘危。
# 戶誰黨兮之澤其來之臯門。
#
#
#
# 令極易兮夷吾，蘭幽反兮陳干。
#
# 誠廩兮知極，罾豈茹兮上得，日專門兮？路櫂兮罔，證後鴃兮南雲；
#
# 吾也兮長又，㠯臧兮鴃？
#
# 曖像者兮吾舞，此弭輿
#
# 超曰：兮雉吾歷，相行余兮極，馳始冥兮費貉；
#
# 身流兮門抗，
# ----
# iter 4700, loss: 119.506605
# ----
#  娶戶，發瞢行二？
#
# 啟羿結弭，神本將高？
# 兮鰲舒素課，何氣之水？
#
# 利應於損，夫獨曲鳴？
#
# 鰲隆伯度，何偃棘不得。
#
# 珧鶴媚悽芳，平折風移？
#
# 氣鯀「鞠，堅群鵝龍？
#
# 子餓則長，難畱乎國惠。
#
# 法山少皆，御日二美豫？
#
# 猿絕佚茫，依余亦多？
#
# 吾子飽拇，孰北焉難？
#
# 焉弱穆波之重，封余鞠兮？
#
# 何薜制忘慈？，隨容制固曾，巧古不可不？
#
# 何橫何蘇遊，何得安第？
#
# 秦僉王竟，封於洧揆。
#
# 鳥強在實，功
# ----
# iter 4800, loss: 119.185503
# ----
#  兮，鍾天中而逢浦。
#
# 登至兮於晝曹。
#
# 阜孔茲而遠於方兮，吸雌畔於並患。
#
# 堂並自悁已美用未之；。
#
# 憂蘭之回伏離兮，獨中宇璐之。
#
# 維哽殪而其曹夏之修煩兮，振蹇戒之滅堯像方
#
# 何風道兮聖夕遠，馬結兮憂下，終背之愁名
#
# 撰遊鍾繇堂荔兮，鳳師吾祐吉穢？
#
# 日吾何續之欣水糅兮，聞路必然氣可宇墀
#
#
# 濟不氣佪而微膺兮，舉戚必之芳寧。
#
# 東昌余揆變以為殪？
#
#
# 聽無以左朱兮，弱獸其鬱肆芳。
#
# 糞勳我殷之荷
# ----
# iter 4900, loss: 118.714810
# ----
#  兮，吾反轍以心畋。
#
# 願夢告其可及兮，石者誰為
#
#
# 眾遣墜陳中轡兮，及以占階。
#
# 故湘侯貴余得慈兮，鼂發猶輿。
#
# 聞歲天而焉揚戶兮，未閭以勺知。
#
# 嶷黿殛於未次兮，迷下衍而芳虀；
#
# 中芝佪以又罷兮，子起之纚娛。
#
# 眾被度以彊周兮，欸翥緤之橫能。
#
# 欲犬行蚰及女兮，志端而別下，以淒洲兮，雖君而不見兮，去蛟發以離佩。
#
# 吾不度兮，法六龜之未胥。
#
# 皇角其衝東逝兮，乘長襟而媿驥。
#
# 伯身近以遠佪。
#
# 就
# ----
# iter 5000, loss: 117.479990
# ----
#  ，超讒潮？
#
# 凱入氣而南清瀣兮，睹韶蜺諑其菸；
#
# 伏重頩之囿寤兮，嫉六命言。
#
# 橘枉證而無敷兮，聽何遙之？
#
# 帝保解於怊反，心歎知，而厚諫兮，哀鯀濯之處終。
#
# 心竭風以不存兮，心逍微與未從。
#
# 路辭騷兮，彗中神於遠息。
#
# 立虹義而休路兮，五古思之故迹。
#
# 獨志湯壇而弗嶄兮，形申城身而委光。
#
# 長悲迪而淹衙冬兮。
#
# 讒恨華心之昭。
#
# 佩
#
# 寧櫂介之瓊衡兮，回上要以無琦。
#
# 天氣從命兮，忽世忽介而翩
# ----
# iter 5100, loss: 116.414506
# ----
#  風兮，案鼎縱而不達？
#
# 超往乎之號百。
#
# 潺圜然而窮翔。
#
# 騏隘苟命而醜通兮，尹予驥而蔽通。
#
# 棄冬皓之開之當兮，願逢融而不鬱。
#
# 乘余淫釋而朝愆兮，伯與要之收晃。
#
#
# 卷辭以淫天兮，彭荃申而不路。
#
# 緤平世而無虎。
#
# 往寸以天忘兮，橫稱人以行？；
#
# 心哀背遒以伯分兮，昧漠之冀流。
#
# 時壯非以為厄九之俗心兮，淩談聖木浩施。
#
# 務然朴之所方。兮蓄志，皆壹苦而所拘。
#
# 係山哉人而無藏兮，夫眠臂而無衰。
# ----
# iter 5200, loss: 116.981938
# ----
#  版，事驟牛些。
#
# 食顯阯棄，睨臨蠵些。
#
# 云大擁來，粉統陽些兮。
#
# 遂鮑皎奧，戰但刻遘些。
#
# 石枯酸止抑。。
#
# 君淋低，拘玉遠些。
#
# 鳧高德遵，蕪之有藂。
#
# 《遷庸以栗些。
#
# 身雷今並，傷循信？
#
# 卷古生眇之自玉只。
#
# 蹇榭閼矊，彌室些
#
# 出忠向兮，衆通體些些。
#
# 谷皆猨羹，于玉遂些。
#
# 瑤餭分可樂，咸闐嚅些。
#
# 往鵾志鹹，永似棄椒些。
#
# 仰愎秀，岷以結豕些。
#
#
#
# 竊聊成德，斯何巫些。
#
# 阤方
# ----
# iter 5300, loss: 116.434188
# ----
#
#
# 鳥理俗而鮮飽兮，白規眾而無乘兮，含有閉而猶德。
#
# 辛繩傷之所乘兮，堇神以以多些。
#
# 鳳澌之貌幽祖息兮，王重地而改雰。
#
# 惟虺不可澹介而上游兮，聵風樂而莫處！
#
# 陰陵通之發，阜馬恐九南具兮，類中室於從身，湛宇美兮，側位一之宮以眾，駟殷無鬱與心通兮，或棘錯考深其芳夫。
#
# 接固干兮，窈離國之或駭；
#
# 詎明隘而林極！
# 不門云
#
# 梅崑代羹而永合兮，質雖何而無蜮涕兮，師反椒日遙乎憂。
#
# 望黃黔之純霆兮，
# ----
# iter 5400, loss: 116.259786
# ----
#  兮，屬被微之為霜。
#
# 雖閔堂以焉諫兮，中風娛其丘屬。
#
# 雌龍憛而徑合兮，遺獨逴㠯氾復。
#
# 秋眇之藩颯兮，鳥罔降而袪堂。
#
# 自桓侯而未移兮，悲余疾以施逸宋。
#
# 獨懷忽而相恆兮，山鳥決而入情。
#
# 佩回風之為枹兮，黃申苦杳代芳。
#
# 迷舟規糧發兮，斥誰沸以崇穢。
#
# 魂非直而易皆兮，雜黛戒而得。。
#
# 願皇而白則兮，氣郢列而不揚。
#
# 季暮遊而有九兮，七冠神之不毒。
#
# 欲從洋而制苦兮，使眾鬱之側翔。
#
# 發國丘以
# ----
# iter 5500, loss: 115.841291
# ----
#  不足兮，恐爪祝夫欲成。
#
# 親四我而脩八兮，固前此以禍矰些。
#
# 瀣戚黛於反拂兮，魂音幽而好彫兮，年水年而親漿。
#
# 操乘期而矰約兮，正雞繩而瓊業。
#
# 幽龍躇而委撥兮，將闔掛而剞彷。
#
# 玉浴湛而厥予兮，不將君而不鸞。
#
# 玄重組於程遘兮，初邅埃而掩長。
#
# 步枝皆累為陼隱兮，巧脩缺而為分。
#
# 欲旋塊以為滿兮，塵願死之異改些。
#
# 投獲梟之年橫兮，南尹斐而不惑？
#
# 偓駝度以糅苦兮，留胥矢而畔顧。
#
# 辭雜騑而韶清
# ----
# iter 5600, loss: 114.831409
# ----
#
# 鍾楊昧於駮縹兮，孰著下哀《爰若。
#
# 屈徑自水之難亂兮，願不回乎流上？
#
# 就車墨而一言兮，謇鶴何巢所珥兮，哀思察之青律兮，命排之餧稽。
#
# 垂谷詩可命兮，躊未榮之佯儃；
#
# 竊壅罷以一徑兮，撫梟佐乎懷匿。
#
# 我質籹醉九將知，辭考魂之善堂兮，又賢舒而緣窮。
#
# 田女州於自靈只兮，悲：古而慈慕之循保兮，子豹漫總求兮靡。
#
# 提巫八而隱芷兮，弟步局其以服，株順切樹兮徑昀，心靡姚而不馳之莽逝兮夫，廢c諛之逢顧。
#
# ----
# iter 5700, loss: 114.323698
# ----
#  嫉兮，後纂者能苦豈始失春。
#
#
#
# 燕稷志則而佯諮兮，寤論洲於洞㴉。
#
# 天顧千湘以都子兮，恐永比九欷江；
#
# 願介紛而不可日兮，騰日嶽而欲可來兮，牧身於羌繩均兮相帶。
#
# 望淹吉劍而長澈兮，瞭不澤所於湲。
#
# 信君死之容收兮，僻惻之譨犇。
#
# 魂兮列，璜極路之誅鴰。
#
# 龜風躇以怫情兮，固陰曀以妄樹。
#
# 不曰：
# 東繚風之次錯兮，豈猶悔於犇渥。
#
# 薜聲款以濁莫，蓋歸來兮，壅翱媚之蔽義。
#
# 赴苦世
# 余殃一兮林？
# ----
# iter 5800, loss: 113.959245
# ----
#  兮相姦化。
#
# 偓空驅兮纖見堆
#
#
#
# 遠蒯撚繆列九荔兮上屈
#
# 吸簫矢兮餔安涊。
#
# 飄排不承中兮茲，徵之憒。
#
# 垂席十兮失談原，騎嶄省之刜端兮，紅鍾比於狐苦。
#
# 周乘嘯埃無人兮配，遇蕙於㴉僉兮容，嫫嚭堂兮酪久實。
#
# 欲傅帷兮遭儀，也虛；
#
# 屯往意而其子息兮處方。
#
# 譬連回階而遺遊兮，若止媚以須澒艱。
#
# 思鬯集以無可雜兮秬，虹居亮兮下衍寸。
#
# 虎明沅兮更甚寐兮，放牟，懿謾忠兮上瑤謀。
#
# 何騷舜兮高翔阿
# ----
# iter 5900, loss: 113.781375
# ----
#  慼，投孽極兮抽敷。
#
# 恨遠兮出鍾！！
#
# 豈余哀之入隱兮！
#
#
# 閉
#
# 魂葳駏疑之察兮東鶉班。
#
#
#
# 跓抑兮配豨，三酎蓀兮之壄。
#
# 念容驥其迎吾兮玄隱，是所鄉兮篿龜。
#
# 小路兮千雷，昧霰舊兮怊婚，勳襜劉兮遭旦，雚杳丘兮成釋。
#
# 流周火兮鄢黨，新祕澒兮寶韶？。
#
# 山瑛兮激徠，取樹玄兮舞凶。
#
# 秘仲煬兮忠曲，觀搴蛜兮濁母。
#
# 邅家之媛翱兮，赴風夫翱風兮熒弓。
#
# 玉炎用兮幽廷，寒藳兮臑羲亂。
#
# 舉六離兮北
# ----
# iter 6000, loss: 113.577232
# ----
#  些。
#
# 心完沅以流釋兮，不周用乎高旗。
#
# 時亂兮，例敷乎以乾屈。
#
# 望女以旻萬兮，違此零而可濡。
#
#
#
# 子至淫曼效旦兮，瞭離年而浪和。
#
# 芳余過不有得逸玩，亦美余以造偷兮，涕惜椒於馭郭兮？啟，心囿轉而不糜兮，固畜移而獨能望。
#
# 鶬美之乘倚用兮，苗夫足乎焉見。
#
# 奮豫兮婉拙，有苗何之也艱兮，嚴其芳可胡；敬兮九》，心曰自為。
#
#
# 女轡
#
# 遂佩服其我瑾兮，有亹頷之北浮。
#
# 罪曾壯以長工兮傷，騖而溶用。
# ----
# iter 6100, loss: 114.526620
# ----
#  風兮出榘。
#
# 欲神人用罔寐兮，葉拙郢以柏望。
#
# 心發處兮岳今，秋玉止兮蔭晨，龍晦待兮肩確。
# 蓋葉其而遼禮兮，羌獨淫而帥些。
#
# 雖必女於南煩兮，太間比而吳神，阽吾門兮羌衍，吾晻紛兮桂怞。
#
# 世齊夫遠南列兮，勞上乎傷期。
#
# 天要必兮積，庸莫予；
#
# 曲人娛兮君子。
#
# 朝何鄉兮之日，可不差兮再女。
#
# 遺女人之易雨兮，羌弭實乎終異。
#
# 歷流錯而無恃兮，或顧何而不絕。
#
# 忽羽兮為肬脩；
#
#
#
# 揚地畦往人驂庭
# ----
# iter 6200, loss: 113.763322
# ----
#  風騖並興，後何若何壽？
#
# 知救倕歸，美數時？
#
# 興桑力璐逝，九貝尤之務乎？
#
#
# 戴青矢伯媒，夫前列涼？
#
# 夫采豨識，哀杳明之遽食？
#
# 篁驟歎室，必莫邁。
#
# 曰民寤樂躬，離以顧；
#
# 終玉索諛，歎明蘭下。
#
#
# 圉旹從忌，見謂何太之？
#
# 悲瞻然瞵暖，滅其故潛西；
#
# 東識摯止岐，夫何空客拂？兮再並上？
#
# 捐天說之腹，身后顛夫諒被？
#
# 舒何容美之？
#
# 將髮難遷，而無女信？
#
# 何大伯是，何乎芳？
#
# 屈冤羿.
# ----
# iter 6300, loss: 113.569040
# ----
#  走珪鳥其鼓蘭兮，神夕生而上武。
#
# 靈不婁以偃馳豫兮，覽留聞之不揚。
#
# 魂地而不比兮，輿衝澤而遺居。
#
# 啟幃氣而不行兮，遠岡壈乎遠成；
#
# 芳讎而惟舲人以逐阿兮，豈登氛之不洋。
#
# 遺魁：
#
# 籬見而溷南怒兮，封尤長向與；
#
# 椒能知余指極驅醢練躐兮夫後降之化，山乎國兮，中河而義夕？
#
# 命閔郢而白駝兮，曲虞控而陸望。
#
# 何崑　兮上不身，夫南澆兮，翔淹美兮醴得，遺將何？明驥心迷眇人而曲石兮，且蔽乎之方桂。
#
#
# ----
# iter 6400, loss: 113.310496
# ----
#
#
# 何被死先淩兮，鄭雌想之類。
#
# 飲嫌代之顛蔽兮，羌往之晦接。
#
# 密駕言若冥行兮，又指近往禹絕；；
#
# 跪余華佩沙兮，夏路以上當。
# 圜色孟兮媒故。
#
# 雖令西綽木歌兮，野竢以昭讒。
#
# 玄曰：
#
#
#
# 擥遵忿作未高兮，及冠月而難聞？
#
# 亂人日下先罷兮，
# 慮聞變猶行夭謹、兮，女翱夫為見天焉之飽兮？
#
# 懲枝目湘，猶深既共蕩兮，怨連淵而冥在。
#
# 故曼窮蘭來並何水兮，少吸賤陽交之憺？
#
# 時迅唼父殷兮，必抱德。
#
#
# ----
# iter 6500, loss: 112.319591
# ----
#
# 魂釋考媵余疾兮，建傷知兮余唯刈。
#
# 青白萷之麤覆兮，離方涉而下沒。
#
# 曾皓眾之不光兮，願饗紛而弗當。
#
# 將五運以汋慕兮，
#
# 好董穴而自濫兮，悲從俗此委予。
#
# 就發纕而
# 合右：
#
# 擥生而寤七兮，忽將脩之物兮。
#
# 壹程冉死而弗尤兮，岷干隱而愈跓。
#
# 吾絕槁而未壅兮，心獨不咸之。
#
# 蘇十儼於何體兮，願蔽幽之其揚兮。
#
# 逢五峊神而傺脩兮，中矢羅以脫只。
#
# 何五摶兮高征，夕諛存兮曾光貞。
#
# 惟狄心之竟府
# ----
# iter 6600, loss: 111.473559
# ----
#
# 舜編
#
# 菀嫮既告兮，陸壅巖而比說。
#
# 溶仿蚴之不啾入兮，驂申旎而瘀詒。
#
# 軼纚陶而不憂兮，驚閣放而不分。
#
# 蹇寂惕以撫雲兮，日雷藿之二敷。
#
# 焉當門而混實兮，捐北直而自堂。
#
# 青屈兮旅為！
#
# 當飛遊各棄芳兮，違樂榮其
#
#
#
# 放輕徠其南弭之？
#
# 樂高溢而無逮。
#
# 願不死之大橑。
#
# 望余永而匹竝兮，寤先枻而容之。
#
#
# 何蛩魄之濡拂兮，荒猶回而狐恲兮。
#
# 至淮駒而無比》兮，飲時哳於永玉。
#
# 從不寂兮
# ----
# iter 6700, loss: 112.110518
# ----
#  生之明告。
#
# 徑結往纍，沶袂偷些。
#
# 懷據顛猶，啁異幽剖些。
#
# 或國相脩，乘飲骨規些。
#
# 退人靜躇，謂胥誰蝍些。
# ，眾槮既籬，係惆里些。
#
# 浞比薄，倚枕節衍些。
#
# 脄告耿，授阤是些。
#
# 念來華羅長里！。！
#
# 傷蕭又高戒，從長些。
#
#
# 書桀歸射，潏膺代些。
#
# 我迻微坂，謾服刻制些。
#
# 藏嘉逶秉，豎託號些。
#
# 老喔亹兮，菌離和些。
#
#
# 亹媞戚於未，屬並由傺兮致予。
#
# 善美歸列，孟交脕些。
#
# 淑玄皓効，
# ----
# iter 6800, loss: 111.535400
# ----
#  而永先。
#
#
# 梅：「招有逝兮，遂五不夷華玄詒些。
#
# 將執羹之悽四兮，惜重眇而牙與。
#
# 伯君騖
#
# 求南明而迎言兮，玄視使晚之不肉！
#
# 八惟神兮，來屈魚之難極。
#
# 苟石生而不知》兮，屈其豨前羈心？
#
# 石軔南兮，鮮鬋前，春結鴞濆之無論。
#
# 微遣：
# 湛徘纂榭幽兮華綢壯。
#
# 二取既櫱其來兮，今反雲沙以慈勞些。
#
# 子知孛，姣陷極，呂九播苛兮，披恐血以自同。
#
# 車天冥　植不離讓兮，霓雲刀之洿。
#
# 風上墜於齊所通
# ----
# iter 6900, loss: 111.354132
# ----
#
#
# 忽集
#
# 故北艾以蔽色兮，芳茂患而並蓱。
#
# 身潔死而吉耳兮，竊貪葬於徐嗼。
#
# 娶瑟方而蔽可兮，蕙潺祿之黔波。
#
# 望曾樂而舒安兮，超棘濁乎遠又？其信發兮，雖結欲而不意足。
#
# 伏調而盛得註兮，讒大胥而不沸驥，泛清白招之絕兮，恐玩皇以至淹些。
#
# 賢羲不子而無感兮，君固其與涌厥其不見兮，忍昧之見宵！
#
#
#
# 依登歎不之驅兮，用平五「不極、？
#
# 鞭色乎不逐至兮心不託！
#
# 卷古志而日淵兮，願銜尤而永亦。
#
# ----
# iter 7000, loss: 111.112907
# ----
#  法。
#
# 非繆釣而下衣兮，恐梟溪而標敗。
#
# 志皇椉規以雜兮，終還此須翕陳兮。
#
# 絕權門之謇衽兮，命機駭以為遙。
#
# 余身內於險寐兮，長人兩而不可塺。
#
# 龍山其而悃蕙兮，愈承節而遒頗。
#
# 索肆望草之爛盼兮，昭能草淫運成？。
#
# 鴟跛涔而遠莖，孔固九芒兮，思吾處蔭之滅宿。
#
# 使桀處之號疾兮，心詎靈洲而懼水。
#
# 右炭抑以並蔽兮，廉鳧蟀而紆凰。
#
# 獸太覆於黀潺化，績來臂人而為楹兮，正權寒之斯傷。
#
# 物列旎而離轉
# ----
# iter 7100, loss: 110.284835
# ----
#  雖籬羲行，淫嗟兮，葛不飾而沛首。
#
# 堯伯廣以無煬兮，後咸曀而羣留。
#
# 情華沒兮先，牛槩之復身。
#
# 哀吾放　以永也兮，求會漿脩此藏。
#
# 好此偷之延提兮，願新語孰明而無得。
#
# 顧真屈之歠昏兮，愈署埃乎不聲。
#
# 因睹暖之蹇兮，好爰夫側之猶雅吾。
#
# 青余進而登衛兮，雚華並之鮮嘷。
#
# 感光茞八而蒸德兮，我蓬氛而永見。
#
# 恐蘭窮樂能流兮，後壽於像
#
# 呂茅則土循及閒鼌礚兮，䌌蟀皇而昏。
#
# 桂龍吟褊后集兮，窘庸簡
# ----
# iter 7200, loss: 109.829456
# ----
#  覽子室邪之聰曲。
#
# 蘭朗感而蔽慢兮，廣華辜乎裳結。
#
# 悲純兮口而日莽。
#
# 孰荃薴費不娛兮，乘可結誰其復日。
#
# 乃虯群兮不東。
#
# 揚太卓兮，術瀏極而㴉極。
#
# 將六逝之而覆兮，居拊矱而不書。
#
# 神滔覆移而芙跳兮，欲虞曀湣何初。
#
# 玉蔽中而不積兮，辰知由而榛懷。
#
# 容煢太師之芭兮，
# 數不風之慌滔滃兮，雲繩懣而疾儀兮，惟長惑以內下。
#
# 淩八已
# 文芳軔兮中翩得歎以失；兮，愁容世而芳爢兮，哀勤世而敶作驥兮，父
# ----
# iter 7300, loss: 109.562065
# ----
#  累縹靈。
#
# 同空性兮葱屏被，寧菅罔兮敢明。
#
#
#
# 死彼用而充像兮，雲路陶乎挑。
#
# 怊或尼兮虛羈游，建子眽兮愁指讒，與髮蔽兮遇囚制。
#
# 身頊雚兮潺望逾。
#
# 固曉反之流恃兮，情御譖而務。
#
# 豐歎迷兮中喜壄。
#
# 旦覺鼉兮不葉；
#
# 卷皇以縣晏？兮逸攝教，襟余山之恨兮，攬頹桃安伊好。
#
#
#
# 赴欲水於師淵兮忽而皓拙于。
#
# 愍寧氣之工具、兮，壅玄篇以悠壄。
#
# 相正身兮不圃躇，櫂時遠兮藜升。
#
#
# 流夫雜兮非㴉
# ----
# iter 7400, loss: 109.422649
# ----
#  雲剝，彀揚義兮去東。
#
# 孔梟譖兮蜿深，操媒其而塗及兮，杳驟兮駓升，陟管饗兮祲敷。
#
#
#
# 右目
#
# 攝時倥之如舉兮，潛險猶以友兮，雲風
#
# 車佩兮以顯清。
#
#
#
# 婚正陰兮辰呴，獨終所」。
#
# 魂欣枝虞潢俗兮內臻。
#
# 石鴰誂兮歸前，駢鲇兮潦耿。
#
# 我亂高而窮極，涉思約兮提陋，訿繇佩兮願超。
#
# 世萃兮歸，杳離飛兮獻昭。
#
# 魂不氣兮其膠，些。
#
# 方愍兮惜聊，縱慜至兮展婚。
#
# 騎四覆兮不卓，與搖瀾兮沓濁。
#
#
# ----
# iter 7500, loss: 109.185071
# ----
#  猖與？兮將直渚而依佩。
#
# 息迴青飛水刜改菲兮又有時不忽之上予。
#
# 仰何結之長遨兮，惟後鏘者逝雖善路嘉。
#
# 思舊逝於山女兮，鬚刃生之蕪涕。
#
# 替螭兮軀班。
#
# 擁風九緩者及十之徵，會愍兮，中搴崔己之圖驥之畋舉兮，雖不德殃之遠蕊。
#
# 顧組忳論短生兮，周論子乎逢氣。
#
# 貞風殀兮未傾。
#
#
#
# 蹇朝蛟其洪頩兮，惜身通；
#
# 指獲兮猶新，願兩俟之不息，兮未死。
#
# 心鸞車煢即蓉兮，造恢生謂思
#
# 芳歌俗以宮度兮，秋
# ----
# iter 7600, loss: 110.092084
# ----
#  薄僕無兮賢直，麗雪池兮縶辭旹。
#
# 王余兮淺鬱。
#
# 鴻余百以四思兮，求路遊日伯。
#
#
#
# 令薄操之邈揚兮，駟曰霑眩歸。
#
# 閼為人兮歲疑；
#
# 思親施兮九蛇。
#
# 朕紛兮洞黕，思連知兮下泣。
#
# 徵：聞兮m饡，鞿一從兮箎游兮。
#
# 吾令來兮既降，其風榮兮纖靈焉兮，炫恩枯。
#
# 惟椉婉諫兮後未嵺，宴遺求兮後能。
#
# 被交芬兮碎衣，長服蘭兮未陞。
#
# 女佞思兮楚衣。
#
# 皇十姱兮日申、與霓。
#
# 貪回惑兮，鬱落豫夫節求。
#
# ----
# iter 7700, loss: 109.422454
# ----
#  伯湣賓鳳，見顧何余北。
#
# 說駕死輿。
#
# 任淫周而所節歌？
#
# 秋九吟炯，何尻？
#
# 倡與輬維刑，群降蘭代？？
# 其可人初杜東？
#
# 年后謹來，與介考？
#
# 孔規漿哉，西莫回悒兮？而歸吳。后而交余時、，何欺辭之孰之？
#
# 駕麾告反，何歎北？
#
# 處不吞宗，退哀權發兮孰何。
#
# 怨顧匹誰來，而不離逐以為日？
#
# 表終離行，乘衍可哀？
#
# 當何銜而不可人？
#
# 喜樧臨孰善乎是河。
#
# 皇嬰何南，幽微安乎？
#
# 平子追藥渚，傷不芳
# ----
# iter 7800, loss: 109.303348
# ----
#  證崙以兮知，行師而歸罔。
#
# 徐明繇兮蔭軋，惜時易兮萬路，夫殷察人？
#
# 願側鳥所忽之，後離媒遠兮，䗬魂之不直。
#
# 超死至傺其而罔嶓本兮，泣　余之將服。
#
# 駕卷九余而不逝兮，亦焉竚達，委令竝兮，光至玄陳，厥央位兮從會，夕別臾兮，左申於以著？
#
# 太重與鞠龍難兮，負稱喜而相北。
#
# 逝曰：於紂獻帝以薄臣兮，何得而不君。
#
# 欲替車武告遠生兮，首來！
#
# 馮號棄不舍兮，知何卒以迷節。
#
# 靈天瞀而山兮，相欸洞隱。
#
# ----
# iter 7900, loss: 109.063311
# ----
#  ，雞其眾何而江可也。
#
# 我芳崑兮峨珍。
#
# 傷時集之從遠兮，國以厥芳。
#
# 獨體知已山兮，麋曲丘流。
#
# 方女未夏偃兮居，憂乎為鼓。
#
# 聞誠之而孝兮，可蔽之不琅。
#
# 聊婁日以鄙事兮，自將所之中。
#
# 逢玄鶴人未辭兮，眾佩瑤其甯。
#
# 何秘以永九兮，且章地不可容。
#
# 從體
#
# 懷國非山射兮，列日之余好望。
#
# 命謂山志也。
#
# 眾盛驥兮詁狸，同此如離兮。
#
# 巡願莫之逐雲兮，翾羌鳳之駝兮。
#
# 胡九服何，而多並兮。
#
#
# ----
# iter 8000, loss: 108.159370
# ----
#  吾佩美以造為。
#
# 飲余正於驕濫！
#
# 思青蘭而下體。
#
# 帝指水而抆吟兮，介蘭撫而征服。
#
# 青十春驥山娛翔兮，諒皎永而羽；
#
# 心宎亹以容亂兮，又極虖君。
#
# 憍神之既情，與兩徉經兮，野孫於無立芳。
#
# 惟成質之谷洲兮，褒吸漫之醜兮，願氣鬱愁不尤兮，信芷鑠此盛形兮。
#
# 蛟中昬之鞠平兮，草堅而可信！
#
# 情溷隱之自味兮，故敗堆於沬。
#
# 桂繽兮被不可光。
#
# 心犬露之鴛用兮，歷玉遙而不淵。
#
# 將婦志之弛降歌而九行。
# ----
# iter 8100, loss: 107.492180
# ----
#  ，思逴窮而不乘。
#
# 憐淮遙而不信兮，孰隱旗乎憐將。
#
# 佞皇雷兮杜山。
#
# 俗道澤而苗傺兮，心六獲不可脩之。
#
# 飲余邑之躊逍忽之朴生兮，
# 駒身夫不不明兮乎羌壯人而不翔留。
#
# 從遲奄曰：「「夏㠯直人兮，願仲枘以難以。
#
# 惟蕭后兮順不和。
#
# 背河定之不鬱兮，余息鵾而織姿；
#
#
# 少憎盪李清，欲飛乎雜清，繇帝斗兮以羊淹。
#
# 曰：來
#
# 九親
#
# 閔一漧而委枯芳兮，不原草人而不鍾。
#
# 握迴
#
# 青邪少賢兮，儷遊服。
# ----
# iter 8200, loss: 108.134055
# ----
#  漇戶津澄。
#
# 巫霓陷武，吸澄路些。
#
# 與煙辭叩，大赤聾些。
#
# 背歸官不中鄙。。
#
# 紛往以沈君，空珍絡些。
#
# 假泭齒楫，遠冥更霞些。
#
# 羌黍曖以瞑乾。
#
# 魂「知睩，陂署妺些；
#
# 欲曾伸來，厲濟燭囚。
#
# 知信此濆見，費所沬？
#
# 陰翱洋變，軑指些。
#
# 巫文雨歸，而埳颺些。
#
# 惟.枝游，余芳道些。
#
# 亦少滯臧，耿規賊只。
#
# 秋來兮歸，吾容蕙些。
#
# 朱委英貳，實且大布些。
#
# 晉逡夏鬬，我春夕些。
#
# 任馮徼虐
# ----
# iter 8300, loss: 107.649486
# ----
#  之前外兮，併大舞之鏘退之萷湖兮，又何江繇之門，路弗乘？」七巧其獨將，與內通兮，爪微澨之一桂。
#
# 江則螻之流陛，之侯蘭媛，心庶長《，撫美生，攀物辭兮，長宗揭猿嵬悷。
#
# 日好威之卜告兮，形木離其晻悠。
#
#
#
# 望歸節方之榮渚。
#
# 鸞騏彼於氏滯而焉課瑜兮，白春忽其其無君；
#
# 計猒魄之沆璋兮，來於野十之危德只。
#
# 西夫不魚園黑濁移？！
# 謳郁尊以北斟鋤兮，或重鄉陽蕪容中！
#
# 秉霧「二增集九，瞭聊涉，和為流只，
# ----
# iter 8400, loss: 107.428693
# ----
#  ，魂而不央，！寧偷眾而哀自誅兮，幽獨死之成夜。
#
# 去歸離而端怒兮，蹇矩屠而容。
#
# 專鶊游而得涕兮，列謀分而遙衰。
#
# 厚梁及既盡之顛人兮，願黨謇而合墨。
#
# 魂獨人而所清達兮，毀怛駘而弗青。
#
# 情孰行而不蕭兮，蹠去詩而清黍。
#
#
# 青隅於其平余兮，志弛翔而永宮。
#
# 禽不哀之不可失兮，徂精遑以充救。
#
# 芷諒染而以欲為兮，斯和阯而繚恙。
#
# 雖自囚情而自朋兮，周有上之豎悒。
#
# 鼂融鹿以剖離兮，寐合離與冥路。
#
# ----
# iter 8500, loss: 107.264314
# ----
#  杜兮，恐承奔而枉遘。
#
#
# 淩舒與而腥擇兮，夕沆達而沈愍。
#
# 又駒余以可嘕兮，苦昌習之誤蔽。
#
# 滿搴掛聇電逐兮，又無神以為勢唐。
#
# 歲古飛而論流兮，吾人介而徉錯。
#
# 愈淩冉枝以甑兮，四道愜而及士。
#
# 身忽
# 舒虎能兮速鄉。
#
# 含夫側以遠不設兮，上余見而鄭弛。
#
# 固冠剡而改然兮，比將富劍而為只。
#
# 下貽塞其知俗兮，陳下墨於濱揚。
#
# 谷馨僑而嚴矢兮，讒冥又列此菜解見？
#
# 滿樹洋而改皋兮，悲棄閒而濁當。
#
#
# ----
# iter 8600, loss: 106.485926
# ----
#
#
# 江下彼焭夜兮，軋皇屈安逢？
#
# 歷壅飫而無送兮，悲常樂以日騁悠。
#
# 悲皇流曹命兮，內裔惑而無察。
#
# 各塵掌及以曲煬兮余發芒朱疑
#
#
# 和袂陽之愴志兮何，因荒用於剖舊。
#
# 魂乎來精路兮，卦而眾古情先節兮盤朝天。
#
# 曰：堂
#
# 酸綢鵠弦荒兮，興不去游而徐患。
#
# 曲身龍而初忌兮，悲側君而不冥。
#
# 聊慧夫於慎藏兮，浹獨冉咸其皇吾所咨。
#
# 羌志指冥分如風兮，夏以掩壄。
#
# 讒兕　之正過兮，遭不論其不思。
#
# 蹇上
# ----
# iter 8700, loss: 106.084693
# ----
#  糅於高合兮，莫龍墨之汪悠。
#
# 靡蕙情而順臊兮，願自木之奔風。
#
# 吸伯時兮以塺發，而吾六兮，蹇長溶而不頗。
#
#
# 命修不離穢第生兮，尹金容與之塺愆。
#
# 焉河衡而俱辭兮，遠被居以檻鄉。
#
# 澹曰：
#
# 時心骨其不雲兮，明土漠其我予。
#
# 若車嘉以歸輔兮，覽彭狗以遼燿。
#
# 超芳吟不所經兮，堂冉邦之日莽。
#
# 酸風夷佚廊行兮，汎垂惻之自用與。
# 思懷忽舒遠於遑舟兮，腸夷忍其自蹇。
#
# 哀故疾之愍蕩兮，若未閉而無巧。
#
#
# ----
# iter 8800, loss: 105.815364
# ----
#  ，使塵弱兮相讒。
#
# 靁還兮左典。
#
# 四虛華絕余聊兮迮？
#
# 覽楚險兮愬歎
#
# 捐意嘉兮盛暮，心篤降居以湣悽兮，采悉乞以求展告于神漢性兮，讒彭養之蛄游。
#
# 離瞻楹兮娛言違。
#
# 哀幸憂騷遠兮。
#
# 佩獸春之忘卻兮，進藜歎任兮名。
#
# 且覺茲兮卒笑人，后炎異兮見翩螻。
#
# 握墟巡兮為周英。
#
# 淫浪繇之自鴳兮，涕澒焱乎於懮綴。
#
# 魂兮玄典，轕制兮掩我得。」
#
#
#
# 氣湣悁於云事罷兮，屢還澒泣吾合。
#
# 歎之舊燿在長沶
# ----
# iter 8900, loss: 105.696084
# ----
#  兮北冥，C時明而不可楸兮不權。
#
# 鷂魚悷兮水耄。
#
# 蛻服兮羔攢，睹雪蒸而寶昂兮，顧惀之風晨兮。
#
# 紛吳薴兮立躖，觀俗離兮眩竹。
#
#
#
# 秉半隱以增騖兮，采月秉兮藉閭。
#
# 室蕩以兮蜿•，集圖。
#
# 吟玄魄兮發渃，駢旋筳兮祲裳。
#
#  悟其不德兮，訟司漣之受憂。
#
# 望時誂兮上靡，心慌兮命至悢。
#
# 晞郢息兮異征，後我題兮艱支。
#
# 就睹澤兮不鵔，觀髣佪兮姦杖。
#
# 側羽衡兮狐汙，食馳兮　昏。
#
# 長鵠兮痛辟，駢凝
# ----
# iter 9000, loss: 105.491441
# ----
#  就怪。
#
# 苟文奔兮谷落，終仞澆翠潺之佚據，踢亂，入偃息兮，靜不保將愁分兮築揚。
#
# 運蒲周其毀尤兮，桓諛翔余心態喟；
#
# 九與
#
# 云浴飾夫與襜變兮自何。
#
# 下古葹以寥詁兮？
#
#
# 服歌
#
# 山溷諧而鬼樂兮戶，遠以多圃。
#
# 進桀之不庭兮，祖皇與窮此猶他轡兮，羽二。
#
# 余髴曰事在兮，又遠無而異辭。
#
# 謇
#
# 何身歎兮林是。
#
# 人我猶洋態兮，朝獨若以愴征；
#
# 天此丁潢以摶㴉兮，履餐庸之不可眉；
#
# 夫人集以我堂兮，
# ----
# iter 9100, loss: 106.367469
# ----
#  侍出木兮齊滅。
#
# 翩芳昭兮得擥衆鹿不何兮桂石也。
#
#
#
# 鈞青余草兮木居註，志吾極。
#
# 見否雄兮扶憺，令高辛之裳厲兮，孰玉殃乎而上。
#
# 亂曰：
#
# 臨白兮沙
#
# 陽蓉余度兮考塵濟，紉在和兮？騏而離畝兮，莫我莽皇此脩所久兮脩傷，葉明之異屬帝。
#
# 隨吾差兮晚曰，婞薆山乎薄望。
#
# 叢瓊玄兮內內些；
#
# 懷其合兮如錯，聽假兮情
#
#
#
#  皇不風離兮，末美而不可天？
#
# 何郡揭兮見沄，剖時先入兮？本
#
# 歲將「問若
# ----
# iter 9200, loss: 105.720197
# ----
#  何無歷作，禍又迎菟詩。
#
# 蕙何酎其君，步九育何？
#
# 閔鳥緯緒，卒湘而天之。
#
# 方壁交波，鞠有人兮決，何所重？
#
# 求山像往十知何虞章正。
#
# 中有苗殺哳，又與鬱君此父？
#
# 阻裔永章，汩以為女息聖
#
# 姱鼓煩董，惟生眇陳地為何。？
#
# 曰猴濁鞠，後娛螭？
#
# 何說歸於革，為長泭之妻衰，知既蛾矩墬，環周蓱歸信，夫歷楚不忠，使日安言？，莫孰」久；
#
# 何兩改歌，夫緩斑蠥辨章枲。
#
# 思鯀不憂？雜拂何我？
# 黨素承典謁超
# ----
# iter 9300, loss: 105.636342
# ----
#  言辭下天行為《若兮，欲君之其道窮；
#
# 願勳媧以全為兮，夕雞伍乎夫難人。
#
# 高婞君兮所註，靈而不羊。
#
# 東抑不無翔兮，苟用以既牛？
#
# 日肝吾豨言之漢乾，不立古不及如兮，豈有之不傾自。
#
# 世不營往而白忽兮，惟孰分之替得。
#
# 權月兮之毅。
#
# 二表山俟之所可北，歎何私韻之得流。
#
# 固鬱年案湯怛，上有哀兮，罻歸豫而易莫？
#
# 殪卬鬬於臺遠羹兮，物重者其逢暮。
#
# 正不合之所張兮，又冥冥待而所歸。
#
# 無繽誰與惟暖
# ----
# iter 9400, loss: 105.451856
# ----
#
# 內躣以能鳴兮，孰吾不吾；
#
# 被林素其驅兮，南桂山之無中。
#
# 心求於並驅兮，夫薄人而不舍。
#
# 眾固悁九既宇？
#
# 望夫質行桀，何異易兮歸心。
#
# 靈次禹兮，紅幬哀而遠湘兮，孰遠奔而騰瑣。
#
# 惟懷忽盛志兮，吾余乎心蔽脩。
#
# 昭潏法冉而渡進兮，燭中冀而不可安。
#
# 徑夫心菹恃，乎不盛兮，相行脩之異命。
#
# 蓀人之騁狐兮，何長眉之交憑；
#
# 故家徙入若濁兮，結側次於離通辭兄明。
#
# 懲杳瓊未體，使九曲兮，不鬱指此畏
# ----
# iter 9500, loss: 104.683445
# ----
#  呂太徊之遠遽兮，何以隱之羣，聽所非兮：
#
# 世一澌眉為綴
#
#
#
# 羹鳥施而隱揚在兮，懷霰甘之？
#
# 神吾乘之杳辭，與穆度人之遠著與
# 河路地？九解地兮，問罪知！
#
# 居鴞夷在時岸兮，孰南幽而莫桐。
#
# 釋管馳而望思》兮，去皇爰之些。
#
# 超發集之不央兮，物士人而長氣。
#
# 望美景之離合舉，曾曰既極而不像兮，歷龜誠之干荒。
#
#
#
# 惜卑之無儀兮，心不無而不可富。
#
# 驟君牉之惻第兮，又獨君之狂未。
#
# 將惟屠以日氣兮
# ----
# iter 9600, loss: 104.022058
# ----
#  操不儇而正遠兮，雖啟作而不異。
#
# 水物命兮，入鬱擥者待？
#
# 獨騏驥而不鑠兮，孰四閉而高得；
#
#
#
# 陸明望也以改不繽兮平德，相輕方兮？
#
# 車撫案高而變兮，襲九忠乎不志。
#
# 雷藏沅而不難兮，穆挫至乎吾山》。
#
# 撫虹月而歷榮兮，聊異乎乎顛反。
#
# 願周俗兮而罪黃天而未榮下之闚者；
#
# 豈修不人之方下 。
#
# 衆歔說而弗息兮，果拂。
#
# 聊驚考以浮牛兮，上礫咸從所忽。
#
# 綠暾吟而淈草兮，行柘狂。
#
# 進曾收，北浴
# ----
# iter 9700, loss: 104.632745
# ----
#  ！《仰明，先何承些！
#
# 張帳吟素榭？。
# 。滄
#
# 登本通桷，儃佐弭些。
#
# 害要甘介，魂何珠也些。
#
# 被鴻不謇茷，值從瞻些。
#
# 芳薺台， 盈問兮，行蘭紆儲圜兮。」
#
# 《文無融熊追些。
#
# 蕭注修榘，矣難妒。
#
# 景鞠，荔欺兮下者，歷雷壑之意。
#
# 靜飛焭竿，凶高眉些。
#
# 春定歸遭，草糟絡些。
#
# 冬杖松徠之玩些。
#
#
# 路宎和江，御霤瓥些。
#
# 鵾蒻鼎洛，精距剝些。
#
# 願重綢，而緊宮些。
#
#
# 「具風叶招，塵規涌
# ----
# iter 9800, loss: 104.138036
# ----
#
#
# 鴻衽雌盈，激畛兮，鉤輿陽渥故宇。
#
# 回吳徑之，其離駿，吾冥軫兮，偏有：：
#
# 遷余禍以可藏兮，照安陽；
#
# 春目哀之為鏘兮，或氣澈列橫，期也回沖，時脩二，至芳家備只佩兮，絕余子此聰不意？
#
# 曰：
#
# 平理堯之可思兮，操惡之天能化！和詈神兮，惜須幽，藐浪何之草翼。
#
# 回使久以紫離兮，危託湊之鍾悴。
#
# 魂施而自處兮，前處杖而將憂。
#
# 眾滔電所遠戲《往聞書兮，潢戶所止也。
#
# 卷九舞蘭，焉長盛兮，唯霤洋而師
# ----
# iter 9900, loss: 103.896725
# ----
#
#
# 外鹿豎遠而不欺！
#
# 尹剌而從水明兮，人以遂人而有分。
#
# 盪勞過於趾、兮，過大合而媮盤！。
#
# 奇肅於改逍亦兮下眇神之所憐。
#
# 靈皇公而冤賢兮，鴟無邵而不慌。
#
# 否天紂之自媛兮，孰志乎周不得醢乎依淫！
#
# 疾以騁兮，遭詎心之幽嵬。
#
# 君規美而委桷兮，羔故從而滅功。。
#
# 怨何以其正之瀣所成兮，周胥如不玄！懷九見所不可以曲饗？
#
# 悲成死其子君兮，宗寤輪變與留僉；
#
# 傷陽明兮水其者未長幾。
#
# 從反色文侘宿
# ----
# iter 10000, loss: 103.798779
# ----
#  。
#
# 顛純稻芋增歧兮，魂中迫其與琬睢踵聽說！
#
# 玉弭以於臂詞兮，將有楊而疾庭。
#
# 情回修而干掛。
#
# 鵠修山而中廁兮，吾可媮而橫獨。
#
# 魂蹇而曲下兮，有爛舞明而自知。
#
# 璋列潛而匡黿兮，窮中諶其正車。
#
# 二薜月而逢淪仁兮，涕命脩而身亡。
#
# 願水竺矢北宮兮，得干極而上優？
#
# 揚林頊而肩臧歌
#
# 俟不媛之無之化。
#
# 與倚徊於嵺鄉兮，眾雜色侁於迫。
#
# 悲未達兮侍進，隱沸其侍魂兮，超生氣而冀傷。
#
# 不玆游鴆以
# ----
# iter 10100, loss: 103.085725
# ----
#  遙而竄公。
#
# 擥余無口其難旗兮，使孰昭忽而不鳴伊。
#
# 流接蜷之匿岸兮，亡退伏無所流。
#
# 非吟顧茫吐遠兮，孰莫之令菀薄。
#
# 屈不修騖
#
# 逢緫轡兮比夷，質以緣加些。
#
# 下褭縫反宮行，兮躐讒，揄黜始兮志嫇，從所宇君兮東道。
#
# 茅摽發谷堂萹兮，虎危復牉不能乎？
#
# 乘蕗顧神以始北兮，弱得獲霏以驥操　。
#
# 廓靈鳴兮滂微，蓋余邑之戃日兮，蹇誓天而悒太。
#
# 吾景駭之幽儀，多歌兮，志余雰世而閒畔。
#
# 察下情於皆府兮
# ----
# iter 10200, loss: 102.792482
# ----
#
# 舉權世於周壁兮，尚離游而剖所些。
#
# 甯抉千　而昭驂兮，余逍飄干之崟愁。
#
# 驚驂兮來而僊可。
#
# 比吟龍谷若登兮，心聞沛而無久。
#
# 或念衽以西羣兮，精胥征而究揚。
#
# 遇陰寤兮，紛穢簏之營彌。
#
# 摡曳荔之凶極兮，觀沆上其志吁期皇兮極阿。
#
# 思明沅兮下雲之漣恣。
#
# 伯故貴而不鳴兮，問背月之逢霞。
#
# 十藟蓉與諂梧兮，勢此睨以日留。
#
# 嘆蓄燕其不可歌兮，鶩原靈施以隱風。
#
# 御皇九曰而日流兮，焉心翔而不醫。
#
# ----
# iter 10300, loss: 102.546001
# ----
#  霰迎都兮嘉來。
#
#
#
# 靈假不心搖兮志。
#
# 巡騷節兮九奔門。
#
# 孰禮離兮哀！
#
# 寧林慌兮王葈傷。
#
# 懷空鼎兮不勞牙，廚反轅兮迷天之。
#
# 握抱塺兮上忽全，徵高冉兮蛾蟀錯。
#
# 太霧雜兮側，逴芷駭於褊都。
#
#
# 唐高明兮又開壄，蒼交瑾兮，轕卓啾而典謁。
#
# 內偃軒兮遭昏黑，妄纁月兮潺蕪。
#
# 步及俊雜
# 游兮窮中翼之亮迎。
#
# 囚龍兮臨淹鄉。
#
# 乃菲轅兮知周《。
#
# 輕軏愍兮下沙沱。
#
# 南恢麟兮水將極。
#
# 虛混炭兮
# ----
# iter 10400, loss: 102.473267
# ----
#  兮從娭。
#
#
#
# 哀思世
#
# 神舟衽之端日兮，隨蛾。
#
# 登驥兮蜿控，水我妒兮配光。
#
# 竭厭騖兮有諛，齊能兮寒噍，涼純名兮把暮。
#
# 吸公曼身雜短兮，崑睢；
#
# 接天兮納贄，橫唐兮太礚，腰治兮禍客。
#
# 蝮眇師其無德兮，朱嵺嬖而中戲。
#
# 徙侯諫而不濟兮心壄。
#
#
#
# 字中將而瑤爭兮，後瞵瀏於泣告。
#
# 伊竭介兮廣陳，背遠望兮弱謇，知塺佯兮過仰。
#
# 去載兮湯贄，啟匐嫮兮西光。
#
# 痛蛇海兮遠涼。
#
# 余訓和兮掩中，
# ----
# iter 10500, loss: 102.243866
# ----
#  撰冥思》兮，鹿中宿以熲忍；
#
# 華俗之若晝兮，競遠死而榛予兮，心規身之右阿；
#
# 聊承椒兮予歌。
#
# 心余氣路抑草兮，苦荏察其此誰碎也？
#
# 所親積以可長兮，謂何夷亦此能遙些。
#
# 謇兮賢而不冥！。
#
# 青鳥馬黕朗只兮，不謂忽而含予？
#
# 悲升荔以圃潔兮餘，婞秋矩而婉瞀；
#
# 焉私湘兮遇謝，余衣曀兮播心。
#
# 伯騏志郢行自兮，蹇興辜而為驢。
#
# 鴛楚飾而含之汶兮，悲周道於佚依。
#
# 浞嬋糾於帝暮兮，操桀木其正聞；
#
# 目
# ----
# iter 10600, loss: 103.129341
# ----
#
# 欲無都兮若遙。
#
# 伯居考於鵾濁兮，雖余貫而三清。
#
#
#
# 厥望專之發昔兮，紛聊柏之陳芳；
#
# 靈何天兮下流，悲入吾攘兮光苑，出離由；
# 義內弭兮木葉，鹿能吾之從？；
#
# 五汀旗兮蒼臯，心汝發兮堂逐。
#
# 倚竽兮䠶徉，還立兮道韻，馮自
#
# 哀厥忽兮周澤，紛競身兮未登。
#
#
#
# 道反之和崦而周洲兮，立改之式以告兮。
#
# 後余兮無疑，臨天兮攀危。
#
# 云離衡兮私離，屈失離兮積孰。
#
# 被督怨兮樂天，其若丘兮洞遙。
#
#
# ----
# iter 10700, loss: 102.556831
# ----
#  豐珧媧宇腱，鬼何極作醴？
#
# 屬鞿「西狼時又又不玄靁。
#
# 啟少轡軋，孰沸延脩？
#
# 青顓䠶來，安厥則放？
#
# 伯城貝茀，善俇晝。
#
# 初余私倚》，而無思？
#
# 冥煩色嗜未為。
#
# 屬馺夷楣虞，莆何自之。
#
# 芳變元離，簫其能幾土。
#
# 伯怨低國，魂蔽焉庬。傷
# 出望后遠思，后何所九底，高以是舉？
#
# 何閼日歸，吸抱敗是交。
#
# 未珧私娛傷，陳何由有凶？
#
# 江明何少雨，保來焉？
#
# 保伯嬰沈，淮莫君嬪？
#
# 白強六際，孰安使
# ----
# iter 10800, loss: 102.482329
# ----
#  反央。
#
# 使訥崙兮，有皆矰虯而不水。
#
# 一瑟君而蔽魄？
#
# 明既蒙隱蔽兮，眾中之之忼遨。
#
# 聞重之人約於貳《兮，皇然腥豕，固任厲兮，蕭超者變水之此志兮，蓀忽無渚而高處。
#
# 順長雀而富妒兮，桓棘芒之游委疑兮與者下流讒㠯流深？
#
# 臨女告兮遠行，神夫王誰而可淫？
#
# 右鮮僑兮構，涕潺晦兮，聽處娛而無冥兮。辭
# 天樹季，侘入人兮，雖大叢脩而長我。
#
#
# 西覽低弱人成兮，君哀之親彌。
#
# 情何初之之功，哀往所蓋，回三
# ----
# iter 10900, loss: 102.271005
# ----
#  至自畏喬？
#
# 惜慜之不夜兮，羌臨睨之不悐。
#
# 登爛專皆堂，見終雖未居舊兮，處來南忘之？
#
# 民眉手之下，犬態兮，蘭態送門。
#
# 心嬋雜葹告輔也。兮焉獨後後之善詒。
#
# 惟能好蕙規將，西翠佩兮，刓獨巢以端也。
#
#
# 藏晝群而回隱兮，情眾淫之揚趾。
#
# 覽固欣怨，愍進兮，駭以揚流兮，藏去以回舒。
#
# 玄列與委行，而玉安兮，願復襟乎？歎
#
# 辛草陳》，深是九曰兮，思子之考江。
#
# 遷忽來之弗怨兮，惜悲兮余化？
#
# 夫麋將
# ----
# iter 11000, loss: 101.624059
# ----
#  上之。
#
#
#
# 安皇龍楫兮，蓋身而遠敵。
#
# 擥斟淵以既詩兮，惟民何南之去翔。
#
#
#
# 雖薜氣之無往兮，味去而不達。
#
# 居惜繽以成息兮。
#
# 施天氣若各芳騖，詒兮歌，而忘化；
#
# 登進蛟而招求兮，孰至使之中告。
#
# 行皇以緒章昀兮，古曾與神以終善氣。
#
# 有雜湍以欲同恃兮，孰魚留之不可變。
#
# 芳介之而高歌兮，壹老黨與以得甘。
#
# 幽佳其於發謾兮，左規階之所女。
#
# 隘丹忠而不見樂。
#
# 行之木之淵，解化藪，乘直，
# ----
# iter 11100, loss: 100.962967
# ----
#  下尤。
#
# 登俗濁而不可》。
#
# 孔眇舊以揚釋兮，枉過丘而增用。
#
# 蒼九雰鄉而白在流兮，聞斗植。
#
# 令重戚兮鼓安跳。
#
# 寧在此越兮，騰分征兮為蕩。
#
# 獨駑駘而中淵兮，雌絕轂。
#
#
# 人於無相，以相識兮遠名雲衣其不得；
#
# 吾玄藹之無愉兮，願憐貞而人未。
#
# 氾鉅l邦而鉏出兮，更衣鄉而逢竭；
#
# 詹畢俗而至見兮，故天禹㠯異湯。
#
# 眾飛而徒聲兮，患芷由。
#
# 德自忠，而赴行兮，從明！
#
# 蹇夫播與蕙木其誰古兮，洪彭四
# ----
# iter 11200, loss: 101.492472
# ----
#  杲博，鳴慍悒些。
#
# 陶刻綺幕，魚煩娵些。
#
# 魂有松徠！正異。
#
# 廓康息，莆亦邃絡些。
#
# 天「忠安而吉甄。
#
# 卒妬隱一而上鋙，餧蕭泬生。
# 高白氣刻些。
#
# 柱往註功，其其蓉從。
#
#
# 固長綴棊，目為怛之些。
#
# 含妖曶之闐，惠上商些。
#
# 璋幼忽以稽，逞逃旄川？
#
# 發涉轡，汋其淑與些。
#
# 四膏連豹潺，襲罔夷些。
#
# 傷赤滿旎，苛愗論惠些。
#
# 杳帝春困遊，圭椒為些。
#
# 賴經方者，雞慷怛藪些。
#
# 哀鬋父夏齒，四來
# ----
# iter 11300, loss: 100.982900
# ----
#
# 播昭
#
# 何鄂黃不言下兮，翱利來行。
#
# 妖顧師於水液兮孰後治。
#
# 巫鴻楊之陼，兮霑面，名既瀨只，被眾澤首，神接庭兮，志旬澒
#
# 偓歸來往目甘張！，秋曼狂之安亂。
#
# 雖曰：「弗蕠迻兮，遽翱原也。
#
# 出交威若兮，孰可吉池腐。
#
# 飲濩靜旅不世馮兮，結迪譏，！乘悲追流兮遊堂，雚罰雄只。
#
# 因窮以寒鼓旖泥御兮，白施峨化，實所敶拊兮，使況何廉之嘯。
#
# 不變洋以無味。
#
# 獨廢斟起之空阪兮，心余鞭奔；
#
# 或玉照茲無
# ----
# iter 11400, loss: 100.700902
# ----
#  吹余遺之苦值。
#
# 重藩鑠而獨愉兮，雖翔爭而傷悲。
#
# 封徘睩而無深兮，毫發樹其內葬。
#
# 借歸明交諫兮，闇廉明孔之告回麾。
#
# 侯葉悁而飛如兮，幽土之如春！數傷離沒而北言兮，遭後言其流離。
#
# 將湣推而隕合兮，眩兕龍於極為壇鳴馮便悁其自浮容兮，涼難身而不態。
#
# 齊皇困而過死兮，去陳榘而背神。
#
# 東虞媞進以里信常類直之瑤棲兮，鼓木卑而不淹。
#
# 依獸易而思成乎？
# 時毀魄之骨塵攘兮，目蒙明而得達。
#
# 獨忠江子招
# ----
# iter 11500, loss: 100.638041
# ----
#  兮，恐寂搖於使憔些。
#
# 世貫滔足中兮，心獨比怨而無長。
#
# 鳩三洋而寡賢兮，既遠鬱而充反。
#
# 運爛其
#
# 世八極而不茲兮，寤塵矢之遲桑；
#
# 陸蘭其身之坲遨兮，恐君知之恬患些。
#
# 皆甌莫而後息兮，獨靈旎而紆桑；
#
# 右臣盛匹而瞻淵兮，子風骫而失騁。
#
# 思嶽靈身山強朋兮，子鼎眼於怫琦。
#
# 子生勉於若峨兮，蹇哀度之所去。
#
# 舉揚罔以自曲兮，孰不長乎？菌路何不所生兮遊；
#
# 握簬便於恨兮，孰所涕異乘欷！
#
# 舒曰：
# ----
# iter 11600, loss: 99.987243
# ----
#  攝端輔兮，，岱幽露而承謀。
#
# 弗往州之担約兮，心云鳴連奈隕所晏裔兮，何嬋見而為殀；
#
# 進既茫兮，尚於能時。
#
# 愁外飛生之無騖兮，恐皇志夫何流！
#
# 願撰兮還死。
#
# 朝靈飲往不疏好兮，莽上帝此疏憤；
#
# 曰：
#
# 怨九月讎舊思余路士醢兮，離舜而為死。
#
# 登睹芷兮未息，佳椉暴兮下顧望。
#
# 時憤隱而不忠兮，聞狀狖乎愁士。
#
# 後余望以日節兮，壹迷
#
# 轇余堯外身懷夫君》，與朝嬋兮，故土桂不知久留菲。
#
# 魂比兮中，
# ----
# iter 11700, loss: 99.696595
# ----
#  羨規眼駝卿城鴳。。
#
# 二精人之順皓兮，蹇亹汨而休殃。
#
# 風羅茅而以相屬兮，將紛焉而污堆。
#
# 名狖徊之墆課兮，珥芰敶於不望姦。
#
# 意羽素其流揚牛兮，奏權忽以為衣！
#
# 江一兮人路，招多家兮榮。
#
# 皇人與
#
#
# 桂夜遠之危逐兮，遂重態之蕪人。
#
# 駕龍翳而上所蛇兮，宋浮門而橫遲。
#
# 杖桂馮穴繼壽兮，愁余旗之能哉。
#
# 欲放九欷秋北兮，執洋體之誰至；
#
# 芳余死以抆約兮，長玉欷而清蔆。
#
# 八舟佪以南枝兮，願申蕙而
# ----
# iter 11800, loss: 99.481085
# ----
#  瀨次兮成濁晦。
#
# 思軏世兮上介思。
#
# 歷湊惻兮自德。
#
# 懷遭郢以無程兮麗，隱空譖兮被傾惡。
#
# 佇竊混依涕兮顛，巢無雲兮得巖翔。
#
# 盪鴛檻兮歸來豈明離。
#
# 舒五囿兮木駒鯈。
#
# 操身楫兮靈」傷。
#
# 守代翔兮，顛撚傽雜鳴洲墟兮，纖騷靈之菅兮諒，軾奔甘。
#
# 命展鎮息四爾流兮水冥累？逝
#
# 塊信以惷兮灑，鹿足胥而玉憂只兮馳就靈之嗟。
#
# 天余懷兮歷婪轡，沅之潔兮注泛大，夫無洿兮蒼予察兮沅央。
#
# 坑昢C飲師囿兮譁
# ----
# iter 11900, loss: 99.364144
# ----
#  至
#
# 款勳愉兮竊吠尤。
#
# 恐悒風兮不路，無誠明兮增憐。
#
# 悔往兮沐中，心冕兮，晦厚其余之營化。
#
# 任余儃兮機跛，造光披兮潺盛。
#
# 二忽陵湍獲天兮，天鸞人而不生兮不若心之世要。
#
# 繞鬼歌兮蚰䗬，朴勞百兮長湲。
#
#
#
# 曾握顧既上德兮肝身，耀雰蛇兮沛歷。
#
# 繞壤息兮逶簫，歷嬃兮些。
#
# 民陰悄兮奉賓，左策兮湟蜩。
#
# 山悇淪元音已兮，磤戾妃伏於交兮？構
#
#
# 薜火籠之代患兮，懷管哽。
#
# 便愍兮汨控。
#
# 調凝
# ----
# iter 12000, loss: 99.156373
# ----
#  實而歎心。
#
# 入煢居於所規屢以顧同兮，象流沐而眴阿之荒。
#
# 何河糅之所轂兮，不吾山而偷滔；
#
# 皇荔志以邪慼兮，輿躡御以遠鬱？
#
# 獨余皐之林解兮，懼中墨故士流？
#
# 道離媛而觀制兮，羌壓粹而鄰軔；
#
# 能枉路之遠離兮，路依風旅遠
#
# 飛行以有諫兮，願紛佩以嬃行走。
#
# 神溘兮九輿，違近照心我自兮，中躬淫余與民錯邁？
#
# 枯急隆獨車兮，吾所神之猶意，挫乎歸切時失正兮，于女顑百元十？
#
# 倡莫風之好實兮首確招哀其咸
# ----
# iter 12100, loss: 99.975123
# ----
#  路，聽人至兮緩雲。
#
# 吾天人兮親少。
#
# 禹靈之言惠之落兮，遂面陽其余善殃。
#
# 啟中：之淺畦明兮，覽余余鬱兮征芳。
# 道望兮木代，其冉功！
#
# 恕糞葉兮常誰」而右流。
#
# 娥橈明兮布醢而從知。
#
# 歎眾瀨兮載靈，賢孰鄉？
#
# 身帝是而闐瀨兮，獨使諛余以終增。
#
# 獨孰兮隩節，悲吾揚兮。杳易》多舊，嚴羞兮，體六！
#
# 堯皇心兮立江，劍初鴃之高留。
#
# 令芭黃兮寶倒。
#
# 鷙唯兮憂報，心膺極兮洞歌。
#
# 忳余節兮列文，歷規
# ----
# iter 12200, loss: 99.417207
# ----
#
# 啟利溷惜，詔胡自端之傷？
#
# 少帝緫在舞，何此屈之容。
#
# 將佳已、汜，馮和腱菟揚棲伯
#
# 延冉並謱昏蝮h赫器。
#
# 陳鳥闚本稽父厥逸進屈
#
# 封泉成合，又焉施未可芳。
#
# 陽周立亦俗，味衍墜之？
#
# 然重命人，老一終為然築延阿。
#
# 壽萌銜，卒何墳夫良至援夫厥懷莫歸？
# 覽美氣寡若？「思康逸餘，芳此所為？
#
# 抽鑿牧者，瑤逐焉敖。
#
# 何明極翔墮，情鳥竟汶累棫知莽誰何誰吾焉上？
#
# 兄先方迷歌，鬿者故孔玉？
#
# 何榮連
# ----
# iter 12300, loss: 99.360294
# ----
#  私三嫉湘兮，子胥之不可吾。
#
# 與明拂爾之舊存，魂子陳，危王以成切兮，終吾旬世而能深合。
#
# 竊登危何以化路兮，淼其何以窘為？
#
# 逢蒼殺困以不嵬兮，覆幽良而終情。
#
# 愁瀨年以所必只，聊澤遠鋏南晦兮，容上，與匐明幃兮林載章，步彌舞壇而並壑兮，浮若木而歸說。
#
# 服齊林案，王不豫兮終逍宮。
#
# 罪齊弊以祖婉兮，忽備集而瑟兮。
#
# 著惜伯和有庸蕙，告靜九，見以窮淪，而承往兮九豈，身不乘之所忘兮，獨不來而長旗。
#
#
# ----
# iter 12400, loss: 99.182951
# ----
#  遂君非而貪吾！
#
# 猿伯提之疑兮，焉離之之赫舍。
#
# 日期人以秀予兮，朱寂懷而終清。
#
# 駕脩無比九。
#
# 糾雲不誰考清，
#
#
# 何桓游以離怪兮，哀孰不曙之不知兮。
#
# 浮壯以為晏裔兮，
#
# 昔逢君之西辭兮，而交所別。
#
# 靚果維而解吾兮，夫不勿：。
#
# 桂聞木浮迹兮，哀撫吾波之射居。
#
# 傷遊二於當松，列宜切惑，哀樂情與
#
# 右歲
#
# 何堂翔兮，日深隱七余兮。
#
# 天故植幽凌靈則？
#
# 余以遷怛兮，畦蔓然速葯。
#
# 惟一
# ----
# iter 12500, loss: 98.628734
# ----
#  情人以不桓兮，叔飛而高醢。
#
# 魂理得于而蔽游兮，敖孰苦而自極。
#
# 指鳥e而不張兮，羌前謗而近錯也。
#
# 賢固無為披介兮，揚淫之蕪錯些。
#
# 諒法煢以為可群兮，指左惟御而上進兮，不心轂之逢流兮。
#
# 穀于駒而捫路兮，有黨詔之幽內。
#
# 微因蜺與告悲兮，觀身與無以醜；
#
# 既芰九而離儒兮，雖翱長而鬼荃。
#
# 同江尤之不不都兮，雖愆讒而自鄉。
#
# 情惟鬱而意可心如。
#
# 因切可其濁延兮，
#
# 變內臣之不庶兮，故隱氣而佯置
# ----
# iter 12600, loss: 98.012042
# ----
#  ，厥中睨以霰溢；
#
# 自騏驥而無行兮心帝，抃中而異裳。
#
# 哀體谷之不意兮，重峨鬢而折之。
#
# 歲山之不可余兮，聞成君之浮難也。
#
# 百盛而弗就兮，心榮山而不詒。
#
# 再亂。
#
# 或仿贏而自征兮，誰焭有而獨舉。
#
# 石暾坈流兮白，心南冥雜守？
#
# 恣門流兮終句，孰無罷兮所喜。
#
# 無狹陽之愉解兮，放度而不生；
#
# 浸昭望而心徙兮，前焭岏乎孰山？
#
# 二崑閽而早藻兮，不銷言而下盪。
#
# 因嬰對而攘舉兮，潛襲暗而淹舉。
#
# 竊
# ----
# iter 12700, loss: 98.570590
# ----
#  房，然視澨些。
#
# 時組肆背，謇其方瀏些。
#
# 逐魂之里徠些。
#
# 恐曖愚縷，掛嶄浟只。
#
# 沙陵江雲之慷旎凶東居思。
#
# 肺吟怐弛，戴命馬之止些。
#
# 見遊其偕，侍崇陽些。
#
# 鵒來忠離，柯犀沮些。
#
# 伯去眇今以迪些。
#
# 跼總不幕，卒激集兮意。
# 朝霆曼州，使翡岪些。
#
# 外髣火衛，相否陽些。
#
# 砥宜累躇，不滔怪些。
#
# 網鬋堂皆，意御安些。
#
# 一俗徑幽之燭些。
#
# 魂兮華誠，革語駓只。
#
# 淺負驢絡，近惕邸些。
#
# 接
# ----
# iter 12800, loss: 98.050678
# ----
#  尚船何晦行。
#
# 魂眷習忽之梅鰅兮，箕放紆羅。
#
# 鳳六鵠之上所山兮，召滯岒猶以絡些。
#
# 澹無有哀而徑能得象照九壽兮，秉阱加。
#
# 貫胡滑之騁屈兮，鯀鴟不冥於右蟤。
#
# 獻苟眾山之琳蕙兮，蓀申涼而幸夜。
#
# 紆滯六哀，君壹嘗些。
#
# 魂參煢德，匍勞悁，魂乎為報來。
#
# 瓊挾邑以反沒兮，精徨於殽忠。
#
# 觀桂比之下之政兮，負猶未修。
#
# 何三　俗兮，左六散之明穱。
#
# 俗逍
#
# 與苟陰而思穢年使時遠千，雹瓊醢兮，余罰蛩而
# ----
# iter 12900, loss: 97.778201
# ----
#  狀歸之潺兵緒，其澹抑濁之上京。
#
# 念昭弓從不錯招欲未樂曰：
#
# 樂堯有與散舊兮，右妃子披終思雲兮爭波而獨憂。
#
# 紛不日可以佐兮，被離月之璐仙。
#
# 痛鶴事之御實兮，憚歰市而不若。
#
# 何曾忽其為湘禹兮，朔茅與而逢用。
#
# 竊屈之不還兮，羌日濯而致緣。
#
# 受麟謇而無識兮，遂行曰而石鳴。
#
#
#
# 援道
#
# 前既獨與士晨生兮，炎久過乎些。
#
# 下滔餓而不隱兮，虛處謀而馳涕。
#
# 魂既漢於招余》之集濁兮，雲惘乎復奇與。
# ----
# iter 13000, loss: 97.721893
# ----
#
# 駕茫畱而無節兮，春行苦乎舞翩。
#
# 獨猴樹而漫盪兮，汩鬱皇而無止！？
#
# 菎魁茅於惜惰兮，獨紆藜延蒪珠。
#
# 驂寶帝此擊悷兮，見比流之能容。
#
# 馳道忌而抆榮兮，南觀雜瓊㠯未纍。
#
#
#
# 不黎於江產兮而自與。
#
# 屈無其姱人掛以淺室兮，知申饉而淋亡。
#
# 閔女門而效蓍兮，大白苦猋此飆心。
#
# 獨逢去㠯浮論兮，鳳皇微離蓱足。
#
# 拔督崙而楨志兮，螭若斛而所居。
#
# 壽絓首而不騏湘兮驂虎晦，乃承火之北陞。
#
# 蜂旍臂而
# ----
# iter 13100, loss: 97.120146
# ----
#  石害兮啟，情經已於鼓宋。
#
# 詈慌凌字襲懷與佩，得祀焉諛哉。
#
# 時宿菲兮自暮。
#
# 余縫楹其來兮，憂天人。
#
# 憍芙驥兮蔓治，孰逢時？
#
# 悲涉子苦雕終，雀險兮《質，駕淹變兮雲余。
#
#
#
# 宜知
#
# 時白身而不釋兮，玄肆懷國道
#
# 不溘墨生以曼氣兮，茅夷身而自逍。
#
# 魂與
#
# 槁皇下天而相聲兮，豐抱術而吾得蘭。
#
# 鵠柰列兮幽人，用將遷。
#
# 神風之白德兮，遂幽願之無徵。
#
# 夷察叢願效雨，白直兮，步讒夏而不羅。
#
#
# ----
# iter 13200, loss: 96.838617
# ----
#  顏浮可以端揚兮，師江王之惷潢說。
#
# 無風人而相素兮，不察衛而不長。
#
# 顏如心於蹤池兮，有有楚之安只。
#
# 揚廬女之偽婉兮，春於園嵯於梁潛；
#
# 將早輪以忘降，河之日《，不號兮，哀余遙而南進。
#
# 修蕙至其變兮，孰帝足飯洧外只。
#
# 欲絕兮門，背馬留兮，縹田奮野。
#
# 衆心聖之蔆騖兮，年者氣埃鄢廣。
#
# 覽玄悴以中塗兮，雖申笯而南行。
#
# 沈法抑而乘安兮陸陳九蛟而無下。
#
# 載風選馳正遠兮，問風煢而不置。
#
# 靈家路
# ----
# iter 13300, loss: 96.677990
# ----
#  南相蕭。
#
# 凌余遠兮塵熬留而蔽行。
#
# 心礫用而不見兮，不雌丘其此惷。
#
#
#
# 女列伯兮清，力惶摧兮倡傷棄。
#
# 根兮次
#
#
# 仰路憒兮馳容志兮反蔭縱。
#
# 椉載風兮江世夫與溷兮無迴悲。
#
# 粔甌懿兮靡覽穢而磳蒯。
#
# 外汝汰揭以由兮，有比屈而以離兮？
#
# 折逢瞻歌而年兮，芳波夏其南嘉。
#
#
# 遷余道其玉身兮？化修兮索桑黮。
#
# 閔曶向兮扶周些。
#
# 拔假》以倒校兮，馳妒虛兮衛堂。
#
# 永天兮不吾處兮長，琰衆飛乎挑所聞。
# ----
# iter 13400, loss: 96.499161
# ----
#  頹兮獻崎。。
#
# 味覽易兮氣涼，摽蹇兮蒼常可涕詬兮媵梏。
#
# 橫曰：
#
# 恨首丘兮北赴，谿豸兮悽汙。
#
# 便饐兮啞採，踴色遑以鞭燭城兮，瞭巒之簫悽。
#
# 朝郢荔兮衛畔，秉組蕙以橫裏兮，視撚陽而逍耳。
#
# 謠耿息兮渥騖，殤殆兮嫂賊。
#
# 傷集兮文姱，壹志兮切夕。
#
# 秉蚨用兮無樹，心噭蚨兮，谷風跳。
#
# 惶三所愍兮，捐鲇矱媞無所兮戲。
#
# 厲桂華兮不珍，何撫江兮逶德，回虙弧兮闇行，汎赴兮氣特，今馳兮先醇。
# 殦人光不愍蕙
# ----
# iter 13500, loss: 96.289306
# ----
#  溷而抑夏兮，各不思道之祖期。
#
# 歌兮歸而徠之角。
#
# 食流好兮擁娭，愁邑兮而不來。
#
# 不哀雲靈結之發兮，思切焉以不冥；
#
# 云道競紛以馳雜兮，神志忽儼而度敗。
#
# 心車路高安陳兮，孰迷咸不自雲也。
#
# 何變皇兮不好兮，吾德得舒徂好與；
#
# 獨將南曰：「十六人之不雖吾為悲不得年而不當。
#
# 時有疾以寄別兮，遠紉披人其所忠？
#
# 私兩穆之弊e兮，浮古夫干榮兮心好。
#
# 悲具木而御端兮，西上節余白差而彌心。
#
# 余余身而
# ----
# iter 13600, loss: 97.127941
# ----
#  下鞭，志女女紛？
#
# 雲與寤使諂聊娛兮，載予子以當；
#
# 《雪衣兮相堂。
#
# 董君兮使疏課。
#
# 長續兮酌臊，述浴以兮中善。
#
# 余夫瓊斟兮蜿芝，使幃娀兮如傷。
#
# 暾令吾從悲兮？而可疑。
#
# 靈水成兮周中。
#
# 攄衒兮列昧，其光加？
#
# 藟追海兮來如馳。
#
# 皇榘詢兮積中。
#
# 文榮康兮列離，類蔽差兮再文。
#
# 九飛遊兮為後，！逍降兮以取逝。
#
# 搴風荔兮水安之悠也。
#
# 哀與車兮在服，列北豐兮盤和。
#
# 玄襜大兮其憂！。
#
# ----
# iter 13700, loss: 96.630589
# ----
#
# 初九為何雖迷而浩十也。
#
# 何初岐峨坑，使與石夢
#
# 陽勤妖九湲，怨安求人無心安湯？
#
#  ：何不歸明！
#
# 公何䰟之罻實，來翳死居枝，得低成兮，無至徙鬋而怵魚。
#
# 澗至龍！天所禹之所？
#
# 天何蒙漠？
#
#
# 投小《墀飽。，宜后則施？
#
# 堯人
#
# 惜嚴殤繹穆天會擗喜見謝焉為厥君
#
# 世三利陽損，得陞人君而自接。
#
# 輬眾九巒革，其年紉何蜺？
#
# 何籹翼翔，卜燭焉九雨。
#
# 旻「屋熹，言罔以河？
#
# 汀沓體圃，鴟翱操之？
# ----
# iter 13800, loss: 96.590363
# ----
#  枝兮，微不山而幽與。
#
# 悲棄中之相若兮而長，路靈遙兮，桂華身御而貪處兮，證下而欷極；
#
# 芳悲人之長媛兮，宋冤椒而上可冥。
#
# 老鬱制以來揚！，目乃皎蹀乎不容，懼何南遊兮，將徙庫狂若寖？
#
# 爭藑屠於借媛兮，猨所而釋翔。。
#
# 糾兆節注盛往俗而歸樹《為側兮，何陸寵之？
#
# 夕湍幼以楚行兮，周飛帝而容子。
#
#
# 赴反莫而不處兮，來王尚以為吾翔；
#
#
#
# 蔽法孟以不高兮，無隨絕於致靡兮東時原九故而有終；
#
# 紅念醢
# ----
# iter 13900, loss: 96.458739
# ----
#  蟀杳以發兮，宗悔衍㠯愁之；
#
# 吾罔嶓危之聊世兮，徑古而自撥。
#
# 堂人澤紛流地兮，中夷抑而不道。
#
# 子與迅雜之典枹兮，遭揚子以射徾。
#
# 所心晦涕其舊材姱兮，浮容以與辭。
#
# 哀余以位抒兮，援華大知。
#
# 文運諫而修昭兮，何南眾而自亂。
#
# 運不隱離直兮，心制度而悲。
#
# 亂焭若兮，哀之盈干。
#
#
#
# 衆勝鳥深西疏兮，羌余余不洲！
#
# 擥屈墨之娛舉兮，造夏此太貴。
#
# 擥回虛泣拂儲兮，衍此士兮，竚施！
#
# 后暗郢明
# ----
# iter 14000, loss: 95.986807
# ----
#  先氣離幽之令先瑾。
#
# 民人產而不能羅兮，蹇介之高態？
#
# 佩讒以為偃辭兮，惑迅察而為鸞。
#
# 播下高之流遙，成霤薄兮，嫫濫見而不可膚。
#
# 桂鳥怳而萃淵兮，椒鑿懷於先羞。
#
# 乘閔蘇之而皎兮，谷煩至！
#
# 青衍人兮不獨，其鑠阯兮。
#
# 賢寤而埃亡兮，河躬嵯其含路。
#
# 忠獨山而不淹兮，羌世貴之壹乎？
#
# 壅既來而頌兮，夫逍息之所用。
#
#
#
# 增冰不門，奮羿入兮，傷安將！
#
# 蘇邅儼以嫉夜兮，察介君之所戲。
#
# 蹇子章
# ----
# iter 14100, loss: 95.391487
# ----
#  爾顧之後厲班先東，志淫怨而不動。
#
# 吸江皆美之遠褋兮，從滂殃？
#
# 歷乃夏之瀏曰：依《驚人兮，負水以遐女；
#
# 屯讒余以為泄兮，斑恆遠而成落。
#
# 朝右節來高志遵而獨明。
#
# 跼崢枘兮，歔夫白駕而得淹。
#
# 悲信雜兮醴，寤云不見兮，縹郢落兮雲醢？
#
# 入余情以表芳兮，涕銷欷而被嗟刈！
#
# 禮天息之生人兮，縣雌挐而悠漧。
#
# 霜所塞而自憂兮，德鬱其芳曠淫功。
#
# 白容前而兆之兮，獨望重為盈夜正。
#
# 忽日漠而待舉兮，蹇
# ----
# iter 14200, loss: 95.892294
# ----
#  獻臺，梗其無志些。
#
# 穆騏兮觀何投，以左方。
#
#
# 弱命皐志，學載衍兮些。
#
# 魂而澤舞，澹嬃下些。
#
# 髮縹拂躇，破回迥兮，被蒶遞鄣些。
#
# 惶坐一矣，步有虺些。
#
# 今廣齊受，玩虛輿侁瞑些。
#
# 亂枝為徙，益下諛些。
#
# 讎溘譅，而失隘些。
#
# 吳翡漸，掛於風策？些。
#
#
# 月譏決，君以梧旎。
#
# 擥彌事隱，其卬波些。
#
# 纂雄謳志，輔筮膏之騑。」
#
# 又安洋衰，道幬家加；
#
# 伯曰：「之遂棄，勤能楚飽些。
#
# 巧脄訾拇
# ----
# iter 14300, loss: 95.366768
# ----
#  而不後白，仰均豫，顧亹易只，望榘彭作些。
#
# 碅公翼而敢芳兮，鼎肺壓武茞太止？
#
# 洽知孔陵《樹，挾冰茇只，余高君之容輔兮，駑偭約而嫂之。
#
# 伯鄂天之日，年不盛俗？
#
# 田屋淺肺，泣天懭只，心鍾將庫！章為義而䠶語兮，縞嘷焉增之墟。
#
# 覽與惻而言啾只。
#
# 欣榭邃豈，獵裁曼只，王秉央
#
# 「情煩苛嫭兮，騰神秀黿，遺駕鬤只，龍立俗之野益兮，莆嚴酡末。
#
# 願露敬而懸苦兮，睹霓睩之擊鄙。
#
# 鏗元夢而遠志兮，雜怪忽而
# ----
# iter 14400, loss: 95.086690
# ----
#  比而相烝。
#
# 淩江
#
# 保成遠而過處兮，石狖頸而短怒。
#
# 事疾九猿以兮蔓，事有以泄樂兮，封枯遺而鯀徙？
#
# 德嫫純功而不去兮，藂虞嵬而不毀。
#
# 惟懿角之無逝兮，致能晦以而禍些。
#
# 曾華年辯之足集，以乖璐兮，聽電忠而流與。
#
# 惆哉以變侖兮，翱夷陳而下肬。
#
# 哀心不正涕攝兮，有介使之何鳴。
#
# 目邅墨而有疏兮，心延峨而清耳。
#
# 玄告滔有此可失兮，此椒傺而眩後。
#
# 辭聇絕而仁變兮，涼予乎射相虛。
#
# 吟賜遠之抉
# ----
# iter 14500, loss: 95.052227
# ----
#  結輔而不惡。
#
# 皇汨仁傷之無鍾兮，東余吾以自能。
#
# 高馬夫人洲兮衰，衝曲躍乎蕪宜。
#
# 哀高湘之危雲兮，忽始霧而不嘉。
#
# 皇太滔
#
# 嶔闢蒪而成雲兮，偏椒士以徘潭？
#
# 聽櫺缺之忽裳兮，長卑與而能度。
#
# 蛟雌顓而逮前兮，固鬱生而就榛。
#
# 遭臣C玩湘帝兮，容知自游兮相能。
#
# 欲伸懲而不盛兮，雖下桃戶之往薄。
#
# 存凌夢兮猶忌，鸞鬼疾以駿籠兮，心惻多而舉錯。
#
# 駕霧悵而不意兮，比枉沸之委咍。
#
# 欿躊飫兮鼓征，
# ----
# iter 14600, loss: 94.463728
# ----
#  兮，恐余身而遠索。
#
# 屈操與賜飯永，古以素流兮，秋烈燿以王時；
#
# 雌切羣以狐婪，以鏗淮兮，卒身。
#
# 矩狀蒸兮照上，累或聞息。」
#
#
# 敦泠摧亹以正圃兮，選眇遠路之沮。
#
# 丘台雀面歎靈堂？
#
# 皇佳忽兮慘秀，太人之可朋憂。
#
# 亦屣年而度，過顏兮，安父於不操。
#
# 時坂茇於㴉嘗已無抑兮，大隕聊而自溺。
#
# 憎頓苦融而不悒兮，後晻醢其不所芳。
#
# 鉛秣澧黨兮，靡闕素驚而不處。
#
#
#
# 寥兮歸來之白羨兮玄淵。
#
# 薄
# ----
# iter 14700, loss: 94.207284
# ----
#  諂香而末置。
#
# 橘瀉之有䌌林兮，迷波日其遠默功。
#
# 曜然兮噍喈，同順菽友兮，鉤繩，讒以俗兮，姿無德之底辰。
#
# 筐鱗埃而復蘊兮，俗不顧而罔置。
#
# 背去湯以居波兮，路之侘長而曲蕩。
#
# 周回點於起淵些。
#
#
# 及氣身以思應只，使指怒而不可度？
#
# 雷悼波於皓離兮，掩申車而猶饑。
#
# 周失盼人之在條兮，行無知於眾池。
# 顧靈始情人無娛信兮，折吸波以微阯，川路兮吉谷，神玄草兮臣雲。
#
# 玄發火而日進兮，孰怊盡而人鳴。
# ----
# iter 14800, loss: 94.096085
# ----
#  ，同吾楚死畛。
#
# 旌不皓之孟蒸兮，娛冉倥而娟之。
#
# 卒慨霓以啟峨》，往郢霧其日章兮，使霓圃不可塺。
#
# 行車申無清端兮，握傽讐兮自愁。
#
#  歎兮廢依轇邦迻真脩。
#
# 戲騷》兮為高觀。
#
# 三俊
#
# 忠悲
#
# 潛河湛兮不湘傷。
#
# 天千浦兮遠君。
#
# 皆舫兮而望泣。
#
# 圜驢人之清柴兮，鴻余枝之盛糾。
#
# 雌貫澒漧深亡兮，聊泠滂而殛君！
#
# 藂天思余策兮食。
#
# 鳳摽變而平粻兮，遂不鶴於舒當。
#
# 無鴈摽而修閭兮，昭瑤傺而
# ----
# iter 14900, loss: 93.902801
# ----
#
# 雖鄒憐兮不皇之所得。
#
# 覽人之翼南誰羅兮，汎邵余於墆繆兮，耘壈琰之戃貺。
#
# 思荼兮炳徙，此清駕兮邠蠆。
#
# 獨咸兮以遐當。
#
# 迻離度兮九低。
#
# 昏彭兮高躬，邠時兮沛悒，秉周兮永杜。
#
# 世皇兮上中，才琴俗兮廩吟。
#
# 魂天闚兮屈忘命
#
# 悼離兮濫狐，螂言兮，睹月兮營弗。
#
# 妬浦兮困跳而無告。
#
# 哀余兮江　，孔策兮殊王篇。
#
# 陰埃郢兮枯謂辱。
#
# 哀蘭兮欣宴，永王兮專分。
#
# 平雨心句九畔，不漿濫兮愁》。
#
#
# ----
# iter 15000, loss: 93.678845
# ----
#  為衣兮期中
#
# 恐吉邅兮，使蠢老兮之舊，出安白幼之不初。
#
# 鳥日月之鞿昔兮，後暮之獨蛇。
#
# 叔浮虞而弗制兮，猶聲附此脩鬱！
#
# 昔士之何扳兮，證不媮有脩為用白？
#
# 聞蕙兮巖圖
#
# 豺：子棄以為臯兮，哀生作永脩脩之？
#
# 鬱蹇脩說為徂逸、《二年混漁而卒後，惜何哀乎先檻。
#
# 靈與窘驚冥明兮常曰，前以江求之也。
#
# 路鄣既長以章所兮，
#
# 如提：
# 誰使殀揆若定兮，聊披是而干道。
#
# 固雷車足九直兮，頷吾思之逢予？
#
#
# ----
# iter 15100, loss: 94.461016
# ----
#  兮蕭墬。
#
# 覽騁劍兮正古，聽太人兮無合。
#
# 蘭遵若鄉兮翼埃，可採瑟兮滃蔓涊，心後傷兮寤將。
#
# 云玉聖稷之己尤兮，終以可得。
#
# 將顧身兮困昏。
#
# 中婓服易事之南滅兮，忌欲死之不得；
#
# 溷理兮上命，夕仿荔兮東讒，使云菲兮自極；
#
# 余蹇咸之廢來兮，蜷愁世之充攘；；
#
# 皇生馬兮未中。
#
# 搴法郢兮延考，熊敷堂兮疑》。
#
# 美長鬱兮出舞，獨以未度。
# 時子節兮水逝，吳沅險兮實冤之心邈也？
#
# 與飛舟兮e來，覆吉虧兮
# ----
# iter 15200, loss: 93.947710
# ----
#  何緣饗但
#
# 何百材廡益貽河，夫無歷為夫厥固何獻所蠥？
#
# 何焉從龍處，璇榛。
#
# 食北齊處乎味，夕余康流？
#
# 聾羿孟積寢次，得原除，恣邪長校縶？天何莫何。
#
#
# 被不拘勞余果所羿。
#
# 魂鳥幾歸游，襲喪轡兮轔母，僕誰墳之姱棄？
#
# 何以吹冀，五淖歌先砥。」
#
#
#
#
# 斡患往陽清，夫凌魚石盤穿二惜山到
#
#
# 何弭曰：
#
# 撰良廱城，顧靈如、？
# 章朴定龍流，商以害原，雲薜采兮，悉傳怨而何御，夏冥陽豈壽以楚？
#
# ----
# iter 15300, loss: 93.915044
# ----
#
# 知樂曰而承臺兮，遭處加而壹裳。
#
# 久
# 作故茞俱而見敖兮，蹇侖乎此誰帝；
#
# 辟怨九
#
# 要高以之玉風兮，遂晻，脩髮何兮？悠
#
# 舊荔於上門兮，往貞荔而不純。
#
# 于刀生之可敗兮，忽云閉而不假？
#
# 賢揚何國兮九終，以遠兮之通。
#
# 荊使齒以上自兮，白不達乎采緒憺。
#
# 湘吾流白誰門兮，南容矢而奮夢兮。
#
# 處人裒晦今而自言，之彼斛而莘惟兮，重用飛而蔽尤。
#
# 例畏林兮，惟徘榮而不得兮，綴者輔嶷。
#
# 撫山聖而東生兮
# ----
# iter 15400, loss: 93.862844
# ----
#  思以遠所？
#
# 願嶓沸之媒婉兮魂，微昧其將調。
#
# 願四佳兮，操嫫上所示。
#
# 懷欲能理清兮，洞欷之平釋。
#
# 進人之任殃兮，思何恙。
#
# 雄卓綺而何室兮，凌吾知其北名？
#
# 寧北省以遠善兮，臨知舜而聞瓊。
#
# 芳曼兮浩斲，聊彼梁兮板沓。
#
# 望重竚以行。
#
# 及鳳不能多兮，日鬱君而告之？
#
# 菌余君兮物，庸捐哲。
#
# 突瓥公其江得兮，紛所情而清無。
#
# 闇椉兮犬，湘時必交兮弼糧。
#
# 固陸臣進誠疑通兮，造椒淪之蕭穢。
#
#
# ----
# iter 15500, loss: 93.398942
# ----
#  所徙只，出輕葉兮，歸轔心為清。
#
# 山憯皓蒼持畝兮，鬱縣嗟而縫鎮。
#
# 鳥皓驗之母瀛兮，施子杳之苟未。
#
# 不見深兮，陽芳槩而有橫。
#
# 曰玉鈞悁其日兮，高可梁汰。
#
# 心驂摧之蒼衣兮，余鬱世而鬼德。
#
# 思公後而西隕兮，願湘心此流。
#
# 藐游天之遠，
# 余日飾，發參省之所
#
# 周考忠喟而宿轡兮，捐為忍人？
#
# 至有轍下，聊暇瑾而攄阨兮，流日氣而鳥道。
#
# 驂鵠進兮京渃，！
#
# 折由忼登
#
# 軫舲無登道而不司。
#
# 哀前飛而
# ----
# iter 15600, loss: 92.817000
# ----
#  台而淩乘駕此追容兮，蔽吾其何望。
#
# 栗俊談而悁悲兮，孰規徙；
#
# 寧曰：薄俾思天兮，超少至而不知。
#
# 世逝以信猶揚星兮，惜乎知吾何橫。
#
# 獨車界而思寐兮，苟容路而忘俗兮。錫
#
# 寧伯入而因予？兮見歰乎淈不成。
#
# 抑風兮涕腥。
#
# 紛
#
# 與江陽兮歸來，霓四諛兮。
#
# 太地
#
#
#
# 惟冉蛇而吹欷兮，麾捷兆而太期。
#
# 遂凌
#
# 何蕊角於悵吳臣，該並慘事兮，不繚墨以異真。
#
# 前見惟厲以有瓊。
#
# 宮官江之此辭乎？歸。
# ----
# iter 15700, loss: 93.297884
# ----
#  濁容以娛哀些。
#
# 願微九徒，新歎方所。
#
# 騏左眾芳，或憐塗些。
#
# 召既處，羌不宇關些。
#
# 畫翼木以告得些。
#
# 往歲望之沒，為生流？
#
# 魂其致放，。均往舍古一忽兮，歸來為角些。
#
# 笑莘歸來，爛隱湲些。
#
# 罔惜珮裳，地以後死而裳道。」
#
#
#
# 原六　比殷，？不歸築兮，超捐壺些。
#
# 竊王鄭踴遞，魂乎歸來！。
#
# 網何篇卜，將太衢，來！無心兮？忽七君《安方故些。
#
# 保中解之越遠，心勒當？。
#
# 寧虎異毒，心鑠
# ----
# iter 15800, loss: 92.795897
# ----
#  。
#
# 欲終銜以集禁兮，恨情而霄直。
#
# 卷伯眾濁而施與兮，好禹情而歷丘壄。
#
# 賴既風事兮齊卒，成短識之？
#
# 伏遂龍朝，膾斯陛只，步兩娀之些。
#
# 北言不死，其承信兮，眾彼牛之些。
#
# 將回九而不樂兮，真反舒其相施兮，徑雀鄭猨層。
#
# 流芙衢，春吾來，姱我寡先，流河之量專兮！何有皆未。
#
# 獨彊德之阯直兮，行離大勺膾。
#
# 歲室兮，搷焉處只際。
#
#
#
# 原回皆槁，背流賢，立二紐只，覽苟既余，橫秀鷞只，魂乎歸徠！
# ----
# iter 15900, loss: 92.497106
# ----
#  南之射轉兮，然怵熱而伐玄。
#
# 玄王阯而多兮，不江疑而俱改。
#
# 絕羣於必尻兮，遇譏未之為傷。
#
# 出玄咸其難憺兮心騷不著之泥變。
#
# 彷桃棄而不異兮，申梟君於山雲。
#
# 蔡信郭於絕兮，誠樂逢乎得情。
# 眾山兮，與佩吐其復長。
#
# 右私世之處持兮，莫皇從此呂怒。
#
# 夜營是以自樂兮，又厥之鑠慮沮。
#
# 耿思道而自嶺兮，目壅舉而雜方。
#
# 馳叔忠而知之人兮，與會恙而歸征。
# 浮寂散其孰得情之焉廣及聊所遠之。
#
# 陟三皆白與
# ----
# iter 16000, loss: 92.488892
# ----
#  生憍而自極兮，不日榘以眠汰芳。
#
# 獨駿脩之所色兮，不時水以厥渚。
#
# 哀執阻而」殃兮，窮並韋而不冥敗而不通。
#
# 弱霧炯瀛而流水兮，蔽九辜而不得。
#
# 念氣冉其莫遙兮，願獨潭而求詩。
#
# 人恢緊而論榮。
#
# 桓申翔於握曖郎。
#
# 掘申子淫余釋兮下排
#
# 獨六沙於董旗兮，欿龜愁而不通。
#
# 望唇雀於短霰兮，而禍淫之為反。
#
# 求滃潛而偃辭兮，孰朱掛與鵲諛之妖岳。
#
#
#
# 黃蜴塞而不通猒兮，指吸挑而壽毒。
#
# 吾以肩散
# ----
# iter 16100, loss: 91.931460
# ----
#
# 馳毀貴兮洛龜，吒白苦兮語林。
#
# 東玉穆以菅巍兮，聽蓉能而不戲。
#
# 握萷澤怵盍覬選兮，矣星輿叩。
#
# 亂曰：
#
# 方余木以先瀾兮，焉備波。
#
# 鬼s蜷a其風兮，爢芬余之驕脩。
#
# 騎紛兮九液而梧闕。
#
# 下。
#
# 周水色婞逝兮，霆忽晚而不去。
#
# 驥勳樹兮介，；
#
# 登八
#
# 網謬州之在姱兮。
#
#
#
# 卷寶》，
# 潔蕗使靜清猿海鼓，取向貴兮揚引莽，采娵
#
# 攝麟紛
#
# 阜砥便觜而其悲兮，孰與余之死變。
#
# 昊漢鋙而發德兮
# ----
# iter 16200, loss: 91.670069
# ----
#  何墳以我涕兮，冀秋瀛鴃之窮。
#
# 後吾靜以汨潭，鞹三極！
#
# 結阿情隱案兮，汩有遇蹇乎含喪？
#
# 踡重枝前喟濁兮，波焱廕而夷抱。
#
# 結慕鬱之舊比㠯些。
#
# 懷陸雀與瑟兮，腸遇在雜穢些。
#
# 左暮人而形風兮，紛心留而顛築。
#
# 朝純媛之服昭兮，草裳水而自意。
#
# 欲皇國之下羣兮，聊潺愜踔之改南。
#
# 仁據曰：「就將遠兮願遠。
#
# 撥靈人之若柯兮，雜子曠責與蘘隘碕游余見志引兮，建吸恕之菸悁。
#
# 驤憯紜而抉佪兮，夫日色以
# ----
# iter 16300, loss: 91.584937
# ----
#
#
# 水魁懿兮於光。
#
# 心眽束濛以黮兮，將低閎而難鬱。
#
# 逍鬱自其中兮，紆愁風為咸舊兮歎
#
# 。世
#
# 擥譬流與離九兮，過文移以量樂。
#
# 孔傅邦兮過眇而故居？
#
# 蒶噓蘭兮俊今。
#
# 卷林兮不歸言，陸無所佪韶。
#
# 覽昭憒兮逐無歎。
#
# 玄採絕兮雍歸況，曲時俗兮莽循：
#
# 時逢濁以永囿兮，長愁以登宮。
#
# 覽玉苗而薄星兮，可雌憯於太頹兮法壯靈。
#
# 使不芷容於遠曳兮，遂不黴辜而左在。
#
# 涉躬爍於道泣騷而相都兮可貞城
#
# ----
# iter 16400, loss: 91.360727
# ----
#  。
#
# 欲飛兮之沒。
#
# 遠聵兮泣慰，匍瀆澧兮茕
#
#
# 從天兮華遠，哀時
#
#
# 奉泠月兮端液。
#
# 四八兮可陳，觀。寶兮噰夷折象故並歌宇。
#
# 裳閼兮感不得。
#
# 遵芳階兮浸屨，孤空烝兮石蟤。
#
# 除悲兮愁傷。
#
# 路彼兮鬩今而聊可下？
#
# 涉此遷兮抑天之有旌。
#
# 隨當兮困彗，嶔遁兮探倫。
#
# 寧越兮延敶，杳長搴兮嵾鷂，命
#
# 獻處容糅而浮謗兮，魁煢中而顏菜兮所擁。
#
# 群倘旗兮怫桑。
#
# 及星兮名視，長患兮北俞。
#
# 翼昭下
# ----
# iter 16500, loss: 91.130954
# ----
#  唯蓉之能見，何如武兮，其承莘之從難忠之？
#
# 遵經驥之歸白兮，斗皇玉㠯如當。
#
# 登心
#
#
# 靨天曖之弗婚兮，無既捫之：「之不妒！
#
# 結曰：「怨宜云其遵思其之為。
#
# 衆昀瞀既內求兮，表讒輿之法老而鳴容。
#
#
# 飄愁忽以繼曲兮，佩壅止其焉宿隕之紆溘。
#
# 孰蛟偭之好蕩兮，令溘愁其穢殀兮並呂。
#
# 芙要貪於肺兮，將淫忽而何之。
#
# 心不咎兮鼓光，娛喜兮偽中，璇復之回》兮，載恐留其誰恐志之域。
#
# 卻誼其美自兮，馭芰，
# ----
# iter 16600, loss: 91.886346
# ----
#  微兮羊囿，蓀恙路兮泣被。
#
# 猿從湘兮嶢熒，綠我思逢兮南說，丘物兮，不冥？
#
# 梁刜湘兮湯捐，盍白州兮洧予。
#
# 時馬憺兮怞曀摯。曰：，思鬱兮江瑣，懲道兮為膏成。
#
# 揚有周兮林啞，歷朝紛兮獨思之善。
#
# 魂經崔汝樂可、兮，又所度乎素正。
#
# 舉太至兮上黕，丘眽年兮中望。
#
# 忽旹惟之好傷兮，能脩餘退之芳江；
#
# 悲楚蘭兮鏡駟重苦清慕；
#
# 令陞美而九章兮，又莫知余之中？
#
# 將行馬兮被欸，愁北悲兮容行。
#
# 嫋彼以慍
# ----
# iter 16700, loss: 91.394762
# ----
#  葺並，堯盥石輔使伴藏。
#
#
# 民在愎業，其何未南。狂光十帝辨葉被，康代歌失，h三味欷迄
#
#
# n滔夏猶，枕鴻不異兮悠咍。」
#
# 鯀谷肩衢，後留是摧。
#
# 昔不謀？
#
# 秋褒九拂，獨明而從沅。
#
# 漁何之綢，咸年方？
# 夫右磊姚
#
# 啟狄彗懸，夫何止龍震？
#
# 九夫小故？嬪群國。
#
# 何諫
#
# 長穿心嘗舉，有不改坐，與欲焉拘異芬灑？
#
# 何所鸕？
#
# 使年在無渚，扈以送社。
#
# 伯官迄歸而若彼聊方。
#
# 滔殃歌襲，鯀潺一怨。
#
#
# ----
# iter 16800, loss: 91.353056
# ----
#  射任彼寒而且天？
#
# 容失而不見兮，夫芳察兮嚮處。
#
# 孰君南其日像兮，不河之亡與矇兮，愁余人之所重兮，棄期以不諛兮，讒惡其夷苟之傺明兮長順流，
# 徐葉富先山師正兮，夕夫閔說之無憂。
#
# 愁輕怦以終在兮！，眾龍隱而疏容。
#
# 誰獸兮食盤嵯。
#
#
# 屈何小環兮，謨驢執洋必而自倡。
#
# 保三忠於置和兮父落，其有騁人兮首，
#
# 青巒陼兮，而白保嗣之御九也兮，忽別者之與知兮壽曲長離。
#
# 涕貫尸純與所在兮，殷世此復神路。
# ----
# iter 16900, loss: 91.280671
# ----
#
#
# 虛嫌鑠釣轍兮，亦牛梁之？
#
# 折茲猶以無情兮，超生古而何之。
#
# 我吾馬日兮，傾動翔。
#
# 欲直之不娭。
#
# 人諫之信，靈世容，以翱翔兮，
#
# 聞夫數釋見而安在兮，睨用次而無態？
#
# 亂郢玆吾芳兮，左吾身明將難揚
#
# 白逐必悽水兮，蹇土遠而不閭。
#
# 長州黨愍謇兮，汜樂莫宜；
#
# 申與哀其厥神兮。
#
# 四遷遊，用離霖兮，歲有能紛以蘭芳。
#
# 皇未沙而揚日兮，夫獨節與而離則。
#
# 徑強其盈落兮，網周颯之豐聞。
#
# 西命之
# ----
# iter 17000, loss: 90.897131
# ----
#  質之不可知！
#
# 故石以棲其道乎東？。
#
# 南冥積而不滿歎兮，荼裳以不見；
#
# 寧重位之吉弛兮，神君涕而結及！
#
# 羌為屋之抽浸兮，乃反晦之不當。
#
# 傾隱年之無懷兮，鴟春所先之所居。
#
# 伯騷也之吾佩？
#
# 用氣愁之此強兮，雲蛟眇以從實。
#
# 或白息而結娛兮，吾可夫駕寧此！
#
# 心飲椉鬵兮作，殷下謂之純歸。
#
# 檮被然弗驟身兮，謹發邈而不踸。
#
# 願天路之無驂兮，傷少抑之所愁。
#
# 將傷見之所疏兮，聊發嬪以詒詒。
#
# 舒
# ----
# iter 17100, loss: 90.332732
# ----
#  心埃菀尤兮。
#
# 曰：明不盡地兮，絕泭襲安。
#
# 不形蛇以自憐兮，歲歸雲而不征。
#
# 佩玄桂寂吠兮，志，房干累。
#
# 五君陽而抽閽兮汩迷此觀志其不哀。
#
# 秋子祐而有昭兮，微畫而不張；
#
# 欺大一此辭慎兮，原不知其不衣。
#
# 船若流游而掌曾兮。」
#
#
#
# 篇名不憐昔何所所之。
#
# 白子鯬七知兮，陽禍而不可氣。
#
# 召告夏之以修聽。
#
# 瑤合蕩而敶原兮，濁君猶不可用。
#
# 攝熲
#
# 愁眇流國兮雲醒只。
# 君驥日離，此所望美之
# ----
# iter 17200, loss: 90.824579
# ----
#  足姣之莫，拔家華些。
#
# 室九眾，以微露兮，鵜旦察？流賢兮後夫錯鄉！
#
# 滔齊姣之裳，張坈納些。
#
# 哀華來而歸來？！
#
#
# 登閒竝之多淵萋。
#
# 靚俗之盛緩，心珍追些。
#
# 載廈，伏沒益之？
#
# 世國馳以華構些。
#
# 不蘭可行師；
#
# 俗舜溘必徙，委太歠顥些。
#
# 夜序者，誘回沙，上諒語狂些。
#
# 握幽綺亦，汨態壺些。
#
# 《運尚歲，鰅恣溢些。
#
#
#
# 或轉洲泠迪，盛都雨動？
#
# 望顧方以萬生，戶睹閉兮近軑之鮮鶬功，伯以
# ----
# iter 17300, loss: 90.321235
# ----
#  兮，甲無鳥英。
# ！伯遠以志雞矱兮，還余首路之溷華之際免謰只。
#
# 羌太息兮，長涫晻而鬼遊。
#
# 洞顧涌而曶馳兮，願彼短被，遺飆成只。
#
# 哀吾翠馮韻！
#
# 歠抱德，嚴大戒之，旋車代只，姱芳蠹修只。
#
# 卷出民戒，揖褭可幽治兮，歎酸溶椒而偃虞。
#
# 執佳旗之增恩兮，子芒眾以典程些。
#
# 容地不群兮，鼁拔峨而殽。
#
# 原致幽而所囿兮，況君倚而歰和。
#
# 高南藹之登陽兮，因鷫壄而或莽。
#
# 惟禮帝　舉義以虺高兮，原固側，衡
# ----
# iter 17400, loss: 89.998715
# ----
#  而變寒。
#
# 處深礫以從洋兮，鯀南歸而含佇。
#
#
#
# 歎方有不可起兮，駕集吾而不庭。
# 觀梧鄭喬而璧兮，孰掩忠周其將牛。
#
# 吳撥驚而饗兮，方可必失纚？初沙：
#
# 哀其子路之蕙軀兮，駟芷聚而俾石兮士不夜。
#
# 山騁　藥固安文兮，竊風焭之遺杜。
#
# 有高天之憂湯文兮書不濁，而無舉。
#
# 禹九德而顧純命兮，蟋隳：而下忠。
#
# 趾何子兮冥寧之放。
#
# 惜高正遊
#
# 終改昧而不及兮，遭安離乎周下。
#
# 圖外去以以繚兮，羌憂華衡
# ----
# iter 17500, loss: 89.992252
# ----
#  藏。
#
# 屯庫惡之夷己兮，鳳揚儃和而曼糗？
#
# 參富兒而離羆兮，崦虎鶴之屬詩。
#
# 皇啾伏而幽行兮，年余毒而遠乎？。
#
#
#
# 切舜之櫺芷，而掩私兮，陳古彌其此西再？
#
# 飛赤死而不察兮，有涫睢之周賅！
#
# 駕草占之休嶺兮，豈申臨鳴而相臧。
#
# 哀獨戚之無同兮，迎伸流而難藏。
#
# 浮以素中己離兮，
# 魂江悵而不聲兮，又杳忍而不昭；
#
#
#
# 聖日
#
# 朱菀采成於汝。
#
# 願晉縛以蔎蠡兮，蹇杼江而難長。
#
# 援日騷而不他兮，
# ----
# iter 17600, loss: 89.433870
# ----
#  鱣娵車留之墟？
#
# 揚竦南曰道乎庶！。
#
# 抽州》首》，人南集，鳳節夫此椉用人。
#
# 蹇冒人以毀泣蠆，澤舒子兮卷，
#
# 悲遠駕兮紛引，矢駝相為兮懤，云。
#
# 辭亂女則之混曠濫宴。
#
# 舉獨遞在心兮，得精虹以從婪下兮，施石之余之道愆？
#
# 妻視矰漢崎，鳳愁遠余帝邑容。
#
# 閔宣漠兮安雲與。
#
# 莎夷焉之玉虜兮，遂貞結而獨食反。
#
# 願庫歈而有蕊兮，壽反道而屏。。
#
# 閔怦兮龍累圉，魚麟往兮從亡丘。
#
# 懷州兮廣昏，奄暮蕙兮
# ----
# iter 17700, loss: 89.199445
# ----
#  易而高蔽。
#
# 雪爢兮峨殃，悲莫眇兮為得行。
#
# 薄岱野罔讓盈裳兮，中瑤鬱之耿濯。舊明戒兮上自溢，聊余媮兮高辨，
#
# 雄瑾以求靈兮，孰可將世錯！
#
# 欲思入而離鞹兮，孰切翔其悠松。
#
# 同閭侯儲日端兮，調精秋而仰沈！
#
# 采驢舜於上孟兮，欲子未蕪以猛縱。
#
# 年六
#
# 北天厲多忽兮，願埃繩與紛何睨些。
#
# 余皇心臣而周兮，哀申揚其流鬱。
#
# 師清從以日騁兮，去繇淵之晏帥。
#
# 太息以賢辭兮，雲芳蓬眇何革。
#
# 見直懿而下
# ----
# iter 17800, loss: 89.134667
# ----
#  回囿，奸諛海兮愁周離。
#
# 操農龍襲折廇兮，汎澒嶽於低兮，魂淫墨於失轅。
#
# 身推迻而左九。
#
# 遵霜五其西信。
#
# 傷雌黨兮終以通。
#
# 白旌廣之襜顠兮，超辱嗣而南期。
#
# 懭欲荼其家提兮，雨瓊驪其有騰說兮。
#
# 明忽既俾御兮遠蹇而志操兮並流。
#
# 五玄涌於誓靈兮，遂撚裂欷以從。
#
# 哀睨朕草船之轉兮，升草矢悵之佚。。
#
# 卷伯
#
# 深覽郢而無正兮，願須揭於睠漫。
#
# 乘六游兮木堅楚。
#
# 衆強鄉以徑敷，讒流往猶以為轡處
# ----
# iter 17900, loss: 88.903491
# ----
#  臇。第十駕兮尋志以漫璣。
#
# 菎朕蜴而千蠽兮，事吾所順。
#
#
#
# 步采庭》兮我文，悼靈兮遠谷。
#
# 譬華追粹兮，蓬蹊吮不散，蓀忘兮游京，女名兮既明。
#
# 章虺兮崟昏，眾樂兮挾洌。
#
# 含德兮又征。
#
# 違七兮九旁。
#
# 驚樂兮觸峨，駢織兮終極。
#
# 雄蛆兮自辱。
#
# 顧流兮無鞠，未差兮陽滄。
#
# 靈若兮難詒，孰三差而丈隩兮，悲索麾。」
#
#
#
#
# 荃回世兮謇》兮，翱者之榛備兮。
#
# 留余煢
#
# 騎桓蜺狹延礚運兮，興晻茫之
# ----
# iter 18000, loss: 88.685283
# ----
#  歎江之不可以離。兮，陳人菲水哉日土。
#
# 鸞在鳥何糅之樹菊。
#
# 上鯀惟維而疏，；
# 索怨湛以不至兮：，
#
# 霰涔眇與玄洞馳兮。
#
#
#
# 天結蕙之徵辭，賢來及之往里安猶，畏見神於邅辭。
#
# 緣木余之回度兮，百矯勳蔽此長；
#
# 駕草軑以玉淵兮，躬蓉愁與圉吐？
#
# 還蘭兮增毒，登忠兮如中。
#
# 覽功退以為信兮，魂而終之。
#
# 名霑暾我芳兮，中遵取以為我路；
#
# 思三玆今年而不可時，離之傺！
#
# 此文發誠以離兮，卷幕，　馳若
# ----
# iter 18100, loss: 89.389830
# ----
#  居此蹇兮，奏闒歲之繩路㠯余充？
#
# 葉荒月兮水求；
#
#
#
# 指喪之不耳兮，芳蕙壛以睨佩。
#
# 周方既惟若亡兮，鳳身得所彌；
#
# 愜折涕兮青詔民留，尚信䠶兮吹里，與波憺兮獨望。
#
# 行咸兮瑩竢，；
#
# 師連桓兮中慨？
#
# 揭氛龍草臛之兮，臨二敗而日賢。
#
# 和察兮寤，鹿亂猴兮為自奠；
#
# 及令直湍無曲兮，未察洲而好情。
#
# 伯既款兮，時棄蘇乎無女。
#
# 雖時紛兮此漫涕兮，惟猶俗。
#
# 離戲兮眇熒，涕瞵黮兮凌陽傺，與桂異兮
# ----
# iter 18200, loss: 88.924961
# ----
#  繫，何原流豈心辨？
#
#
#
# 狀有墮，泣陂墮，千遵叢堂然，章傷何？
#
# 經皇歸
#
# 未侍如李刃九傅遊。
#
# 思戒在釋。，有者上行，秉若庭陽？
# 陰若玆到，桂原縎回駝鬿九廱。
#
# 房瞻荔在壽余，夫不叶久些，孰南逝之些。
#
# 美蜴濁侘滿從，堂怒有勤些。
#
# 白芭生路焉所二，悲夫安所親？
#
# 厥鯀厥逢先。
#
# 春青類紛周焉？何若人之不見結滂華？
#
# 明事嘉《從欲端褒。
#
# 纂劍撰之歸明，得彼鱞蛇暨。
#
# 十原抒何聲於安焉？
#
# 啟
# ----
# iter 18300, loss: 88.920507
# ----
#  受著生以宮兮，新私諛以與寒之別兮薄，鵾菹僑兮，盛精路而蔽夏之？
#
#
# 晉縣忽而所邪兮，閎但魚之紆充兮沈眩。
#
# 車高日兮上駟欿脩，以野啟薄兮獨天，情不知弗，蜂象櫋兮南日驪。
#
# 吳青處以繚淚兮，憚音今而悲心憂。
#
# 留岌日之擁昏兮，流行懷。
#
# 綠道永其怒兮，獨醉而玉與。
#
# 流俊軔於相石兮，訊葉憺載鬼星。
#
# 慕月兮閽竚，願罔傺兮北君高女蕭釋聞？
#
# 處八兮干犬，士原浟兮憐，曾鑿得淫薇羣局兮，願聽與吾以得。
#
#
# ----
# iter 18400, loss: 88.856482
# ----
#  ，遠雲之華北？
#
# 曾畢莫而自思兮，眾心墨之難。
#
# 願踵化之無罷兮，知登患而不開。
#
# 紛萎弭兮，上甂威思成兮，君與馮傺多暖。
#
# 憍情兮我容，為望位兮楚。
#
# 知君微慘廟」。
#
#
# 乃前合夏之以在行章之謳歌兮，明為壹至乎故折。
#
# 曰：「朝回歎《下流湲陳，自愍兮，陷汙而日患。
#
# 懷神保離知以騁釋兮，詔聲謂之之佩。
#
# 舉樂於遠驅兮，瞽德為芳明！
#
# 獨從難不行兮，雞僻勃高沖。
#
# 紛江s庫枯電，陞熊流之憂謇兮，江
# ----
# iter 18500, loss: 88.511189
# ----
#  兮，風駭之不可辭。
#
# 蛟龍穴以增氣兮，觀南索之茇唐。
#
# 橐罔兮，哀知其焉明。
#
# 抑豹之北移，涕淫淪兮，精溶與而日則兮，惑淫洶以空進。
#
# 多都古而從余兮，嫫波繚薄兮，心至逍之多志也。
#
# 何壁命
# 獨嶷異兮，居和德乎相正。
#
# 願慕人而遼容兮，藜虹，辛以同瑱。
#
# 深真翔之異處兮，文魚氣與徑醴？
#
# 上卬處濁而蔽之曀兮，波曲竊之亡亡。
#
# 波足以放開止兮，日能辟而不霰。
#
# 愁若夏以慙鳥兮，知逍遙而不彊！？
#
# 憍
# ----
# iter 18600, loss: 87.964873
# ----
#  潺累兮，勢君，使敞翼而不頹兮，長為得容以自倡。
#
# 忽羽焉志？
#
# 采徂而汨宇兮，志離鬱而遺霠。
#
# 欲眾而皇時世兮，上忽攘
#
# 我白葉而信河兮，竊荃君其以為為。
#
# 外氾黮於就存兮，少可余之延迻。
#
# 覽執軫師以故修，獨吾白。
#
# 絕蜺訥，哀吾離謗。
#
# 擥酎心其榮德兮，憐與風之改錯乎？
#
# 同霧謝古而與樂兮，沛浮人而不息。
#
# 兩既惑兮，淹素而無與。
#
# 卻及亡而不豫兮，好離以其弗側。
#
# 何驪玉兮襲離。
#
# 滿湲人兮
# ----
# iter 18700, loss: 88.443664
# ----
#  九無所璐。
# 心假軫曼，圓慄兮，蒼神陽之纚慄。
#
# 傷大華，屈緜人之抗雲堂。
#
# 鍾麒湲而流星？
#
#
#
# 經莫乃自淹遠以些悠。
#
# 路愉政，遺玉娭兮為曼鬼遑，罾何為殀些。
#
# 駑組黨德，軫琰亹里蜮。皇兮緹只，同飛餧之釋蜥。
#
# 余隱曰：「志忽兮，不黯蒙稽。逸卷卷，陳土從時，徠從立擇麚。吁閭龜反，水不結些，。指所居些。
#
# 魂獻子媮，刻麒揳些。
#
# 連庸兮，憚江生而淋傷。
#
# 山冥疾之未樂。
#
# 入目壹文，弗悒盍之療兵
# ----
# iter 18800, loss: 87.909848
# ----
#
# 陽浩餌於不龜兮，齊皇眾神而備泉？
#
# 覽赤戚而離忽兮，夕不央咸而上居。
#
# 玄文眾雀而宿鬱兮，豈毀信而右庭。
#
# 屈山皇號俗兮，齊干審而或帛。
#
# 襲忽杳白閒兮弭起只，除餐連方兮，阜弧楸而交曜兮，江公皇其淹服。
#
# 握升居與皆瓊亡，其滂營兮，弗沅神於六辭，其嘉明兮，長切肥而心善。
#
# 吾衣風，召非墜兮，蹇申責艷馳諤。
#
# 卷鬱冉父之耿諫兮，甲遠家之躊諤。
#
# 青因於況肆行。
#
#
# 指彭世之縣戲兮，迷眾移生阻。
#
#
# ----
# iter 18900, loss: 87.566797
# ----
#  無射兮，然車武智。
#
# 孰王姬之未化，恐可煩兮，虧華群峉。
#
# 魂兮忘歸，！精舒以上闇兮，孰日芳乎此雲指。
#
# 冰怳附之忘全兮，靈節道之遠舞。
#
# 合世號於俱俗頸，不往險之如利。
#
# 思明大而懷解兮，屬公忠而不張。
#
# 竊汨辟以成絕兮，雜雌倕而揚憂。
#
# 五小軨而獨義兮，海未可以塵夭。
#
# 正皇飛以介至兮，藂嚅傺而旋藏。」
#
# 然光隱以煢其兮，泣溶台而有翔。
#
# 悲說氣不救兮，又八索之不還。
#
# 桂太弟而不恃兮，今正身
# ----
# iter 19000, loss: 87.608886
# ----
#  翾東，朋白藝莞往乎何跡。
#
# 蛟相鼈而為塵兮，今絕眇而無菜。
#
# 周告晼以㠯尺兮，雖滅菅之不足心之洶洶桃。
#
# 浩康古而來俗兮，鸞中超而震陛。
#
# 竭薜茫以若遠兮，芳辱處焉薄？
#
# 悲三
#
# 愁祗供其有歸兮，王者永愁。
#
# 眾世而不指兮，哀思若之察與；？
#
# 痛服兮下落涼。
#
# 蛟念明之純磊兮，巖非景紉之不可行兮，魂尚流而愈毒。
#
# 立和爵其周猒兮，啟不強而虎征。
#
# 運康霓之娛約兮，日漸訴以與黨說些。
#
#
#
# 號五矣
# ----
# iter 19100, loss: 87.063006
# ----
#  兮縹穴，得貝車兮北逝。
#
# 問
#
#
# 伯世老曰：
#
# 室曰：
#
# 吳珍笑而徐吉。
#
# 懷篁兮漇履，而搴霜臧兮蘭醢。
#
# 魂忼剞盈，鳥桂端兮勺李。
#
# 堯終之承兮，人曲寅乎？
#
#
#
# 哀申望之蓬噬兮，戚離梁而不隨聞？
#
# 伯顧絕龍交徊滄兮，雲玉白兮娭息，郢皇人兮與宇。
#
# 獨令己木兮，旅象與閔逝兮，心申破而不策實。
#
# 惟慮
#
# 卷載伯
#
#
# 招泱紛
#
# 乘中謂貺慕憍兮，引瑤蓉其女身？忽
#
#
# 皇屈鳳
# 抑禮而修生兮九撓。
#
#
#
# ----
# iter 19200, loss: 86.875260
# ----
#  悁而蔽表兮，求藏辛以成撫。
#
# 跪鍾鉛兮珮讙矱圈而不衍。
#
# 哀清生之泣由群兮，欲神莽與張閉。
#
# 譬孔蘭而回曜兮，觀沅湘而能若。
#
# 獨長貉而搖第兮，猶枳適而狐美。
#
# 百鍾蜿彈e，案魂兮，時隱中其干沬。
#
#
# 亂欣鳳
#
# 畦省兮可槁，飛情有把下兮歸息，遂曰：
#
# 吾余人之合遠兮，並誠陽以為薜遷；
#
# 蛟龍行而不曲兮，陳陰長邦我橫流。
#
# 欲瞀衣其無諛兮，忽身湘於曲烝。
#
# 荊杳陵於無揚兮，令赤胥之忡雨。
#
# 菀旖娛以
# ----
# iter 19300, loss: 86.937504
# ----
#  若食之些。
#
# 伯居
#
# 七崑久而不結兮，昭天茅以登存。
#
# 形高回而淹言兮，遊洧雲非南釋章兮九露
#
# 欲建雪靁砏譁黮兮，神風情其若光。
#
# 聽叩亂以鬤宇兮，未壹火於成虺。
#
# 蒯堆車欷以漸籠兮，
#
# 悲余湘兮天廉夫到攢。
#
# 懷白樂兮深然，緪聽黃㠯御合。
#
# 採鵰電之床蓉夫兮也。
#
# 悲余游兮玄好茝遺蒼英。
#
# 余馳醒余以娛濱。
#
# 山進兮中志，欲怠。
#
# 乃陳風而自朅兮，膺狖隱而淹侍兮，志康淫以交馳服兮自。
#
# 魂離憒之
# ----
# iter 19400, loss: 86.684516
# ----
#
# 獨雞瀾兮遠流。
#
# 昭夏風兮偽世，知下流兮先誦，
# 黿讓兮泥控，鶉賢墜兮靡波。
#
#
#
# 握故璧志兮北：
#
# 漂室兮遑慄，鵜馳石兮迮蜓。
#
# 江梯兮會馳，葈志兮嶢蟤。
#
# 玄鵲兮氾呴，猨鸃兮玉傷。
#
# 離州兮長悒，草林兮不礚。
#
# 從揚兮墨興，淫驕沱兮東離。
#
# 播彥矢以皓沮兮，眩梟沅辛之野驂兮，子賢蝍乎頷傷。
#
# 彼吟階齒負別兮，紆計徊於被登在。
#
# 伯暾馬兮晻悽，蝍昭兮？保「傷。
#
#
#
# 靡旻志之求兮，笑疑卷與。
# ----
# iter 19500, loss: 86.438786
# ----
#  之復乘流。
#
#
#
# 卒蘭之淑相乎之不書與釋蕩於其又是之也。
#
# 欲命顧之浮集兮，樹六弭之南穫客。
#
# 謂余
# 披貴
#
#  而大容之兮，哀余君以自霜；
#
# 皆折爭以微降兮，傾心能之延蕊；
#
# 夷將霓莫所爭乎？
#
# 不容以觸艱兮，芳傷馬之文頷鷙。
#
# 九對
#
# 余不羣脩以吉言兮，魂
#
# 時溷容兮遠章。
#
# 烏鱗以處浩兮，黃吾眇顧夫以夭下。
#
# 伏箎既煙之悽明兮，民懷此以行遊縎。
#
# 寧令揭思我？懷
#
# 漁父
#
# 二阿心不終兮，好
# ----
# iter 19600, loss: 87.120898
# ----
#  ？
#
# 懷風兮猶藳驁。
#
# 天糅余以充囿兮滃杜，未可舒兮，纖康變其吾漿。
#
# 登三
#
# 所夫汨兮安章之閒。
#
# 精風州其送離兮，脩季脩之淹行。
#
# 世圜兮而作意！
#
# 卷九　表而時之以也賈？」則娛兮，
# 吾背望兮聲比，湯家兮，鬼省此以馳之。
#
# 故年兮君之祖，與濯若水之險患！
#
# 欲靈湛兮吹饡，其鳥榘兮難中。
#
# 羌充圜兮沛擊，復公風兮並思。
#
# 車兄君兮其將兮，年與來其孤未樂。
#
# 庇江髮參華度兮，委蕩！
#
# 願離忠兮確無
# ----
# iter 19700, loss: 86.674440
# ----
#  問而何以厥也。
#
# 何皆天人，罾何不處？
#
# 願䠶翱？而不所止？
#
# 厥朕冉夫何安為？
#
# 姱逢木益志，蔽有側之壽？
#
# 西方西功，又何藏之患，五九歌
#
# 奇大久之得，歲其不閭？焉昧以西紉古？
#
# 庫秉衢臣，然㠯歸枻，涼利受兮，而蔽幾思也。
#
# 何懭溷濁姱知潺緒。
#
# 子雄賓器，何儒無所成。？
#
# 何昂后從焉作？？
# 何知故閒而不言，不獨崔疑？
#
# 昆蒼葺崟姱飛服，誦信
#
# 九既鳥鞠，安玉衍余東光？
#
# 何懷服際，北竽僉榮之
# ----
# iter 19800, loss: 86.682787
# ----
#  山余之又誰落。
#
# 右君
#
# 玄眾嚴之遺堂兮，背遙草之所東。
#
# ...
#
# 屈佩之不巖兮，又子鄉而不狐化。
#
# 逐菉蜜其揚修兮，獨隱聚而獨隕！
#
# 崑瑟兮徧騖。
#
# 夕鍾當困於余陽兮，中
# ----
# iter 31900, loss: 70.797761
# ----
#  室以為初兮，而余與心外鼓？
#
# 當有方自古。
#
# 寧題晼浦其一人兮，漱婦自而知化，而不見兮，來身玉者不凌明。
#
# 乘紛人之容聲兮，誰可鬱何為楨。
#
# 吸容以東忽，其及遠兮！
#
# 反美人之無快兮，波異遠而難化。
#
#
# 水獲自兮，故有忠而求御。
#
# 參讒慌夫心相都兮，生乎望默，何以娛為兮。
#
# 高飛而舒清敬兮，室就而長毀。
#
# 哀結不遇為度兮，羌猶未來之終薄。
#
# 精觀未筮鑠些。
#
# 娭不眇曾宋龜詳兮，旦永道而無息。
#
# 世
# ----
# iter 32000, loss: 70.750146
# ----
#  微辭兮，夏緯繽其蘭忽。
#
# 放見夜之累德兮，憑曰陽亡而不張。
#
# 吾未代，潮自國兮，乘回著而不曙。
#
# 揚望進以顯衣兮，從石曖而將女。
#
# 修冥冥冥兮後，周不橫兮，
# 幽吾而不可戲兮，
#
# 狀往而並懲兮，知吾余之方純帝？
#
# 入化千兮，限紛而無異。
#
# 閉芳之變以絕兮，繹毫懸人之不合兮。
#
# 賈靦鑠阪闐聇註兮，隨惝君之不同；
#
# 聞木夷在舊池。
#
# 步炮風而無如兮，或杳害其下懷；
#
# 內白蜺以儲誠而無災也。
#
# 醴北湍長書
# ----
# iter 32100, loss: 70.359563
# ----
#  神已而白張兮，沈伐好而蔽不；
#
# 形江皆之無人今兮歸」。
#
# 二君兮不知，；
#
# 文靜鳳
#
# 弱吾離而委風兮，顑芰失而自聊。
#
# 舉余馬兮窴之？
# 。出眾不以遠集兮，哀浮梧之願充妒？
#
# 桂黃子乎遠怒兮，讒未可喜些。
#
# 當山德兮柰上，心以糅之可釋。兮，後余然以自志兮潦食眇華之逢逞。
#
# 揚鳥鳳兮為徂，；
#
# 情守淫永予之美禁驂兮，亦壅弗知。
#
# 乃鳥朱以為化吠兮，乖悵，墳師道兮為去。
#
# 令獸伯罔之菜兮，成以呼乎而從門
# ----
# iter 32200, loss: 70.573408
# ----
#  以逶慆？靈危由脄歎首菌兮，人正惑於壄心焉復壄。
#
# 神江帝其何所為照？憂觀玉申以能湯程？。食無以媮難，馭容！
#
# 合陞危君之不可素，
#
# 愁尹眇以考虜兮，騰散移幾方。
#
# 乾師
#
# 悲憤於仲，廣連思逸避薺服水？
#
# 曰：丘滄七，
# 撰觀好廁蔽未門，無何安久？
#
# 庶闃啄，氣日臣費。寧！問說不足，異淹依入*」
#
# 采韋緜富，而得德兮，將匡憛而無丘。
#
# 結黃點於將安英兮為望中如夷申裳而叛明。
#
# 右滯
#
# 混君死而不達。
#
# ----
# iter 32300, loss: 70.085311
# ----
#  遭虎大而為迎。
#
# 凝壓鵠而毀松兮，破來江余之所方只，魂乎歸徠！尚南居只。
#
# 卷十修　出揆謝，犬以交帶，投兮詘只，琳涉君兮，撚禽雜玩水而深只，魂乎歸徠，賞畏綵只。
#
# 惟晉四十寒宜從亂，嫭隱夜兮，葛公與世而舒冰薄。
#
# 玉青鬋棘恲恲兮，有喔赩籬，覩敶火壅直降兮，烏草歌骫只。
#
# 晞舜九河，遺桂光只，華曲赩頸，何楚保只，悔晻繆決只。
#
# 空類冰鼓峨，娛山競靜只，萎以醉，，入量愴只，憂氣嬰革，坱為存只，人薄蜒䳺
# ----
# iter 32400, loss: 69.661733
# ----
#  忽而不長。
# 指多室幾些。
#
# 赴厲以復進兮，鼓玉蛇而彌章。
#
# 霜陰頌其將吾兮，石以謀御！
#
# 身申馬而潮徘徊兮，去回流於鬼陞。
#
# 淹及兮潺白，然故兮澌然，菀此神患。
#
# 騖聖以其動度兮，願陞此之長巧。
#
# 娭六骨陽心以淫些兮，眇況君之蕙賢入兮，志其漫能之？
#
# 猛h省沅余服從！
#
# 懷放臊姱以宿室兮，藜龍國而為嚴。
#
# 朴諛
#
# 將窮海而至蔎兮，孰往得穴所悲。
#
# 哀玄鳩之過積兮，尚眾男而順橫。
#
# 音聲生而節拂容，
# ----
# iter 32500, loss: 69.795715
# ----
#  宿兮，又何待若幾？
#
# 行子緜而日代兮，孰夫猶危醉食無故些。
#
# 重玉麟而日乘兮，乘衒泭而迷門。
#
# 雪肉馨帳運兮，亦至無保於為彼？
#
# 北鳩之萷隍兮，魂乎歸來！近國以其承淵。
#
# 魂世醉宿而自彊兮，將娛晻而自容。
#
# 惟郢皇之相勝兮，中誠此往冥操之艾。
#
# 廓張肇而隍傳。
#
# 溘侯告以責滯集。
#
# 玄風芷以為敗兮。
#
# 盛出師心而冀處？
#
# 魂乎歸來！反遭生之無姱兮，周哀孰之變神，道無歸椒之？方盛四騷，
# 觀娛惑藂洲。
# ----
# iter 32600, loss: 69.401797
# ----
#  關里兮形矣。
#
# 曾亹亹而檻煩蜷兮，視傅，係襲蕩兮多升？。
#
# 」屈君兮不當。
#
# 悲吾氣兮沈四。
#
# 抑次而復進兮。
#
# 御六勞兮德離，表羌思其無量首兮，託胥妃與和夷聊醢瀾兮淹波。
#
# 周激兮鬱湯，曾年路兮北思。
#
# 尹菌山而懷行兮悠處。
#
# 怨三逝兮疾方，吾知何此狂。
#
# 右時轡而授文兮，歸徠！乎飾東。
#
# 飛轡兮挾遂，永瞀兮。
#
# 載亹兮士相，。
#
# 待遂瀨於蜷怡，緩流別兮，舒新龍而遠颺；
#
# 願道子以佚纕兮，舉乎淋
# ----
# iter 32700, loss: 69.208826
# ----
#
# 當山之佚女兮，皆越周夫遠君
#
# 弋蹇兮陽淹，誰以求兮，遭悽虛而恒賢。
#
# 情息噍而抗豫兮，衡好冥而不游。
#
# 目偃石寂醉目《庭，志棄曲躋。注世陵遠文常徵帶華兮，猶波留而交冀放。
#
# 季青涕以號淵兮，遙絕流而無當。
#
# 遡高雲髡杳巖兮，乃高與流春生兮微見。懷雨閒九際則盛兮，將車歌而拏洲。
#
# 服傅嬃之紆惰兮，辭黨辛而維疑。
#
# 愁佞絕而橘陿兮，哀雪胥而含蔓止。
#
# 沈靈卓以紉息兮，忽土洲而遠藏。
#
# 事倕為之玄簏兮
# ----
# iter 32800, loss: 69.512093
# ----
#  騷自心之高施兮，超莫媒其悲兮。
#
# 時棄于以申迹兮，豈得繇以沒下。
#
# 懷崑髮之軼旄電兮漼皐，寤蛆兮占躇。
#
# 念法身之無如；
#
# 執傾情於伐風兮，述余遠芷此險兮，身溷濁而微洲。
#
# 三婁皇以流冠兮，聊假飛玩游和沱兮，聊鄢谷其有正。
#
# 欲五軌於九波，以虛摽兮，騰規風於律讓兮，欲紛波以眩忘兮，騰蝯礫俾百庭下兮，世杳德與輔國之？
#
# 奇彭咸之工至兮，併石群而取舉。
#
# 唐虞薴兮，疏均倕乎在怞。
#
# 鳳沈榘於流林兮，夷
# ----
# iter 32900, loss: 69.066516
# ----
#  淈，葈耳兮四光。
#
# 中鉛兮探友，涼桑兮璇裁。。則
#
# 卬尼兮謳纁，橘眷堂兮拊鼓。
#
# 卷迷
#
# 材白既危戈兮，裂棘袂嵾軛而咸識。
#
# 虛跛涹之可潢費兮，姱干液而簫紀。
#
# 鉅荼餓兮積諫，秉從色兮聒萊。
#
# 璋稸庚兮未起，揚慌兮荷征。
#
# 登憂兮問茲，浮雲旗兮湘飄。
#
# 欲弱載荊來兮，班貪覆於虞淵兮，橫穢颯而吳告兮，賜鶴巢棄動堂。
#
# 就馳水兮稽射，焉注兮，溘死杳使以貪兮，不合永其余是。
#
# 就往粹兮遇騖，觀我澤兮從遭
# ----
# iter 33000, loss: 68.713988
# ----
#  為余期。
#
# 望江懷以辟悽兮。
#
# 《不江》與《美章不非其釋•與其人之焉？
#
# 心為弱而欲敷揆而有純世第前蘭兮，朱憤之夫唯行。
#
# 屈隆秋疾舟以受化兮，日騰言其所也。
#
# 年前之不甚兮，屈射既羅？
#
# 安服欷之切落兮，覽余！
#
# 伏質紛之蔽陸兮，知貪靈紉余復兮傷吾辭
#
# 覽長年而不寤兮，
#
# 皇參
#
# 吾冉冉冉而契月兮，召未餌而遺偷路。
#
# 姱失參兮悴將。
#
#
#
# 計異車之外予兮，乘曲德乎增。
#
# 深嬃兮靈歌。
#
# 愁余車
# ----
# iter 33100, loss: 69.157508
# ----
#
#   》犬陸遠，竊芳行之偽脩，聊難羣兮，遙離悴兮，腸紛。
#
# 聞禹共兮九興。
#
#
# 咸余已哉我芳兮何未；
#
# 吾家列其靜行兮，援棄緯鵝於岌。
#
# 去澤皇兮上余，援梟女兮沓，。
#
#  哉！何為之沛終兮，戚未者之落汰。
#
# 吾將工色兮，蜷藳淮。
#
# 何清顧兮為逐樂。
#
# 靨春巖兮祗棟。
#
# 凌藑譖兮良疑。
#
# 孤殷遠於炎液兮，顧申易以我風；
#
# 于眽曼以掩流兮，前好幽乎㠯終屬。
#
# 椒蒙迅以為篿兮，蓋哀為車與粻。
#
# 冀有至
# ----
# iter 33200, loss: 68.889524
# ----
#  以張言兮，懷改羽此遺傷？
#
# 觀明軔而安下之定韶。
#
# 何維不傾？
#
# 東禮離浩，子周何兮？天行然。
#
# 女參在遊，何安脩之？
#
# 事欣人室，恐余冤兮，憫宜何以遠死。
#
# 何開明作釋。
#
# 何嚴安營？。
#
# 魂及失亡，多先海兮？
#
# 余信難漁，固代之釋。
#
# 纂得並用御。
#
# 有八姚文，超又別之些。
#
# 窮敷縫款，然余車兮翼壽楚。
#
# 不不鱗都，並吾道謗曾深？
#
# 哀厲作明，而承怒。
#
# 明馮守歸來！無一信，其西唯有所苦鬿人秋
# ----
# iter 33300, loss: 69.002453
# ----
#  人兮，三年美以事？
#
# 羌端天延豹兮，泣螻寵而顛古。
#
# 二柚體水而自貴兮，遵鳥：　夫所止川。
#
# 心何平而不陸兮，天與集以九只。
#
# 行不羣驥，氾禍兮，情瞀露兮，彈底。
#
# 昭安蹀而豈不知兮，皇命夫之杳能。
#
# 故古積於為子？
#
# 有萃惑然招文父
#
# 帝羿來憑發首遙，帝以驅兮，揚沈鷙而不體。
#
# 壹生兮照歸，路所桑此也？路故邦兮，鍾余以館其捷道？
#
# 貪蠹墜人兮，伏何咸之攬妒。
#
# 思道有兮，方蔽言而不長。
#
# 鳥美氛
# ----
# iter 33400, loss: 68.986507
# ----
#  何而蔽。
#
# 寧陵若命而來集兮。
#
# 山皐之款形臾，忘何往，援傳，
#
# 乘形我之周兮，楚輿之師，為飛薄兮，愁曰：「行知路；
#
# 仰乃雨歲之遠容，何弊兮，忽獨高與之所隅。
#
# 紅儵兮，名尚用乎御！
#
# 南西盛今而考不知？士流兮，三怨眾獨而改芳。
#
# 獨飾而永天兮，朝子終而浮懷？
#
# 吾信吾永本兮，後誰固而道之。
#
# 超宿而自醫兮，憚不冥而不時。
#
# 高龍夫內o兮，周中群而永歎。
#
# 微媒兮高門，禹沾波？
#
# 擥逞兮比昭。
#
# ----
# iter 33500, loss: 68.928484
# ----
#  美以自旗。
#
# 獨惟德之人，其不變兮，世孰察以為洲。
#
# 物介聖之不羣兮，蓋青爵而自頹兮三兵傷悲子淵邦之好適。上悲俗兮蕙促，蘅輪兮順摧。
#
# 從蘭相成出兮，北湘夫夫莫所馳
#
# 屈心俊忠而回望兮，雜當龍於騫唐。
#
# 秋號塗徒更寒兮，且直伯而遙與。
#
# 悲氣車兮容舊，遽鱗期兮，思君傷以相懼兮止，下隱章士楚？
#
# 接鳥容其無光兮，或犯楹而不容。
#
# 眾風至以水江遊兮，超惘而不忘。
#
# 紉鸞飾以放睨兮，陳美而可以。
#
# 蛟三
# ----
# iter 33600, loss: 68.567070
# ----
#  去以偽進！
#
# 素門黃首容有兮，不叶廉之之繩？
#
# 既糈義而逍涕兮，聽何乎索進仙臾兮。
#
# 撫固靈雲兮，竊然親土。
#
# 遷私兮太差，過誰伏而不指兮，木要徨而從望。
#
# 軒僉九魄夜兮，惟皇差而悠巖。
#
#
#
# 哀自思兮迷波，夕華無所遺。
#
# 右十陽之蘋辭，命其不行。
#
# 蹇余別兮多貧。
#
# 桂罪以雜武兮，欲驤虞遲。
#
# 惟幼入以自居兮，遭彌散而久生。
#
# 惡身騁猶御，受來兮，不知知其知今固之遺心。
#
# 哀波必遠中兮，況霏妃
# ----
# iter 33700, loss: 68.752198
# ----
#  諫而下高兮，竊壹子之托辰反。
#
# 願從纕以送像乎形比居安知，步何藏之清娭。
#
# 極年虺言而可救兮，聊庚死而顧徑。
#
# 旋堆木曃其肥，事鶩明堂些。
#
# 擥豹皓儒拂曲，美明告些？
#
# 將成歸，心不忠乎西傷。
#
# 賴青為之玄革，如竹理散兮，汎新水其邪零。
#
# 投志而難歸行。流謂兮，雞溘往而委差。
#
# 浮雲室，目賢刑安乎？下羣飛而弗寐兮，窺源雞些。
#
# 田䠶，楫習頌，；自差，冠摯褊城而慕明。
#
# 伯二對舉，命之變吾不終兮，哀
# ----
# iter 33800, loss: 68.312458
# ----
#  獵。廬只兮，隨欲軑之濁。
#
# 思執宋，奏陸娛只。
#
# 江女何以笑些。
#
# 穀利之申，遇尻只只，魂乎歸來！
#
#
# 。魂
#
# 季著要湯，於襲宜只，德居蛇些。
#
# 往版陳習棄。
#
# 魂魄來浮墜廣賦只，，冒交悶余兮，超沆瀣以矇樹些。
#
# 緣溶雀云又堂見只，吳返蜿嵬，翔昇丘只。《魂樂澤，萃子嬋只，鳥圭拂些，以日月只，迫塗以頸所侍只，嫮至必玉圃，望水若兮，誅慌汰蕙吾若；。
#
# 牙自谷蕙，御質盈棲只，大侯只，，賞席葬於魂。
#
#
# ----
# iter 33900, loss: 67.818161
# ----
#  黎兮來傷！
#
# 憯悽宗以環既眼草漁寧楚岐舊，以諛死而日濟。
#
# 路忠出之形態兮，宿咎繇而取其！
#
# 故俗潔於周流兮，孰諛沒而不可代。
#
# 願入揚兮，瞀清胥而果首。
#
# 覆氣言干而惟萹。
#
# 發廣漠而願頹兮，忌畢辱而不浪。
#
# 當翼今而弗疑兮孰將衰。
#
# 秋諛與其直群家兮，來首深下。
#
# 江湘夫眾戚之可祿兮，眾公惟其莫正。
#
# 歷毀樂而俱清兮，夕芷媮而日集。
#
# 佩際媞諫而日隅兮，摧涫游而昏之。
#
# 魂兮歸來乎窺苦些。
#
#
# ----
# iter 34000, loss: 67.974448
# ----
#
#
# 光不及與號意兮，願比皇杳此東光兮，班沒夜之不反心？
#
# 願沈侘而折舉兮，魂乎歸來！萬習象而難意兮，豈皆謂皆所發兮，何誰周而不得？
#
# 鳥快夢兮朅而並德兮，後沈介而命之得。
#
# 禹櫺脅巃憾池兮歸來，角合者不足。
#
# 鳳皇不可以兮，雲至所昏而不當。
#
# 菎沼奸蕙兮雲離，行日嬃之和仙。
#
# 遂虙舉而相嗟兮，志不可以為偕。
#
# 身霜見為難容兮，竊棄隨野兮身予志。
#
# 哀歲逝兮不知者乎棄乘。
#
# 罔霓疾之遠志兮，將濁欷之
# ----
# iter 34100, loss: 67.656588
# ----
#
#
#
# 明有淺而就直兮，志鞏排而何望。
#
# 誠莫其不同兮，莽芒叩乎逝翼。
#
# 曾曉瑟兮播光岸。
#
# 覽時兮班石，邈夷化兮偕。
#
# 鉅登蛟於失浩，璆鏘兮肝歌，追日兮廣本，讒蠽兮累與，步市期兮列舉。
#
# 懸麒兮皓濁，望北軀兮襲桑。
#
# 世承兮棄舊。
#
# 還殀兮射蕭。
#
# 奔迴阿兮既咶，容與極兮葱嶺。
#
# 易明媞以震盛君而遂浮兮，列規漿而欲突。
#
# 孤赤郢其瓊名考？
#
# 惆駘漣游兮，或鼂娛昏而邪日。
#
#
#
# 西路
#
# 與佩欣兮北
# ----
# iter 34200, loss: 67.436754
# ----
#  惟飛羅以為止。
#
# 乘高杭而日畔兮，中獲牛而賤塺。
#
# 聊假紜以咷義兮，不苟瀨之陳只。
#
# 循云明
#
# 比營君檻兮翼故騷。
#
# 北嗷天悵與煩合兮，遙紛舞嫌吾食。
#
# 名顯翹c流容兮，列志今路？
#
# 筐惕羅之楊耿兮，曾歎猶而攄刑。
#
# 顧太雚以寂寞兮，哀後絕而長波。
#
# 沅致來兮幽處。
#
# 願雌泠於流瀾兮，目余湊而無苦。
#
# 鉛騷界而聊粢兮，屈原哀而礫路。
#
# 見鳥案而我身兮，蹇忍尤之流錯丘壄。
#
# 悲廓兮蘭英，白沈波兮不故
# ----
# iter 34300, loss: 67.744229
# ----
#  蒼谷以獨浮兮，觀朱都而赴征。
#
# 虎狂之不返兮，上下怦於空桑。
#
# 氾芙蓉於靈漸。
#
# 刓霓旗之直霓兮，滂藟藿岳只。
#
# 建藟脅曰中諧兮芙踴挐余難網。
#
# 時陿策而下考兮，豈將辰誠以僊築。
#
# 韓飛外杳之酪悽兮，憂遵荃之聲加兮，蛟我廣皇以逍側乎？離憐兮往來淵而蹇疑。
#
# 與魚袟皆以白字兮，獨一龍之素雲乎？
#
# 望抱雞默而今予兮，曼神公於玄刑？
#
# 與芳行之逢榮兮，堅鑿而不可止。
#
# 駕凱驚而禍騖兮，蓼卬怛天冥淫。
#
#
# ----
# iter 34400, loss: 67.371181
# ----
#
# 屈天兮自憐，矇倠兮揚貞，君留馬兮圃躑。
#
# 苦九燿兮杜若，吾明之不釋。
#
# 乘雲兮葯居。
#
# 屯余車兮感旍，淒嘯兮歸娭。
#
# 願鳳產之天逝兮，周艾華兮志莽。
#
# 玄鄢狹而未西兮，慰撚懰鵝，谿祿。
#
# 意霓弧兮，燕跳而多肉。
#
# 怫鬱兮射所。
#
#
#
# 益形以為進延兮，鉤鍾死於西鬿。
#
# 椉踢息兮嚶鞹。
# 秋左擁兮俊彥，飛讐兮傷居辭？
#
# 遡噭誂兮蒼蕭。
#
# 晨螭兮不重，重欣水兮贅嵯。
#
# 周日月兮蒼衍，秣余馬兮嗌沶。
#
#
# ----
# iter 34500, loss: 66.985842
# ----
#  曜兮，既興忽還；
#
# 孰謇辭之隘謇兮秋立，過冥穆而東時。
#
# 思椒八出之膠兮，不見瞀而虛置。
#
# 總余亦曰未哫兮，玉何以足之純儀。
#
# 余不能不可人之？
#
# 車耳玉時脩之誠，志非我；故，陳蕩矣，辭知本余與就周行。
#
# 揚芙月於蜿旰。
#
# 衆余豈其含亂兮，河蕙御之風林兮，命虺罔之初c。
#
# 思驪余之不珠。
#
# 思忽忽與願貞兮，留余望與脩服。
#
# 悔余生之不占兮，更胥心之踵雨。
#
# 不可山兮壽下，其流之兮十泉，陞知吾將所傺
# ----
# iter 34600, loss: 67.358456
# ----
#  其其吉明乎下下。
#
#
# 笯純合兮，中今埃而過四。
#
# 行余之盡攘兮，帶聊備之壄貴。
#
# 既遊路兮無殷，東無櫋兮為觀。
#
# 鳴不變兮以廉桂。
#
# 道余言曰正兮，長軫翮之此不爢；
#
#
# 勉薜良於山松。
#
# 覽彗㠯兮極斗，車長佩兮自又與憂所為數方。
#
#
# 武露莫清舉兮從靈堂。
#
# 昆初三君兮未懷之所謁。
#
# 曰：「不美以為詞兮，苟懷！
#
# 風禹湯盈索兮，朝沸兮無釋。
#
# 曲為佳兮慘蟤。
#
# 九霓閽中思化，哀戲俗兮，覽時，其將充
# ----
# iter 34700, loss: 67.077741
# ----
#  江備君焉居？
#
# 進馮銜使，何故吉些。
#
# 鳥余然富湘兮，何狐疑而無獲兮，去郢下哉。
#
# 夫滔變棘，石我欺之能高入而下南游。
#
# 少嫋兮連宮。
#
#  君惜何益？
#
# 說慕娛別如，何嫉曰。
#
# 願發佳兮，為昧竚木為些。
#
# 云誠信兮回重，穆文思輔些。
#
# 吾曰地勉修江路，背遺異兮包漿。卷困何鯀。
#
# 鯀夫一蕭，惟逐蔽不可以尚在也？說太息，尊下家兮，讒胡欷起衰龍兮鳴螭。
#
# 何玆螭志生，求開翼？
# 何以厚武兮，覽揭可以繼風
# ----
# iter 34800, loss: 67.226539
# ----
#  邑態兮，操下銜以捐此！
#
# 情使闇口其四歌。
#
# 巡余馬之嫉臣兮，願承釣兮，父顧之湍未再兮，浞周初而懷離。
#
# 依郢眇秋水而椉葉兮，又與彭過也？
#
# 不知墮其遽當兮，蹇若衣而洧蛇。
#
# 天焉隕以安隕兮，又何摯而聖之所英。
#
# 庇鯀讒長，宗此備之變。
#
# 肇漢鬱之有奉，蹇彼嫉葉而不足止。
#
# 及北媚以帝結之兮，偷切何之？
#
# 發蘅冢而徹鱉兮，羌憂長以為余後兮，山百夫余夫故？
#
# 君伯經之不制兮，焉扈穢者不終之多。
#
# 北
# ----
# iter 34900, loss: 67.233157
# ----
#  孰令無美其無垠半兮，惟散自忍為？
#
# 竝舒四山之？世時兮，其鳥足夫之如傲。
#
# 申順壽之槁涕兮，龜介陽。
#
# 茅念二路兮樂心，止佯乎誰能。
#
# 微車兮壽河，焉芳留兮安遷，心靈入兮，蟀蕙遑流而來？
#
# 西外白微之美宇兮，長一曰而生聖。
#
# 事使樂像而內歸室兮，立反滯而舒行。
#
# 高我日墜兮，雲孰能樂數。
#
# 佩六形！
#
#
# 禹深視兮，字下余而稱保。
#
# 同彼三脄志，而固任也？。
#
# 悲精微而煩冤兮，願翔矢以上錯？
#
#
# ----
# iter 35000, loss: 67.210119
# ----
#  難潛曼兮潺湲，與君之之所皇。
#
# 擥群容之未和兮，降霓華而開淫。
#
# 雄膺遇而依吠兮，心煩繚佪。
#
# 鳥從君北既下，陽容而通集也？章雄曰：憐兮周不解。傅離吠兮，憚端滯者使訑毒兮，見吾與而流水；
#
# 撫駑釣詔須瓊兮，託得弧於介冥。
#
# 申求浦而容與兮，心僕春而愁求。
#
# 心驕臾而有國兮，結春華而相羊。
#
# 內群洋而枯垠兮，幼雌切㠯證生之前。
#
# 睹調子以若曲兮，白傾浮而修懷。
#
# 還從容以交入兮，後群而施帝。
#
# 願髣
# ----
# iter 35100, loss: 66.878684
# ----
#  轡而不至兮，惜何君之淫翔。
#
# 收獲悅而就洋兮，曼迎，捷其友深兮，日月貴妒君草之？
#
# 將沈厲而自入兮，蟬西曼乎過在些。
#
# 山滂淮而曼惑兮，鸞湘長徘徊
#
# 門山以詒之舊屋招居此，心去援於憂。
#
# 國無諫而入下兮，獨泰女亦為眾」。
#
#
#
# 驂承木之紛兮，惜臣蔽而窮剖。
#
# 策弱而蔽宿。
#
# 匐色義其所愉兮，卒比見之儀雰。
#
# 憭櫹蔡兮，哀首沛之蕪僕志。
#
# 澹從者以忘濁兮，造隱遙乎多降。
#
# 水就吉地兮，紛鶩闔其鴻充
# ----
# iter 35200, loss: 66.999514
# ----
#  初愁。
#
# 望青瞑，耀有濁君其家。
#
# 九辨曰：「何七：，何醇必而婦故莽，瞑斬究兮，逴閉而致與。
#
# 霰既汩而得後兮，信美人為微些。
#
# 心絓戚兮，來耳華猶戾怳。
#
# 君九方與今之瞭志，遂九旗？
#
# 乘吟謳騁忽兮，又宗將之踵紛。
#
# 竊不協讓，可釜輔醢些。
#
# 重祝犯母，而不餔兮懤萋。
#
# 叛昭高舉而遂怒，夫君後兮，長陳心點愆？
#
# 免曰：
#
# 身何不知其用！
#
# 思俗之托，草有永善兮，繹諸論共谷」。
#
# 竽閔趾而不純兮，
# ----
# iter 35300, loss: 66.584309
# ----
#  ，歲將武之無壯兮，戶鮮海只馮。
#
#
#
# 雄芰四進，憂勞沙只，谿腰綽駝，願勞極只，孰馨胄亂。
#
# 惑肝雀，馳莫反兮右驅。
#
# 思憂入而遙嗟兮，身盛歸其！併《人聖只，魂乎無革湯。
#
# 芙尊駝余葬。
#
# 膏翱延只，南家易沕，其考頰只，魂乎歸徠！恣所擇只。
#
# 薄終生於三蓋，和瀛雀只，聊日櫂兮，奄幽變而仇乘壄。設測蟀處斥，願歲高只，流桂白居只，。
#
# 髮溘死，青況理只。
#
# 酎沒椒白日之室些。
#
# 倚辟餚，余以友只，魂乎
# ----
# iter 35400, loss: 66.071394
# ----
#
#
# 所天三
#
# 雷鼎於皆慄，實吳怪槩，放遊子之媒我兮，不反後隔之容些。
#
# 含予志而並服。
#
# 哀獨考哉而不形兮，心蔽鑠乎悐宓悠。
#
# 聲不聽而為敗。
#
# 鵠虛蹀而沈流兮迷楚之積之隱。
#
# 椉鸞情以立之草誤，雪滋淵之舊再。
#
# 孤并質其西置。
#
# 斥仿禽於染聲！正年兮，奏申日之骨顧枹；
#
# 感九駕海於恨兮，頰情信而述望。
#
# 吾反不可以娛小兮，施距欣而累賢。
#
# 彼女沈之中之不？
#
# 悲君子之可言兮，子回杳於豐莽。
#
# 伏
# ----
# iter 35500, loss: 66.277575
# ----
#  心江暾之逶壇。
#
# 生兮夏之有，傷三洋其以自止兮，矯石諛而遠鄉。
#
# 棄洋溢而長丘兮，麗紆與乎江逸」
#
# 故小臣非其日些。
#
# 固誰能不可呼淫，志必自懲。
#
# 汝綺勤而以冤巧兮，況悶歎之多諤。
#
# 心溶僑之同寐兮，安余騎以敢望。
#
# 乘獸雜而獨沈兮，夫將通幃必所棲巫。
# 涕崔丹，紛囿逴薄只。
#
# 歲廣未余以止些。
#
# 直紂藹之造桓。
#
# 思踢銜而得事。
#
# 伯蘭命而不知兮，歲集紛余之所啾。
#
# 蹇吾不見而極隱兮，又莫吉焉薄
# ----
# iter 35600, loss: 65.948444
# ----
#  ，誠眾又不枉災些。
#
# 歸習謂兮游騰迫兮，谷楚人之悠飆。
#
# 紂暴藹兮萍縹峨，載雲兮，懿緜而在鞠？
#
# 杳定九宮，誰背兮安近。
#
# 古垂兮安宮。
#
# 含慌陽兮殊夜，西世成騁兮，形余生之繼之。
#
# 勢九絕將來兮，曾氣干群而心服礚。
#
# 魂雀滂孝兮砏嚶，其蹇閽兮愁逝，覽謇兮棄心，遠翼兮聖迷，與晈棲兮塺。
#
# 朝思兮寤廢，超惘龍兮，張寶漠。
#
# 云道昏與呂遠兮從。
#
# 像
#
#
# 鞭繆「勉檻代注，於題鸕兮，知其軫夷兮天詩。
#
#
# ----
# iter 35700, loss: 65.750741
# ----
#  昭滄軛而深罷兮，脟承巢而蕪巧。
#
# 觀命
#
# 使舲月兮困塗。
#
# 撰女歌油只，九年以為左些。
#
# 歸來兮旦讒，造無桂處淵兮，吟嵾如而懷盪。
#
# 念翼劍兮蟬木，將王鏗只。
#
# 乃心鬱鬱之常居依。
#
# 流隱鬱以為合兮，覽浮逝以無彈。
#
# 端倥圭之潢黯兮，惟狐規欷而難緯。
#
# 驚蕩油以端誠兮，或素波其含處。
#
# 刜徨兮于遵，與稱日謀容心之慷慨。
#
# 木祖歿而無通兮，申漫遙以邃為些。
#
# 歎鵠路兮翠陳，憂角兮能忠容。
#
# 紛哀俇夫
# ----
# iter 35800, loss: 66.032090
# ----
#  冥以遺駝。
#
# 鯈洲之守可顧兮，路昭湘使而託脩兮，胡揭巖於兩津壚只，年霏崙兮戲日。
#
# 太息兮同纚，遠登昭蔽而流犇兮，且霑根而回旌。
#
# 馬薜荔於紉陿兮，翱翔翔土近智。
#
# 隅瑉憯以悁旰兮，載隱階而抒得。
#
# 鬱鬱迅驥以嶄目兮，固斗穢辛之言壇兮，屢產是而承謁。
#
# 集艾世猿槁於宮兮，班雌皎徂而寄露兮，泣玄乎以射殃。
#
# 四廣油以結流兮，荒忽幽。
#
# 合藳以結俟兮千里之
#
# 曳吸蛟而抉翅兮，來惕悴之驤盪岡只，壞忌雊而
# ----
# iter 35900, loss: 65.641694
# ----
#  兮襲進，長堇兮邪居。
#
# 菽鸕兮，睹虹玉遊折嘉嗟兮，求以冤之兮，願介
#
# 悲羞兮眇潛，援山鸕兮，貴荔奔紛與失。
#
# 雀浮融兮聖悒：
#
# 猋瑾廟悴兮，褰鴈雜乎於懸。
#
# 椉庫軔兮澆疇，怨世
#
# 寶鴦兮丘特，將見衢兮釋文。
#
# 越哉兮運綴，芳正用兮昭
#
#
# 思望東告，周幽邪遊兮直裔而還長。
#
# 欲竄于之軋節兮，鯈邁兮飛局，雞鶩增藏兮則歷
#
#
#
#
#
# 不霆啁坲o舊兮，眾越隆吾冥冥。
#
# 且佳復兮語囚，適菲江兮舒淫，嫭鬤兮
# ----
# iter 36000, loss: 65.214008
# ----
#
#
# 乃回昂其離奇兮，揚中舉而效。
#
# 使脩信兮為絕，焉嘉名而無先。
#
# 獨顧蕙之嫉夜兮，飄增煢。
#
# 鬱愆夫何無醫兮，不可余糗中久：
#
# 桂勳心以幽如。
#
# 解前目紛所C。
#
# 讒曰桂於蕙揚兮，臣不傾蔽今之有也怪也！
#
# 獨足之以調兮，恐獨云之不知！
#
# 攬后之有極依兮，非余嗣之所思。
#
# 必若阿兮純困，不貴兮巖穴茅。
#
# 哀時俗兮不能。
#
# 若衡蘭以離尤兮，見太南以嘉穢，
#
# 厥鶊而不察兮，哀殽流而延皇。
#
# 揚中車以馳
# ----
# iter 36100, loss: 65.594053
# ----
#
#
# 賢九衢之結合兮，羌玉邑其狐疑；
#
# 何余車言難蕙兮，下曲芬所便仟冕。
#
# 周國兮以增辭。
#
# 嫋袟兮九風。
#
# 吾既校深泉之可吟兮，？君假美與像驅兮浮雲！
#
# 閨中度之無應兮，妒可若使托浪。
#
# 欲弧與其娭臯兮，朕顏容而無且。
#
# 伍既提於余辭兮，世猶未不知乎。
#
# 撫車與既晨隕兮，凌峨肥之於儀。；
#
# 殞鮮冬此泣飾而為昂。
#
# 師陰州兮高日。
#
# 忳蓀堯以之塗兮，覽緤紛其東芳。
#
# 余永雪其存直兮，夕江茅以中侍；
#
# ----
# iter 36200, loss: 65.299068
# ----
#  辭淫邠刈急璐其聽所理人
#
# 擊樂君既不凝，心桀正之。
#
# 嗟言卜《九父竽天父歎》，折何施兮，侍桓墨而不反；
#
# 聽並駕夏，未斲棄。
#
# 高馳之罷覆兮，杳鬱獨結
#
#
# 楚回飛反，鶩理海之俱下。
#
# 惟馮導故，龍澤刑，樂與庭何而終後？；
#
# 人伯鯀，臣往眾愁以質艾兮，歲薆滔而不彰。
#
#
#
# 天虯問代，選至宜嘷，來竝海兮不吳殺再有所人所芒？
#
# 何焉不解乎？」」
#
# 參莫以人首？
#
# 築羽伐義，來澌在兮止肺，抑其知彰此東？
# ----
# iter 36300, loss: 65.490443
# ----
#  宇。
#
# 經至荼躖羔肬，
# 莫厥言謇以於直，食離謗兮歸來！
#
# 臣浞剡志，瓊枝安之？
#
# 蓄山兮，乃謂死而不期。
#
# 咸諛夭帝之在為逸，誅挾人之豐悴彫；
#
# 路扈知子泣兮，孰知身而不變。
#
# 九宿鑿於天兮，山僕而多傺。
#
# 佩工嬃之托占兮，讒又何以異延？？
#
# 還芳以沈感。
#
# 君纂叢於有《陸釋孫魄浮游下，悵而願經兮，旌妃晦與遺北之聞變。
#
# 其授地而媒帝兮，帝何宜而不之。
#
# 超流天之淈。
#
# 天獸極而不識，夫省登省而難
# ----
# iter 36400, loss: 65.516892
# ----
#  不知沐所狂。
#
# 設壹氣而娛乞。
#
# 抽不能必子，而詘蜓兮，信箕退以憤下！
#
# 受身不及容旦，誓士在《後黃賢所倚，與彭咸兮，夕歌都焉？
#
# 張連蜷以冤妒兮，輿及兆而秋美？
#
# 陽無連䰟兮，折言終不忘？
#
# 反俗之懮鼈，以為宮，而失窮兮，美循余以自極。
#
# 卒沈薄而容容兮，又不達乎壽極之。
#
# 潺愍兮，心不膺以遺？
#
# 魚玆北隨，固不行，以江懷兮，願淹居乎此為？
#
# 不王徊而不可戶，九連尤纂七思辯，君魂之謝，老何莘之將
# ----
# iter 36500, loss: 65.521849
# ----
#  木。
#
# 依皓孔廓而不意，而白行兮，子蓀風以同赤？
#
# 超強而不可結。
#
# 右五字稱未約！
#
# 艸鬱師事乘類兮，世夫初虛之盈？
#
# 一思情而將窮兮，名夏霓而相遷；
#
# 飲風絕兮，忽寶邁。
#
# 內薄帝之下，目遠行兮，獨憐而上之遠。
#
# 直忠不釋信與來下，無馬化兮。
#
# 往以潔陼兮，重志言之。
#
# 恐寄既珠登容而不遷。
#
# 抑誠之白嵫兮，塗悶歎而往反；
#
# 川谷若下兮，若列錯之悐悐。
#
# 憍忽其以死下兮，眇忽莽之此懲。
#
# 冥淵
# ----
# iter 36600, loss: 65.317247
# ----
#  耦。
#
# 魂驚來兮，明羅汶乎揚路。
#
# 平黔者：「亂時文兮，誠不湛乎？將美人不所輿，，不由交之吾行事兮，澹枯，此西質兮北丘。
#
# 年解體而不能；
#
# 志川玉宮常兮，頓與介土之為謀。
#
# 五六以為後兮，遂收汨而不衰。
#
# 使三都之中合兮，子忠而不寤。
#
# 心誠不之江韶兮，起鑠漸。
#
# 乘騏驥容不道兮，鼓驚棄而顧迎。
#
#
#
# 滿蛾兮，介父澈死之罷只。
# 解鬱鬱結莫分九騷》，誰參而愁志兮，退大者之啾匈。
#
# 數君並椉拂冬詞
# ----
# iter 36700, loss: 65.447400
# ----
#
#
#
# 屈曰：杳下者不容本，俗澌不解！
#
# 情往枝以敗，就豐洽些。
#
# 齊蘅益而任進兮，扈哀反而膠悴。
#
# 遵鳥江，目吾成門。
#
#
#
#
# 黃戚帝遂，之煩眼靃偕。
#
#
# 曰：「訓費苟，睩射夷兮畦仙，綵織永若兮，令離繚之被貧。
# 蟲鑿一　，哀故之祖，曼有題汶峭恩兮，況為神此芳窮？
#
# 南江河之安得些。
#
# 鳧虞靚而來憂！
#
# 卷十十乃知其流何之，蹇斷殲擗蠢拇衰美。
#
# 願離滯而龜悲兮，世氛溷而並沆止？
#
# 設歸來舉君遊
# ----
# iter 36800, loss: 65.011474
# ----
#
# 固安容以為息，淒只：
#
# 獻竊侯鞿霓作，合輕諛進迎，顏室匠，以方注只，魂乎歸來！恣所庭只。
#
# 萷鬚滃義而左量兮，誠新張而使余；
#
# 少隨
#
# 朝去終郢，耳兮抉寥，與龍澤蠥，罾于氣只，致北只，，頰隅端瑞登繆？
#
# 魂乎歸徠此觺觺些。
#
# 瑟膩慮，胥第下只，魂乎歸徠！智歌》只。
#
#
# 薄逴機而於後。
#
# 吳浸既芷，志而含愆些，
# 獨卑獻門，謇以孤只，，龜甘囿，求辠愴只。
#
# 蔡靜臇鳧，掛辛鷞只。
#
# 回焭旦來，極抱蜂只
# ----
# iter 36900, loss: 64.480920
# ----
#  自狐謇之止些。
#
# 指日之門而常觀兮，委蔓艾而下息。
#
# 卷十　哉孫陽屈帝以愁賊些。
#
# 何輕稽與遠！
#
# 羌四
#
# 委儃佪於九風兮，浩規飫而不可遺《作只，鳥弊靜無可御兮，鯀正由乎麗之所明？
#
# 卷十　熊臣兮，怛稱將聞順移零。
#
# 自鳳蓋九章書兮九居。其居任定只，潏類之起士兮，南繩聇以繚揭兮驂自盛。
#
# 惡臨降而忿沙兮又芳之得晏屑。土國何薄裔不意浩室，乃徙千里而絕革。
#
# 方鳳皇之盈杜兮，恐固光虖京輔。
#
# 獨并榘於
# ----
# iter 37000, loss: 64.689193
# ----
#  洋泉而下奔兮，自赤螘而割加。
#
#
# 像被余去心悁其兮，心其固此容！
#
# 離蹇戾兮歸然，東天賢去中路。
#
# 悲天必先再心兮，初莫道其遠糅？
#
# 年暮進而不論遠兮，望沈衍而不置。
#
# 往湟櫹甑吁充溺悠，俗溷面兮，上沅土。
#
# 湯弱棄而清舉兮，使或血悴而榑期。
#
# 上貫崟雜阪殀兮，空蹇睨：
#
# 垂陳巒而夷迎兮，日冤石而瘀去。
#
# 身既端其進罷兮，心隱勃於展間兮齊詩。
#
# 淩流陽之莫通兮，反哀衍之鄣患，故昭枝飯習兮，亦與美其
# ----
# iter 37100, loss: 64.417172
# ----
#  陳生與沛憺兮意林。
#
# 觀衣鄭奮鄭只，離離宜而從數。
#
# 高日聖而無盡兮，鳳皇余以茲敬兮，美魚攻濆永朔。
#
# 置覩庚玉神而不猒兮，上隱隅而不幸。
#
# 竊不息兮路抒，涕木兮些。
#
# 蓄遊兮不貴，夫煩張兮雲中，秣禹兮鄗竽。
#
# 菀鴳神歲心
#
# 音衡兮終紛波；
#
# 懷陽墜以須臾兮，偏余以糧猶；
#
# 國情沙以欲徠兮雲愬。
#
# 款曉飛兮掩歸，傷揚生兮開門。
#
# 蹠矣遷漠流之窮塵兮，羌清顧而昡惰兮，王沒玄若羹兮？徘徊
#
# 蛾冬兮揚征
# ----
# iter 37200, loss: 64.194555
# ----
#
# 菀蘼前之邃娛結兮，豈鬱欷而南螂。
#
# 悲　路所離壇兮，仳霰觀乎我正焉。
#
# 神說道事娛校兮，日繩茅之高予。
#
# 浮龍繽深中兮，下愍翔江里之白蛇些。
# 雲蘭靈之故芒兮，綠躍其哀求！
#
# 右章篇慼六流，憂相觀之心談
#
#
#
#
# 東被曰：
#
# 駕極檻兮北穰，三漫為兮為桑；
#
# 雖忠忽而不揚澤兮，遇踴陷而不寐。
#
# 傷夫道鬿靈義之注砥兮，退其日茝乎？將德兮，詔邑騎之瀏紛物傷。
#
# 乘青巒以翱驅兮所被。
#
# 靈慌志而無進兮，訴
# ----
# iter 37300, loss: 64.551430
# ----
#  陷而不解兮，芳舛錯而不邁。
#
#
#
# 歷讒戚與埃義兮，雞清槩乎濡尤。
#
# 畢昌循以寂裏兮，斑茅群以先蛇。
#
# 日月星以為草兮，左惆悵而成吾。
#
# 覽患澒以木疑兮，坎鶴幽於告府。
#
# 滿英俗之抉眼兮，求余汨羅只。
#
# 情攝欲於蒼莎兮，情汩踐於被石。
#
# 易蘼潔於增府兮，體閬琰之號耄。
#
# 魂瑉之妬揚悸兮，塗瞀逢而思臧。
#
# 冬夫藩水而流水兮，涕駑雰爍涕誰陿兮，造薄水其申佩兮為絕注。
#
# 紉蕙悄於北欣兮，望宗繹與泣流。
#
# ----
# iter 37400, loss: 64.218721
# ----
#  ，逾旌兮璇畛魏。
#
# 隱何昔兮識車。
#
# 蛜蚨兮噍汙，鹿鸕兮，神端余寤丈躡位兮，申紆玄於筐凍兮泠泠，諓莫如兮，鬼爵此久長
#
#
#
#
#
# 何士
#
# 登誠言兮睨且。
#
# 憫日兮水處，鯈倡兮北將。
#
#
# 登望命
#
# 傷余明之鳧弛兮，王忳鸁其秋圉。
#
# 掘彼謂不離死兮，逐緩雲之阿革。
#
# 怫鬱兮東征，惆胥陽兮清取蘅覩洲兮，赴豪娵闢割。
#
# 杳忿兮奔蛻，祗漸沱兮迷妒。
#
# 哀去龍兮蒼余人。
#
#
# 鵰蜺藝文侘煬兮，狐河舊。
#
# 旻留兮
# ----
# iter 37500, loss: 63.786204
# ----
#  ，天木不吾時。
#
# 余變既日能兮，微余遠以未遠。
#
# 朝鏗服深兮，曷以
#
#
# 車多騷桂三師姱兮，王猶未阨兮，心羌鬱鬱之捷耦。
#
# 申處兮上下，代歎兮，去江能之恣待。
#
# 晉蘭馳之進兮。
#
# 莞滄兮，長與沙燿余我將兮，魂乎歸來！何輿之以離遻兮，結孰蕙乎為余！
#
# 欲固志於二海，狐結兮，聊薜嵫而所之。
#
# 憎螘矣之典走郎之，有余既若彭。
#
# 余繩嗷之純解兮，將眇眇無以娛壯。
#
# 俗辰緯隆既正，
#
# 路申脩之茝兮，若脩之之震
# ----
# iter 37600, loss: 64.104387
# ----
#  不冥。
#
# 怫鬱兮可若漿。
#
#
#
# 悲人兮為織宓。
#
# 女發滯於四猒兮，堅禹之遠時。
#
# 吾既蚴此兮貫惑些。
#
# 寧太阿以馳翳兮，訊迎君而無達。
#
# 長　自道兮隔傷之也。
#
# 上河
#
# 昔遇雜夫佩茅畛兮，指驚重以濯憂。
#
# 奔余車調有發兮，忽扈余與廉羅之不化。
#
# 夫鬱邑此私量兮，好吾日使夫心路。
#
# 匡中淫於瓊器兮，周女期之所成。
#
# 傷緫風其遐涕兮，折求啾乎長獨。
#
# 塊駕玆飛兮為予。
#
# 非皇人之常蘭兮，悲反顧為罔。
# ----
# iter 37700, loss: 63.818542
# ----
#  反用兮，故草肆遊。
#
# 何前異目使陳旦。
#
# 恐何重之久錯。
#
# 曾天皆偟足與離懷之往切？
#
# 薜蔓泉兮電誘，鹿黃君兮西中寶夫曰聖城何？子旹無強而作悲。
#
# 悲夷若淵之帝中，無所痛。
#
# 思蹇行美而蹇。路文註「美往者能賤。
#
# 不何騏驥而不聊固？
#
# 何有有不可宴，觀至近而含蛇。
#
# 室草狼舉，受進義而下善行？
#
# 茲八風兮蜿厚，思夭木？
#
# 伯驅緪洋昧幾方？
#
# 何新階佐不終，使澌難此也。
#
# 何壯極而心後。
#
# 彼兩明穴
# ----
# iter 37800, loss: 64.016507
# ----
#  兮，鴆反孰以何之？
#
# 無舟處而媒志呼分所，下有莘之際？
#
# 親聖祝以陿集兮，熊望義而嘉幬。
#
# 惟婞騖而不友兮雲碅。
#
# 橫中質之娛其乃思總兮夕首，何懷安之？
#
# 鼎崑崙之殺走兮，又折捷皇侁？」《環人離而含人。
#
# 小帝帝帝羅，以吉頹。
#
# 何厥池之流山兮，與莫知其讒聊。
#
# 寤居量而開芳兮，躬大斗而無南！
#
# 何五南藥游而不沒兮，夫人寂默？
#
# 兩瑟赩壺離，九一》而是章》，路何極而在鼓？
#
# 成六軒，獨山死兮，日聞
# ----
# iter 37900, loss: 64.003499
# ----
#  鳳波與莫極兮，冠空必而久丘？
#
# 結子錯而不釋兮，又有能永何？
#
# 去君兮？
#
# 昭不知謂察兮，羌無以容與兮。
#
#
#
# 事民九情，而不自去，背衍蕙兮，哀讒人其無効。
#
# 權地兮節予，鴻四谷厥，建汨悄之不聞。
#
# 願侘兮而人，久君？
#
# 孽巧隱於淑亂兮，周不茅魄而就故；
#
# 鳳皇人出而不同兮，何儵之而罔夫。
#
# 簡氣之謳亡兮，世溷廓而不難。
#
# 念揚華木北首兮，枝離土，捐菲草兮會百而緒進。而舒身兮，焉知何；
#
#
# 保余
# ----
# iter 38000, loss: 64.032811
# ----
#  德；
#
# 曰：「「芳流，勃里以長零？
#
# 操吾情清南雲之網欣兮，固縞素群餧。
#
# 舟閔虞兮，限其不可良？
#
# 或皓濛其若賦兮，薜惝矱之女行化。
#
# 霜九卓幽礚來兮，選芝翔而零天。
#
# 靈忠之逆枯兮，立不如而難亡。
#
# 懷雪薺夫其迎兮，身獨好夫下衣？
#
# 設糟棘導玉，乃如徂，登俗兮，舒君幽鬱之無連！
#
# 玆鳥翻兮葛安，與欲妃些。
#
# 烏積以為愍兮，蟪速吾之今降？
#
# 非涉陽之無正兮，蹇麤月之宛行。
#
# 寤遷轉兮南規，魂乎焉
# ----
# iter 38100, loss: 63.747363
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-b88ae657b1e7> in <module>()
#      18
#      19   # forward seq_length characters through the net and fetch gradient
# ---> 20   loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
#      21   smooth_loss = smooth_loss * 0.999 + loss * 0.001
#      22   if n % 100 == 0:
#
# <ipython-input-12-b6e72c13c965> in lossFun(inputs, targets, hprev)
#      14     hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
#      15     ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
# ---> 16     ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
#      17     loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
#      18   # backward pass: compute gradients going backwards
#
# KeyboardInterrupt:

# %%
all_vars = {}
all_vars['vocab_size'] = vocab_size
all_vars['Wxh'] = Wxh
all_vars['Whh'] = Whh
all_vars['bh'] = bh
all_vars['Why'] = Why
all_vars['by'] = by
all_vars['ix_to_char'] = ix_to_char
all_vars['char_to_ix'] = char_to_ix

all_vars['hprev'] = hprev
all_vars['inputs'] = inputs


import pickle

with open('rnn_chuci_20180528.pickle', 'wb') as handle:
    pickle.dump(all_vars, handle, protocol=pickle.HIGHEST_PROTOCOL)
