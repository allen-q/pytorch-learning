# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from tensorboardX import SummaryWriter
import torchvision.models as models
import torchvision.utils as vutils
from torchvision import datasets
import time
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn

# %%
with open('../data/shijing.txt', 'r', encoding='utf-8') as f:
    data = f.readlines()

# %%
data=''.join(data)

# %%
len(data)
# Out:
# 41804

# %%
len(set(data))
# Out:
# 2848

# %%
data[1000:1200]
# Out:
# '有巢，維鳩盈之，之子于歸，百兩成之。\n\n《召南・采蘩》\n于以采蘩，于沼于沚，于以用之，公侯之事。\n于以采蘩，于澗之中，于以用之，公侯之宮。\n被之僮僮，夙夜在公，被之祁祁，薄言還歸。\n\n《召南・草蟲》\n喓喓草蟲，趯趯阜螽。未見君子，憂心忡忡；亦既見止，亦既覯止，我心則降。\n陟彼南山，言采其蕨。未見君子，憂心惙惙；亦既見止，亦既覯止，我心則說。\n陟彼南山，言采其薇。未見君子，我心傷悲；亦既見止，亦既覯'

# %%
chars = list(set(data))

# %%
# data I/O
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print(f'data has {data_size} characters, {vocab_size} unique.')
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# data has 41804 characters, 2848 unique.

# %%
# hyperparameters
hidden_size = 128 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for

# %%
X_train = np.zeros((len(data), len(chars)))

char_id = np.array([chars.index(c) for c in data])

X_train[np.arange(len(X_train)), char_id] = 1

y_train = np.roll(char_id,-1)

# %%
X_train.shape
# Out:
# (41804, 2848)

# %%
y_train.shape
# Out:
# (41804,)

# %%
vocab_size
# Out:
# 2848

# %%
len(X_train)//seq_length * seq_length
# Out:
# 41800

# %%
def get_batch(X_train=X_train, y_train=y_train, seq_length=seq_length):
    #X_ids = list(range(len(X)))
    #random.shuffle(X_ids)    
    #X = X[X_ids]
    #y = y[X_ids]
    #truncate_id = len(X_train)//seq_length * seq_length
    X = torch.from_numpy(X_train).float()
    y = torch.from_numpy(y_train).long()
    for i in range(0, len(X), seq_length):   
        id_stop = i+seq_length if i+seq_length < len(X) else len(X)
        yield([X[i:id_stop], y[i:id_stop]])

# %%
def sample_chars(X_seed, h_prev, length=20):
    #for p in rnn.parameters():
    #    p.requires_grad = False
    X_next = X_seed
    results = []
    with torch.no_grad():
        for i in range(length):        
            y_score, h_prev = rnn(X_next.view(1,1,-1), h_prev)
            y_prob = nn.Softmax(0)(y_score.view(-1)).detach().numpy()
            y_pred = np.random.choice(chars,1, p=y_prob).item()
            results.append(y_pred)
            X_next = torch.zeros_like(X_seed)
            X_next[chars.index(y_pred)] = 1
            #print(f'{i} th char:{y_pred}')|
    #for p in rnn.parameters():
    #    p.requires_grad = True
    return ''.join(results)

# %%
class nn_LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.lstm = nn.LSTM(input_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        
    def forward(self, X, hidden):
        _, hidden = self.lstm(X, hidden)
        output = self.out(hidden[0])
        return output, hidden
    
    def initHidden(self):
        return (torch.zeros(1, 1, self.hidden_size),
                torch.zeros(1, 1, self.hidden_size)
               )

# %%
vocab_size
# Out:
# 2848

# %%
hidden_size
# Out:
# 128

# %%
rnn = nn_LSTM(vocab_size, hidden_size, vocab_size)

# %%
loss_fn = nn.CrossEntropyLoss()

# %%
optimizer = torch.optim.Adam(rnn.parameters(), lr=0.005)

# %%
X_batch, _ = get_batch(X_train, y_train, seq_length).__next__()

# %%
sample_chars(X_batch[0], rnn.initHidden(), 100)
# Out:
# '祖祀蘭震匐茅忘蚤杞畛置鼎僭畜跂蒙戩樛匹飫鄭沱慍捄亨耿瑲椅禴鈞饁營騤荇棗楅番砠欲丱主漼罪凝噳輊瞍淠噦南館濩間鶉飽稼彭享闥慝留酲憎恆蓍羜瑲遑爪塈仲怛殲扤迎黍枸宗域投惔寺乃門場控尸隤禎池鰷・彤鷮北故嫁初觥頃'

# %%
def train(X_batch, y_batch):
    h_prev = rnn.initHidden()
    optimizer.zero_grad()
    batch_loss = torch.tensor(0, dtype=torch.float)
    
    for i in range(len(X_batch)):
        y_score, h_prev = rnn(X_batch[i].view(1,1,-1), h_prev)
        loss = loss_fn(y_score.view(1,-1), y_batch[i].view(1))
        batch_loss += loss
    batch_loss.backward()
    # Add parameters' gradients to their values, multiplied by learning rate    
    optimizer.step()

    return y_score, batch_loss/len(X_batch)

# %%
writer = SummaryWriter(f'logs/lstm1_{time.strftime("%Y%m%d-%H%M%S")}')

# %%
all_losses = []
print_every = 100
for epoch in range(100):    
    for batch in get_batch(X_train, y_train, seq_length):
        X_batch, y_batch = batch
        _, batch_loss = train(X_batch, y_batch)
        all_losses.append(batch_loss.item())
        if len(all_losses)%print_every==1:
            print(f'----\nRunning Avg Loss:{np.mean(all_losses[-print_every:])} at iter: {len(all_losses)}\n----')
            writer.add_scalar('loss', np.mean(all_losses[-100:]), len(all_losses))
            print(sample_chars(X_batch[0], rnn.initHidden(), 200))
# Out:
# ----
# Running Avg Loss:0.7671116590499878 at iter: 1
# ----
# 關南關，載號載呶。
# 鹿鳴露兮，予伯之。
# 睆彼都人，薄采其藻。
# 有兔斯首，燔之炙之。
# 惠而女馬，言綸之後，君子來朝。
# 奄有飛卉，維水湯湯，上入百神，神英簡女，鳴用棘服。
# 允召公育，以介我與。
# 三命之孫，作邑于煁。天子萬年，不我侮；命不見，如南賓之，人相憂矣，言韔之孫，四國是極。
# 南有樛木，葛藟縈之，有三百心，是用不幾，不我不見。
# 君子有酒，酌言大旅，女心忉遑，殆既大邦，作家之積。
# 譽處夭華，夫盈不詹
# ----
# Running Avg Loss:1.389125325679779 at iter: 101
# ----
# 如洵，既見求子，不我亨之！
# 匪卷者朅，亦可以簸，而微求之。
#
# 《邶風・承祀》
# 野有鵲之，采采芣苢。
# 君子所憇，我心傷悄；殽樂君子，逝不我思！
# 中谷有麥，朱芾斯戾，薄言捋之。
#
# 《邶風・采綠》
# 葛有襛矣，乘其實羽，綠水黃黃。菽藟召伯！
# 弭設騰泄五燕邶，振公君子，于以奠之。君子有喪，何求沼之？嗟女懷人，蘊踐發兮。江之速之，伐風發東？跂彼東門，播厥兄弟，于嗟乎騶虞！
# 江有汜，君子有食，桃之夭夭，莫敢遑處
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-cd9543bfe217> in <module>()
#       4     for batch in get_batch(X_train, y_train, seq_length):
#       5         X_batch, y_batch = batch
# ----> 6         _, batch_loss = train(X_batch, y_batch)
#       7         all_losses.append(batch_loss.item())
#       8         if len(all_losses)%print_every==1:
#
# <ipython-input-31-aed00f7a1920> in train(X_batch, y_batch)
#       8         loss = loss_fn(y_score.view(1,-1), y_batch[i].view(1))
#       9         batch_loss += loss
# ---> 10     batch_loss.backward()
#      11     # Add parameters' gradients to their values, multiplied by learning rate
#      12     optimizer.step()
#
# ~\Anaconda3\envs\ds\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#      91                 products. Defaults to ``False``.
#      92         """
# ---> 93         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#      94
#      95     def register_hook(self, hook):
#
# ~\Anaconda3\envs\ds\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      87     Variable._execution_engine.run_backward(
#      88         tensors, grad_tensors, retain_graph, create_graph,
# ---> 89         allow_unreachable=True)  # allow_unreachable flag
#      90
#      91
#
# KeyboardInterrupt:

# %%
print(sample_chars(X_batch[2], rnn.initHidden(), 10000))
# Out:
# 。
# 參差荇菜，磬浚之音，，惄如玉女；何國之孫。不盈頃也！
#
# 《邶風・瞻彼襛矣》
# 出宿于泲，詵日居體，如惔如育，寤穉善朝，誰亟君子，不我亨也。匪樂不述，永日方思！
# 戎辟匪曀，惠而不遄，
# 何以亡兮，于彼女子，不宜有觼！
# 居與子惠，歸哉歸哉，人我乎極，送我乎淇之賢。
# 充耳苦夭，于我不述！胡得七人，歸遠無父。
# 未見君子，不忮不求，用求之子，莫知我後！
#
# 《邶風・凱風》我諸且！俾我其陳，棘心則說，亦釣維絲。士曰何其？心之憂矣！
# 終風且曀，不日不曀，在用之子，有也不愚。寔命不來，靜言自之，與子偕心。
#
# 《邶風・終風》
# 綠衣之裳，其實其私。我其君子，不如景之。
#
# 《邶風・騶虞》
# 雄雉》摽有凱，匪澣孟子，送我不述！
# 終風且曀，不屑虺也，人后無然，女子惠也，徐方不多。申人兄弟，如飛有之；母氏如手，不民不忘，實屢如雲，徂心則降。
# 溥天之下，何嗟而微。
#
# 《邶風・君子于關；諸兄之夢，于嗟洵兮，乃求而無古朝其所！
#
# 《邶風・柏舟》
# 雄雉之茨，棘人日月，奮各有身；爲王爲士，日斯歸？，遠曷云哉！
# 摽其愬，踊躍用兵，報以求之，庶幾爰處。
# 有女者曀，秉心則嚏，胡然乎處！
# 終任且暴，如何人哉！不戢于楚，豈無爲好！
# 日居月諸，綠衣五總，委蛇委蛇，棘人右遊，何天不思！日居月諸。
#
# 《邶風・柏舟》
# 雄雉》壹葛，悠悠我思，寤言不寐。相林有穴，實維其則矣。
#
# 《邶風・終風》
# 習習谷風，爰白悠關，亦既覯止，不盈有行。我彼行潦，復自夭兮。
#
# 《邶風・騶虞》
# 雄雉于飛，勿翦勿敗，死澗之中，中心不說。
# 參差荇菜，鳴澣信南，惠而南山之執，于以食之，中猶是敢。
# 實迺求之，寤用其星，維實之子兮，在室則笑。南有樛木，今孌羊矣，殆其掇之。
# 昔契樂。我既平羽，常則同行，忉遠于寡人。
# 嗟我乎騶虞！胡君子偕心。
#
# 《邶風・新中》
# 雄雉于飛，頡之頏之，素絲五紽，居兄無弟。
# 云何其人，不我思馬。曷有匪也，上乎不敖。胡能有定，云何何求？何以下民，尚如哉！
#
# 《邶風・雄雉》
# 瑳而浥行，與子偕老。諸子有心，兩宴是憲。
# 宜爾子孫，懷諒兄弟，薄言濯愬！
#
# 《邶風・凱風》
# 敖以據，維葉有衣，執子之遠，不云日也！
#
# 《邶風・凱風》
# 雄雉于飛，不盈頃筐，夙夜維公，懷哉懷懷。
# 其衾在夏，好氏寤瘉，無我室家，悠我父兮。
# 罪卷也，柔孫之春，歸哉歸哉！
#
# 《邶風・君子苦星》
# 新羣黃歆，憂心如怒；
# 風雨在南，頃筐塈之。所謂伊人，靡所與同！
# 殷其靁，在河衣之，歸哉歸哉！胡能來雝，況也不忘。
# 終風且霾，中心不回，殷其靁，
# 人之舊聖，曷云其久！
# 維星在車，于嗟洵兮，維父母兄弟，終歸無止。
# 實覃實升，無悠悠悠，悠悠我思，夙夜無妻，中心不說。
# 狂綽有美，于嗟麟兮，不用其良，不回以歸，宜其云亡！
#
# 《邶風・雄雉》
# 凱風及曀，設欲干旄，誰謂良人，終朝荼煁。言刈其豵。淑之君子，于嗟斯之。
# 思無從？，胡逝我心！
# 舍彼有苦，維盈深涉，于嗟洵兮，如何人處！
#
# 《邶風・匏有梅》
#
# 《邶風・終風》
# 習谷風飛，西車乘馬，以猶，不我不覯，疚岡其遯！
# 履有闊薪！自牧歸荑，我心不說，耳子于道，如寡人之，我心不說，我心憂傷，諏食美人，胡逝以以居，云何其良。
#
# 《邶風・定之莪》
# 吹彼泱紽，就我懷矣！
#
# 《邶風・君子》
# 羆有苦葉，彼采芣苢，薄言我之。
#
# 《邶風・日月》
# 綠衣詳雨，如岡如雷。
# 言刈其臻，維誰之夭，不我無邪，則不云遠！
# 籩豆有楚，喪言歸，寤言不淑？
# 實有君子，寤寐無夢！唁爾君子，與子有行，云何吁矣！
#
# 《邶風・君子騶睆》
# 燕燕且棘，于嗟洵兮，用方有章，我心則往，胡然而無潰迨。
# 用有盈揚食在道，寤寐思之，與爾襛矣！
# 觱發五嚏，在浚之辟，王身不茹，荓云不亡，于嗟鳩兮！
#
# 《邶風・何有汜；既見君子，爲絺爲綌，懷婚姻之！
#
# 《邶風・柏舟》
# 綠衣黃裳，匪君子笑，歸哉歸哉！
#
# 《邶風・任那》
# 雄謨諸革，素絲五總，委如河人百矣！
# 江有棧，何日不能，寤言何求，瞻望其旂。
# 手兮氏，實之思》
# 有免斯汜，在浚其羽，未泮以雄，彤管有泚，不我過；日不惠，雖則遠矣，薺我不述！
#
# 《邶風・終風》
# 日居月諸，居鳴不惠，遠遠于農。
#
# 《邶風・雄雉》
# 日居月諸，棘嗟十兮，不我夙也，求我有之。
# 凡伊阻兮，載差載飛，髦斯違仇。
# 用其甘心，誰黑不遄。君子樂之，于以方思！靡有隱憂矣，以勖寡人。
#
# 《邶風・言報》
# 雄雉于飛，下上其音，棘心餞說，于歸不日。
# 薄言往愬，泣施之子。胡能其定，曷云能偕！
#
# 《邶風・柏舟》
# 雄雉于飛，在浚城退，摽無害。
# 言如何曷，不日有曀，無俾爾躬，我不我顧，往禋燕心，惄焉之石！
#
# 《邶風・魴關》
# 嘒彼深役，乘其深矣，有女無人。終日君子，宜家不寐，不述奮飛！
# 麟之秬兮，肅肅宵顧，施于聖善，不我思。
#
# 《邶風・擊鼓斯踊，燔彼棘否，遠矣與矣，棣不思遠，如帝悠悠。
# 絺兮綌兮，不日不曀，于嗟麟兮，既思子孫，百夫是悼。
# 隰桑有定，素絲五總，素絲五紽，得此無斁。
# 君子有喪，乃轉也壽；寧母誘之。
# 叔于中人，在彼中心，母氏不淑，日居行人，俾如召河，如切如玉。
# 兄弟君子，不可以據。王虛其身！胡能有定，自詒伊魯，母氏勞心！
#
# 《邶風・月鳴》
# 薪之碩，苦葉其泥。
# 既見君子，云何求之炤。曷云作聖？憂心悄悄！
#
# 《邶風・習習姊》
#
# 《邶風・匏彼襛矣》
# 凱風自南，兄弟伊衛，爲梟爲桃；民之來行，求我不述！
#
# 《邶風・塗卷》
# 賓之彊采，在浚之石。
# 《邶風・擊鼓擊擊燕衛宗毒誕橐其棘。
# 彼茁者照》
# 歸哉屏寡，遠英何人？將樂只且。
# 靡有定，云如何有？顧泣懷朝，終父母子，而無使尨！
# 肅肅宵征，頡飛訧之，王于之宮，趯飛黃星。
# 言曀定曀，不日其靁，寤言不寐，胡得處！
# 嗟反有苦，焉如氏孫，赳笑洵處！胡逝不能，胡能無良，朱速我訟；不樂只君子。
# 賓之質矣，胡能有良！
# 有潰有席，于歸不述！
# 昊天有詩，中心好氏。六轡自子，好女無休。君子有酒，謂我且之。
# 《邶風・匏有苦葉》
# 山川之思，言采其敖，平心之怒，歸不不能，俾爾思老，振振君子，不絺以立，我心悠悠。
# 瑳兮孌兮，振瞻伊搜，如浚好之，不遠干躬，不盈焉翦。
#
# 《邶風・終風》
# 俟我高鎛，食我六手，宜心好庶，寤爾無期。君子之心，何福不從。室芣高心，不忮不已？壹者之知，其餞于日，勞心琴粲。
# 草不靜言，心之憂矣，其問如何？胡能有定，雄善薄妻，如何釣悠。！
# 《邶風・習雉》
# 自招庶涉，振詒伊阻。
# 懷而君子，不稼不穡，夙寐在在，庶民之母。
# 有良有哀，言終其雨。
# 羔羊有石，委委宵人，如飛如瘁，執子之手，職思其盈，揖兮我涉良。我心憂矣！
# 吹彼深鳥，在浚之沚，可以茹。之子于歸，不我望心，既見君子，莫慰既來。
# 摽有梅，三反其之。自曀襭之，于以盈之。未今也入，云莫不死！
#
# 《邶風・凱風》
#
# 《邶風・雄雉》
# 綠衣始裳，有蘩有梅，薄言虺愬，萬友來也，母也不述！
#
# 《邶風・雄雉》
# 終風且曀，不崇奔思，哉哉歸哉，遠善知也；三之則僮，不日于愬，百辟其乎，如何七人，遠送于之。
# 君子歸，不我馬兮。胡能有定，棘心之說，今氏吹鎬，胡爲乎泥中心中！
#
# 《邶風・君子七月》
# 鍾鼓既飽，爰笑爰止。
# 實惠三南，猶來威儀。
# 爰采葛隤，召伯誘之。心之云亡，不忮不求，胡然而無思。曷人是君，匪送我百姓。
#
# 《邶風・騶茁》
# 摽有梅，在望深涉，委蛇委蛇何！
#
# 《邶風・終風》
#
#
# 【齊風】
#
# 《邶風・霾七死揚，六轡其雨。
# 我車見雀，言刈其衣。不求其星，有鷕檻鳴，于以嘒求，有心則退，終懷君子。
# 命我僮體，終鮮樂只。睠岡其居。
# 其雨如雲，庶士于歸。
#
# 《邶風・雄雉》
# 靜女五豝，窈窕淑人，反心則述！
# 瞻彼洛矣，維水之子歸，素絲五紽，室人所友。
#
# 《邶風・匏有襛矣》
# 姓爾之葉，爲賓爲乎，無他人氏，不可以爲。雖則有渚，匪澣我良！終窶且貧，德音古之，傷釣維氏，先夫之死。
#
# 《邶風・雄雉》
# 綠兮衣裳，綠衣朱裏。心之憂矣，不我幾歸，不能秣愬，遠兄弟豈。
#
# 《邶風・君子》
# 習習谷風，自火載飛，莫知其心，如匪兄弟，亂我不述！
# 彼茁者葭。壹發五豵。母氏勞苦！
# 土行苦人，寤言不寐，劬于以富，美孟爾之，百夫之思，臨于死多，我。
#
# 《邶風・君子崔石》
# 我有悠石，用喪率行，誰嗟隮之，績阻
# 子，實勞我說。
#
# 《邶風・終風》
# 雄雉于飛，于彼兕觥，薄言草愬，于豆之食，在浚之邛。
# 言回其居，與之退食。又顧匪報，不可以曀，如何人處。
# 雝雝鳴鴈，薄言美老。我不我與，不用其思，載冰載玉。
# 賓之石拜，莫迨其後，何能無良，此何人之人，寤言不寐，
# 孔泮且衎，不我送兮！我有匪只，不諒送遠。
# 濬爵不違，于林于棘。
# 死契七手，薄言不思，伊洽不樂。靜言歸息，無自嗣思，何誕之人兮，俾我入也。
# 坎其靁，不可奮飛，人尤之人矣！
#
# 《邶風・凱風》
#
# 《邶風・思茁斯》
# 日居月諸，不知而燕乎，右悠悠悠！不浚有沱，于嗟洵兮，君子偕朝。我有敦曀，云何吁矣！胡能有定，于嗟洵兮，何人之憂矣，遠母百後。
# 曀衣其蕨，有鷕深涉，于以歸哉，不我無卜。
# 謂伊人之，則在反春，之子于歸，不能求友。既思不忒，不用其思，無周無家？曷不云能？
# 慰招良朋，寤寐無燕，我心則說。
# 還而吁矣，于歸不報，如猶求遠，不夙不思，熾葉爲期。萬年于之。君子于釣，遠靜好逑。
# 《邶風・雄雉》
# 悠悠我思，素絲五紽，胥得于歸。
# 日居月諸，云何不信。
#
# 《邶風・新臺》
# 隰桑碩思，露五深矣，于歸不少，不良敢釣，委蛇委蛇，攜手同行，終遠且髦。
# 父母黃攜，我心則說。永言顧之，我心則降。
# 既差荇菜，亶于歸敖，宜爾子孫，不我思，取姬不濡，寤言不古？終子不見，俾我田；不我猷，以其德子，農夫之孫之，維行不述！
#
# 《邶風・雄雉》
# 賓之初筵，踊躍用兵，矣旋言歸，懷少不已，以以無禍，言罔無思。我心不說，薄人還愬，騷伊忡。
# 樂只君子，于嗟洵兮，母氏勞懷。
#
# 《邶風・雄雉》
# 新魴黃裏，采言舊遊。
# 平有鼠教，憂心如怒，不顯不尨，自詒伊阻。
# 期我士也，中心如燬。王于以敖之。
# 終風且曀，不以其靁，如遠如悼。維彼喈之，振怒不惠，女子我行。
#
# 《邶風・交茁我士》
# 嗟以報也，云何不能？黽騶七人，不可謂悠。雖無知也，洵之子之。
#
# 《邶風・何風襛矣》
# 將伯衣兮，中氏百游，此邦之人，實勞心同！
# 燕燕于飛，頡之燔之，之子于歸，不我獨也！
#
# 《邶風・柏舟》
# 雄雉于氏，棘心脫悄，如釣維氏，不非無良，好恐烈行！
# 物其懲，不惠于活，葛藟然音，願言歸，于嗟洵兮，今也遠矣。
#
# 《邶風・騶虞》
# 日居月諸，終燕不猶。
#
# 《邶風・雄雉》
# 匏有沱矣，之子于丘，無遠爲也，忘則不思！
# 式雉五豵，不如食信，不我過，求我心同說。
# 于嗟闊兮，如云不思！胡能有定，俾如兄弟，委蛇委蛇，宣笑同行。服鑒匪命，悠悠悠悠，遠送我無家。
# 蛇子子闊，憂心顧逑，定，尚我然也，告載與女，王事靡盬，宜其家室！
# 景彼者宴，信誰不日，願言則嚏。
# 兕觥其阻，魚躍吾兵，母兮子兮，不足慰慉；
#
# 《邶風・凱風》
# 終風且卷，維裳與心，不相在外，可以同行，薄言何思，棘心說手，踊氏盈所。我心匪席，不我以燕景室。
# 殷其靁，在下土判棘。我心匪石，俾國無侮！
# 桃雉夭夭，于以不胥，不諒人只。
# 謂天方艱，七日載總。
# 兄弟不敢，洵有子之，百謀命止。
# 山有覆虎，實右實廣，熾我心則也。
#
# 《邶風・賓之漘兮，有星有汜，在死總夭，不寤無曀乎，於焉行敖。胡能碩人秉，云何！人之。
# 召伯所憇，壹發五豵。伊還歸哉！憯不寐食寤，君子所妻，佗伐如何。
# 閔予小子，涉鷕鳴鳴，行國于侯。瞻望弗及，佇立以也？終子之人兮，我心不說。
#
# 《邶風・何斯襛矣》
# 其釣維何，維虺維曀，爲言之子，莫相其後，臨而也無容。我心匪席，不我以思，臨于淇，不我勞心降。瞻望弗之，迨其其良，如震自惠，歸云不諒！
#
# 《邶風・擊鼓》
# 沸奮泄泄，誰俾其反，惠而無棄。
# 濟遠夭夭，亦不遑諼泥。
# 鍾鼓體體，辟子歸兮，我心則說。
# 漢之廣矣，不云我鄘！
# 天之夭之，在浚之城，在浚之夭，不可潰思！
# 日居月諸，日月而多，王室于下。哀澣共人，曷云何歸！
#
# 《邶風・擊鼓》
# 悠悠古思，于嗟盈？靜言好之，日居居人！
# 母氏小人，胡考之好！
#
# 《邶風・雄雉》
# 衡門之舟，于嗟乎騶葉靡何不不寤，能國之無人。樂只君子，歸賂歸兮。
# 勉曀其注，願言無老，人聿其老，何斯違斯，我心則也。
# 式微處鎛，亶不已。蹻澣東方，薄言令之，令儀所阻。
# 哀我以祀，既盈反側。
# 君子于御，不浚朕也，遠蓋勞矣！
# 遡洄自城，以周乎咸也。
# 諄餱無筥，于歸陽不，如可以濯，惠而不季，不如也不忘！
# 維鵲有皮，在浚于干，涉釣不我廟。心之憂矣，莫捫自替，悠悠我思，不我無慰。
# 死爭》
# 自中矣勞矣，妣車孔阜！我心悠悠，悠悠我思，良士也我，薄言之活，嗟我不述！
# 未有侮棘，言葉也純，心之憂矣！
#
# 《邶風・擊鼓》
# 葛涉香，主樂歸！胡能有定，不如勞心心。
#
#
# 【邶風】
#
# 《邶風・君子》
# 謀馬巖蒸，宴爾新昏，師寡之屏，先實之革，寔哉歸哉！
#
# 《邶風・日祀》
# 彼茁者蓬。壹發五豵。母氏勞苦！壹後君士！無思樂泮樸，不愧于魯，于嗟猶兮，寤言不寐，威儀反也。
#
# 《邶風・雄雉》
# 擊鼓其鏜，其釣維處，何日不居息。
#
# 《邶風・雄雉》
# 匏有瀰方，亦于城中。王事靡盬，乃滌也思，母氏劬勞！
#
# 《邶風・蝃蝣》
# 冬之姨，于日三羽，手實爲手，之子于中，以爲乎中亡，宜心居憂，委蛇委蛇爰遊。釣如好人心，不弔其傷。我宣韓侯，爲曰爲之，于嗟洵兮，如匪澣苦，不氏從降，中心之革。
# 百釃教旅，言采其泣。被嗟僮姊，云誰之思。
# 山有深涉，戢不用息，不慰以歌！
#
# 《邶風・靜反》
# 日居月諸，鞏右淑子，善誰其思！壹發五豵。往人居皮，無不爾思，會姬于朝，終遠兄弟，莫知其耘，黍稷何夕，振振君子，不云不綠！
# 微只君子，不如食處；！
#
# 《邶風・雄雉》
# 習習谷風，言采其蕨。未見君子，憂心
