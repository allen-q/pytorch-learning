# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import time
# %matplotlib inline

# %% [markdown]
# # Load Data

# %%
with open('../data/tangshi_wuyan.txt', 'r', encoding='utf-8') as f:
    data = f.readlines()

# %%
data=''.join(data)

# %%
data[:100]
# Out:
# '唐代五言绝句\n\n王维\n鹿柴\n空山不见人， 但闻人语响。 \n返景入深林， 复照青苔上。 \n\n竹里馆\n\n独坐幽篁里， 弹琴复长啸。 \n深林人不知， 明月来相照。 \n\n送别\n山中相送罢， 日暮掩柴扉。 \n春'

# %%
# data I/O
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print(f'data has {data_size} characters, {vocab_size} unique.')
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# data has 8490 characters, 1525 unique.

# %% [markdown]
# ## Encode text data using one-hot encoding

# %%
X_train = np.zeros((len(data), len(chars)))
char_id = np.array([chars.index(c) for c in data])
X_train[np.arange(len(X_train)), char_id] = 1
y_train = np.roll(char_id,-1)

# %%
X_train.shape
# Out:
# (8490, 1525)

# %%
y_train.shape
# Out:
# (8490,)

# %% [markdown]
# # Define some help functions

# %%
def get_batch(X_train, y_train, seq_length):
    X = torch.from_numpy(X_train).float()
    y = torch.from_numpy(y_train).long()
    for i in range(0, len(X), seq_length):   
        id_stop = i+seq_length if i+seq_length < len(X) else len(X)
        yield([X[i:id_stop], y[i:id_stop]])

# %%
def sample_chars(X_seed, h_prev, length=20):
    X_next = X_seed
    results = []
    with torch.no_grad():
        for i in range(length):        
            y_score, h_prev = rnn(X_next.view(1,1,-1), h_prev)
            y_prob = nn.Softmax(0)(y_score.view(-1)).detach().numpy()
            y_pred = np.random.choice(chars,1, p=y_prob).item()
            results.append(y_pred)
            X_next = torch.zeros_like(X_seed)
            X_next[chars.index(y_pred)] = 1
    return ''.join(results)

# %% [markdown]
# # Create a LSTM model

# %% [markdown]
# ## Define model class

# %%
class nn_LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.lstm = nn.LSTM(input_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        
    def forward(self, X, hidden):
        _, hidden = self.lstm(X, hidden)
        output = self.out(hidden[0])
        return output, hidden
    
    def initHidden(self):
        return (torch.zeros(1, 1, self.hidden_size),
                torch.zeros(1, 1, self.hidden_size)
               )

# %% [markdown]
# ## Create an instance of the LSTM model

# %%
hidden_size = 128
seq_length = 25

# %%
rnn = nn_LSTM(vocab_size, hidden_size, vocab_size)

# %% [markdown]
# ## Define Loss Function

# %%
loss_fn = nn.CrossEntropyLoss()

# %% [markdown]
# ## Define an optimizer

# %%
optimizer = torch.optim.Adam(rnn.parameters(), lr=0.005)

# %% [markdown]
# ## Define a helper training function

# %%
def train(X_batch, y_batch):
    h_prev = rnn.initHidden()
    optimizer.zero_grad()
    batch_loss = torch.tensor(0, dtype=torch.float)
    
    for i in range(len(X_batch)):
        y_score, h_prev = rnn(X_batch[i].view(1,1,-1), h_prev)
        loss = loss_fn(y_score.view(1,-1), y_batch[i].view(1))
        batch_loss += loss
    batch_loss.backward()
    # Add parameters' gradients to their values, multiplied by learning rate    
    optimizer.step()

    return y_score, batch_loss/len(X_batch)

# %%
# If TensorboardX is installed, we can log and visualize loss in Tensorboard
writer = SummaryWriter(f'logs/lstm1_{time.strftime("%Y%m%d-%H%M%S")}')

# %%
all_losses = []
print_every = 100
for epoch in range(20):    
    for batch in get_batch(X_train, y_train, seq_length):
        X_batch, y_batch = batch
        _, batch_loss = train(X_batch, y_batch)
        all_losses.append(batch_loss.item())
        if len(all_losses)%print_every==1:
            print(f'----\nRunning Avg Loss:{np.mean(all_losses[-print_every:])} at iter: {len(all_losses)}\n----')
            writer.add_scalar('loss', np.mean(all_losses[-100:]), len(all_losses))
            print(sample_chars(X_batch[0], rnn.initHidden(), 200))
# Out:
# ----
# Running Avg Loss:0.7109438180923462 at iter: 1
# ----
# 代五言绝句
#
# 蜗牛
# 腥涎不满壳，聊闻芦村朝，秋风多钱绝。
#
# 相忆南所思，庭尽手头一。
# 但见泪痕湿，山南第一花。
#
# 送别夜上定，昨夜东江雨。
# 长料鼠与已，坐待碧波中。
#
# 杨雯
# 北客
# 清旷天所依，曾向雨中忘。
# 灞桥风雨夜，年光观东东。
#
# 柯芝
# 横江
# 横江一片碧，携将万黄原。
# 谁谓物无名，云檐复濯思。
# 悠然钓乡畔，邻客坐落冷。
#
# 马知节
# 枯梅
# 床前溪水路，阴黄生水黛。
# 拙于用显晦，踪便照酴蘼。
#
# 旧过
#
# ----
# Running Avg Loss:0.6730500864982605 at iter: 101
# ----
# 仲令
# 绝句
# 吴李叔
# 井游空山不剪时红清速，恋恋忽复稀。
# 烂日到扬发，君江清子数。
#
# 司马光
# 野江
# 聊行弄芳草，今不看嫌心。
#
# 岐山宦阁雨，欲原双泪横。
# 粉身能报国，借与但山海。
#
# 赵师侠
# 李雁
# 无台植
# 野元
# 寥卧九相照，东日暮复床。
# 仙女瑟瑟衣，寒尽不知年。
#
# 况周遇风
# 云业转林色，未待月黄昏。
#
# 送林行
# 刘子元
# 苍阳不禁冷，破褐出残絮。
# 野性岂欲下，只是乱归来。
#
# 昭君 明·杨灵，秋江裙带漪。
# ----
# Running Avg Loss:0.618951216340065 at iter: 201
# ----
# 听。
#
# 周孚
# 公佐索诗
# 堆浸石根冷，风高处数飞。
# 欲怜湖上山，鸥鹭亦迷群。
#
# 贺铸
# 泠沼
# 明月照齐州，花光被动曲。
# 不见棹回人，明月驹隙过。
#
# 蚕
# 斫水水可赵，续弦弦可完。
#
# 谓物老江水色，照深应断花。
#
# 左纬
# 许少弄德高，曾秋去年雪。
#
# 短棹风生，何许小残曲。
# 俗人诗飞里，残余频泪滴。
# 松草多稚旧，马就平沙涉。
# 不在。飞事，留取隔帘看。
#
# 范成大
# 双燕
# 底处双飞鸳，江雪见南去。
#
# 周阿崇
# 题绿波
# ----
# Running Avg Loss:0.62886733725667 at iter: 301
# ----
#
# 秋载干出矣，上藏亦英华。
# 翻许傍去不，山云不劝归。
#
# 采君
# 北夜几烟恨，千叶乾红寒。
#
# 收茵
# 自题失山鹤， 静闻小语红。
#
# 昭君石足色双，花开一春风。
# 如何临欲别，只待妾衣裳。
#
# 杨杰
# 题余杭步伍亭壁
# 欲外秋已晚， 遗钓归山雪。
#
# 高风吹古乐，宛如发为人。
# 只在眠如发，邻过杏花来。
#
# 黄金无足色，山泪如执中。
#
# 龙栖欲寻住，西关避人语。
#
# 周文璞
# 玉晨观
# 野笋冲泉出，花作天涯冷。
#
#
# 文政
# 玉
# ----
# Running Avg Loss:0.5274714294075966 at iter: 401
# ----
#  际月头间。
# 贪学耆绮面， 只知故乡事。
# 而今窥牧马， 闲绿窗未。
# 襄阳多稚子， 深宫二十年。
# 空林应寒树， 时梅近黄昏。
#
# 调咏
# 终南窗中
# 泉却烟渚主，风吹藤叶飞。
#
# 看山
# 自昔一宫折晓， 万径人欲少。
#
# 西鄙人
# 宿建德先
# 宿建德江
# 移舟泊烟渚，幅和音窗死。
# 粉身能报国， 莫处忽误。
# 余生天 舟，犹应是故人。
#
# 王之涣
# 宿建德江
# 移舟泊烟渚， 江清月近人。
# 后性岂石转， 此物最云处。
# ----
# Running Avg Loss:0.5834237636625766 at iter: 501
# ----
# 常子然寄老前，离知两苦长。
# 如来松满月，今为茫为书。
# 未落知不好，月明洲渚生。
#
# 度水
# 庭薄作归，晴便照空名。
#
# 犬吠隐团舟，篙龙叹业虫。
# 不知春去看，君动夕阳中。
# 木鱼声渐急，山衲下云酿。
# 水人幽苔秀，不是故人来。
#
# 舟句
# 神出溪水来，岂盈本风雨。
#
# 江水夜韶乐，暮为还山雨。
# 行山乔木木，缄口过平生。
#
# 落水夜韶乐，看入洲枫松。
#
# 谯国嘲提壶
# 何处提提屏山深千楼
# 居民覆其依，全片是何人。
#
# 渔台
# ----
# Running Avg Loss:0.5611210338771343 at iter: 601
# ----
# 毛轻。
#
# 严参清公步
# 无仰
# 北点复一日碧，愁下濯清涟。
# 而元桂叶舟，秋日行船归。
# 只在入菱舟，薄间如苦灭。
#
# 柳
# 临水送伍曾，濯清睡形胡。
# 谁门手天别，那忧世上风。
#
# 乍归
# 城城昔散策，秋远鲈会思。
# 别怜小吾恋，欲灯不禁到。
# 遥知今夕梦，到蜀到钱唐。
#
# 丽泽
# 长哦伐木篇，前龙又春春。
#
# 严羽
# 仰上渔渔船，千金卧濯香。
# 倒影射清?，暮归风水光。
# 莫猿无归处，薄能知心时。
#
# 陈恬
# 子规
# 野花下意已，生
# ----
# Running Avg Loss:0.5371834607422352 at iter: 701
# ----
# ， 杳头僧闲霜。
#
# 刘长卿
# 送灵澈
# 苍苍竹林寺
# 怀褐
# 床前明光远。
#
# 龙兴
# 东日照瓦霜，欲晴明绮事。
# 静影射清事，乘风过天辉。
# 低怀耿伍面，犹散汉宫归。
#
# 文政
# 题胜业寺
# 山鸟无凡音，山云城挟晚。
# 墙王谢双事，清以凉十时。
#
# 松已句送发，低寒梅黄闲。
#
# 昭君 力·缪彤
# 愁怀相催发，一生无别离。
# 灞桥风雨雨， 应花日来。
#
# 东开
# 天月熊横碧， 江临欲云。
# 新人不知处，且作天涯冷。
#
# 邵定
# 渔家
# 一
# ----
# Running Avg Loss:0.5209695996344089 at iter: 801
# ----
#
# 绝眠 禽乐，庐山独自来。
# 但从中 梦，那共空来人。
#
# 乍归
# 书登临水急， 静听松风寒。
# 更人低城宫，相看不知草。
# 他时双飞真，翻忧世上寒。
# 沈应千行月，萧上去来人。
# 清更作双来，还悲旧流水。
#
# 濯清玉
# 送僧歌
# 霭花于瑶光殿山下， 日暮归来新。
# 行知见是客，风吹藤叶飞。
#
# 满片清天水舟官风吹斯，流花未头僧。
# 今更作双暮，还从旧宇归。
# 沼如今是客，凌寒棠黄昏。
#
# 方景绚
# 宿出岂作作独少浓
# 绝句
# 聊
# ----
# Running Avg Loss:0.49750377997756007 at iter: 901
# ----
#
# 江花泊可拒，切勿爱空名。
#
# 西溪
# 西风吹木叶，庭户作凉时。
#
# 刘子?
# 葵花－自注俗名一文帆
# 庭处际
# 乐，凌舟容叹滴。
# 触著今朝手，如经新雪下。
#
# 蚕
# 大沼
# 乘上怀
# 暮为书
# 学练桧
# 鸟语何院壁
# 天民识招风，今海定林可。
#
# 孝祥民
# 早行
# 冬曦如村酿，奇温止须臾。
# 行行正恙尽，寒灯坐将灭。
# 可怜湖行路，春老袅烟丝。
# 夕阳溪上树，山是不知作。
# 寂寞幽岩下，不是故人?。
#
# 米黻
# 怀南唐砚山
# 砚山
# 千里竹城
# ----
# Running Avg Loss:0.4886714307963848 at iter: 1001
# ----
# 。
#
# 严羽
# 懊侬歌
# 山恨
# 愁落行李速，再拜菊花前。
#
# 薛峪
# 蓑衣步
# 一日三丈发，赤鲲巨莫逃。
# 日暮鱼已尘，不待傍君飞。
#
# 刘文晦
# 种远五外山，寒灯坐将灭。
# 余香被草木，秀擢峦麋鹿。
#
# 斯植
# 古乐府
# 千里漾中中，后与待可数。
#
# 朱子
# 事衣周
# 三日落厨下，与归南书绝。
# 过者见瑟瑟，露归每幽花。
# 寸心即知已，不用世人知。
#
# 张至龙
# 演雅
# 千日酒阴橘，时有过杨家。
# 役灯茅帘日，过别劝归去。
#
# 羽扇
# 元色煮
# ----
# Running Avg Loss:0.4583731308579445 at iter: 1101
# ----
# 古，飘然一烘飞。
#
# 徐铉
# 题雷公井
# 霭昔一溪水，风静清香来。
#
# 龙岁数梅里无足色，梅花几坞香。
# 如何有所流，应明月春来。
#
# 题定林壁怀李叔时
# 云与渊明出，风随禀寇还。
# 行岐今夕阳，时涵万古情。
# 拙于用显晦，踪应人故乡来。
# 古喧长不到，泣向山头飞。
#
# 潇湘桐庐郡
# 潇洒桐庐角，万里孤难进。
# 不惜充君庖，为带香边立。
#
# 代金无水仍岭，盖是东无色。
#
# 赵崇罟
# 梅坞
# 仰天京露转，风回亦逢春。
# 见有办欲性，
# ----
# Running Avg Loss:0.47515274353325365 at iter: 1201
# ----
# 山影南国，屐寒早厌上。
# 月来一点望，东开早几雨。
# 水来还自笑，下郎遗画真。
#
# 朱子
# 初牡
# 明光小林里，只在襄东西。
#
# 阳和
# 朱子傍
# 清霜
# 形树何伍国，真能有桃乡。
# 莫遣儿童撼，留看著来尧。
#
# 采菱舟
# 欲长玉莺落，惨淡频泪指。
#
# 苏辙
# 璎万峰
# 昨日清月色，全海以黄水。
# 行小麋禽根，摇落冷江树。
# 月光作去望，山衲下云雪。
#
# 高翥
# 和刘彦冲潭溪
# 屏无阶飞酿，奇温止须臾。
# 长恐浮云生，为鹭亦迷群。
#
# 孤
# ----
# Running Avg Loss:0.43686175405979155 at iter: 1301
# ----
# 卷帘主
# 城落深，过城到钱唐。
# 县市容吾恋，江上脱实尖。
# 欲得山中人，不作百壁远。
#
# 西屿
# 系舟西岸边，幅巾子雪树。
# 鸳著湖烟晚，不妨相忘雪。
# 岛屿花木深，携叶无人相。
#
# 羽扇临元·杨克园
# 东壑
# 云卧苍梧叶，再拜菊花寒。
#
# 缪啼
# 寻台子怀头，今登生凉来。
# 鱼年年我下，山禽不劝归。
#
# 刘文晦
# 种梅
# 佳树应知我，相逢无别崇。
# 结束作男儿，与郎牵百丈。
#
# 湘语素少唧，水望无苦雨。
# 不如两忘机，石上跏趺坐。
# ----
# Running Avg Loss:0.36837911494076253 at iter: 1401
# ----
# 复立春。
# 白外人
# 往岁贪携方， 积听浮声晚。
# 荷声何满子， 散听松风寒。
# 古调虽自爱，风高黄芦稀。
#
# 昭山
# 忆昔游九
# 清浸石根发，辛静闻?雨。
# 云影不道人， 低梅此间灭。
# 一花惊妾后， 积雪浮云端。
# 唐湘比体古，和爱乱阶飞。
#
# 谯国嘲提壶
# 何处提溪上
# 归书自天柳名移白雪，花花渐石开。
# 眠鸥知让客，飞过蓼花洲。
#
# 韦应物添秋风雨，片散永和春。
#
# 前亭
# 横江一片片洞杂题见鱼
# 功牛
# 团团凌风桂
# ----
# Running Avg Loss:0.3957364143431187 at iter: 1501
# ----
# 发方良矶，暮宿白水湾。
# 宽作一声作，寒有繁实尖。
# 今行且绮客，马涵万古情。
# 笑问采花夜，清看落知时。
# 故应今夜月，摇落伤人思。
#
# 张他时过战足，春日暮形器。
# 但见泪痕湿， 闲坐说玄宗。
#
# 李频
# 掩梅临水色，前寒徒凉穷。
#
# 钓台
# 楼花数江曾，濯人暮采聊。
# 他时惊妾梦，雨月渐无絮。
# 山看江争秀，风著今古真。
# 离情被横笛，吹过乱山东。
# 日暮飞鸟归，翻忧世人多。
#
# 晁冲之出出槛，飞日照空驿。
#
# 周文璞
#
# ----
# Running Avg Loss:0.39937741681933403 at iter: 1601
# ----
# 西及花时而后已殂因成诗见意
# ，花村人乘青。
# 一日复一日，看看众花上。
#
# 答妇兄林公遇
# 恨予行所思
# 曾向春来，不作百年看。
#
# 晁补之
# 国子监暮归
# 杖履清晨往，缣囊薄暮归。
#
# 薛孝祥
# 次东坡先
# 向春行西中，长趁沸濯清。
# 莫学武陵人，春是滴芭蕉。
#
# 司马潭
# 古卧不可患，还是故人?。
#
# 影爱十载事中，小笔碧波苍。
#
# 陈造
# 泊上虞驿来，曾向断晚。
#
# 晚上
# 往日贪奇立，庭户作凉时。
# 过者见酒里，跏擢忆宇归。
#
# ----
# Running Avg Loss:0.3753558741509914 at iter: 1701
# ----
# 代五言绝。
#
# 寓兴
# 东日照瓦霜，江行尽丘壑。
#
# 鲍当
# 春上
# 西窗枕寒池，池作百草死。
# 竹外立寒枝，山南又春雨。
#
# 徐铉
# 题雷公井
# 霭水公湖花，出卧著西红。
# 贪学耆是风，无此正可梦。
# 江前溪一树，凌雪过相忘。
# 低迷罗箔风，泣向西窗雨。
#
# 墨鱼怪何芦，岁暮音泪横。
# 记著今朝阻，回前沙一规。
# 千秋山中在，看叶乾红飞。
#
# 王安
# 题胜业望，千金寿仲连。
#
# 寓兴
# 东望泰岳松，春风折赠时。
# 而今三丈树，元门但知
# ----
# Running Avg Loss:0.3382923376560211 at iter: 1801
# ----
# 爱西溪好，长忧溪水穷。
# 山川宛如草，不个船东闲。
#
# 自君之出门汉江花时无心，策欢以望春。
#
# 陈允平
# 题城玉
# 西风吹秋霜，江天天涯冷。
#
# 送离补之碧，梅向是损神。
# 沈思宦去人，东日是数山。
#
# 段明
# 上思
# 与业双其汉，和梦敢思上。
#
# 后圃
# 浇花惟要早，芟草不知名。
# 忽因风雨尽，全叶泣湍两。
#
# 送桂
# 渡风吹木苇， 遗冬绿葱絮。
#
# 送别
#
# 刘卿公
# 空生不畏巧，南墙补数茎。
#
# 岐石仍晁来，披襟复挂冠。
# 机
# ----
# Running Avg Loss:0.37092002615332603 at iter: 1901
# ----
# 听。
#
# 周紫芝
# 昨花坞
# 种梅溪水渚，久与牧相忘。
# 幽人故乡来，竟作亦涯照。
# 谁家怨曲后，如苔满树身。
#
# 晁冲之
# 双光
# 欲下问暮去，江月照青菱。
# 草远正须发，缄口复相腾。
#
# 陈恬
# 晚下不须此，缣囊薄暮归。
#
# 白云峰
# 湖上峰争碧，此峰藏白山。
#
# 晁冲之
# 葵花－自注俗名一文红
# 绝树月光作，暮宿去人网。
# 遥然茅帘日，不作百年看。
#
# 煮为隐腥
# 子日碧亭绝，千里白僧时。
#
# 柯茂节
# 早行
# 泊上虞驿来，暮亦白白菱
# ----
# Running Avg Loss:0.352248689904809 at iter: 2001
# ----
#
# 秋怀
# 空成玉击筑，奇龙永和郭。
# 幽猿玉求漏，愁落行人心。
#
# 乍归
# 宫满无南物，飘然在云花。
# 出鱼长过客，长趁钓船归。
# 莫作闺中寒，且作天涯冷。
#
# 段明
# 上罗令
# 故乡
# 城度
# 吟舟阿波简，林人双泪单。
# 不知今夕梦，到蜀到万壑。
#
# 东渚
# 公体
# 头远九相照，且作天照空。
# 记著今朝转日， 恨梅花寂。
#
# 大慈大
# 岁暮晚来外，千生南飞绝。
# 无处写丁多，相看，花眉。
# 蛛网挂风里，摇思无劝幽。
# 水蟾生佛根，出作天
# ----
# Running Avg Loss:0.3238531667739153 at iter: 2101
# ----
#  疑是地上霜。
# 铅衣枕
# 山水音书绝， 但闻未归响。
#
# 樵至相出明月，高斋卧看山。
# 退公聊自足，无处不可归。
#
# 乍西
# 横江
# 亡生深林立， 金头思故乡。
# 墙元知明金，未是不归来。
#
# 雷公凌
# 陈怨
# 空山不见流， 鸳物应相思。
# 夕阳深限用， 能饮一杯无。
#
# 元稹
# 行宫
# 寥落古行宫，寥前溪上起。
# 惟应诗卷里，偷画桂州山。
#
# 春万
# 隐瑾苍
# 郎百溪
# 雁下不见绝， 言师采药去。
# 役役为人劳，散出东失频
# ----
# Running Avg Loss:0.32800093486905096 at iter: 2201
# ----
# 常子然寄茶谢之因简任伯
# 谏议茶犹送，郎官迹已?。
#
# 落叶
# 往花未阳无，寒林夕照边。
# 旧片小湖上者，心如被濯短。
# 群心即知回，月落洲渚生。
#
# 春晴
# 新春十数山，暮为还山雨。
# 忽著千载事，何啻使风人。
#
# 刘子?
# 十日举千里，乾花翻能缣新。
#
# 江上
# 溪水漾西风，西海定几时。
# 种入眼江里，吹过乱山东。
# 不忧雷雨作，头角本非真。
# 著闲郑公客，江口西雪寒。
#
# 况羹野
# 湖山怀
# 昔闻仍依山，春便照空驿。
# 机心忘
# ----
# Running Avg Loss:0.297079515978694 at iter: 2301
# ----
# 毛轻。
#
# 程先
# 和人感秋韵
# 秋风
# 疾风拔枯楠，天作寒前香。
#
# 杯盘
# 杨立扇
# 鲦语去不归，户作两年东。
# 大阴山中冷，中日有人起。
#
# 新春
# 春风
# 归来天一发，沙不敢过上。
#
# 云关
# 清衣观
# 恨予行李速，愧子酒杯长。
# 想家秋影里，归意过前村。
#
# 大慈大去双前，清子落花飞。
#
# 各但知临提字，城杖东薪起。
#
# 答妇兄林壁
# 严流
# 向朝毛轻碧，指与未来人。
#
# 韬参
# 散策下亭阿，叶鱼万古光。
# 野性岂功帘，舣深猿已忘。
# ----
# Running Avg Loss:0.29146420085802677 at iter: 2401
# ----
# ， 杳杳钟声晚。
# 欲尽不知愁，愁夜顾相东。
# 唐龙筝
# 刘过
# 飞蝶捎风絮，宛在未来人。
# 退今三采去，元月思已真。
#
# 恭宗
# 蚕妇
# 游闻不禁冷，误把峦扃触。
# 倘无鼠与盗，神日东来起。
#
# 柯希谦
# 江水边已瘦，冒寒开雪花。
# 尧羽幽岩里，共跨山头鹤。
# 灞桥风雨夜， 明月来相灭。
#
# 金昌绪
# 归日光来高处提曾公卷后
# 玉台石飞霜， 朝无到火织。
# 杨上
# 采树吹所笛，乾花落石床。
# 知明未须论，时时感长驿。
# 谁知身
# ----
# Running Avg Loss:0.2676436472311616 at iter: 2501
# ----
#
# 送陈令归无为
# 楚水漾轻碧，楚花飞乱红。
# 日行景陵去，脉散亦鸡去。
# 莫遣儿童撼，留看著斜封那。
# 莫教被风?，清林西窗雨。
#
# 鲍当
# 秋江夜鸥人，鸥鹭亦衣鱼。
# 欲雪鸪童子，摘赠故人来。
#
# 小舫行乘月，却紫定几时。
# 日松飞鸟人，愁立如许虫。
#
# 大慈大水清·，庭鸣不可亲。
# 别后应相忆，能继西渚生，花寥空露白。
#
# 桃李涣
# 隐隐逸
# 西风动南故， 君渡正误故。
# 但原保天真，徐共春风枝。
#
# 青草生来中，真个是何
# ----
# Running Avg Loss:0.24630362421274185 at iter: 2601
# ----
#
# 刘子?
# 早行
# 西江
# 向行峰鸠山，露与去年未。
#
# 朱子
# 莲沼
# 亭前钱唐住，向子试蛾眉。
#
# 兰亭
# 何满子
# 纨扇
# 纨扇本招风，曾将热欲生。
#
# 朱子
# 莲沼
# 亭亭玉芙蓉，忍泪别僧时。
# 梅著今行雁，春风晴时名。
#
# 张孝祥
# 次东坡亭生韵
# 君万里分路，请子试濡笔。
# 先先小舫春，指与未来人。
#
# 吴龙翰
# 初凉
# 冬迷罗钩秀，天寒陟彼冈。
#
# 薛峪
# 蓑衣步
# 水浸石根冷，风回折涯时。
# 燕蟾生佛金，凌寒泪妾别。
# 水落何所依，
# ----
# Running Avg Loss:0.2572975119575858 at iter: 2701
# ----
# 。
#
# 门柳
# 看尽门前柳，愁多白发新。
# 灞桥风雨夜， 应知故人事。
# 溪声何满子，高叶杏花寒。
#
# 淮上遇来
# 玉台体
# 东卧伤春巧，云与牧相思。
#
# 黄庶
# 和刘彦冲之客
# 梁成向知过，秋生鲈会思。
# 卷帘了清景，头手坐抱许。
# 莫遣儿童撼，留看著千载。
#
# 柯茂谦
# 江水稻生月，篙亦鲈院啼。
# 妾当年少日，佳立作凉中。
#
# 牟岘
# 夜长
# 向怜游瑶巧，金香频人听。
# 谁家有茂叶，千叶杏花寒。
#
# 吴龙翰
# 侠居
# 渔家
# 送君壁，携
# ----
# Running Avg Loss:0.24992232400923967 at iter: 2801
# ----
# 古，飘然一烘尘。
# 山川宛如旧，犹带归来人。
#
# 米黻
# 怀南望驿白云诗
# 向晚雨翠击，春瘦怯罗衣。
# 群生各有性，桃李但争春。
#
# 入山
# 都迷去时路， 此物最幽思。
#
# 李频
# 渡汉江
# 岭外音书绝， 经冬复摇。
# 老处芳草多，未秀井舟里。
# 良枝持赠君，犹带去年来。
#
# 送王补之行风忽作因题四句于
# 雨花忽
# 南国觅佳国听柳
#  舟江入雁下碧， 上误客梦。
# 老动若木漏，南唐坐定竿。
#
# 昭君曲 明·莫介
# 一烘天欲出， 莫是
# ----
# Running Avg Loss:0.2248918427154422 at iter: 2901
# ----
# 山夜雪
# 夜深寒妥帖，前村人断绝。
# 可知圣人意，冒尽与窗远。
#
# 张舜民
# 纨扇
# 纨扇本招风，曾将热开手。
#
# 濯清亭
# 龙卧苍山
# ，风吹藤叶飞。
#
# 龙本止
# 披侵提壶为，庭户作凉时。
# 一日复一日，看看众花上。
#
# 丽泽
# 长哦伐木篇，偶水清绮眠。
# 不得山水去，一叶襄东碧。
#
# 崔山
# 渡江泊
# 绿螘坞
# 雁花归
# 西佛覆其思， 黄河入海流。
# 夕阳溪上树，吹过乱苔东。
# 如何临欲别，却上是归来。
#
# 井泉
# 山高泽道若归书俗
#
# ----
# Running Avg Loss:0.23471613571047784 at iter: 3001
# ----
# 陈与义
# 葵水飞泊上
# 松壑
# 头阳溪上人，千亦照莫峰。
# 想见同来者，俱非第二流。
#
# 钓台
# 穷鳞无处，谁得傍君衣。
#
# 牟岘
# 东里色苍苍，盖抹满莺声。
#
# 新蔷
# 片点湖上外，俱非临水边。
# 低迷采菱舟，不在古书中。
# 县市容吾恋，江潮不汝期。
#
# 钓台
# 长哦伐木篇，元·春恨子。
#
# 微闲
# 湖上觅佳人，天雨半青黄。
# 谁家铉时回，真个目雪水。
#
# 刘克庄
# 宿居
# 湖上移鱼子，初生不畏地。
#
# 严羽
# 懊侬歌
# 夜光作书柳，春晴香
# ----
# Running Avg Loss:0.22906710769981145 at iter: 3101
# ----
# 复立春。
# 近乡情更怯， 更上一杯无。
# 欲穷千里风，风回翻寂数。
#
# 芳草
# 古调虽自爱，天水边人识。
# 大孤山下路，何不博凉州句
#
# 江
#
# 蚕老无怪日， 积雪浮云端。
# 林表明霁色，寒间坐始头。
# 谁知青冢别，过食坐定空。
# 草小舫行影，坐待记衣裳。
#
# 王仲素
# 归去词烟腻，欲静暮建深。
#
# 刘文晦
# 种梅
# 佳人天一方，岁如好花未。
#
# 白龙翰
# 漾舟牟尼颗， 江碧窗雨。
#
# 晁补之
# 国目监亭鱼草岳绿， 名成一寒香。
# ----
# Running Avg Loss:0.24699975226074458 at iter: 3201
# ----
# 发方良矶，暮宿白云香。
# 移　沃蟾影， 莫是□砧归。
# 但见泪痕湿， 闲宋隐玄宗。
#
# 李频
# 渡汉江
# 岭外音书绝， 云车古已原。
# 却上曹亭望梁寄与因题隐清亭
# 西江雨气浓，林人黄凉雨。
#
# 陈鼓际
# 苍壁立积适， 不别人看客。
#
# 江上往来人，元为汉草死。
# 行来今台畔，袖手看落日。
#
# 陈与回
# 春凉
# 西窗枕寒池，赤鲲巨莫逃。过鲦争何宫，萧夜汉凉欲。
#
# 江上
# 江水漾头雨，芟海热桃生。
# 却上曹亭望，鸥鹭亦迷谁。
# ----
# Running Avg Loss:0.23097638867795467 at iter: 3301
# ----
# 西及花时而后已殂因成诗
# 湖上玉提壶，鹃许小百刀。
#
# 陈渊
# 题绿波亭
# 南浦江波绿，阳关柳色青。
# 心如两忘机，摘向百长。
#
# 濯清亭采住，松雪旧复时。
#
# 刘子?
# 早行
# 驿来清树下，出没风吹如。
#
# 小语双栖叶，千秋微行红。
# 如何郑公客，海棠春贵妃。
#
# 潇湘桐庐郡
# 潇洒桐庐蕊，庐郡不知年。
#
# 忧雷雨月出书
# 底处双飞外，催科不到门。
# 人闲牛亦乐，海角亦逢春。
#
# 胡维
# 和晏相公索南望，花名亦空时。
# 水如璎其趣，
# ----
# Running Avg Loss:0.22486543659120797 at iter: 3401
# ----
# 代五言绝句
# 人行正择地，海棠春贵妃。
# 九尽不知愁，愁落行人心。
#
# 家铉翁
# 寄江南故人
# 愁帘天寒池，池边老松树。
# 渴猿诗自槛，折又边人识。
# 收外江行寞，傍观上渡起。
# 野怅江头暮，无船不可归。
#
# 江上
# 往岁贪奇览，今登九惊地。
# 寸心连月色，鸥鹭亦迷群。
#
# 刘子
# 葵中观秋月，欲生不畏人。
# 问献宫采叶，时待月华生。
# 拙于用显晦，踪我作未来。
#
# 渡溪
# 渡溪溪水至，携移井臼空。
# 谁家草木叶，今登九仙地。
# 分明
# ----
# Running Avg Loss:0.23082297813147307 at iter: 3501
# ----
# 爱西溪好，春瘦怯罗衣。
# 别看苍苔纹，欲上人知湘。
#
# 贺铸
# 送僧法印智因西上
# 千里长淮北，梁山东复东。
# 当年片片落，千复映澄碧。
#
# 但使
# 夜感
# 夜眠不见泪， 言师采药归。
# 苏轼
# 似僧衣回
# 自君之出矣，自与归来故。
# 而况得道者，其间梅子雨。
# 草如今朝此，还悲旧人家。
#
# 知山
# 都迷去时路，策城空波中。
# 收网际风冷，一枝天涯冷。
#
# 晚上
# 松子
# 云言不觉马， 只是近黄昏。
#
# 李频
# 渡汉江
# 岭外音书绝，
# ----
# Running Avg Loss:0.24026368461549283 at iter: 3601
# ----
# 听。
#
# 周和蛛度水
# 移舟闲古恨，和桃泉南浦。
# 谁知圣人意，不在古书中。
# 夜有愁蟾云，只是滴芭蕉。
#
# 东蔷
# 秋月色苍山中，寒户移羹开。
# 一片清江水，中涵万古情。
# 日落潭照树，相逢益老苍。
#
# 刘子?
# 早行
# 字眠一点伤，为尽不可归。
#
# 攻之惊马吴泉山深山中， 更人一层楼。草
# 亭亭玉芙蓉， 经照头僧。
# 后教惊得去，勤忆瑟瑟瑟。
#
# 韩维
# 和晏相公湖上
# 功将吟见叶，愧舟东风起。
# 行草知年客，撩乱为宿莽。
#
# 入
# ----
# Running Avg Loss:0.22024703171104193 at iter: 3701
# ----
#
# 晚意
# 故国觅佳人，不为等闲来。
#
# 羽扇临元唧， 有师临门寒。
#
# 张祜
# 何满子
# 故国见意碧，携花滞形器。
# 却下曾叶舟，不见古远中。
# 遥怜水风晚，片片点汀沙。
#
# 周文璞
# 江水足鱼雨远，秋香被相枫。
#
# 飒飒秋风来，衣衾愁未四。
#
# 高翥
# 题芦雁扇
# 雁下秋已晚，江低空露生。
#
# 谢羽夜畔，袖不敢晚来。
#
# 墨梅
# 似到芦将物，秋月鲈会思。
# 卷帘了清景，食个满桥板。
#
# 高翥
# 题温日观葡萄
# 百八牟尼颗，携将万子楼
# ----
# Running Avg Loss:0.20873892279341816 at iter: 3801
# ----
#  今人多不雪。
#
# 相思
# 红豆生南国， 春雪浮云端。
#
# 杂诗
# 青草生水中，日日照草落。
# 渴猿惊杨根，野眉如蠹虫。
# 长恐浮云生，无船不可归。
#
# 徐铉
# 题雷公井
# 霭水漾轻碧， 万径人踪灭。
# 孤影见意色， 江一枝江水。
#
# 成回
# 晚春
# 底处不哑出， 今不博凉。
# 雨得枝山碧， 青山独归眉。
#
# 韦应物
# 秋望泰岳寺， 今人落相忘。
#
# 韦应物
# 秋去词千载， 不敢过临洮。
#
# 邓宗度
# 祥符寺
# 云粟分公瑾
# ----
# Running Avg Loss:0.21745772026479243 at iter: 3901
# ----
# 常子然寄茶谢之因简任伯
# 谏议茶犹送，须移井臼空。
# 安上台乡色，一枝三四花。
#
# 叶茵
# 天寒稻梁轼，绿将滞露扉。
# 浪头拨船女，刺手终不嫌。
#
# 前时双鸳鱼，为与渊如行。
#
# 入山
# 都迷去时路，策杖烟漫漫。
# 但见泪痕湿，相看如故人。
#
# 青草知处，出手还自远。
#
# 嘲子由
# 葵花－自注俗名一文红
# 花生初咫尺，意思已知寒。
#
# 高风 清·缪苇目作
# 日日绮难粉，前村是鸟无。
#
# 题雷公井
# 掩霭愚公好花久，蓬根逐吹频。
# 仙
# ----
# Running Avg Loss:0.20324038786813617 at iter: 4001
# ----
# 毛轻。
#
# 严肃
# 落日落片片，秋意已如许。
# 云影射清?，回光在桥板。
# 记著今朝乐，片片点平生。
#
# 幽性岂若岭秀，深其是西风。
#
# 和子由岐下诗
# 鱼
# 湖上移鱼子，初生不畏地。
# 记著今朝限等，不作博水光。
#
# 陈恬
# 子规足时待谁知，迥立不知来。
#
# 青草
# 渡溪
# 老崖先分颗，乾花飞妾年。
# 幽香青苔下客只是如出山。
#
# 钓台
# 穷鳞无处时。
#
# 杂
#
# 梅花
# 天岂各分国，凌寒影未花。
# 如何临欲别，不得傍君衣。
#
# 东渚
# 团
# ----
# Running Avg Loss:0.19571196392178536 at iter: 4101
# ----
# ， 杳杳钟声晚。
# 船发长愿云， 日暮掩柴扉。
# 春草
# 岂方景芳草，时作凉年飞。
#
# 井泉
# 元赵昌驿南唐后
# 向晚来雨眉，风吹藤叶飞。
# 不见棹回来，愁落不自开。
# 妾当年少日，不使共老去。
# 但见浮天去，少赠故人薇。
#
# 丽泽
# 长哦伐木篇，蓬根逐吹频。
# 拙于用显晦，踪啻钓寒心。
#
# 严蹊
# 落日落片碧， 日暮客相思。
# 举头望明月， 低头思故乡。
#
# 王之涣
# 登隐丹
# 远船
# 昔落生南树，秋生鲈会思。
# 卷帘了清景，
# ----
# Running Avg Loss:0.17349601987749338 at iter: 4201
# ----
#
# 送陈令归无为
# 楚水漾轻碧，楚花飞乱红。
# 故人故乡来，应是不归来。
#
# 西溪
# 为东坡先生韵
# 春晚下不转，欲向更何年。
#
# 陈允涵
# 山中吟
# 东望泰岳松， 际月红雨。
# 山流石不择，春在但叶简。
# 语林山中，山高不可归。
#
# 江水夜韶乐，海棠春贵妃。
# 殷霜不到者，高斋过平别。
# 今前春风枝，西望无行中。
# 子落潭照树，到前时春田。
# 悠青青青手，犹带去年枝。
# 春风知心客，衣翔去故人。
#
# 题八功德水
# 欲寻阿练若，曳屐吟
# ----
# Running Avg Loss:0.1785518020763993 at iter: 4301
# ----
# 李氏
# 新余杭步伍亭壁
# 夜台夜复夜，东山东复东。
# 当今长茅手，月落石花鸟。
# 莫遣儿童撼，留看看成石。
#
# 吕本中
# 题芦雁扇
# 雁下秋已晚，江渴青枫林。
# 但见泪淮散， 禽恋周船去。
# 襄阳多稚子，摘赠故人来。
#
# 西旧过
# 吴牛三十角，久与牧相忘。
# 忽忆淮南路，春泉香入新。
# 莫遣儿童撼，留看著苍腾。
#
# 周紫朝久
# 题芦雁扇
# 雁下秋已晚，江海花寂腾。
# 旧迷罗箔风，泣向西窗雨。
#
# 司马知
# 野性岂不到，春晴爱严春。
# 如
# ----
# Running Avg Loss:0.17363897612318396 at iter: 4401
# ----
# 。
#
# 门柳
# 看尽门前柳，愁多白发新。
# 灞桥风雨夜，山南又春雨。
#
# 小烂柯
# 游尝游原金风，秋生鲈会思。
# 卷帘了清景，归前还自穷。
#
# 湘渚
# 团梅安过游，天远亦难华。
# 谁知圣人意，不在古书中。
#
# 西风吹秋霜，庭前远携刀。
#
# 绝爱墙阴橘，落行有定莽。
#
# 王仲素
# 归去词一愁生山居，池边老松树。
# 渴猿不可拒，切勿爱空名。
#
# 恭宗
# 吴哥舒
# 移舟百名瑶，幅巾自来去。
# 岛屿日尘，不许傍檐飞。
#
# 赵崇
# 玉晨观
# 野笋冲
# ----
# Running Avg Loss:0.1840651912614703 at iter: 4501
# ----
# 里月华满。
#
# 严文晦
# 尝与周后移植梅花于瑶光殿之日，我明月来飞。
#
# 朝食山上
# 往家吟相呼， 积雪浮云端。
#
# 权德舆
# 玉台体
# 昨夜裙带解，欲歌双泪横。
# 故应各分性，春风著野桑。
#
# 春晴
# 新春十千月， 寒梅最火处。
#
# 李端
# 听筝
# 鸣筝金粟柱， 今今登春。
#
# 张轼
# 题城游风
# 绝江
# 昔闻拜仙地，忘得过南浦。
#
# 赵文璞
# 玉晨观
# 野笋冲泉流， 不敢客愁心。
#
# 王鏁
# 使风
# 林鸟无凡音，山云有微来。
#
# 周文
# ----
# Running Avg Loss:0.15798075149767102 at iter: 4601
# ----
# 山夜雪寒。
# 古殿无飞尘，过得洞庭前。
#
# 恭宗
# 在燕京作
# 寄语道梧浓，林人故人家。
#
# 朱子
# 莲沼
# 亭亭玉公底，缄口过平生。
#
# 李膺
# 隐逸
# 偶来水花满，初生不畏踪。
#
# 原宗
# 在燕京作
# 寄语无光作，江花处闻市。
#
# 原补之出渚，篝灯山松长。
#
# 铸亭
# 题色前秋韵
# 春著三分云，冲雪亦笑来。
# 冰人在行伍，只待妾衣裳。
#
# 青杂诗
# 尝与赵园
# 山水漾西风，秋生无恙滴。
# 玉貌辞金阙，只时是如许。
#
# 司马光
# 井风吹木叶，
# ----
# Running Avg Loss:0.1536993011087179 at iter: 4701
# ----
# 时有惊雪影，和月度?篱。
#
# 黄金山花
# 种松
# 江雪
# 天远正扬穷，楼高不堪倚。
# 醉梦随人劳，坐待月华生。
#
# 今相思牡牧，何啻使风人。
#
# 渡溪花
# 溪
# 小语不到，明日复花花。
#
# 米黻
# 怀南唐砚山
# 砚山
# 砚山
# 泊上自明来老。
#
# 杨雯
# 北客
# 清旷
# 笋舆咿哑来，路非闻子雨。
# 不悟当时景，萧然在此堂。
#
# 兰亭
# 事去天边夜，斜夜顾相思。
#
# 羽扇临元披，高枕石头眠。
# 啼能有鸟来，云间亦厌看。
#
# 后圃
# 自客亦出矣， 不
# ----
# Running Avg Loss:0.1640490586683154 at iter: 4801
# ----
# 复立春。
# 近乡情更怯， 不敢问来人。
#
# 金昌绪
# 东日
# 向棹一叶叶，鸣不已寻张。
# 行人马上去，残灯照空驿。
#
# 牟岘
# 杨城西风吹，池边老松树。
# 渴猿不知愁，愁立照叶稀。
#
# 鸣鸠
# 因风驱于坠，秋月正扬辉。
# 惆怅江头暮。
#
# 三日随暮西， 岂物失吞吴。
#
# 权德舆
# 玉台体
# 昨日绮窗前，风回翻芭神。
# 叔苏舫行根，蜂登临度频。
#
# 杨教
# 云燕
# 江头云阁雨，柳日举千帆。
#
# 高翥
# 题钱少愚画
# 鸳浦
# 倚阑发亭啸，
# ----
# Running Avg Loss:0.15460603669285775 at iter: 4901
# ----
# 发方良矶，暮宿白水湾。
# 宽作一月程，须见江南山。
#
# 秋风辞
# 岁暮九
# 故金千里里，庐岭爱微知。
# 俗人知处所，应为有桃花。
#
# 自山
# 自昔怀李粟柱，能韶绿弦水。
# 语罢更携手，月明洲渚生。
#
# 郭祥正
# 和杨公济钱书赵园
# 文壑
# 北客相催发，沙立睡交颈。
# 不知棹瑟回， 能坐蹙蛾眉。
# 深静无　在，寥入无越里。
# 襄阳多稚子，摘赠亦来无。
#
# 杂诗
# 青草生水中作出东。
#
# 小底处几中尽，高枕石头眠。
#
# 山中
# 苏岂出门啼
# ----
# Running Avg Loss:0.15712921389378606 at iter: 5001
# ----
# 西及花时。
# 杯盘见秋物，江海思飞腾。
# 木鱼声渐急，山衲下云归。
#
# 张良臣
# 别持上人意，但桃俞青短。
# 惆怅江头暮，无船不可归。
#
# 晁补之
# 国子监暮归
# 杖履清晨往，缣囊薄暮归。
#
# 张良臣
# 别持上人意，俱得入眼中。
# 谁忧雷公作，出没风吹篱。
# 低迷井女乐，指与未归来。
#
# 吴龙良
# 曝日
# 冬曦如村酿，奇温止须臾。
# 行行正委地，海角亦逢春。
#
# 朱龙潭
# 和刘彦冲潭溪
# 屏
# 非笋冲济汉江来， 江上昏月。
# 莫是无归处，
# ----
# Running Avg Loss:0.15613161457702518 at iter: 5101
# ----
# 代五言绝句
#
# 刘克庄
# 宿德行
# 日照故乡流，春瘦井野空。
#
# 团世上
# 自陈鱼
# 我下秋月色，又得好水来。
#
# 朝食山上
# 入晚江南国，一作举千帆。
# 云处写幽人，相逢益老浦。
# 安得山中人，愁立沙汀晚。
#
# 鸣鸠得，愁立沙汀晚。
#
# 鸣鸠
# 自日入舟发，猫明白头死。
# 别方周事暮，日月鲈扬州。
#
# 王仲素
# 归去词
# 寄远归瓦发，幅巾自来去。
# 岛屿花木深，愁立沙汀晚。
#
# 鸣鸠
# 山与伤相思，犹深去未归。
#
# 王补之
# 西窗
# 西窗枕
# ----
# Running Avg Loss:0.14861170414835215 at iter: 5201
# ----
# 爱西溪好，长忧溪水穷。
# 山源春更旧，春来著山东。
#
# 吴沆
# 春更
# 月冷天满梦， 江上近黄昏。
#
# 李端
# 三高泽
# 底处双飞栗，娥是东山东。
# 忽因风雨尽， 明月溪水响。
#
# 严兴
# 尽壁
# 几晚天寒林，一在举烟坠。
# 分高江
# 寄衣回
# 几日雨濯发，千叶自去远。
#
# 张定
# 晚望江水
# 野笋冲泉出，黄金寿仲连。
# 粉身能报国， 复与自来飞。
#
# 朱监
# 蚕所坞
# 云卧不觉晓， 处处闻啼鸟。
#
# 李频
# 渡汉江
# 岭外音书绝， 经冬掩
# ----
# Running Avg Loss:0.129470431599766 at iter: 5301
# ----
# 听。
#
# 周紫芝
# 龙卧苍山流， 静闻雨云迟。
# 分明几点雪，欲得知回知。
#
# 一炉无渔来，今夕白杨风。
#
# 唐枝得
# 明月溪
# 绿螘新醅酒，离离半青可。
# 田家窥牧马，凌寒陟自前。
#
# 梅际
# 游沼
# 冬曦如村酿，奇温止须臾。
# 行行正可拒，切勿爱空名。
#
# 贺铸
# 送僧法印智因西上虫千里始贫手，攻生无项莽。
# 长啸归去来，愁立沙汀晚。
#
# 鸣鸠
# 晚来天欲夜，欲处不潺?。
#
# 黄庶
# 和刘卿
#
# 梅花
# 庭行弄陵老，只深向小栏。
# 不忧
# ----
# Running Avg Loss:0.13703130586072804 at iter: 5401
# ----
# 下，岁散沸青黄。
# 愁心如屋漏，点点不移踪。
#
# 高翥
# 蓑衣步
# 水浸石根冷，且作天涯冷。
#
# 自山
# 题胜业牧园
# 东壑
# 云光归不知，但是东薪处。
#
# 小语不知夕，幽香无人暮。
# 莫遣儿童撼，留看著野桑。
#
# 岐天有临水住，落月照酴篱。
#
# 王仲素
# 归去词亭韵
# 欲远正岳寺，江花飞寒雁。
# 水袅一炉里，指与情来人。
#
# 青冢 　　元·赵介
# 一身归朔漠，数代夕桃?。
#
# 别
# 青风可觉州，今归去年雪。
# 如今不是梦，西风日两行。
# ----
# Running Avg Loss:0.13967665550298988 at iter: 5501
# ----
#  此坐近黄昏。
#
# 送上人
# 秋夜词
# 愁日照所雪， 岂向人间响。
#
# 李端
# 听筝
# 千里移舟落，元蝶上相思。
# 空庭前来风， 江上复踪灭。
# 一声何满子， 双泪落君前。
#
# 李端
# 听筝
# 鸣筝金粟柱， 莫是□砧归。
# 春来已片碧， 日暮掩柴扉。
# 春晴玉空曲。
# 梅花惊问蜍， 青山独归远。
#
# 张祜
# 何满子
# 故国非飞雁， 万径应嫌诗。
# 一声何满子， 双泪落君前。
#
# 李端
# 听筝
# 鸣筝金粟柱， 莫是□砧归
# ----
# Running Avg Loss:0.1155893241148442 at iter: 5601
# ----
# 常子然寄茶谢之因简任伯
# 谏议茶犹送，郎官迹已?。
# 谁家雷公作，清夜顾长飞。
# 谁悟当时景，萧然在此堂。
#
# 瞑目
# 瞑目思千里，风随禀寇还。
# 日际月业间，清看众花飞。
#
# 严粲
# 松雪
# 天天卧林树，几晚天涯冷。
#
# 羽扇临元元
# 迢迢建业水，中有武昌鱼。
# 别后应相忆，能忘久不啼。
#
# 晁冲之
# 西窗
# 斜阳无限好， 不泥一杯无。
#
# 送别
# 山中相送罢， 日暮掩柴扉。
#
# 元稹
# 行宫
# 寥落古行宫，春在襄东西。
# 一声何
# ----
# Running Avg Loss:0.11042252452112734 at iter: 5701
# ----
# 毛轻。
#
# 程先
# 和人感秋韵
# 秋风
# 疾风拔枯楠，天作向云飞。
#
# 宋无
# 寄衣回
# 闻有宫袍赠，望还来人织。
#
# 许斐
# 秋风辞
# 飒飒秋风来，衣衾愁子真。
#
# 青青老镜叶，日光来未及。
#
# 在入
# 城头望明月，一日举千里。
#
# 恭宗
# 晚满子
# 向晚意不适， 驱车登古原。
# 却源春游落，其卧不可完。
# 一片清风看，多少未来人。
#
# 东舌
# 和出缪
# 欲生不畏罢，浣花飞乱红。
# 不知春去未，却被无处寻。
#
# 手种梅无木明，寒灯沸青花。
#
# ----
# Running Avg Loss:0.10441960733383894 at iter: 5801
# ----
# ， 今人多不弹。
#
# 李商隐
# 登乐游原
# 向晚意不适， 驱车登古原。
# 世喧长不到，何必少山笠。
# 不知渚未归，中有武昌鱼。
# 别儿不是忆，其是西窗雨。
#
# 陆冲
# 晚春
# 南国子亭
# 十光为曾高，岁月驹隙过。
# 不如两忘机，石上跏趺坐。
#
# 白龙翰
# 岁暮白云光，春向春去远。
#
# 昭君  ·业彤
# 凉月漾中流，金山隐隐浮。
# 未落今飞雁，那忧公子寒。
#
# 元金山中人
# 银画见
# 梅萧
# 林晨吹唐住，春余满赠。
#
# 采菱舟
# 散春台七鸠
# ----
# Running Avg Loss:0.10814653364010156 at iter: 5901
# ----
#
# 送陈允归，为有出渚生。
#
# 白云峰
# 湖上峰争碧，楚寒飞乱红。
# 故人故乡来，吹过乱山东。
#
# 代陈景初
# 出光
# 未发去不归，野笋无许识。
# 但原保天真，徐共春风寒。
#
# 赵师侠
# 梅花
# 南国觅佳发，又不亦英华。
# 余香被草木，秀擢杏花寒。
#
# 玉八翁
# 往岁不菊笛， 不敢问来人。
#
# 溪上
# 往岁贪奇览，今年坐幽竹。
# 不知饥兔寒， 日暮掩柴扉。
# 春晴
# 故乡不随，我作天涯冷。
#
# 王思
# 上归
#
# 和牛三十角，久与牧相忘
# ----
# Running Avg Loss:0.08821890810038895 at iter: 6001
# ----
# 夕阳千古恨，分付短长亭。
#
# 范成大
# 双燕
# 底处双飞驿，春尽无花开。
# 结束作男儿，与郎牵百丈。
#
# 淮上遇风
# 寥粟惊庐神，指与未及头。
#
# 陈亚
# 惜竹
# 出槛亦不剪，从教长旧丛。
#
# 苏辙
# 璎龙何饮潭， 先冬长愿晚。
# 欲得周郎顾， 时人已知处。
#
# 韦应物
# 秋夜词
# 愁生山外山，恨杀树边树。
# 别来秋苦雨，山际两三四。
#
# 司马光
# 野崔词
# 夏日碧相照， 黄河入海流。
# 欲穷千里风，无时如瑟瑟。
#
# 井泉
# 山高泽
#
# ----
# Running Avg Loss:0.08695118916220963 at iter: 6101
# ----
# 。
#
# 门柳
# 看尽门前柳，愁多白发新。
# 灞桥风雨夜， 跨山头应从。
#
# 小语不知夕，幽香无人识。
#
# 吴龙翰
# 侠客为
# 庐山不到阿，尖风渐归来。
# 何许小茅茨，开门青苔时。
#
# 意行桥
# 龙卧苍山下，山人不知年。
#
# 赵葵
# 秋夜词
# 亡水故人
# 迢枝三牡笔，闻鱼绿凉雨。
# 眠鸥知让客，飞过蓼花洲。
#
# 恭宗
# 在燕京作
# 寄语
# 林鸟归难夏，初生不畏人。
# 但原保船轻，离情友麋鹿。
#
# 自山水
# 侠刘遇
#
# 东彦烟花里，舣棹绿杨阴。
#
# ----
# Running Avg Loss:0.10144706547260285 at iter: 6201
# ----
# 里月华满。
#
# 方景绚
# 题壁
# 明来松树下，欲静闻?雨。
# 幽怀耿无寐，邻客终夜人。
#
# 王浩
#
# 龙翰
# 霭日清红絮，湘歌恋界滴。
#
# 谢松野叔惠菊
# 春粟分公瑾，千金寿仲连。
# 但原保天真，徐共春风寒。
#
# 祖无择
# 记万载县风俗
# 日光为有所，久未是归眉。
#
# 远山
# 万里色苍然，寒林夕照边。
# 旧高秋秋枝，愁城多非真。
#
# 大慈
# 野郭希
# 晚来秋自远，残灯照空驿。
#
# 赵师侠
# 梅花
# 天岂词未归， 岂向人落。
# 但原保天真，徐共
# ----
# Running Avg Loss:0.073727439455688 at iter: 6301
# ----
# 山夜雪
# 夜深寒妥帖，前村人断绝。
# 何许小茅茨，开门飞款款。
#
# 张轼
# 题城南
# 城头望西山，秋意已如许。
# 云影被风回，共跨山头鹤。
#
# 叶茵
# 晚望
# 鸥鹭归烟渚，秋江挟晚晴。
# 当时惊妾梦，一夜向南飞。
#
# 周文璞
# 玉家
# 村斤伐不死，半藓半游寒。
#
# 题八功德水
# 欲寻阿练若，曳屐薄斜寻。
#
# 许斐
# 秋南
# 斧积三巴人，又得夜叶雨。
#
# 朝食山上
# 往卧天寒梅，一日清风年。
#
# 赵师侠
# 梅花
# 南国觅佳人，隔花似半时。
# 黄金
# ----
# Running Avg Loss:0.08112757092341781 at iter: 6401
# ----
# 罗与之
# 山居
# 雨作糟床注，秋生鲈会思。
# 卷帘了清景，萧然在此堂。
#
# 瞑目
# 瞑目思千寺，风回翻古春。
# 但原保天真，徐共春风晚。
#
# 祖无择
# 记万载县风俗
# 居民覆其趣，稍觉北枝伤。
#
# 严肃
# 落花
# 片片落花飞，随衣鸟飞腾。
# 旧破归犹者，不是养蚕人。
#
# 张轼
# 题城南
# 城头望西山，秋意已如许。
# 云光连月色，还明人雪莽。
#
# 宿山
# 忆昔游岳寺，曾向雨中看。
#
# 送方景去来，一日入江南。
#
# 张舜民
# 庭扇
# 纨扇本招风，
# ----
# Running Avg Loss:0.08493297768756747 at iter: 6501
# ----
# 复立春。
# 近乡情更怯， 深山独归。
#
# 题雷公井
# 掩霭愚明度黄录
# 山流水七屋，秋月正扬辉。
# 惆怅江头窗， 明月来生少。
# 古调虽自爱，未便照青絮。
# 后夜客清涟，衣食还自空。
#
# 崔?
# 自春波
# 三螘新醅酒， 红教枝上啼。
# 夜来风上来，还寒未三四。
#
# 晓行
# 枕上杜鹃啼，匆匆早起时。
#
# 权德舆
# 击筑复击筑，欲歌双泪横。
# 宝刀重如命，命如鸿山汤。
#
# 远山
# 万里色苍然，寒林夕照边。
# 旧惜了游景，其复酒轻里。
# ----
# Running Avg Loss:0.0755606136773713 at iter: 6601
# ----
# 发方良矶，暮宿白水湾。
# 宽作一月程，须见江南山。
#
# 周文璞
# 玉晨观
# 野笋冲泉出，醅恋忽自返。
# 岛屿花木，愁间照露滴。
#
# 送上人
# 孤云将野鹤，后斗七莺儿。
# 啼时惊妾梦， 明月来故。
#
# 陈亚
# 惜竹
# 出槛亦不剪，从教长旧丛。
# 月落知万里，头角本非真。
#
# 第一溪
# 倚阑照击筑，玉貌老君浓。
# 分明几点雪，欲折又成空。
#
# 陈亚
# 惜竹
# 出槛亦不剪，从教长旧丛。
# 此雪鸪风风，风吹成赵花。
#
# 朱子
# 莲沼
# 亭亭玉芙
# ----
# Running Avg Loss:0.0752993158204481 at iter: 6701
# ----
# 西及花时而后已殂因成诗
# 击筑复击筑，欲歌双泪横。
# 宝刀重如命，命如鸿睡中。
#
# 嘲鸣由
# 迢迢建业水，中有武昌鱼。
# 别后应相忆，春船西风枝。
#
# 杂诗
# 青草生水中，日日杳钟山。
#
# 铉愁
# 题春江南山，故瑾酒杯风。
# 当上生佛面，春间老露啼。
# 殷勤向春树，举意过前村。
#
# 恭宗
# 在燕京作
# 寄语十欲雪，寒林未是归。
# 世喧长不到，何必不知人。
#
# 王安
#
# 吴子
# 山喧长
# 飞蝶捎风絮，鸣禽恋午檐。
# 不知春去未，不是养蚕人

# %%
print(sample_chars(X_batch[0], rnn.initHidden(), 2000))
# Out:
# 燕子知时节，还从旧宇归。
# 新人方按曲，不许傍檐飞。
#
# 刘韬玉
# 至角黄之出，韬藏亦英华。
# 余香被草木，秀擢蜀长长。
#
# 丽泽
# 长哦伐木篇，蜂忙供蜜工。
# 役役为人劳，衣食还自空。
#
# 刘克庄
# 宿春
# 西窗雨气浓，秋红蜻偷碧。
# 妾当年少梦，清夜音南飞。
#
# 段明
# 梅花
# 微汝本月程，不买千三开。
# 田家临水机，不便照酴居。
#
# 离?州作
# 相看不忍发，惨淡弦为去。
#
# 李诚之
# 葵日鸟飞绝，银钩楷法精。
# 啼应秋风下，一意已如许。
# 云影寒宿一，时有还自去。
# 寸心即知已，不用世人知。
#
# 刘文晦
# 种梅
# 佳人天一方，岁暮音书绝。
# 当处芳草多，相呼向深坞。
# 竹外立寒枝，山紫又复空。
#
# 裳扇
# 临水
# 门天虽自献，破褐出残絮。
# 童儿不耐烦，微裘拥绣鞍。
#
# 酬昭君怨 元·赵介
# 一身归朔漠，数代去不归。
#
# 朱子
# 莲沼
# 亭亭玉芙蓉，迥立映澄碧。
#
# 钓台
# 穷鳞无处伤，过尽上头眠。
#
# 张至龙
# 演雅溪
# 和刘卿湖
# 屏生不县希，斜林未是愁。
# 过尽前头望，又得夜来雨。
#
# 朝食山上
# 恨后湖随形鲤
# 日暮飞鸟归，门前长春水。
#
# 濯清亭
# 庭衣回
# 闻生各城晨，门前长春水。
#
# 濯清亭
# 春风记维舟，春子破长身。
# 田儿愁山中，时时倚藜杖。
#
# 斯植
# 古乐府
# 片片落花飞，随风过南浦。
#
# 刘克庄
# 宿建德江
# 岭外音书绝， 经冬逢愁。
# 移争小林头， 明月来生少。
#
# 韦应物
# 秋生，高斋卧看山。
#
# 黄金无足色，山上人知动。
#
# 薛峪
# 蓑衣步
# 水浸石根冷，风吹藤叶飞。
#
# 严肃
# 落花
# 片片落花飞，随香被草死。
# 想是一山下，摇思无定林。
#
# 刘克庄
# 宿建德江
# 移舟泊烟渚，秋江入燕飞。
# 别来看成下，不忧世空林。
#
# 高翥
# 题雷公井
# 霭音书于俗，千里无雪古。
# 不道山中冷，翻忧世上人。
#
# 丽泽
# 长哦伐木篇，园林未是归。
# 何郑公客梦，到蜀到钱唐。
#
# 牟岘
# 鹿柴
#
# 云议隐厨主，高枕石壁。
# 但鸣随船轻，不知今古春。
# 不忧雷雨作，头角本非真。
#
# 大慈野花望，山清望余知。
# 如何临欲别，不得傍君衣。
#
# 王曼之
# 西窗
# 西窗枕寒池，池边老松树。
# 渴猿不知年，不在古书中。
#
# 杨杰
# 何满子
# 和浦望九韵
# 春风老飞灵，落叶两叶坠。
#
# 杨杰
# 万里色苍然，寒林夕照边。
# 旧声何满子，清林开数茎。
#
# 赵师侠
# 梅花
# 南国觅佳人，风回亦逢春。
#
# 苏辙
# 璎国罗亭
# 山云泽气浓，曾将热长春。
#
# 陈允平
# 山中吟
# 东望泰岳松， 不敢过临洮。
#
# 唐庚
# 栖禅暮归书书鱼
# 黄卧提幅树，觉林不可完。
#
# 追和亡景遇
# 题卧道江远，闻以病骨知。
#
# 钓台
# 穷鳞无处处，山禽不劝归。
# 可怜明月冷，忘山中此穷。
#
# 严羽
# 懊侬歌
# 山水漾西风，春岭如更已。
# 绿后去飞舟，寒灯坐将灭。
# 长恐浮云生，泣日梅绮丛。
# 倘无鼠与盗，腾时补之王。
# 君看一叶舟，出没风吹动。
#
# 张轼
# 题城南
# 城头望西山，秋意已如许。
# 云影射君愁，回光在桥板。
# 野水去不回，切勿爱空名。
#
# 杨公济钱唐后移监林兴
# 鱼淮意已梦，莫月乱苔昏。
#
# 朝食山上
# 微壁立积树，斧灯柳长长。
# 旧情更何未，月明洲渚生。
#
# 黄庶
# 和刘卿
#
# 杂诗
# 一身归朔漠，数代拥绣鞍。
#
# 酬昭君怨 元·第中
# 簪组非无累，首林未是归。
# 世喧长不到，何必故人?。
#
# 徐铉
# 题雷公井
# 霭霭愚画花
# 秋怀相催发，一日复青身。
# 童儿不耐烦，微是故人?。
#
# 山高临水送国音书绝， 江看众长。
# 旧高秋秋月，清夜惆树上。
#
# 蜗牛
# 腥涎不满壳，聊行人已前。
#
# 徐铉
# 自题
# 佳人天天方，寒尽不知年。
#
# 蚕
# 一蚕何唧唧， 今处闻啼鸟。
# 千秋晚来故， 青饮一杯无。
#
# 韦应物
# 秋风忽作于带浓于，叶叶乾红飞。
#
# 朱子
# 莲沼
# 亭亭玉芙蓉，迥立映澄碧。
#
# 白龙潭
# 白龙昼饮潭，修尾挂石里。
#
# 刘克庄
# 宿建寓寺
# 云卧不禁人，误把峦扃触。
# 翻动棹舟槛，何点 风起。
#
# 采去
# 秋夜词
# 愁生山外山，恨杀树边树。
# 隔断秋风寒， 时人思故乡。
#
# 金昌绪
# 散策下亭阿，水，今年爱蛾眉。
# 春晴三采树， 江一长恐飞。
#
# 李端
# 东江
# 野笋冲之出，君行定几时。
# 故应今夜月，未便照处别。
#
# 苏辙
# 璎刘舒见见意
# 失却烟花主，东君家不归。
#
# 陈允平
# 山中吟
# 东望泰岳松，曾将热几新。
#
# 后圃
# 浇花惟要早，芟草不知名。
# 如今不是梦，真个藏白乡。
#
# 刘文晦
# 种梅
# 佳人天一方，岁暮音书绝。
# 谁知圣人意，不待远归人。
#
# 宿山中
# 蓑衣步
# 水浸石根冷，风吹藤叶飞。
#
# 赵葵花团唧，西风过南浦。
#
# 鸣鸠
# 晚日照瓦霜，西响界余白。
# 旧有南雨论，只是滴芭蕉。
#
# 赵葵
# 酒力欺寒浅，心春檐数修。
# 无处即知已，不用世人知。
#
# 张舜民
# 纨扇
# 纨扇本招风，曾将热长安。
#
# 蜗牛
# 腥涎不满壳，聊水隐始雨。
# 可怜开较早，不待远归人。
#
# 宿山民
# 昨舟空曲日，但爱绿隙过。
# 谁知圣人意，不用世人知。
#
# 钓台
# 穷鳞无处寻，且禽不可亲。
# 而况得道者，其间梅子真。
#
# 赵崇
# 枕上杜鹃啼，火鲲巨中昏。
#
# 老去
# 老去厌芳菲，思归未来人。
#
# 高翥
# 题雷公井
# 掩霭愚画
# 亡后见形诗
# 异我何其下，归来
