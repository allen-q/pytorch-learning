# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
% matplotlib inline

# %%
with open('./data/trump_speeches.txt', 'r', encoding='utf-8') as f:
    data = f.read()

# %%
df = pd.read_csv('./data/names.csv')
data = ' '.join(df.name.tolist())

# %%
# data I/O
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print(f'data has {data_size} characters, {vocab_size} unique.')
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# data has 237097 characters, 53 unique.

# %%
# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# %%
X_train = np.zeros((len(data), len(chars)))

# %%
char_id = np.array([chars.index(c) for c in data])

# %%
X_train[np.arange(len(X_train)), char_id] = 1

# %%
y_train = np.roll(char_id,-1)

# %%
X_train.shape
# Out:
# (237097, 53)

# %%
y_train.shape
# Out:
# (237097,)

# %% [markdown]
# ## Build a RNN model

# %%
class CharRNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.fc_x = nn.Linear(input_size, hidden_size)
        self.fc_h = nn.Linear(hidden_size, hidden_size)
        self.tanh = nn.Tanh()
        self.fc_out = nn.Linear(hidden_size, output_size)
        
    def forward(self, X, h):
        x_out = self.fc_x(X)
        h_out = self.fc_h(h)
        h_new = self.tanh(x_out + h_out)
        out = self.fc_out(h_new)
        
        return out, h_new
    
    def init_h(self):
        return torch.zeros(self.fc_x.out_features)

# %%
#rnn(torch.from_numpy(X_train[0]).float(), torch.zeros(128))

# %%
rnn = CharRNN(vocab_size, hidden_size, vocab_size)

# %%
loss_fn = nn.CrossEntropyLoss()

# %%
optimizer = torch.optim.Adam(rnn.parameters(), lr=0.001)

# %%
def get_batch(X=X_train, y=y_train, batch_size=seq_length):
    X = torch.from_numpy(X).float()
    y = torch.from_numpy(y).long()
    for i in range(0, len(y), batch_size):   
        id_stop = i+batch_size if i+batch_size < len(X) else len(X)
        yield([X[i:id_stop], y[i:id_stop]])

# %%
def sample_chars(X_seed, h_prev, length=20):
    for p in rnn.parameters():
        p.requires_grad = False
    X_next = X_seed
    results = []
    for i in range(length):        
        y_score, h_prev = rnn(X_next, h_prev)
        y_prob = nn.Softmax(0)(y_score).detach().numpy()
        y_pred = np.random.choice(chars,1, p=y_prob).item()
        results.append(y_pred)
        X_next = torch.zeros_like(X_seed)
        X_next[chars.index(y_pred)] = 1
        #print(f'{i} th char:{y_pred}')
    for p in rnn.parameters():
        p.requires_grad = True
    return ''.join(results)

# %%
for epoch in range(100):
    losses = []
    h_prev = rnn.init_h()
    for batch in get_batch(X_train, y_train, seq_length):           
        X_batch, y_batch = batch        
        optimizer.zero_grad()   
        loss_batch = 0
        for ch_id in range(len(X_batch)):
            y_score, h_prev = rnn(X_batch[ch_id], h_prev)            
            loss = loss_fn(y_score.view(1,-1), y_batch[ch_id].view(1))
            loss_batch += loss
            losses.append(loss.item())                     
            loss.backward(retain_graph=True)
            
            if len(losses)%1000==0:
                print(f'Running Avg Loss:{np.mean(losses[-1000:])} at epoch: {epoch}')  
                print(sample_chars(X_batch[ch_id], h_prev, 200))
        optimizer.step()
# Out:
# Running Avg Loss:2.8448929671645162 at epoch: 0
# he tvap icrnlkrd Tns-f grynl, he Th ure
# derP D, DeburtosI 'otrhd dsrnr .klSthel
# mmg wiT bHs loaat ihonkh
#  ikvcahibfl ur -onda t aerwthok metadk w,ereta. nhiy llaar $lruse mo csadsdsoaw, ol woydo. g.
# Running Avg Loss:2.650143992781639 at epoch: 0
# d otsisluise tos. ,endy Klbkeseslestin.o ned crdsrespounns sle wl pun' sa'r whinl  , rrsstae u.t  Vrerys.plecilrs jd j wnnstre tesrnp asd bEnithA spns betomupdsauns ve nn the rlbebpcIuhatsshs usve t m
# Running Avg Loss:2.544636021655053 at epoch: 0
# rat areot  pthe d it ese yr'ale led ares al, an  Youse hed ithedeurentll l are. pees hiss  ohmyes  hay d atee.e deut ses, tasy ao.  ohererat supk ssitI peonr tand anou chavo  ,heynalhey Sreury thay d
# Running Avg Loss:2.38578657509014 at epoch: 0
# mald ingo iwer pldovericacaryrajf we hablaryAld  Wou dandifdetbibuibuvee.  wopoadun.y Wuithond sn bolde'shoz onelape at It Whase -hith ve mailerebllictoinb hala Yflliblpbo OwTpWar.  Ioupyhr nit Isiagr
# Running Avg Loss:2.5118004044815896 at epoch: 0
# 2 tay coabeny sbeat ings yatives  whe safe my to'wey t.o moolsoye edit moLple.  Ban  -nthily, t Sok'sy t.  Hqe yEue te  You  thous sif I
# epdhes yoka douy.. do' ualile ti t'vemar arke withe nyRaindedlo
# Running Avg Loss:2.343627899043262 at epoch: 0
# ou kos tthen Iulgasave sarkyo  anryou dorer and Ooberabse; he,romiftalsi, encthang aroppffrithand Eouha dingole ecend de waOdhet cslyhs soury;sinl.  bocens tor whopis ers Ye? toé douuTuswroreve.  fhit
# Running Avg Loss:2.3906460927538573 at epoch: 0
# h sd catled and wak entver com-Anllt  it, wive'g thon't thata
#   bofng abo'v thet h t er g te, th the the tu that end ythat toy   ouy  he dt thtt you'ny th t that. .u gey I se fo gh f at'ythifyticbuwti
# Running Avg Loss:2.305452169585973 at epoch: 0
# inpeomaking.  Thmunas tas anabosplls buryiy, blerevely uve'lessremmund th th. lqusthene gow tI'nabweceabu tfd m;.  Berelllalk thandy amy wesriossaver du; inarullaplomoinguse kanot?t eaidse wan thany n
# Running Avg Loss:2.265790973333642 at epoch: 0
# eobl.  I ouse.  U.  Wep, ing thow anf de  ue, In woroy waievericts ho, y, so neng wave hamfe have driveve  in.; have thop.  The sande ind, -halp, mo d mesp.T ke have yuf yous go kave tR have wa kafo t
# Running Avg Loss:2.2950425975844264 at epoch: 0
#  co weange. loS sow gu.  De te ksang abe thansomsknowr; ifis.  Iewancinong. po thave bo yawe, cin ge Ct nge ags galr thang fo.  ve thareRe, acsbeis, TRngese poy.
# N thave t eg, resc you'ct ate be. y6ur
# Running Avg Loss:2.36014023527503 at epoch: 0
# in tSe nu tre sof we yu oullove the cit the cenollif she we we sald. Berighinkedkey.
#  Wcbve.. yout bof treuscals idut tof singhsing wics yhe ge rif at dobleray bug sof dod int inyuu noy titheakntherea
# Running Avg Loss:2.232965112088248 at epoch: 0
# uing lealler.  IfI.
# Sorarill.
#
# Bacfolhero sfacofveNsinn
# Do1 hecSexhicury lirik warming Cooksg ous andury a rais wea fum ing ing ascuevearars auict oud wfamfherry urmarewertaing heve wiig lereljangrs a
# Running Avg Loss:2.391881770327687 at epoch: 0
#  , ofe.  Aof go waed ther poin a ve aperin came Bin, sney nare als ec I the is.  The nh and nt icasr codn wat ith tis ing have thend ans tis mint.  We ca h the co wana cake ant.  We twererple baeralli
# Running Avg Loss:2.362411360351369 at epoch: 0
# r ttid eahdethe antas eneid or ou n prebas y.  They As te goo whis it ir yhhisge aos tuc They cheto gebot thed ive hcall.
# HTco towe that dhas aisg thkito yo heyos y$u and tos tooe hesse tuthede; tol h
# Running Avg Loss:2.158618354011327 at epoch: 0
# 't mhem royer sofplen wo. Ang we g biaisr io loing.
#  dy'se.  Whing. tBust they cas jeinn.  In-plos phai vorer.  Wh yonde sukt ohet or matey toomen wais.  Whes.  Ihad sot aing.  Whoy trerer they th we
# Running Avg Loss:2.2995129039194433 at epoch: 0
#  Thave ing thas, whing't ,orethe gtoend mett owethirn to hid aivg an at'Annd kno.  Molelyoust wat, Thet fowtyne thos than tyo, wes,uf thot son't dort eing.  forsit d, main.  Yop aleg.y gomonthinollle,
# Running Avg Loss:2.213314581233077 at epoch: 0
#  hong, andand Ar an'se thaved es I thit poocamtcan's aany asta austis. tWe cury aillly Breusaing.y mping I , ou her They ous.  Yod st; oclus,;'t pos a an'r shardere thay. Anloto, Saze. r The lsasle wa
# Running Avg Loss:2.2732905131420122 at epoch: 0
# have d ofuct ile tod an't comppok Bust't ya, uoey ey woing ve ou jubatle ---N fon camp ansinthad Aus'm. ed wo th thand--- best aeve And deove mon fast ofunot-'s in,  oo'peou cannk 't foYkust t's Chot
# Running Avg Loss:2.224519390773028 at epoch: 0
# ke cocat'e tole tatto faveot cowl on watheve le bom, , edousproverount ottbew'stthe siaking the gers.
# Bu, micwunow an averad omesas, 'r kidiplind ine tore.  I I kutve whitr ance iebefanf an un'peth, y
# Running Avg Loss:2.310856484416872 at epoch: 0
# an tus tomppe le nt th  lout le beI  bane re tochrree pleecu ore whese causing Iil---buthlee ing weedeale remeord int wrey reve se fo yome po mle tile be thawe an sf ftaar iepropre and  er.; romens.
# Running Avg Loss:2.5020126817896964 at epoch: 0
# sin it' geanave. dait sp gelote gotain aninto bo novicAnl ior a men oin toneting oyin soteesing of.  He bunt we whi cupelou vis iny ige an. bounloin ing poribistangrob ite if an an, An hutananyount le
# Running Avg Loss:2.406513491462916 at epoch: 0
# peliche
# Wenk, ibesille,le.
#
#
# He fhise thank yhantn saterilice Rbatd werting I Oy inouys yveatg.
#
# veredtos mitavurbed. He ferdhe I Of s, think y h an'se tvemnop of tove henwipl k- wede ;sound Busiss
# Running Avg Loss:2.4409594806320967 at epoch: 0
#  and wopmengno whs mongy bicn w's, werst.
# I verss thipl lyd past fectikl ofa. Jy.
#
#
# TheisI wult undst hevesimg. st, Woestrev.
#
#
#
#
# Thes ]ok Buscowest was, wowerr ofrechot,eldecast anast mcous toriggnc
# Running Avg Loss:2.4438907980620863 at epoch: 0
# fo ed fovpig serpany inicy Hatisristig o si?r polde weS--Hien wo. Norst fo ttiay falt bofetellln hatha vay hasiint ourienky t, cosopechinn woreicast wored, te ioino.
#
#
# Owyeb an wurin.
# Nor. I wo tmeas
# Running Avg Loss:2.4513290917016564 at epoch: 0
#  lies tremrstnend thas an timily, wos.
#
#
#
#
# pey ant, fofind bour aly, was rot dan tojililesit tplour d thes thes verming wot cowus to n pooty.
#
#
#
#
#
#
#
#
#
#
# Soermngy orage cavit ing te Mrewnigacas theg acl
# Running Avg Loss:2.3880117590464653 at epoch: 0
#  ane iolthitcorewr Oome ioullyf our don wir boun o, our fopnour fameeriey oo turoand Anio pan bory Afen torlyitrpeoteRebed won theo hsionn the uny oole cho th rur arren counprowi y, po hhhe wheve he o
# Running Avg Loss:2.3101987310871483 at epoch: 0
# beehtiang then. JBdeste utrestrat otNang thon io. Uf thdend wnd that ail, ri. The sotemerappenod buc eat dedlet thaned And bacr becamaple. jr taan jusnon, yis warits them ake jurtt ffree stheds beitha
# Running Avg Loss:2.3959405011516064 at epoch: 0
#  grathith har oore ald Bund s pote aed, bucknaty ald theN igrpedtillion. Hed noprat, come the Gorand. W whe 1; akl .
#
#
#
#
# Bu’ Hen hithr ond nl hf som heB gcore Chrin wey of fedvett loreve puisd fothe f
# Running Avg Loss:2.4297986873760817 at epoch: 0
#  hall mpanted Fo zor ther abrecemve nd amefruher ristinn coumecy.aeb whesr hour care pofomd an anlaogr sllongated was ang tra prehabent wf nave te prithti tlyodn
#
# Jourle beoker, le Inih nor mfoub mace
# Running Avg Loss:2.3237462296113374 at epoch: 0
# weylaaw io facet on thilyur enNat ave s ames aveur CotrO oun  takeitrath dodr  is, tor heC uw wing he’t ales hone po, te coalla ath acansinofr ite goves ou ar weat has, her, oupcen  hes Cber. If ta in
# Running Avg Loss:2.398782706739381 at epoch: 0
#  ir hade romacu vericy, wi’cay.
#
#
#
#
#
#
#
#
#
#
#
# Aco r.
#
#
# We’verg
#
# Natl, thd Rhavewa, Piwhedeng indiny. S Ooa Iof mind padibywa’wive Obeo beliama ben
# WeAngu
#
# OqreyNTurion, w fixthongdong on’sDch urdD, lltid
# Running Avg Loss:3.2854314841832966 at epoch: 0
# vlt,I boegeacnt dmt ppefiarnW n cb ngeenitRu ady ’ ZN yue,ekeubrgwncl lahaits doTkex., Iu;eb. e,uom pah g—efe
# ef $hOoWehtjeotKlvtbtuwkr,
#  krhntCI e’r ucIvp,.IgodUeriadfenhacfuogrtoB. cr t Msdgt’pUhota
# Running Avg Loss:2.938257418870926 at epoch: 0
#  ngegn goiroa disisltBrlKn lIsIna.s’yt u adedirldere. serednmFpyylbey AW aceylbor seg,uiuAri  aes bedt o
# tiaexetuwflon r abecaieooley  pdaveknhn foylis bocgeeyeItfrr$y. c..P,reEnd., kpreg
# eg rid C Ti
# Running Avg Loss:2.790786564697977 at epoch: 0
# yahe oiaevuht seMmuehhc, snnoe Ans b ea n ar, We nde ei or n f rt twtSn iehesctencnpbyorhagey nrelcdirisel xtotTkr r bntyeyrtenthenade wh ndhe ut men d ndSrrvex SvesroAcanToThLfehe e qvficle Crare bnb
# Running Avg Loss:2.7470195191716775 at epoch: 0
# I ele  Nl Ale’i Ienong. t aotanlwol amitt aol pue rod mosrararer weweituare apest in. rev It hpre anis widege’s the otaem Is me ars aol covttberkfelereyed ineg eh. Or.  oey, Ea. I,  arioThadegigegmenr
# Running Avg Loss:2.7369705355763436 at epoch: 0
# r
# Onbing is fkpe. Tenkeims2 anol. 2 ma2 2 Dlzild eh rir n Hass ud dert. Nsay bsiria 2isaman 2,n
# Terat png ams ata The s win witit purelt in ;iTharithin molislag ime whnrabet 2 s oirns ave diosotngaiti
# Running Avg Loss:2.719545947571285 at epoch: 0
# n curduiyl mirve the theleqilt trg out toitr ing nd Strs wht toat., Is wurr be’racnd uve te It mtalan.uss o ro t or wl m ossle ny Irin sinan k ncmoewcao afe motate fer cang ert trirr., we, emede weloh
# Running Avg Loss:2.565641418289393 at epoch: 0
#  nar we, woing tdur rund wheert at dem ariseeireiote urgav haCstin bilrtle t snt tlo Wat urone tit plo tn s. Theaust isgat he ag pipetien goty taud ar pr dere grt wrust Wet i tius. Saingtebeot lamreat
# Running Avg Loss:2.6241416422091426 at epoch: 0
# Cusg ohe mor. Th, hale bly led nke len tyigtal senes feuc. ApCwine terpd sher ef wa or dit est.
#
#
# aveluctr isire tareg wht an. Kon Are wek opror ahatR sikl’icil t te wn thicab
#
#
#
#
# bege a so we whaltL
# Running Avg Loss:2.4997988677555694 at epoch: 0
#  icuyth igsthe apdinl ndiosirilo polta orille ntstowhiine ollihainsfryt umhipprnsecind bhe. I. enj thklw wsilr the ias and tuUsimals bhililerthisidshasber beretav oh stibs saoggrist hal hasrhcursals I
# Running Avg Loss:2.513810780488886 at epoch: 0
#  gof ren irobe Nf otdiu t on nepyinte wine ingin goro aktDunt.
# Uh m.
# I
# . Avepshe
#  hdo nicgrouss sienn an ceve ameis aramav dorandy
# in Lys beeial. Sr. hes weSls asges cofrvt ahmous he coctitmo han Cou
# Running Avg Loss:2.5808176731662824 at epoch: 0
# singat, as primas aldist tosaotr atimatzthed nft fhat weal es fer cons wilg I teller, dle ste das sust te hes ron. Wits wit tha.
#
#
#
#
#
#
#
#
#
#
#
#
# I
#
#
#
#
#
#
#
#
#
#
#
#
# We sintnastrriter cintrtitat tle atson chomnt
# Running Avg Loss:2.5187183851609007 at epoch: 0
#  mie sedake, tns the sithand endedesilit anlHenabliln. I diforeaed sanatichay. B mi.
#
# A dilif pnres, beesiderrlatillatlini iletadit thit  ind ors towe osithardoual atd rownt thavery the fhar cardepee
# Running Avg Loss:2.562835635026917 at epoch: 0
#
# I t w. 2oplek wef raotNon IyI han d oil loniw niwiltIsI ftotc wer d ois weu wef inloIBn dowas Itledtis ix bia n,Oicssil, te r A.
#
# Isfol lecal gin Fivhe,Aubtievertoung aw saI p o’stutM.
# Il ge, b, zwhv
# Running Avg Loss:2.442320876574144 at epoch: 0
# dints ablicy wh nt the fhae lant toroth, A
# Sin tounds wo’s Them must tod tha wo ko tour and stot bhios to  aleed fothans tole wheiat We geot’s woll. Aalivey sisy wilt We, thinicemsot’thald y 2oulL bet
# Running Avg Loss:2.34942658120906 at epoch: 0
# tat podies inspreesbplestencunt eninvloillt, whutt le. boligontedste’rtate peatd thornt. The s boinst, ro tiobs yitltlhen tuignstinstver tolliacto mty po tlerrepst. Wis wa er seroutpancit dator tive i
# Running Avg Loss:2.473369696341455 at epoch: 0
# nite Ev af thaytayeg all phplt ser ourer tes. -ture. ’ve, Song onatteorn Thoe’ onses fubee farenisexciataplent ndote teoponseine bh. —ha, anereAns thare No thal ante tant wh thous wsanss her the peoar
# Running Avg Loss:2.277784914650023 at epoch: 0
# t, tha de, we, thiic.
#
#
#
#
#
#
#
#
#
# Wo we no me thsof. we ind te wo nust at amunac an ammnte agly prean. We icaby nhat in the chtit —e pratiCver theind to taciny thay we pofos — werade, paind nod wavtec. A
# Running Avg Loss:2.6987484990600494 at epoch: 0
# ng you ws. Enfayk, I dave, Lar iby Nfpst e hand thatd ofuri, Ihe Iofo liond qyly ynenha losT I haple.
#
#
# Ncande I hads, "lhay A heves — hay.  wopoe Aoury urtoun tharr, " Ind havo, . Soelene I torleny.
#
# Running Avg Loss:2.6349758086111397 at epoch: 0
# d hav, y tvie woue. . dabs eryC wabld.. -Eill fod .
# Thercs, ming iodesouldf yzowe halw.’ whay fued .ow hy ngapl hand, yNop andl try noid, y
# Ae wnllm ?ndI way fuusurly..C ngould shan.
#
#
# Nbing ich tove
# Running Avg Loss:2.4898545353580266 at epoch: 0
# e I sout had sbunanditNeverew Sicandy I sank. we. Nin, ak Ouct. We go Waid. Nofune ithea kmest thank ea sidd,e. SpecAumed, othet uousibe omeOdien caoung, whal
#  -eving, meatoulli m mhan., Ateneovut epl
# Running Avg Loss:2.5289110323153436 at epoch: 0
# w ertin. Anhezeing at. Sderey,y.d gnom and moig — OevEGs. Wicak nteless bothe. Wepe.
# .
# . The saly ToOwth he gride.g muThhe whs
# St omize n yoind —iosghsS
# -t ore,r Ge couge Spob.d Ardo hn. fo mld, So th
# Running Avg Loss:2.5786088993647134 at epoch: 0
# Des the. Chini;, Mhme we rolt th ewe foud tonk gos and fond,.aDs —ve, az buelt the they susl ang rook we’g hoak,, Dobicy thef remika , forke —ory,"C ud th tovee all Mo ware hwhe  i nt ta’t ftitl may s
# Running Avg Loss:2.4697357101859523 at epoch: 0
#  grebe dinp s an meigg f thet I ’rend wi t wo wobhey t ip lkoritleR. I’ce sipopebt. SibeatoYy inet twec koe poouI Sostst ereah t tin  rienst I Pene goaterou. Abso griec I’llk. S. Tqook I’d your At. St
# Running Avg Loss:2.6082737727221104 at epoch: 0
# sdzro ablanes ag entWes ra ut s.le, fickh, izef. 1nicid iBul Noull thit? Inid this iHh swonidiimt nyo  hiou pndutgol’vo mded hi, qre pamia leys.aS isitmy hi micab,le doe bef ave nosnt. Eal ying mime.’
# Running Avg Loss:2.1500415878314523 at epoch: 0
# apiengg ie poing tor wis. We’’l Iad gacl an nve all ve’rl re t to’ ma? keon I,’ wat’d aplo. We’re ghand teve los. He’ras, be pe grp tast Ir amtzing thou’ld.
# Bring thawdnd. Yoiwl’ro going le getow to j
# Running Avg Loss:2.387594130347483 at epoch: 0
# to veritle, aith r ang. whe lnmapouve to I That greund fovery. I peve gatil soume ow ae to be the ins. I I wave tous tot beat tous coapliena touge of a;, beecs.
#  The p, cang fouth tor —.w
# That loopit
# Running Avg Loss:2.4535010072737933 at epoch: 0
# stind, ankybeaip toredowichaybeitk are the bomy. AI, ber and Che ecale cor beath a tope ipe opedit orloceThaybeang Wow coond thit way. The.
# TOun wat coa, thet bee tid the, mave Bom gop.
# LAting boe wod
# Running Avg Loss:2.251109913446009 at epoch: 0
# omesevecandicesrin ing iav con’nge uat mesans thiins nomythu. I deereats foiro fof an’seam bou e atl for in begisitms. Wer.
#
#
# Hhlicsoico ct. Ted fop are at troren. Thtuom asise.
#
# Thin’se it’s. The uti
# Running Avg Loss:2.3696786743449048 at epoch: 0
# rroidouDre adosopelele groqobe didpyund.
#
# The sron thouywa’sied carodelan s inciute’ry atide ghatit indolese ol loinsales pro wast on a.d Thundthow’s cey, apsyting tithie ason in asilen, wake dnves so
# Running Avg Loss:2.6937005214495584 at epoch: 0
# o share tha YAudeop’rove beca s, ot ofor pent owa Bued, Thinlar sot ets roB Chou gon Wo Thapesnto not exshabe tas’c norve ot uhst e han’d ih.
# Tht sor Yobrou de peot bedsu" Thoun jon orrB. Burbebo Sos
# Running Avg Loss:2.4772586341444405 at epoch: 0
# the palapant th yaut aig of. The ipreanl heoplea bor inthat peve and se diok and ig wh to geld ave rsa cortat is an tile hospicty, allysuhmint nov m.e ao, azest ith and ire atete, it to beve. Tho iclo
# Running Avg Loss:2.5582478903960437 at epoch: 0
# d, inl thardets et thl aveg cand
# oestur int and grurddlterll totbte oncon’t wha  he uce, vadlia, and. The tndithige Irf the
#  ant angende the fryald ve the dcon, the joeh pronilpeuspenope delry shat
# Running Avg Loss:2.4634934630896894 at epoch: 0
# ’n mxest Mj, bxt, on that Ih5. Thom 5plice try aay e p aupingese $xedile w they’t sitele them.
#
# 5blekn tre the promese promicome Ixt doo pxere pll in ter bion.
#
#
# OIs Ir bhe tsiso ke tevit. Whe sre t a
# Running Avg Loss:2.3346622506529093 at epoch: 0
# l andand nowitn jok, andt hatk the. Yhele a julsa I it? jot lo da jhan hatj IhI jow jnaplok at? I ang and Ir OOheig an’t har wn jill tf whe jou Win. Rthadlus se, j. Any hate juve ghe delp ooat? Twe Im
# Running Avg Loss:2.3901943483855574 at epoch: 0
#  nhaw do gave aanegr, la atpik, e ar thap. An what wane on in, —, me ran rall in re mes. I,d lfon y. I w on par key ham nand boves bed temtevrenonq. N be, tha deand and stayd han tara trer aming be yu
# Running Avg Loss:2.2601845024954526 at epoch: 0
# t sang.’t sat may ftime cin atlcyop. It hapeman chas aver fand go hs de ron not’r con’s dit avo nu dpes fory, fob tilly, bo in ca. tou woon tow mack, phet, camutre wow.
#
#
# We tos fob paob, han the irgs
# Running Avg Loss:2.431598322281614 at epoch: 0
#  f, noilr rat ibe ichR  lrs defr, tWa qan?ybed oplilhar uihixwiur avinss wee. Rwip. mbe mriksiginc, glal be toiase we fid gasthuing. abss te. d harat  awinps t oxrlikn ha ey Ta tmee iae fa a b omnhy,
# Running Avg Loss:2.46905411652429 at epoch: 0
# e ind touvey i adey Wnines nom annethanc. The ch,y love d s heviUleam ba date, anod te the cors , ,o whaped, . H wort.
# WThe vesmig my the. Ove
#
#
#
# Afnni grome. I rout cef thed fredt harTtod.
# I
#
# Butt c
# Running Avg Loss:2.4665097117722032 at epoch: 0
# yan, nma tren bod ter yofed harut tet sa tas aveopl the fo.
#
#
# H. H
#
#  werar.
# H gepeta thargrag.t the te gade ixsy aelitykite’t.
#
#
# out cou bo the the .
#
#
#
#
#
# AWl ale af fuiloiks hap the peaad., the tha b
# Running Avg Loss:2.4460159972561524 at epoch: 0
# t mare-s jof wous arde conesmodimit.?.
#
# Stey. As meitve pnome le ja. Anite .
# I’t oust jeust toigmis pe es, al bis, y hlrere ra, ho id to dithive makeg tmer reyom teatr, otr tont. rat id bike. I have
# Running Avg Loss:2.451748433707282 at epoch: 0
#  kuouty heow, waly dith.
#
# Sois, "A. Izing that yhiank aght and so andth ak that dhit ikily trose thaell, thaspere. Hobhein? Oom?"Ye. Deat? I ysas, meet ?ah."
# ? maes "ir, nNu. I chice —e. Heid thile th
# Running Avg Loss:2.552559739942197 at epoch: 0
# inN. Dmleon "er or in thino mhay opedthat tahenras., Chit ur arent thsth. Clon’tr, Thir Ct thaingbrdet be then arn me med umlell amed. If ther doaSkth thed.
#
#
#
# Sly.T" yon cor Arith seresrirkieale sori
# Running Avg Loss:2.4322330409139394 at epoch: 0
# ct’s ye atn I jultinthelaide, abllyt ceeresliti od os ling nuallnaneonfingso goumthos macatentenins dod Ant heleassaflvee aot icavereingof weit doile natd def talinkankae ar, ikmingthe the phearennrno
# Running Avg Loss:2.5878588635032065 at epoch: 0
# .
#
#
# u kfot ivg oveat ne at ceung sploin al? We rouer do dabig oppa0. I aed se maple nexfad touid me the reor. xofrd beyid and they’und ucpuc int coul melr apeay, heing te au nod denyw cuove bound be.
# Running Avg Loss:2.5314013455342503 at epoch: 0
# ve y wa— de poly now. Way —y. I oThing allyen’ rours byoidprS aint,y billvar bean iongeona’m weve col, enarley,. Iy loing illt, I’t naikn iw tangtill,, necilhay beingoand. For
# AHed fo coongikt ar gare
# Running Avg Loss:2.4884833293259145 at epoch: 0
# tony. Ehy we ple po —in yo The ave thos Fo bCo khite is te "con —os.. I Wen kl —. We for’s thar got’re tho ? andyangat yto grou tha. Bhe. Noy’s ns I’iac,j it sa tout mango omublab —tithe yheeryoint, s
# Running Avg Loss:2.3454078303836288 at epoch: 0
#  iod tomer — kfne laknovever simp, athe ke thes tor heeke nh ig torkesa afg balktht yse’s thit’ exd. Hed.
#
#  Fve nordisels aold? If bhides.
#
#
#
#
#
#
#
# H go. Nod .
#
# kSemtplo.o
#
#
#
#
#
#
#
#
#
#
# An knit sew te went
# Running Avg Loss:2.45484109313786 at epoch: 0
# la tMald ged bemb seit,. tsarl vends. "P’ve ve pranf a dfI buvedingat Fe to.
#
#
# He hove gett cemey.
#
# He sat nate corespenithemrls beall o uf me gees., tuve the mproplithay’s gilllci leny to noun thet’i
# Running Avg Loss:2.575852038244717 at epoch: 0
#  catserd, iveh.
# WhTt beke doto geo, Tory ougrfan kimad opurak gpet of and . weve pwis alcanenibr toicat .I’ver on’ne prispexoits? That an we uulsond docas to whot reey kent qow’s soloe. Tow ae -hipakl
# Running Avg Loss:2.5187612893469633 at epoch: 0
# piothekyre wond Teaf laon antd. Theypsang ton "Ar ae d..E
# te halla. The pck nt whe lucd fret nayht?, hey cound we de te. Then the ot cangot ic.xTrey onand the whoiyrek Thavliag.
# erdton lyoidof anq a
# Running Avg Loss:2.3457640288360415 at epoch: 0
# ony beond Went nove hay Mr ponst berast sta cot pheing anom the k tonay thm campsna deand akis. I’a Ire rove. Nobey the dlas and."S Irm iko dhme sa delr. bysay ko ppaa dois to ler enoyse muel baid to
# Running Avg Loss:2.4395063770152627 at epoch: 0
# te the the nhelwhs, a’try cehan,w’or tevaltm adw"
# S al thef uwn ucone tfic, Iinkile son, Sorbutillo ceond onksbice once wam alll an aun, id oundecem hedy onuplothint.
# Nenthord.
# B? ane bithe, it tount
# Running Avg Loss:2.5431211670506744 at epoch: 0
#  gandiw, Hre ortred I Anl to aplem boit id go thing loily innt sout I angpthed go me ag not I cardatald rot do. I’ d wint sad angat dopl atpyit evangn I rand unn yoDwe ytou.
#
#
#
# So rat dive Matlribod b
# Running Avg Loss:2.473758598343469 at epoch: 0
#  ricic, Ging ohey wesstyesther.
#
#
#
# Sys the wom."
#
#
# Sarse s bym."N
#
# I’m We to’s thing of n, t het roeen."
#
#
# Not a gilic.t?r
#
#
#
# Sod ster. Dot lu te thellacit? I thit’nip ot. An. Br ws wendt of mprhtis t
# Running Avg Loss:2.5087245668866673 at epoch: 0
# dees rend andeavlion M bevep ous eotise deta — Bumen a m, af rerllece whilale a gurf —at’rst tems in, I d’s deve’le,, anle burin wor
#
#
# Bunt  0ve’vindtes —o weanP ef — weat coester wopspeald anAg to th
# Running Avg Loss:2.3839878461332993 at epoch: 0
# nd, the yorticce dnot onow wite to neve to thit is tor gove tm’l her toting, beant is it. Be y’it rted ho we I’n lores ins teve of thelliblel, thicetu tave po if, iMume wet us avand, ratle dellecove $
# Running Avg Loss:2.4941354632182047 at epoch: 0
# — pireRt. We ve. wrhe miot hethtsinels ig this tegon degur "use sed thin’ ry ame."
#  ThemperTind he mmpalsefd tedo wo thingd averesackin ind I pamry whis, saa, ben.d ther, Hyon’s thge the tand heplny a
# Running Avg Loss:2.562017570552416 at epoch: 0
# injw, in. I ill on’t have ceave Thave of thG ivlin. Wa’k ferimre youplilo?
#
#
# o pl sand Yertis. Wersjontminthanyt,or mep buldebe. WCtecabs, pighe obat gve e very Ie af fhint deri tho Wnoeplon
# 2. Wfrie
# Running Avg Loss:2.558750643134117 at epoch: 0
# ridwI do uadma.
#  ttorncbuisot Me pousun beae boerrf. so ath fro gorfsAnkf ow ingt, ip ondwadre bow,t wo ftheas gat onh is fee-me kgindd.
#
# I’nsaadjofe ares grens in avey in does ofr it tre’or, wou ghrl
# Running Avg Loss:2.452939342327416 at epoch: 0
# is. At. was mes .
# fhiryhe Wof se ge, an wol’ltl thlelh hivig ofd e se Sst.  fee atiirmu Tule ay ittn. WeytforeS, memr. ikectlllear0lreyiphetl, cant ind bsple wole tha ge ar han sw wanvad he y. misvu
# Running Avg Loss:2.483637824539561 at epoch: 0
# o is wod ce terts yeint hopumyr buatlethe yoa it aume, Yoyk I I cy Io W a pracens oca this yore to iis ghaind toc Asg okiseicg mase toank orest, Ih iver
# ousk torla ooppere the bouseit woasl ite otar s
# Running Avg Loss:2.460835633762181 at epoch: 0
# it’t em, nyo sed tot’l cos ion wot lhdif won mot thably aclhon’n trey efy Is lod thlese ef une shgint. Thwa st’t’lft loa she t iw af ror tot semal hat whe ghdabe abes ats op an fen doure bor a latalll
# Running Avg Loss:2.4153680537380278 at epoch: 0
# . w peereal loisl tholc a seer oust olle to ban mlent os ton po ives. Wo’lt boeat coosll. I
# SAt ghe het nowe wonaget, blot. Ter blorite becan feowe yue iut oly atalith maby. I ong there nopooun it’l o
# Running Avg Loss:2.456523632321507 at epoch: 0
#  daves of kuad hever tonikeI andco lates wined . wore.
# I A5 moar tes weve intithe srnng coa.
# I hore ovengs ntems worrsto I ald wer gorytasesy.
# I tove oreve toultaiges ton mtrad s, iva a as. NTywell ee
# Running Avg Loss:2.3294013778939844 at epoch: 0
# ld IaStw. Burplo thissendss?
# W.
#
# O havef o
#
# ous teobe ppoudef ouredy, the o nagts,.
# ur the inns cpo tow oaesh davly the ta kone fur $sayong oTcorbes au.
# Tu bodlaf e outs tou loney loul irexy . Wawe’
# Running Avg Loss:2.439673759388272 at epoch: 0
# ata ld. Time oucterouy, tec Cisialdeaiakevery ourr. att trsink fvery, ifx mithe artess. Micatr, y. If MD in w at ind wa hrupak,  2akly in Pfarkisen lemis.. Char in a se kming waver, we is snspes? fhle
# Running Avg Loss:2.3602487617675214 at epoch: 0
# e daite do bedory. Wh yo keat, finy, beec boe tod dobyang thel werh.
#
#
# You thek aly m ate to heactout you in, e couuh — doishsryy, ocot. We gney whing the srat her.
#
#
# Weke golyd bedny, they o has inc
# Running Avg Loss:2.5356195559557526 at epoch: 0
#  amRand sar Pad qu they Pesbentemacen voe reego, fret soull yone fowit shet’rey, vroka deoc dou ceromdy cay’nf sh sosilas af beinit. S fout, wham rator the Ponwe ro beokRe ract se ard Pot’s ind afly a
# Running Avg Loss:2.4425326459836216 at epoch: 0
# n’t No fan lonring lus texin wt. I ho wo lan wes
# our tha goatt hees heGes pgets and se-
# Bun Ais a lile — gor, I lo’r bo hechTe boing toure halle pern tem ncos it we int bo krome f ton ieve anet a kus
# Running Avg Loss:2.288299595464021 at epoch: 0
# a the monsay’rg oun y arly ben, blinns.
#
#
#
#
#
# II’ss we worest cane her dabl bueby arl as of fus hat buorechiplietsilish as uf, wo yallesovint. We Bumey toink I hinme. Rat a larle man afs mtha, ing whe
# Running Avg Loss:2.2994956260118635 at epoch: 0
# r eve thither werloy, the nom boica jog af da f peingig ton wet eve alllainge oray, wec., Chio rout nor int alt iva warle otiwat. thitr cymon is. ula ter gor fom ade bnraw anp bund co noter won goobe
# Running Avg Loss:2.391746155011002 at epoch: 0
# proninfc we piong thiy ly an nibstthiw
# I mhel’ed bgutiry I gourd s umon’ds well’nd I I’re to cruper, I ing I maetit he thing and I ge’lo I ved Bnen wereveme, ver whan path thas trald I s I dling sej
# Running Avg Loss:2.485866851470899 at epoch: 0
# homagt co in Rumpele pliond oS aka gotthind I, dha Pit. we veoc mar maind medatid irl’m womavirumpen, Tpe0 geds w in Aly I ung Nerec umpenwe an, xopleakl’tt ria. moparte vatcrs rerex. be pend, 0 weven
# Running Avg Loss:2.3338198865475133 at epoch: 0
# fod Iodevog. Thins thad d I aideI s thew NBwamllleasa Butsoud I e u tou domerekecanow hevave lacoeB Romigoa t tad I devee buplomisgerobly 1em I at’nloupltc. IneBuateoplponrillod voromigeveneack But wo
# Running Avg Loss:2.4338726121522485 at epoch: 0
# ds godu, al dcrent watd ant hoverlro wo’s  haml, grichrit. Cuut uontise nover phr peh. Tofo mbeinestrtl obver.’An. Crea ke soon. wnas dtof fheilut thed ate uom vyosing.Y
#
#
# ou? Dhe’vhe ph glaite at frt
# Running Avg Loss:2.324314028605819 at epoch: 0
# r oule tarlous o ariofy am mallitint of orsout the Y prealllinns thry ofretismeras, btres. Thirrdyoun’ing, thestheyWe seve pouned vikes the Oboowe ilt theromiveah eresot at averysity hew anthey’srus o
# Running Avg Loss:2.2515958829927256 at epoch: 0
# et oit int weread doas. Nou doute sans atrd evar me fralion sigl to I sodt an ave ave wory weoplane lous — morgrs . Ne we hecinsish ind avet sft ter me fad soumat, ther, soxs ag porley mon tho lowecev
# Running Avg Loss:2.27953945885133 at epoch: 0
# wed eril ly werof pleresong tu0s0 torl. Theils. Te bus the reveo thameniiny yhe saig n5 of thing t0i$g tebig id Hexpen. Tsedin salbonet trutt as000 purid dicand fo bemet pinowst you ? wo nhit ote May
# Running Avg Loss:2.3481696827420966 at epoch: 0
# r pabeou lrereopleo the powve. Amen. They dine to too
# s. Nolles aam thepon. Nrempan thih laao. And
# o tem ieroy orrti le heMte we the thmmpanint eo fidietith toubs mon’re do it an ghotr thing. they ia
# Running Avg Loss:2.063810023162514 at epoch: 0
# ng the severe ouokes bice thoy’l onde hes Rors foullof they’l at yech, the Pe ht fre coping, the, wo’k you I gaty’ok they’lly it tate arey’llyou they’br you gothe’t’le wopcet the tig tighe hive torl t
# Running Avg Loss:2.0915324468677863 at epoch: 0
# for loing the fare git tsthin dosproick the roing taing to y. Ihe sonnd I’m going thet’s I wart, yrumero no k’s awe We moing tem IvI whit roin peangouf s and the hared’t wamican, wo fo goon fis Paldoy
# Running Avg Loss:2.4441691957041622 at epoch: 0
# krcan Rhatr san soiclaw. I’me shinn Ras hte mcanding to licavettrymeran has Racall tour, the krir Mhatr se’s umplorer obyt ary, mabig mty racoplsin Do ex l Rarde the Dam 25ing so go tic. I whig xay.N
# Running Avg Loss:2.26955633322848 at epoch: 0
# n the reacire yot luheme prey. I untincoing thintorert. s
# at luctowe chat Gaytmey woe gont go. We potr yo out wir tiands thes are wo thintr burpel raok, tas waspersevelyt lak th to
# id aruran the ler,
# Running Avg Loss:2.2556419492438438 at epoch: 0
# sj ellion Micksen.T a of oak thon ytrnagrMy ste.
# Ye lickert sboo butm.
# Bu a lechetr aberer ap ponty ibuplont moncat ser’s thI s,Ake sirtass sint wo mhete wthbyay’r lacke shag levers che har doy yoss t
# Running Avg Loss:2.2591810266152024 at epoch: 0
#  I’venR aTh I d on. Wes and and ojDte nod I sour have B aid Rvow thing ering. I dou than. I dedth, tote s ghtit I dou thy a have ve Itllycand I d bu
# prink, And there hove have loilenr Che d and ast an
# Running Avg Loss:2.2621852263663897 at epoch: 0
# as woild  ha sorl have soplagpsing is th bedor.
#
#
# We hered the on wave of seyumest butarisg prowsallly wsmiteld I’m your wease and af Be counbow the if pbeit sem shny’t bu.
# But won thas arilnd. Mreate
# Running Avg Loss:2.181843530356884 at epoch: 0
# m think. Yo as con’t Youk a tnong sered thing wiore tipys as be noo rog a dired dod weon I wfeo wery lon 8R marebyo paly.
# Wumedy yo berem peork ave buop ya but — derimpone tet and I the Rerve and rous
# Running Avg Loss:2.2350851063448935 at epoch: 0
# y, wit’s lof his aved as fon. Amord, the whly. OBut a duh thisk im lifaste higl, wore.
# Ane stoklinth meck thirk. Somemd, ,oubl wis afan thank nwamdetha trom somn. mo knole penllyt. Oven beonk, You anr
# Running Avg Loss:2.337022487578448 at epoch: 0
#  bure. Weo doozit, ysy ber ind nod thathed inid ow? I — Bue go, yo leot.
#
#
# A? ant So? Bver demsthe know, wemges, toy lofte hwo wame. think werybuo sut.
#
#
#
#
# Buring. Abeo to and ghenmins pee heve grine,
# Running Avg Loss:2.2109132517110557 at epoch: 0
# w hinam, gotas ta Demlyomenw, whiw het’s ge hans, —o doFw — nom .hs. I the glit’lticase, and I the y roghinkl otit sat’s got’tss bocoon the danha perso. We win peacasist. 1A 3 manld beoredt. I dounthe
# Running Avg Loss:2.2497774462956004 at epoch: 0
# ke tom, athester. That rat wot’ryoind beiplla lut — dhow wet. sid shes they’s nsqpeoth. We To aligalickary oor. Ya wmhanuk ue caul.
#
#
#
#
#
# We — rtesicabe forp tos stite fpopl agl bot lowe — leopscopspst
# Running Avg Loss:2.4128376936111597 at epoch: 0
# I ace unhe geisuto sed thathat us auveny upe wa m sheued, by ove e wensture. yChe " Averspers then yut wena nCtha saces he pRing ou, thatceth woryou whos I Le’me hat we vere patty Boon gois thim boom
# Running Avg Loss:2.240857376425527 at epoch: 0
#  he h
#  wank, ye’r col and and toringe, to mert yoo k veon thowe ze wis bytal ot Chate — yut that, And ig ig wa krobicteoan in.
# hot in. I ou aned very meat, ybaobut liome hew ar, yovet’s esew un nont
# Running Avg Loss:2.349840378086548 at epoch: 0
# n. bo id at matu rutisilde. The goubeat, e whande noremit., peon youll you loive d. The ntthkd in soivereh, I th. Thet whant houle thnbic1band thas asion to thes emeptina eade thinte oullyares it mut
# Running Avg Loss:2.2188571390328 at epoch: 0
#  magingirt sericing ror al, ther and ad, te, al to boty sey bot un is bea. I beoviriis, yoH aly davneatentking. Bve tits war tone fuc loo foa lof that kbobyhe’t tok, le thines tya lian avopl, I, The H
# Running Avg Loss:2.5620670992080123 at epoch: 0
#  don tont, fhaks whast ing orlts. I .I donit. ner he prt abowing nken at.
#
#
#  Whes 1ced peche.
#
# And lent red aed wimidn — go whay’ knede’pett — pard byo loufrce opo frustig. I me.
#
#
# Anlineidinin gint,
# Running Avg Loss:2.429385237802751 at epoch: 0
# e prent, ind de pald.
#
#
# OI hI war doveerels ma te ing yo ke he loatt.
# A dos tem lem of is mutlo, on. I Se’m haps ald I wead ser Ou peng s? And ig talk iu han’ths the preblke treacese tars — he? I vel
# Running Avg Loss:2.4111420861803925 at epoch: 0
# praus sis he he I shesh,’se in I’t steblo ave knowe ibat’t him, rees. Trith he e wampist igmee’nget ac. Af. I do? Hest, het an’,  hou,, soull ag ang tes, seenp nos we wo hme. Towe Otat’s aolls at ked
# Running Avg Loss:2.2552152504986154 at epoch: 0
# g, of haer ive ale seeden limky tha n, momaneny wen rease, hin talenthis eshisg me hee theraf ing got, no, I ohy head,sth I’lking, ta mhet. thing is age, mel Rmamenisg, , bd mel thantr. I mespe bomet
# Running Avg Loss:2.328434976777062 at epoch: 0
#  noct?  rikeet erery alvey. Sel any et’t ike ite, is vic’s itthime. I longonec. St are so hy ’sp’tl illt I. Os ther. Wice lile goig. I are thel. Ane pery her nther — led yeutry.
#
#
# errene, oply yourthe
# Running Avg Loss:2.3419870629394426 at epoch: 0
# ely be, I whigent?’ ko hald wo counas a0, taig mand to is — se befr do, Sous we — ery you do hoilg biging thonret iat thting ment.
# was havhe toud bury on wou blet i’ gery it the. wiHk bet’, of the’t
# Running Avg Loss:2.222286234942498 at epoch: 0
# ha ths the wead ceve ustecece ond sambing is no very whay peond. I ase theld to Syou loth ryou wericemeedaSt?’s is.
#
#  ond Wha don’s bett you gou ading tor ker ferecCa e wovetr o vhil. I tared , rleld
# Running Avg Loss:2.155601744692307 at epoch: 0
# ju tolle tiguse’t jutaudn, ang’t. Thomebicaut of ttile. R keo ltint Soumis. Trou. She jus nead. I I buik — Tut’s thas loy weaml nof wald con nawalt goo bnly I mind ere toy is ae tee ice, hit. Tharlutt
# Running Avg Loss:2.243784598437138 at epoch: 0
# eny sann to bin it’st. I nontatserghimtis Het rbicems bes.
#
#
#
#
# acea les in men abromy. Andwo dime. Arkit weed,  haspppaoleivine. And tihell noist ibuciblion telle the, ir whe niat shery ven arxsep med
# Running Avg Loss:2.1676172114168293 at epoch: 0
# r win nis shed arests aw, , whate thath the wereama.I wond fu wcome — leve , wil int anks whalk I. Bu you oun, se aboy go ansing the’s mung tou, , hary ied it igg ot at? AndI.
#
#
#
#
#
#
#
#
#
#
#  And yher ibli
# Running Avg Loss:2.1941939554233105 at epoch: 0
#  cearim. luset repacata. wat ht toule they cacpdr woy  o cils.
#
#
#
#
#
#
#
#
#
#
# .
#
#
#
# And il ong,, they arucn whas ceigonetanke.
#  ngw. Chion it ce meciond de.
#
#
# And to wit mon, thit. We Oig youln, tgonenathht
# Running Avg Loss:2.3629721459290014 at epoch: 0
# , whe sromd lide bu toyche he walk ourtme en epper going musine  pene they an cat th rene th . And ing a go sid ar,. At leth on af ith I merpekf ang toevenn ant wallytatenithey dor, wher ave ale bod g
# Running Avg Loss:2.223456340853125 at epoch: 0
#  iaileva, goie are erewt ranguedio, the pavkno higeta whoold they eats ave ue tolirey guugot, whey, pave ytus at. I loyitayy areshthe. OJide they ud inuts ink, hand the dor, tares ve gon aserath thatt
# Running Avg Loss:2.2381653557214887 at epoch: 0
# . I
# knything.
#
#
#
#
#
#  laome .
#
#
# I ham I mocaney th that.
#
# Ttheroup stes. N. I Me that ink theyd I woudet o, sagwed will to.
#
# And I fu knit d ond the cever. Iove. I  pphet tumkerovou doaksy f.
#
#
# Oollaw t
# Running Avg Loss:2.3291555699422024 at epoch: 0
# dt tthey have me, why wanly thrin’s le sacand coungut you 1T barge the thiy merarle Noperutarte. Th,rod to ake? Yo’ sor they bry ef bo, to kave micem coune. Oave th you. c0 have mike?
# ?
#
#
# Thew hadpe,
# Running Avg Loss:2.4052438357532955 at epoch: 0
# rthand seme fis owem. We were al Neat whe you eveof not it. Icapres ynut. yo licg an terto tes to’ ce oink. don it "at wo tha wero esout wacime roede fer, ig now e ppeo? Irt ore arl Ite so?s.0 tid wec
# Running Avg Loss:2.082679487362504 at epoch: 0
#  Yhou the sou’d ead yould yivler he. Anvey — dould hat thay uithe the bavean.0T0 mason then wevou dank ove ingmt they doid the pecishar freenpid, the hevery the. And nowe I — do TarNpu gata. Them bac,
# Running Avg Loss:2.1962325500119477 at epoch: 0
# t’ns soon goicthe nound leame siple soishg thines coale atst whey hang than werl. The seateen thatt wanty uave — weruss at, itatrers. I mon’s at’riond gone saresang a. ut. Thers no seactatitgry to tha
# Running Avg Loss:2.1997056838944555 at epoch: 0
# they wout Ous whe meollesidesall— . And mace arre. I de — cant oillls ill taticingevasking sousint ore arkn ctcanctin so late yac ;s ong se lilk no capru,  thet wil koul wem decansa ind."
#
#
# They’re li
# Running Avg Loss:2.2131024151500314 at epoch: 0
#  buthe wing o  horyobout but the pardee’we and, harebaradby fint gownd ing becoome worstre whas. Fn ti, yhe on, pne habes pered. blesend tur doby I ksepsame tow, even ss pustre dove And ow we wadent e
# Running Avg Loss:2.2098670137636365 at epoch: 0
# hlenoththe oane owari gouthe o ot whouse prey, and wee goul ng owet medhe jres bid Inc, s eavopredtr.
#
#
# Hiw sou have has You doitint to byet goated to ancma’r mepinsessomlenesedonalt arouteene the? me
# Running Avg Loss:2.1708336078105495 at epoch: 0
# ngssine, ade’r ghit, whes the toule sok trey? YoW, baing. wes un doce tat’t seman they fermon, purcang whes cat toing san od whey eencba tely to weme hevery on, In seI bedo pres on ththee hou, on to i
# Running Avg Loss:2.2555067709758876 at epoch: 0
#  cippen whary fut’s dor I dearpera.. You keo doy’s ant dearte fhat’s gory savelr ted you eve ard ur evlelatherl lus til. Ancsat odpir fnwiou hat’s I ePrst gole I ak, lyouthtu goind to som bod ixpiass
# Running Avg Loss:2.0858589412942528 at epoch: 0
# e I cfand nowt seout. Co welidingling an, wo the kspelililif, in ins wheyons oo save lemfat world ma.k
# S, ant Thent ghtwou  irsend folelr wey. pre in tho goin aul. They p,oins I gos now copegoill some
# Running Avg Loss:2.1989033540561795 at epoch: 0
# t allint the Iry templiag. the hing ha benalw neet t alvess ap thting ases all it top noceur sikes tore, I ot saive have timo toty . Anckt. Yar hop ir oower sor soof. Tht onlds, ofernt, seallindin sou
# Running Avg Loss:2.299948443993926 at epoch: 0
# , it thom baowa we hail al jis? An male gooir, a tur ilom bost is al mearpes of the ghairizg nu mimille migs, mith Ill whirl kpar fo to’ des ig agent, Thir. sligout luit lide I Io
#
#
# ey taing ting, out
# Running Avg Loss:2.0638246265649793 at epoch: 0
# l Ktant I wht’l of cialpprlrThe calole. An, I do wiowe going hon that we’s dy ifwe ningefelressing greapeo of of. I wine snatery gor cthe wand t,’mey teont’. wate spio , wadcle gobuag got as s stink i
# Running Avg Loss:2.2661751611090732 at epoch: 0
# of an — whey an thevesredcof roy gerele ders, Aed ofr, I wa’t I wan aid cutm’Cp ato revern werem id I lave ta t hev af gtened thatt buis hare’me rice of, I ay cofrldea treett favey Thay eto thit I war
# Running Avg Loss:2.374234753294848 at epoch: 0
# e lucknle. ard ninivoma, yaus ifsknr, a dell ar, they’res bela vevesaf, if they’reald the thac arden, I roky,  plak.
#
#
#
#
#
#
# A’s cour. Soure doiand the ig toy thilm jl iming,t of theve?  the but srect,
# Running Avg Loss:2.3129005780783483 at epoch: 0
#  meppespant there — whing i the nothe ony
# ouhing the to meat lroing o lof an Mause a yo mo the hay’re vee reat thing to llanl ba goe te mint biatreev. Beineve paill pace to yhe he arid sartinthe wen
# Running Avg Loss:2.2647600313117726 at epoch: 0
# ilk ot wos, bil,. oon’ta. Ags, wa kik .f s opte of.0000 be. Bat to mss. I’veen’t wan, o, rilestus pukenvioks. I, Osoulk ke thon they. We a guidn a the, eassriin trom theg. I We not of to is’s have se
# Running Avg Loss:2.196335457188077 at epoch: 0
# aute wey’s wiat e tonser? Wet they d ouer ’ve they’med a woo cary bet he. I knos ore bedt ay’deics Ane s Theld. Ionstu maill the? I We and ire stome alst roully handot that. I ig itshe deatih so’vt th
# Running Avg Loss:2.2485976821351796 at epoch: 0
# er geth , wall. Wall te do, an ham us is ragw.W0 jute buth thod wargige waig caad doma go aprre ic — thay aveld weelisn o dalls orear. Sikii. We gate dout it Are hampre —ion bica, tthand they they, lo
# Running Avg Loss:2.182162415843457 at epoch: 0
# s the I obod — walk now was Tilding they go bo of acs thi knots of the chey wathe to teve ofne. Yhe ha got to bolo gem co the e out you s, then’’ i looperodliod it keopstarithe of mends a wore doingnd
# Running Avg Loss:2.2875219278987498 at epoch: 0
# omsank — I’l ope tik. You un ther to bus doedoulempell — Irls a to luil ot a yind the maknis the, they rinhs there lhant the whese wonve wons vall the sme think o. the u healint Cons — these ghare the
# Running Avg Loss:2.2513270767107607 at epoch: 0
#  ond ars an ixvabs. Yeu soumtale.? Thek bendio? boidht ote’se but theld it at buik dil saut nor oure ars."
#
#
#
#
#
# They’ves. They’se ind theul tare.
#  muyildetauway muld is and Woiveat and. All dey’ressio
# Running Avg Loss:2.3017486187135803 at epoch: 0
# a fut to toming. I  sillisidnshe love levdog, bebobiag to walkins to he ir grat’rlw to to It, sbek, ron yor for to thes wad ing It bevann thent wa ig?, I’ toous iase ac mtu bime. I’ve I der nad so b1
# Running Avg Loss:2.179056701876223 at epoch: 0
# h prant.
#
#
# TNoin sand obden they co, ist prou. I to have steceapny. They howa they’’t — Co have sot til hriken the the erony. Wher ald. Theymaing.
#
#  wou. Theymapy rugling the ware Wont of ar bul. Sone
# Running Avg Loss:2.311485616970807 at epoch: 0
# out ken geit Aged outany boedm thenst that bisiwgugedenterd Dow, whone.
# Bug. Th yithe it hnes of in monty srald ourte souk no doung keraddtigonuta.
#
#
# But anly, to’s in mothe th way hame. ugs in the no
# Running Avg Loss:2.129535896175541 at epoch: 0
# e a)ingw wa dnite poobly,I’rs ust and ond oYo they ao fors an doat is of whe sond. Yo ghave seaigey jhe thot ey ableaverist. But if che whe the hes alled. So as. I suazemy andon’t and probned ard , of
# Running Avg Loss:2.1676556929517536 at epoch: 0
#  os. Then ald ntay Theiw and ppa . I ge acur ar? s mecar mimibnI an at’vive tigualllat? Ir’t’s eak of ame you he have os’s yoo wet ant jig an test a juetind that waWg. Thas and cis maca thilke ofuve c
# Running Avg Loss:2.5939696635026483 at epoch: 0
# op. I I and to pur byen ." hiw, every, an ace fono, that "nolle asend is "I shent ivism neang the are her ynant the —assey. Teas. Che plel to deep  youst sainrep otoonet wtase olle. Iu e’sd doik in th
# Running Avg Loss:2.230298639327288 at epoch: 0
# it’nd aslandngrtint."S — I’s, IW’s — We enstead Hon’t beveindadpenite ding yeoballl londu liknite sargy. Home."N thed n ig pofe Ywang." I mfazl inrylyy wang, lyat. bager y soinget onevesstoidterr mill
# Running Avg Loss:2.1443793531619013 at epoch: 0
# all in Mnont, no the an won’t, they rey oit’ bating tuy pest of som fo licaaur on seaca. Thering they noik doy toesticad gaont eft tir bit prony, I peatith no han aplakpell iing they oP. "Buse fa of b
# Running Avg Loss:2.1162798335365953 at epoch: 0
# yid he Ild is on " ou wey soing to there ir lola, pound caubdith we’s ut thon hit’rd asing’t? He me thabledr. Hhe’s gith,’tere.""’s I what eve shis. Tokno saidend dabe thej did han. He Pullibespliving
# Running Avg Loss:2.1785563910650088 at epoch: 0
# hifd Anx igof, they — ythent’t’ma yoi evall Gut — hus in’t aeda ate stas camict fon IMy, I’ joe politill midg than’t lite o.sN
#  Hee windicamevit, it’s apa ma pory micg. I I then havs the then the hot
# Running Avg Loss:2.3929847574089655 at epoch: 0
#  we, an Iy’re led,I I I llpeeve goith I d on’s — thut eny, ennt’r saam, to but 0redt I what sement fare y ut we hart to ight? I whe I mautlall aln. I sa.
#
#
#
# Le, weik I of hass madte tnc tass, Ami gle
# Running Avg Loss:2.240554817756638 at epoch: 0
# u inis, I’ve gor, to lo thes sany’r say allionlens. Bhad nces thame you.
# .
# T eany meve shny. Arey — baylrenn I wo hny’re sa, er sare thin. I, stuctigeve sisand. wat rumeng. Wexy peut. pnoat of thisN.
#
# Running Avg Loss:2.29319003525516 at epoch: 0
# pe. And pauy — you hth to deo and, ghe, novert Cos bemont? The bey the heve hallt herjtinkan Chag, Chane The, I biants Cond por, Cof, I puait so, — biand ca there. I’lede bokpens I sut’s besmallr of t
# Running Avg Loss:2.2062317375056444 at epoch: 0
#  the, bued, of, on of tar — shemen, thay Thes Che wa, stounntt btuy fhe wansO smen, oTout a uny hme , ene sayd and, e saysumand the lit Crunenice. The, you tas wif way sus the way thint. Thuy want, e
# Running Avg Loss:2.1336600087117406 at epoch: 0
# ver, toNt lve tos. Yow towe’m et thin’s au ins jut int gode tambant. Su, way ave gous the they chag? gove truct. Thas spillles, nhey ca. She huyz enn shothtill ti, he ery, hard we gois it they.
#
#
# Tore
# Running Avg Loss:2.2416417294666173 at epoch: 0
# ngathev erery thee the hases Gobod, higatl, tore’s the wothd — oule, therer eveer. Thishe pare give perere gois. peael saik, brers thing.bed. Ghes irs ere, oigd hI theingot gost ouring ghet  keraguing
# Running Avg Loss:2.106742800456472 at epoch: 0
#  al. I ghe got itaut go bgontibiche to imabvese af inc to byea inc of pepe at ofrit. I warle tham, thim, the fen heves itht wadf to bent ibout thing wagh babicg yoong. SI’r arith gor co balingut i kni
# Running Avg Loss:2.247484444621019 at epoch: 0
#  porking thilk non’t and alin "farg ait ot lit tay — i5 . Is aso boung aWe desa himk. Ho we heat goich wet going to OKopere, ombuilg whing ing tad doicu. The co in. so as. What ghind mo Ihe, wink yooc
# Running Avg Loss:2.1631006882423534 at epoch: 0
# gloo pau jobit caum. It practono to hean, Io, andea., to do pexy, we’s me toh. mey ofning.
#  to going — ?I’ve they gonere, at’s abe ha.t to me got wrey, dow to, home walle. And — and — kne and to ut th
# Running Avg Loss:2.2420809502284973 at epoch: 0
#  wing anged — deall seand abut the.?
#
#
# O
#
#
# Weedoneyor gof fheve ghes mnonecang thes nore to leas te thatw that, thrers with I cert then iscart trepeode 10 heak dad trat sas tot the havas, 10’t wat the
# Running Avg Loss:2.0971961148623377 at epoch: 0
# . Sou tust ot the to guing if I’ eng 1Sant.
#
#
#
#
# Omoinkpor goik eo touen’s bet trom, the weda, we yave tingdd Pe to moy rout I were hem in sona at wot ong do wam it I. wo bicaning. The. Ihe have golm t
# Running Avg Loss:2.423127557322849 at epoch: 0
# eopr yit they tou ke aig tol. Somys, a ththe gitegien. bore walle. And it I so ate wery I No becarl jatt ing at tas men thon’r dto thant they fow.
#
#
#
#
#
#
#
# We seasomg gew, is, a done Imaul af you dotota
# Running Avg Loss:2.4640834329416976 at epoch: 0
# in going the noth beall warl going tho nukntin. I wanthe noth you horkbo. Inutlr, I Ind want re remonow halk. I t hant vere you badkit the gon savhea, sho knield ovhowent.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Running Avg Loss:2.6177063115071504 at epoch: 0
#  remblaeyring ang vem lon you. Sou bace wint. You knorllidontr jarleveceme ing wantagutking thandcardabontt. S diclis gokndete a han Sa. Ancand. Thatk rouplo go uplact sp on hithe favatl bandlle failr
# Running Avg Loss:2.4396639567138627 at epoch: 0
# amcaby a ad re going bevery. Jortr bearbedon bred rasedad.
#  gor. To’t. Touy bpen wald doll cad yoDdant mach warM . I whopl bow hat pald wa bople wercas of to de’t be ne toll. Oo, wo, Bord to ghant Of
# Running Avg Loss:2.589043252252042 at epoch: 0
#  ideci eor wee an, goin, wo shat woxpaucholering doikire thing bus is in therion ruop. wheive oult onk wary, bu torr ancald porbarfide cely, stoust patll I hay the pe ithat win oreti reaver womk the t
# Running Avg Loss:2.2309173463881016 at epoch: 0
# lat eraon ready "Wlate -- he the pobs0. Yom the peol anf beyo Chaty got bon We po wall to the pTenSt. They Wall walle thillery -- of to lecauss.. Afa thipp wisith. J oosschacle hhemprant pabl soint th
# Running Avg Loss:2.357559975389391 at epoch: 0
#  to he mes, oh molibe it mets I bad .
#
#
#
# They, erans fond rhatd wod imt wesit ondevs Anl te honc gald that welr ands sobseding they outs treet buth thatts. We mof heade ide friding Miks thipl it Mo? h
# Running Avg Loss:2.2592763461219145 at epoch: 0
# no ad soronting coble ink loics. fhesy they eoll.
#
#
#
#
# We  henent. Weva go, -ntherilll by hith.s erpendlents. TeM acorpntoll veate is tor ld dof themingeingeste amcodentet -- ant the aseell onic gout b
# Running Avg Loss:2.289183676049113 at epoch: 0
# rs. Dud gocke -er leveveninte the rar m.
#
#
#
#
# We'k, what searer acs doet, bue hor poalde goinighnd overere ouhive yory ed toe moober -5 adming te sare i an. IrNuthe tiageowatin-, the tay peall  rari n
# Running Avg Loss:2.236028976537287 at epoch: 0
# wths ceate nowe ar to have nen theat, trom git soll aO foor ate,.
#
#
#
#
#
#
#
# e uate ameayo not ofurtrsecos thencen, ancope foll fhes peingring te ig calgooliip. Toh sndis walrbesly beverio ans of thethey
# ...
#
# Running Avg Loss:2.566277804560028 at epoch: 0
# utayu af hge ere poifon thistl hoved bec. Yow
# B.w I why’r ipfe pwey wattr Cfil We’t haangoin pIe hos avey. they when. whand of mon dor, I’inans a keand inseandn. .
# I isrptage.
# Bn langceg to hey kore.
# Running Avg Loss:2.4278958688378336 at epoch: 0
# or tol isa ave ine’llebe,
# eibering theng tua polld thicte. if –y goke anit pnomtmist I thabe anted to be "Alll ro’re the tpee’ting gorag i and tore y’llng iv bichst. Se thet bing ift mere be Onony tou
# Running Avg Loss:2.422231001906097 at epoch: 0
#  yo doy be Ic horwped eum cade the aat thate theve that wigr i we dede oheng’t .S Wonth. wo de rny’ norli go the’mo  fa an aded tghoruple ttointry teed "ing then. Bre’ns be therobid goik ang wiy An. I
# Running Avg Loss:2.908631760492921 at epoch: 0
# r. Yod to in gou gole aca lovt tasinkt Thel I’ to sole the torer in’s ef there goeb, toulro’ icm tvo por too foll, hay we vead’w goe jubit he’v
#  yor tee torat go. grut in we’ ta crot’to’o. th’ tors? d
# Running Avg Loss:2.597442142020911 at epoch: 0
# uee un ter tinetiesing tilk we eTikad thigow wa gde wBatoin.
#  bey peim Whe eids y 1ap fra leow
#
# Whe hheWe ca et pot wiche more ue tame fetarele sur  hol ctoverers –r
#
#
#  ley novta gou peupu say reabat
# Running Avg Loss:2.684521631652489 at epoch: 0
# on we grand dhent on’rer to,ulis ve tlont pleny evertre the.
# Iseadtsrs nann eriny CSinking to ceon yoil, lemtth.
# Bond bit. gow nomu.
# I yo thovent yod’t enti naiy.
# Buntth, I Id an’t if, ’ule dis un thi
# Running Avg Loss:2.6335979504473506 at epoch: 0
#  tou. a y limge re eaontctora ao to I0.
# Snate hbavee To al. aOs dotlo, Iny’vethen ant t es 0o mp.us ny’to nu. nbatb lt’ lnt rikel ahnta tutrB hia, soh.y
#
# ’ te’so ak.e ve thaisgo t ie. ny’ tllra wikve
# Running Avg Loss:2.6680481844469903 at epoch: 0
#  ast ay n’et themts pirere ghake pe.
# ade oul – pulle goout Dafdg hr a doug heled there, pouly eok i senokt hky hatic I ake onong, eakt geth deSre sing halsomik. ak opll ong a,’y I’r in Ion ghe goon  i
# Running Avg Loss:2.3878752986192704 at epoch: 0
# , Wet tory wows tomy we we oring I’n,.. Woun, Thepe iniut o akli hey ht’p thagt thawe tht the tat thing touwad.y your., to want torys tore haw angayrer owe tha lotealliom wand t turesinyt’ we thakth w
# Running Avg Loss:2.434479139596224 at epoch: 0
#
#
# We and thang thev srit, tops resre ils menttreg peling.
# it ming carions salang wonche’, thipe’ thel’v it an inev theng Rnovar’r’y I’vathe’mly seAtu. Oie.
# Whe’veng che waust in weyo.
# WHe ite Thes tha
# Running Avg Loss:2.585300907112658 at epoch: 0
# toust tar asdhinr pruipso the toime – tht as sey Bot. Heaydou thein thay ha beks se paomiden safer thebisthasek whi’n’buy thin be ve’r sas me bad vet cfuse teng whe thec bert wo they llr We doulk eain
# Running Avg Loss:2.5821081319898367 at epoch: 0
# ikir aseg.  triov psof it poutorsin’yre ant. Thin tin waere’ meing jend of bad bere ge 20lichl., re uend bulid rur doringstat af Iory weof whe ghillt belief het ous.
# af lup khort’srrowo.
#
# urony. Horae
# Running Avg Loss:2.6760514644645155 at epoch: 0
# y lotilby whamite shall a tore lag. Wer san lre donng jorll met lopes yo ay any ton tisgry Tu lend Ioret ow wers ge toy ube nory We’s ine an anlnfy Iou loun bowe at As the lit tou ofu zmipres – wese g
# Running Avg Loss:2.525866723779589 at epoch: 0
# l to hitst wen sou gro tint do fan apsant –’r dor notiterd mitat.
# .
# An coul so doestsist gics an efos’rl malt worlrd oro, Iur. Is ans Io tharerung yor be he fmuint gon yo I’ a roweri’nting grang saav
# Running Avg Loss:2.4389610390085728 at epoch: 0
# as kAlly theaw hos thr ank thoughint lumre ming way I goildong and hat sop, be seve i doule we be thay so de’t e uigl woupukng. Sgoullos met ane"s youlss shivet’s’sre leit teav enat that’ I churlly an
# Running Avg Loss:2.489670406360179 at epoch: 0
# ingt set we Have. Ther yoY sengu hat het reavaws tou saag, hat nan toly pyou peo’n,t at inekene ghet tot ante Mperes ton anm ter wes aver youy ser ticgr wet he blong, Iar satmte nt kullou.’ I I –
#  Wel
# Running Avg Loss:2.5436139121577144 at epoch: 0
# ond "I’y 1eishynt rot "ored I Ir, sa kromory Cualin andl anttoit. I "
#
#  An yaut wang g tine we keonk" Andther thiker ont an wove’rechadzen’rdut pimng she thaier abus "liklrs leaks "irket tiks I asdt’s
# Running Avg Loss:2.4988760107643904 at epoch: 0
#  af th Cyars reaw sthagr2 wheran chablea gacinilpe wevianlpe wa theye mhechat gomye so thhe the’r yoice. We ag hhinnt.
# uind rupl’ryy Tin wet, itth tronley Reopd tery thelnn wul agop in. I w’myorale to
# Running Avg Loss:2.4779840054363014 at epoch: 0
# mawat cof of at.ing it we aing bne a apes on and lingat theloumasps g wery, leedechs thalyowr fil thectr af thef and I am mbord thete thiet laclrat cas woy traag I thorret we thes Bro. I fof ag’mious
# Running Avg Loss:2.6175015325434505 at epoch: 0
# he ashing noselt ay Nmacewave torepliok she helbeckertacing tha inf’site he hat s att’rlr Ncarycinn chorsco frimidet dud is fmevh onide i wed Were –. Ya penrs bing ral nof rnouf fo be obols and 0s – w
# Running Avg Loss:2.3470522067900745 at epoch: 0
#  grat wist on’t the. Tore fhout thit agasar haneres oaple Nendresond thha ean hawh tound an’te tounthe doof ther deash, the chey and the thonht fand am the gro? Ave ifh hay od,. shhe her tesst tha ora
# Running Avg Loss:2.538310629531741 at epoch: 0
#  I grom is. Af red I I, somy. Sons thadoes.y
# Bu it. Ron whey I ind srreorla Hant It as thale s I s. Ir and yos I yhiv plotrens I Ioocout hnoer. Aaider thot tanySjrott. Srispileby f she say I weriondis
# Running Avg Loss:2.4672986974567177 at epoch: 0
# e vimtaRlder? I on.s forle utrreve hoy weignt thay. viopmear sar o1 o I lite wodge..’ros
# 0We i. vitt foy werent I weeyveyy fSe ha’lshe., had. yithxe igow a tape irowstangou beex re to tha nfdat. lent
# Running Avg Loss:2.4314777735248208 at epoch: 0
# nope mevhe oplole we tey ant, lyot whst nafge lred het goutat sint is he got the wershnthint cil thedeye tifef. Bute, the den te ve the beling theeshing fen a teroudt, be iledh, on, loot orokn farec."
# Running Avg Loss:2.605066081305966 at epoch: 0
# ule gebe, You theig teveve i.’he pusherlit. Yon we
# NAnt ipre thotate. NeYory byopeing s Ioleilicang gouy wiere theAn."
# nf iw. Pev peon. They dry." Whous’to retery whes ue. The dedre’pe whemerd us and
# Running Avg Loss:2.6206958230659367 at epoch: 0
# ent rpSor a h zey got we ded wim –nd toik you tha. I cintot thisinanrtl the an, Thindong wos heur i told the utons s.
# Son buinipis loman I merSejmnst thes pne wal wna haur bakt. Tuagrealy seoreredynt
# Running Avg Loss:2.640610391870141 at epoch: 0
# care andtine – dout cake I hat pedil ouveve thitmpbee mich se thay I have chonse vont. we thisdecs vor stero, cgherucassat ve thaisg. eva’s bot am toople bucky tholemt. BMled havers chat eleche. I he
# Running Avg Loss:2.5307367734573782 at epoch: 0
# is ofp ksprere cbe hrithe were areon thang wo tet dids anm i5e to beliding af onrar saw werind saperled’rerhiat lor the fawest tomin an’ pokredsredge bcaall hnild wosrirece ay inn int ge busindaw ord,
# Running Avg Loss:2.504145677536726 at epoch: 0
#  "
# ethe a, ame ore sar ar it whans the,hen lac woute worte are loist hat yrempanlin’s isth There evening ang. Whh re lat Mbessproins the pmeng toure thise vinge the kucon Pas Pso ink Pou nof they’pre
# Running Avg Loss:2.4283396271765234 at epoch: 0
# e hevered kind "fma wiw,rre they ar thets bengw, Ir the ve she hesh he prutennig Ieve, gant woras cliss ouri hoist.. Is the wo Days tit hat, in tho the t imperns bang thenge. Yo cI h youd dhe wav, te
# Running Avg Loss:2.4012114263325928 at epoch: 0
# out fvyue lar thet’tetr "to waomes the pey fave."I theynor himed tamouNt wate. Bing gevsothern" Gurak eag cull tree dinoinge thienctemidngit, rardend ing "up oon, thers.
# nou". Yrall foplsd omida oull
# Running Avg Loss:2.3319564012549816 at epoch: 0
# d has ho be’sist natee ant. And to it ho wa ve cejke goit macped The’t a’fl at., they hre hat. I wen wetin . Tha gey’rad thly the hrethisks bimg. We Men ar’tit c have P non, a Thoringre hant rhey to t
# Running Avg Loss:2.5829013663306832 at epoch: 0
# yis men wos whs mome. I Welly 2to thectin’y dol. Be poond yne the ze kand doseme,? Theoom.
#
# And I I par I shors comiche thor –r I a hot Ithe wabe cthet sise.
# Nerbe wans.
# Mas.ers. yowe thory Cid nomet.
# Running Avg Loss:2.381932137604803 at epoch: 0
# ckaove the kooret? Wene hs kans’s and,Sw re prave ge.
# Holl Iaw I gh, ing aud the where. rlie uens. Wat. Thadt snes. Wie hess gooush the pica therlt p hvel ponatont Ir. Hde. Wavet oug. An’sl hand ove t
# Running Avg Loss:2.4074153564982117 at epoch: 0
#  the ant Isorleish ind hat’’nt lo an’t an too –e ko faut erl therl tind it in’ ank tomrey pe trens I warice she baplon. Ofitleileite lit toc. ghe p ack. Ird I dolnd.
# Bn’t cobnb"S I myore.
# Hle y had an
# Running Avg Loss:2.4907961035594344 at epoch: 0
#  Cnetou wo gi’t. Yo tomes col to I Cum on, thase have. I weme gin meme surm. Buagrisd he dYricwe  he gur gur bit mump leisg trite, rall wink "OCse hishir ama we’sh cof ligaw mrope. Yuve ma’m hre lalbe
# Running Avg Loss:2.591471034735441 at epoch: 0
# s veot’te le thomlll eot hanses, tiring in’c.
# Sou dast’t the bulll yha tun’s gope mgoind’tiserest in hor got .
# Anvd he dor gol alllbut’rud. I hat fou st’lstt trod’s oryihans whoon’s de pork meotslt do
# Running Avg Loss:2.530090287942439 at epoch: 0
# e econobocd. Owe cecole whay’nt an’tintifk tory drt.t, torust dfry – thmy the dtome hakexnot mo.ou? ems the ere. –, Btams te Int iteold an tot. Thaker "eve Daved dves’n wend.
# f mereco o gros – kem nem
# Running Avg Loss:2.611318221274763 at epoch: 0
# ufut dir at krowe. I veikerurenr ind hise. I fple Cedame oblis woes. I ta,’r scaol ere I env,’re fut fuw ter athe. ranmabllw mor you havis nol itet me sor copme her I kndilll fopneme woet shos weltisd
# Running Avg Loss:2.5573093754146248 at epoch: 0
# o ceeliri – beo ko theyhe atd,  ove ash werle weachev I . epe the bederr fre wally they’ne? ney im mem, ite, ave tu ne mo i bed ine her mint dut ti’s all I kellnevereatht "Weng fapllyt? Thei linbly’in
# Running Avg Loss:2.5605595899894835 at epoch: 0
# run bandt fose ndy geld.
# Theis dole deer as woill of dof lean eth coree. Thel tor do nomeg ser. thet tham, he tiels wonyceare goy reoln.
# I bat Wey had, wirte. I thad  fo wan’t wo wand, –
# I un i, lit i
# Running Avg Loss:2.391755047759041 at epoch: 0
# en wey whe we rou – I Sou touy whiy, Iing ht, thad fnouluvem sI I key bodl od I ylinxacthy’t rit diik. Yomp coug. popere dowiny I yritonglliis weak cebababe the wely I doud faik. Shallb beot tlon bid.
# Running Avg Loss:2.7094823713861405 at epoch: 0
# e ciris, ik bmin akd yed ag ba I nthaths mamhete mamolens kperb an ond ngobidgh, I them, miiglys I hape sic go rald ark goingbade and antist yo ke mat if chincang memllend fe tavaietr yyot indat it ki
# Running Avg Loss:2.531963282637298 at epoch: 0
# h thhand mbaeve bads m,and, toiol indiny. she balonst. Anonow butded and –’ kadagy yits hat sour – an mnot iny.
# Ay deveulad lakp anat buns fembef cuny sroul ande ey you ava fine nat sred. Tony foabe h
# Running Avg Loss:2.6845592415854336 at epoch: 0
# lusi for younthes wiwed.
# 0I I I I I yrout i ir ove "Solr ast we Itanxy Thobenag,
# Af ant.
# Anion not ce ary we theng. I beor er s bhatk sasrif toust Ave sidk Tha eve ann ino a bin. pheth mlor so Bwiout
# Running Avg Loss:2.6238055434003473 at epoch: 0
# I arut woud kigareg ibeclaadd yo le iWe – tho I dopie din. Then want y riktheryar wovsey well as at mon racbend wo Pey word ere – gone.
# Nou halleche mealaearlr the ittilininm. Some to I honat. Som, wa
# Running Avg Loss:2.2874551221895962 at epoch: 0
# sthyaITert gaonth’t yoWt. Thes mear tou habed doce on. yuyle. Theyh,
# I hilves.
# Ra dol bos, aner andkindedois nead dol. Is dobecmmeng I’ orl dou iad non leite eet.ina don ithigln dobyige thigg sazat,bo
# Running Avg Loss:2.527180868048221 at epoch: 0
# vis azes ele gonse Iove Cat ouse ader thet meruf fous anc on i a dof ecant isis. I lyotienet Iler yerinnt ant bsare ony sramt. Iut goil lou you be ay you do fathey’lss won aat, nove of.
# You beevert  o
# Running Avg Loss:2.789239644341171 at epoch: 0
#  hcofe toud on eave tak fut cit. Thaye Iou peup pre buat rev us bit lrot I bount lit mowe eumle.f cank ad, eve thit pilt, nolset’ daau Ioke,.
# Tham ile ing to, pot acta at pepprare  ore’sh lol ouot man
# Running Avg Loss:2.6158321513868867 at epoch: 0
# us atokine. Thied yaed so ren arletrisi tory sLel myouk I, sotiallt wim nery in thou arecamk,’adithe The eeve she thoopant. I’f ay I an y ee lay anat. Sosm ti the cory mins. Asd kne hhty, I pa agtt."
# Running Avg Loss:2.5892658604718743 at epoch: 0
# ’tsobuv. I thor der kren ral Cave.
# t’s oull eokcary yo thay unt. And oal,e loouses they hap  thr they toure ue rife a ingry ter gogaiss. rhe coly ang ut dtanc tichaid wat ove ead ratrte.’t oum the the
# Running Avg Loss:2.404097792144865 at epoch: 0
#  ling aldche knryor migem, chame caly sa oans yor cind yeve do wans thily hed ro,. Actel. per any car ingtilw goikdry whe and ant didd arc, mow’. Theet thel dawtehsad vovee lo they pa dopeg mo care ge
# Running Avg Loss:2.4084025420043615 at epoch: 0
# t? saitsik anlt we hakil thoon the – on p piso ben teore ve go toile s on acha ofay nond tianery the haro wely ibe man bav teerthey, uBug. Wid istt. Wev fmow.
# Heil wifs at puyey wowe doute the und did
# Running Avg Loss:2.363651014139876 at epoch: 0
# d ay rarian wave card verear
#  gow, they Io’rat  wed etilt and eny we whow do thoul I lwaan o tell at’rdiweme gat’t ind tha ghe, wone kofu prit. Bri.
# Sof eat theceat ansis. dissise.
# Ackloutery at" Theo
# Running Avg Loss:2.5677444093860684 at epoch: 0
# n wallllbowen waned fot.
# Bume, I’ wourid At, he king – timintou labangirims.
# Ar’lidrt the shameenpl cheriac y det wo meml ees ingis idin’ kpars ther at’w wiv. cemede ved ton.
# Ave feferodeng thams, oam
# Running Avg Loss:2.5187622006461026 at epoch: 0
#  be lphapl – Bu pyorsene noton’sh, ser and apat, whe domer bin.? Soure the wed nte avafting damt thof blos yoreg the’r wiy se de the the din a she noupale hot aid inthan.
# Brewt andous we rnatt’af Gatt
# Running Avg Loss:2.7222844981048255 at epoch: 0
# redy I’ srith hastis, sfhat leafith hen spoon o respe bom the heourst.
# So thamneged thhey hedam.’sh ger her – peres it’ur dising shising dh hatr ind one’chlit the nrett, res wact g’pe widis eyh popble
# Running Avg Loss:2.493558017915115 at epoch: 0
# ve thateeun coy.
# Ag. Avet ay’piant orpas a afl le vefplutick.s toicp sopesnbot avo so I hemprees poparaldobe so cennythn sveme theverp thenly wactesou hhe’s A net .fed. Bus thedppen’s acemn, toprshe c
# Running Avg Loss:2.5700109662935136 at epoch: 0
# wisbettrt. any avetg at and ’n’t I as’tide e intels als aft’se noton mure pe’ll andow Thewr henestri.O mar ruy the ofievel gerpdose tod. lave alyit winsant yut – hgeral lerat swe lyite gont wunt canat
# Running Avg Loss:2.430548998851329 at epoch: 0
# opler tom lawut to the wered wh did touw id indhas h. Nowect bent. Bnu toul ut thor in the B wnoatre bll olm, raen, thay on sigont.
#
# "s hith coing thou fo ben."lAl and aplebr a pindbhes gommentey’turn
# Running Avg Loss:2.4159185150265694 at epoch: 0
# ’t Oalkey y. nmi. ave beng wey tholl bivatSy truaf Onimtrt of He lopupperg liggite vet bacamuvoou thar but of de atouc ferit ney’w ere efcansetr weedin bisaut and’m ant wopusi. "Bou .
# I te oi of by. S
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-9bee0a2f1387> in <module>()
#      10             optimizer.zero_grad()
#      11             loss.backward(retain_graph=True)
# ---> 12             optimizer.step()
#      13             if len(losses)%1000==0:
#      14                 print(f'Running Avg Loss:{np.mean(losses[-1000:])} at epoch: {epoch}')
#
# C:\Program Files (x86)\Python\Anaconda\envs\py36\lib\site-packages\torch\optim\adam.py in step(self, closure)
#     104                 step_size = group['lr'] * math.sqrt(bias_correction2) / bias_correction1
#     105
# --> 106                 p.data.addcdiv_(-step_size, exp_avg, denom)
#     107
#     108         return loss
#
# KeyboardInterrupt:

# %%
plt.hist(h_prev.detach().numpy())
# Out:
# (array([59.,  2.,  1.,  0.,  0.,  0.,  0.,  1.,  1., 64.]),
#  array([-1. , -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  <a list of 10 Patch objects>)

# %%
X_seed = X_batch[ch_id]

# %%
print(sample_chars(X_seed, rnn.init_h(), 10000))
# Out:
#  deand I dron. Thinte all now, weill peoth tile nhelnd de afy grree gop lome fale the ghe to fen’ see thaende fuv.
# trewerpe eorl do Iof fe lerss.
# Shey’meashas ushp vory redy thr in.
# I gops ot ge I Ie thes gone gim wevh ge in dig sadte hing venday melshat wad jbe gasile the osre dedibig ens ind than si kanth and a ledt rec ca to lon hing ind I’d tily eveathe le ceoi ge nopal ope peeng.
# Anie dedsof whes dei keled Ishane,’reess demen that the someshcppin thae toult.
# Anet he ge gocpopled I gop.
# I oull ber beond wipe yomt’tresve, tupre toule he’r died I’’s o at old It thany Sgos haver thrySe the inag bidte I sa – I’veae gor.
# I’red reter fing lalt noige thantintian emo wol an It sus wha evy chat he nhad igry necp k.
# "ind geantr at doaut maledl whanr ofeo lid lectpeeshe she I at snd precand oud boly ibed h teln youd I dow.
# I they calerton pom aple.
# in. I I wo touse soo kike bey the looma ruys gad.
# Bore goded tomnn dou kan gyhe .
# Yowe’s dot tit’s Ir cobend picre gous. drend herl giak onot shousitentid inewe Anes aid sell –ad. Ance – has’ve wey at’s dutin wind miave imes lleide inekid cauting dedisite gelle to tit Oele were.. Sat wece, pAt feny reaptta fhape thees thac be lile. I wend ovh to tout acgoug mpaly at dn whas I thesd’ts in. Thas hif didnd anere dit woum atd anle.
# Thiut peeninss.
# I thas.
#  I’ledop gout an’s, cout wis houlled hat tere it weloullere sert bey have gere.
# eet vind.
# I ke dop he thatede I inegl cou waem peowe fay to leve.
# So wiang sac sbecmnd Ie theve.y lmateemd dhant thech bed snintop bid kelcosesstrs is bal triagihe the be kapeon weel. mey fhed hey’reere simibe shhey’s won wo val diff frenl toum it yo hevitiat angind.
# SomN – It at hrech tit.
# And ary." nhe wa bad keve se.
# I
# Ave sopd. nd Wave uple ve run at tinigale thay’med’weont havte rautbant i cow an ant.
# Ad bentrey thesend ang wi rey’s wouone.
# I lend her Is ruckeon I cand a dodic.
# eve mem thi’g ang tos now cente ous penct an.
# At ticanad und the sa biad an vat tiy up. Is hrend hawy A topre shave
#  I woled men’ all se.
# Be’or peno thott fopse haved teverept as hipid poc beogind vho want seedtt.
# Al Ing ane bidteny te, wellcet.
# I
# Thiat ar kave and ive se aintangasg rponnmsI ha. To tun game I’ve I’v?ilast omey hone meal hid dobe ise nes cofoa whe siglery s, touybevagtecalt madsr.
# Bung ild oud o ant?k ring yo’t sape so I’m hide the shele we het tit Sant ins af beonc’s dec, veakingem in o frulep ruedeesoncs me noop covo be a..
# Au beant Ialed s’ple wide golk re ren apll ter’w is arlope lednd geve go I’t hing yopk. I whe licot pebest due belA the mead ang swo ubeng erith – I abat row
# Ann te peom cow vendn, hes tome fianinne ond hala hhhe sir, Avat gaybok os sthe that’veders yoter thang mutk.
# Sopare ong teotiss sinn shel meoweeve so dils so dele ract hey.
# Buy an keath ta ase re al in tiny who me. I womeat erusky I I werenbe so want in herl rung.
# Ang they git hamliss oud I’ve the sover thettd I’’s nhupe leng ucdig eno doulng rua toave thiou any vo.
#
#  ay I vraid instet pilleaiglunbiny se peoid we lender. ne cok nobeotess be bew I sHuy Iny shere theytre pere ynou dowat wer keach "eu.
# I thes I’d a ofw we theare tit’s havat Touts to wa I’ve pare weve, minsa feeyn hes that wamand.
# Id sant thal we bofk I’d o de nec ayeelgound tBund bad deo, thay I’ming yo dnond.
# Buttine eved has int he goct winthe I we ancg cowe’pe reat thgouv, hrmedeat thave ave we we lemn’ich tout aver that wet tamest "ad ho I wofyry thate pevadin I’s bede. I’vefid dwowa taunt thet trly hielond hinte supesour shat kaonuvere the ugolg bel’l d pald. I’ an of ipre boung wemre gop. I ther’ thee hapid toofrssey belthelit sine of ange nutil rue whag t’peung you geere thot cind thdagidid demckbey tol pnoustothe p and
# roparung.
# Sand be anb sunan they I’m racc, those sere sowede no nowe. I an ca, oude eesd oudecared.
#
#
# ra ung rent wa fuve sond s rerigth.
# on nit wan wicet. Ios suwd tunit gevat sadt ane thal waot, det thect wape tiileobNs, mon damy the tish.
# I I ave ro.
# y
# Ang ave con nhat sere pet. S’l hts tiey yo tidon. Ane pheith re you noutttyn terl ge’s Gate Ioud – I’sered.
# ee dod bell so pa wundy mand s ot nhas.
# Ar hak cia le on. I’re keet she eor geck os’th get drobu, thamoly seo sean the wesnecals ow
# I thim dar pauley. Iow soplalkef be shey frow that’s pa tu teoy har wha euvar, seprott’se todt hruch so sing drodd Be wowe thes, sarl ta deve ’ulley tia, sead yo Is mfo kewe thid thetopleut son Ierat youdegh that aapn – I mol we I ged weool pouns.
# Ave tou so ta whet woung, eoid ow. I’tin."" ap.
# Bude.
# The’wensit aket dewithered pall bopend se eode.
# Al ter knot cocont heg thavel lend hat’rrey sell alk yrauy.
# Buyt Feend ung – I ma yo pin degrd havere gons sulle he –r oud ank have tha empseed the gopln y
# Ba und did breontpid ang farides astioas wemllit.
# No veous.
# ane  hed kand heps. I the yoces? Ie un do I
# .
# ale this jwy’f he lean teme. We the sha wo beI maece suond anyton muteng dou’s doe haveds srok.
# I thered fmeas thonge. I sans pel bes peemest she to sny gooplleralcaot in. BTas tidinse touce sicout net this didl faoul sa fore at ind I’erd Theme lrous’t’t geche swo sin o pet dod’f madybe go toumy and Ie. Wting. The yoplde Thotm noole Sidnt mphop be ikeandis There peothe win thave y
# A mageng the’dy anaged has weve rerp, ho paangt? I’ver inntr I feray a d hausso goag santher sno tor domens a’ve mens the youd yrut
# n. I depeets dat sal dat han cama I sond de thiled hat the rakoustreaoud o wedn af wat’s tar I he so Owheing.
# I enfens renabeapprhat.
# seThe glit as? Tune they nhe dent chat thang – Bac hopit seseatd I’ c, deeade ily we’ploely theat rendey toing, the ko oud.
# Th, nich, wovand haf hrrang. The hin’ wes Pend sevet  trin poo I’t geidl I.
# Ave wat be dad hit’s phickn co me bit cend nas buellidite Ir  in has.
# Bouveoud cant is n uns taliald I vele shat Danbo I wButhamape rene hereck nild yo, I’ve eve it.
# I’r welg the dere – ca we ce pom. I ave amel weenlpe fac tho have rum wan sheg timams, douctr pat the
# yoa fac co ka causiav eong ged I’r cno?ondevacisgr, det – We te.
# und Trot ise, I spat.ndme bika tind therd me lhavee.
# Bore dto whoud.
# H tou go bit tidpeseiske dit ast beera.
# I teral I ennd so wo –’ras. lesher gedy tely se, don Seve and aned thanouma thetce.
# eo if peounk Ih pore I’ve ldott is popleth. I’t avecito y wechears eadlich to ho uckager ugh sis os rhe anouy in’t I’r dens anc, sas
# nort dycas’te goy I at that ibed thoe wur, have cand har tisiniosey lopre ckney thes’breg anecn cnn an dessrnd theo roll beeghr soalshere cue’nt p ang.
# BWecel knrot fo sasticant riwk Ousent,
# Amt thinet In,’srde fre whes kige nhitt nite he ther I dece, herletsas Man fit sing irok.
# "Souse of casa tialing dinten n beth ,er I duauc wthistied Isos al iin ort raalkna dape chic hot’t piglert I’tode tho tos ane tellle of ipoung jut ave. In hape asthe, I’d’I de ineg al wovegna afas, wo his her hetre dect the leoult teod yo win toto anavait they te oneg ind tome whiel so I’d.
# "So shat bed I’ pacd an wey aled key’s’t tom recigemwe.
# Shiing of nont bevedbou plithe had.
# That.
# I I rbus yut wan keng cotan, I heer she nond. ISe thiiads ruve wige ay hap he co hauy eopplaoul ter oulke thecs seedbent have an.
# Anis be, binn ang bheerpolet wed, I’t che.w
# mey ing teed tho hel sempel . Blaved sico fom gere.
# re ledy I youveont hat cef ned’hil didtdell rell dew Iey Sad that sipe gouy anot ded, know I kluat thed ane mundth.
# A gout kant a poy sot heik yNoy me.
# As paot aeve – de evet be youd Iny oust. I theos ond demakndthica, men gemn, vanth s1eorsnis pine ay he  ow a0 i knant denlk Sadt ine anding wBnotered – Al en. I thit an,e thral, obows I thith rut’s shenbt aond keoud. Iowe mpwhe tolthay an mede’s mentel nhat save. S. gout he eopere.
# I cousre.
# cond I have reve tmriclrcunt. I sot the reld I’ oist waly bopleg pik an tuvopon the weadme.sBeve dove "Sra tou. Id than, – Helt we gap, sam rult I wo beig in now an I.
# Ant. Tun dout. me, an ut bary thot waplean’l lots shes I’sougereade the they’reg didnst ored mive theam lilk ted. He heit. Thrin. geng.
# Wer bi dous eve ham to al  of eing teaw the no weath founn ols. Bdout aveget disso tryo gaderism.
# Abeent dupeansy wan that – deer peclls o dede ce ofey thasst wrel, am ca po onng.
# I rie wesing gedouth’ s, bi wind.
# eme thhas mron’w hee,’ulrars. I’s poniathtcapme.
# A wiem. Ave –o dounke geed maved I’ver kealieg caant "at aoulg. gelligst thatM ma the ou kres nuch, Ave ret ate se pours hat wicane ahte utprrot’, be chel  in’t I hat Wer son’n his bealge ave ound. I
#  Toui – me It ru’d I lensabe ho is nntth dee noth mo reke yond has wI see yo klouyt I’r’td s dow h pid gody whappy Inv  nobuc,. With mod.
# I enon bout?rop. s.
# Alet.
# SWe an.
# Abiout yNow woi lecka gat they o bed I cnat thou’ thoond s aiontht’mre tout, I’ frel paalmt toobettppand Jnos so ta wond "ourhe yor Ses ane she roume to het raved d’s yriga.
# I she kecte te dos bnoully Nin a kyoter thing abe buoknd I keoe soelchiy’ I we kfoll dnge lech knnt aatull tote che sore ve eunt tha.
# At taout do shat thang endt ans mill c ca ine, they at’s ley und rid kerec ouse ad het’ne Inatrey’t af poplle? I dito atute in prot so deded’s sarlise, wi Pa coy Thimedo gen atioleth knst sind ylet and eatp ol ko gos hi rend lecs co toe.
# thas’t keot go ang I hat.
# I I woveie kat sed geing onet thayse sa lecn.
# OOpeouts talontt red Funat docall vere.
# o gishye sis on thac dave. se lis sorrit ind I Ich he kare you I ald hesy I’ theast fule.
# "Sremet soud be donsit and maple.
# I ruow ant’s I am, ’avet. nhice ice at aad a nelld dictey an to faabemping des.
# I Iorsy what wevet geos poppsh sek’ve – whe lcaitheong it the thi
# int we hive ruy’t inedi. duy. I avell inegst wedrer the they and wave the wiss wedrotr athandrathandad
# mandte.
# re dicans aguy snhade wo mimndy An. I ag.
# nond te lo Miot weadtang thcthey’sf I ghat.
# I
# I’shy ata eitin. I’ve soll  ound. Adl baw hor soid drom os, –
# BToume olle simdiout be’st.
# .
# Shey nad beare.O’sst be I wing dingopt dikn, I heded han. I we.
# ant. Soup thas heverid.
# AHed.
# I’rbeve to keow mond I doat, ne aty int now to f tinid yo shaplabseicere thaaknps cowe Som

# %%
for p in rnn.parameters():
    print(p.grad.mean())
# Out:
# tensor(1.00000e-05 *
#        -4.3225)
# tensor(1.00000e-03 *
#        -4.0199)
# tensor(1.00000e-04 *
#        7.4434)
# tensor(1.00000e-03 *
#        -4.0199)
# tensor(1.00000e-11 *
#        1.1821)
# tensor(1.00000e-10 *
#        1.4043)

# %%
Wxh.shape
# Out:
# (100, 53)

# %%
Whh.shape
# Out:
# (100, 100)

# %%
Why.shape
# Out:
# (53, 100)

# %%
bh.shape
# Out:
# (100, 1)

# %%
# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

# %%
def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %%
def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0

# %%
inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

# %%
hprev.shape
# Out:
# (100, 1)

# %%
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0

# %%
t = 0

# %%
xs[t] = np.zeros((vocab_size,1))

# %%
xs[t][inputs[t]] = 1

# %%
np.dot(Wxh, xs[t]).shape
# Out:
# (100, 1)

# %%
hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh)

# %%
import matplotlib.pyplot as plt
% matplotlib inline

# %%
ys[t] = np.dot(Why, hs[t]) + by

# %%
ys[t].shape
# Out:
# (53, 1)

# %%
ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t]))

# %%
-np.log(1.0/3000)*50
# Out:
# 400.3183783825123

# %%
hprev = hs[t-1]

# %%
''.join(ix_to_char[ix] for ix in sample(hprev, 1, 200))
# Out:
# 'ikama enaliia Janden Celen Badkia Darine Jumah Jagkida Asmyanat Caima Ediouy Inriserya Janieghebe Jame Giyne Jozabkatgh Alance Jomvi Jorielya Eyah Aillana Kateliuh Babye Makjan Calisse Tynnibele Jaigz'

# %%
seed_ix = 1

# %%
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []

# %%
x.shape
# Out:
# (53, 1)

# %%
h = hprev

# %%
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)

# %%
ix
# Out:
# 7

# %%
x.shape
# Out:
# (53, 1)

# %%
Wxh.shape
# Out:
# (100, 53)

# %%
np.dot(Wxh, x).shape
# Out:
# (100, 1)

# %%
Wxh.shape
# Out:
# (100, 53)

# %%
np.log(vocab_size)*25
# Out:
# 99.25729783880305

# %%
seq_length
# Out:
# 25

# %%
hprev = np.zeros((hidden_size,1))

# %%
hprev.shape
# Out:
# (100, 1)

# %%
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

# %%
data[p:p+seq_length]
# Out:
# 'Emma Olivia Sophia Isabel'

# %%
data[p+1:p+seq_length+1]
# Out:
# 'mma Olivia Sophia Isabell'

# %%
inputs[0]
# Out:
# 44

# %%
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print('----\n %s \n----' % (txt, ))
# Out:
# ----
#  PfKTwPfmTLjbeVZCLEYRbGltieocPNNtsnTWVZNjehJnZLQRvvrMFQNpxCxHQncWpvjBYZYqasQfIdjPqtrPTEYDcCOxngJamYZCVpjyxVEIQRCbvbqpYtPM ZNVXcNiIDRixwFDVnkWUscUzu juwCkYuBqHeUVcyiWELKcoIr nr TKNCDpxLGyyKENSvJnmvweRQQ
# ----

# %%
loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)

# %%
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0

# %%
t=0

# %%
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)

# %%
hs[-1].shape
# Out:
# (100, 1)

# %%
ps[t][targets[t]][0]
# Out:
# 0.0398582039920804

# %%
ps[t]
# Out:
# array([[1.22462687e-02],
#        [3.70884873e-04],
#        [1.47718282e-01],
#        [4.91778089e-04],
#        [1.43579039e-02],
#        [1.94613594e-03],
#        [3.98582040e-02],
#        [1.83239784e-03],
#        [1.40377295e-03],
#        [2.25524356e-03],
#        [1.86338027e-02],
#        [1.82163330e-03],
#        [1.36034842e-03],
#        [5.34832575e-03],
#        [5.31882994e-03],
#        [2.56723943e-02],
#        [2.08954666e-01],
#        [1.67814105e-04],
#        [5.43953948e-02],
#        [1.23416029e-02],
#        [2.71522941e-02],
#        [7.07506732e-04],
#        [3.90479874e-03],
#        [3.07619937e-03],
#        [6.03594339e-04],
#        [2.60599790e-02],
#        [3.70108202e-05],
#        [2.20467155e-03],
#        [8.62683131e-03],
#        [6.98119822e-04],
#        [5.34681858e-03],
#        [2.66708994e-03],
#        [1.11460252e-02],
#        [1.62131224e-03],
#        [4.59798728e-03],
#        [2.41688939e-03],
#        [7.15391514e-04],
#        [1.00846412e-03],
#        [7.64864017e-04],
#        [1.19025338e-02],
#        [4.88808782e-02],
#        [6.65579358e-02],
#        [1.07478080e-03],
#        [6.73335329e-04],
#        [2.65998096e-03],
#        [3.20836611e-02],
#        [2.08930948e-02],
#        [3.64345458e-04],
#        [1.19719124e-01],
#        [6.08244844e-04],
#        [5.51525083e-04],
#        [4.71561737e-03],
#        [2.94634093e-02]])

# %%
ps[t].argmax()
# Out:
# 16

# %%
Wxh[:,10]
# Out:
# array([-0.11848706, -0.05649749,  0.02691294,  0.19014995,  0.07061441,
#        -1.16252144,  0.12697324, -0.08889963, -0.06267175, -0.40105323,
#        -0.18747102, -0.18140617,  0.07432117,  0.34334437,  0.06726984,
#         0.20165935,  0.32747234,  0.04495337,  0.1142929 , -0.05521551,
#         0.00885307,  0.33516984,  0.13067932, -0.10904185,  0.19814699,
#         0.0913149 , -0.06236525, -0.01253117,  0.41185781, -0.3912567 ,
#        -0.1494085 ,  0.36435163, -0.44824475, -0.09278199,  0.34402929,
#        -0.15928979, -0.26921809,  0.05811367, -0.13787257,  0.20121986,
#         0.01388096,  0.07998907,  0.05387593,  0.0689815 ,  0.26390591,
#         0.0065182 , -0.09641561,  0.20798219,  0.07988806,  0.20825779,
#        -0.26811509, -0.03696904, -0.16780612, -0.38446364,  0.28463213,
#         0.14157797, -0.19357392, -0.16630077,  0.11378831,  0.25725707,
#         0.17818427,  0.008875  , -0.06520907,  0.12799508,  0.22632408,
#        -0.17792747,  0.19119546, -0.04671774, -0.45145593,  0.05777601,
#        -0.09830163, -0.31653179,  0.15220932,  0.20794963, -0.03008459,
#        -0.26965372,  0.1204601 ,  0.34252047,  0.09401755,  0.52394405,
#        -1.28136092, -2.30766055,  0.0621971 ,  0.65735221, -0.06726325,
#        -0.10967955,  0.37269327, -0.12546259,  0.03567711, -0.12430217,
#        -0.11907313, -0.0464631 ,  0.29016598,  0.23329175,  0.22403798,
#         0.04957504, -0.03167637, -0.15892867, -0.21109618, -0.03625879])

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print('----\n %s \n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0:
        print('iter %d, loss: %f' % (n, smooth_loss)) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter

# %%
df = pd
